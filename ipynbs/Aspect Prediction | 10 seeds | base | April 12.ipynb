# %%
import torch
import random
import pandas as pd
import pickle as pkl
from tqdm import tqdm
from os import listdir
from os.path import join
from random import shuffle
from transformers import AdamW
from matplotlib import pyplot as plt
from torch.nn import CrossEntropyLoss
from transformers import get_scheduler
from pdb import set_trace as breakpoint
from nltk.stem.snowball import SnowballStemmer
from torch.utils.data import Dataset, DataLoader
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
# %matplotlib inline

# %%
# folders = ['bags_and_cases', 'bluetooth', 'boots', 'keyboards', 'tv', 'vacuums']

# base_dir = '/mnt/nfs/work1/hongyu/brawat/amzn/oposum/data/seeds'

# list_aspects = []
# Aspect_to_seeds = {}
# stemmer = SnowballStemmer(language='english')
# for each_folder in folders:
#     folder_dir = join(base_dir, each_folder)
#     print('--'*20)
#     print(each_folder)
#     print('--'*20)
#     txt_files = listdir(folder_dir)
#     txt_files = [x for x in txt_files if 'None' not in x]
#     print(txt_files)
#     for each_txt in txt_files:
#         txt_dir = join(folder_dir, each_txt)
#         txt = open(txt_dir).read()
#         txt = txt.split('\n')
#         txt = [x.split(' ')[-1] for x in txt]
#         txt = [x.strip() for x in txt]
#         txt = [stemmer.stem(x) for x in txt]
#         aspect = each_txt.split('.')[1]
#         Aspect_to_seeds[aspect] = txt

# %%
# for each_aspect in Aspect_to_seeds:
#     print(each_aspect, Aspect_to_seeds[each_aspect].__len__())

# %%
# pkl.dump(Aspect_to_seeds, open('Aspect_to_seeds_march19.pkl', 'wb'))

# %%
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))

# %%
for each_aspect in Aspect_to_seeds:
    Aspect_to_seeds[each_aspect] = [x for x in Aspect_to_seeds[each_aspect] if x.__len__()>0]

# %%
Aspect_to_seeds
# Out:
# {'Compartments': ['pocket',
#   'cabl',
#   'compart',
#   'outsid',
#   'lot',
#   'wish',
#   'wallet',
#   'connector',
#   'space',
#   'power',
#   'pen',
#   'folder',
#   'charger',
#   'flap',
#   'mous',
#   'nice',
#   'thing',
#   'insid',
#   'small',
#   'paperwork',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'construct',
#   'medium',
#   'player',
#   'wire',
#   'run',
#   'headphon',
#   'key',
#   'instead',
#   'huge',
#   'need',
#   'open',
#   'fit',
#   'headset',
#   'outer',
#   'planner',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'cellphon',
#   'save',
#   'document'],
#  'Price': ['price',
#   'money',
#   'feaur',
#   'paid',
#   'spin',
#   'spun',
#   'mayb',
#   'cheap',
#   '200',
#   'spend',
#   'right',
#   'vaccum',
#   'twice',
#   'expect',
#   'pricey',
#   '50',
#   'expens',
#   'worth',
#   'far',
#   'wast',
#   'duster',
#   'think',
#   'bagless',
#   'best',
#   'dyson',
#   'need',
#   'ok',
#   'weight',
#   'bag',
#   'power',
#   'light',
#   'like',
#   'good',
#   'vacuum'],
#  'Handles': ['strap',
#   'handl',
#   'shoulder',
#   'broke',
#   'later',
#   'month',
#   'hand',
#   'comfort',
#   'plastic',
#   'wear',
#   'tear',
#   'rip',
#   'start',
#   'attach',
#   'holiday',
#   'left',
#   'lift',
#   'final',
#   'broken',
#   'stand',
#   'inevit',
#   'situat',
#   'firm',
#   'bend',
#   'hurt',
#   'minut',
#   'addit',
#   'note',
#   'buckl',
#   'adjust',
#   'adjust',
#   'short',
#   'shorter',
#   'length',
#   'adjust',
#   'long',
#   'metal',
#   'swivel',
#   'sooner',
#   'break',
#   'felt',
#   'rip',
#   'loop',
#   'hook',
#   'torn',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'use'],
#  'Customer_service': ['paid',
#   'support',
#   'servic',
#   'week',
#   'replac',
#   'mail',
#   'wait',
#   'pay',
#   'ship',
#   '1500',
#   'bring',
#   'deliveri',
#   'come',
#   'use',
#   'peopl',
#   'speak',
#   'technician',
#   'refurbish',
#   'handl',
#   'shore',
#   'communic',
#   'difficult',
#   '49',
#   'diagnost',
#   'fee',
#   '100',
#   'fix',
#   'latest',
#   'divx',
#   'arriv',
#   'undamag',
#   'po',
#   'mention',
#   'desk',
#   'help',
#   'suppos',
#   'later',
#   'cancel',
#   'reschedul',
#   'entir',
#   'glove',
#   'pilot',
#   'deliv',
#   'fact',
#   'clear',
#   'requir',
#   '100lb',
#   'carri',
#   'downstair',
#   'check'],
#  'Looks': ['look',
#   'slim',
#   'origin',
#   'appear',
#   'lttle',
#   'attract',
#   'beauti',
#   'size',
#   'small',
#   'decent',
#   'imac',
#   'backlit',
#   'longer',
#   'pc',
#   'like',
#   'laptop',
#   'nice',
#   'great',
#   'cheap',
#   'keyboard',
#   'good',
#   'feel'],
#  'Quality': ['qualiti',
#   'materi',
#   'handl',
#   'poor',
#   'broke',
#   'durabl',
#   'month',
#   'later',
#   'wear',
#   'tear',
#   'zipper',
#   'chemic',
#   'start',
#   'excel',
#   'terribl',
#   'crack',
#   'strap',
#   'daili',
#   'plastic',
#   'pull',
#   'smell',
#   'edg',
#   'rip',
#   'white',
#   'item',
#   'year',
#   'go',
#   'feel',
#   'attach',
#   'brake',
#   'holiday',
#   'outstand',
#   'strip',
#   'peel',
#   'left',
#   'final',
#   'broken',
#   'stand',
#   'sacrific',
#   'durabl',
#   'style',
#   'cours',
#   'trip',
#   'asia',
#   'rip',
#   'construct',
#   'cancer',
#   'birth',
#   'defect',
#   'reproduct'],
#  'Protection': ['protect',
#   'pad',
#   'protect',
#   'protect',
#   'drop',
#   'lap',
#   'insid',
#   'comput',
#   'laptop',
#   'good',
#   'let',
#   'secur',
#   'damag',
#   'intern',
#   'weak',
#   'tast',
#   'trust',
#   'protect',
#   'construct',
#   'provid',
#   'second',
#   'protect',
#   'count',
#   'sort',
#   'happen',
#   'cushion',
#   'adequ',
#   'thing',
#   'pencil',
#   'heavi',
#   'normal',
#   'kensington',
#   'probabl',
#   'larg',
#   'like',
#   'way',
#   'stylish',
#   'far',
#   'sleev',
#   'pad',
#   'feel',
#   'realli',
#   'perfect',
#   'bit',
#   'littl',
#   'bag',
#   'macbook',
#   'love',
#   'use'],
#  'Size_Fit': ['fit',
#   'size',
#   'macbook',
#   'big',
#   'space',
#   'air',
#   'slight',
#   'lot',
#   'bulk',
#   'perfect',
#   'inch',
#   'laptop',
#   'perfect',
#   '13',
#   'cabl',
#   'folder',
#   'notebook',
#   'sure',
#   'snug',
#   'bit',
#   'te',
#   'seat',
#   'airplan',
#   'fre',
#   'cell',
#   'pouch',
#   'tight',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'enorm',
#   '17inch',
#   'bare',
#   'm1710',
#   'hp',
#   'pavilion',
#   'dv7',
#   '3080us',
#   'disappoint',
#   'cloth',
#   'whatnot',
#   'spacious',
#   'book',
#   'load',
#   'accommod'],
#  'Ease_of_use': ['easi',
#   'cord',
#   'push',
#   'corner',
#   'vacuum',
#   'pile',
#   'maneuv',
#   'nozzl',
#   'awkward',
#   'crevic',
#   'constant',
#   'bog',
#   'imposs',
#   'short',
#   'carpet',
#   'heavi',
#   'roller',
#   'hose',
#   'difficult',
#   'wall',
#   'suck',
#   'remov',
#   'empti',
#   'power',
#   'hard',
#   'jump',
#   'simpic',
#   'automat',
#   'retractor',
#   'retract',
#   'flash',
#   'baseboard',
#   'retract',
#   'easier',
#   'snap',
#   'disassembl',
#   'direct',
#   'propel',
#   'person',
#   'race',
#   'furnitur',
#   'flexibl',
#   'kink',
#   'prefer',
#   'cannist',
#   'car',
#   'refriger',
#   'move',
#   'eas',
#   'worst'],
#  'Sound': ['sound',
#   'speaker',
#   'good',
#   'qualiti',
#   'loud',
#   'tinni',
#   'bass',
#   'hear',
#   'horribl',
#   'trebl',
#   'chang',
#   'realli',
#   'great',
#   'terribl',
#   'bar',
#   'display',
#   'thing',
#   'eye',
#   'ear',
#   'loudest',
#   'volum',
#   'strain',
#   'quieter',
#   'dinner',
#   'lack',
#   'sort',
#   'improv',
#   'surround',
#   'true',
#   'experi',
#   'junki',
#   'mind',
#   'vibrat',
#   'develop',
#   'pitch',
#   'whine',
#   'strong',
#   'track',
#   'cool',
#   'worthi',
#   'shippabl',
#   'adjust',
#   'weird',
#   'kinda',
#   'improv',
#   'cheapest',
#   'laptop',
#   'watt',
#   'muffl',
#   'margin'],
#  'Look': ['cute',
#   'look',
#   'look',
#   'great',
#   'fring',
#   'style',
#   'color',
#   'love',
#   'design',
#   'go',
#   'unattract',
#   'attract',
#   'offic',
#   'environ',
#   'pictur',
#   '360',
#   'degre',
#   'vent',
#   'concept',
#   'coverag',
#   'airi',
#   'hang',
#   'unattract',
#   'durabl',
#   'nice',
#   'casual',
#   'beauti',
#   'moccasin',
#   'shame',
#   'taup',
#   'direct',
#   'smooth',
#   'laid',
#   'rest',
#   'natur',
#   'calm',
#   'absolut',
#   'ador',
#   'pictur',
#   'grey',
#   'wonder',
#   'stylish',
#   'comfort',
#   'boot',
#   'good',
#   'collaps',
#   'super',
#   'crazi',
#   'light',
#   'weight'],
#  'Connectivity': ['hdmi',
#   'port',
#   'comput',
#   'input',
#   'compon',
#   'usb',
#   'internet',
#   'connect',
#   'output',
#   'server',
#   'connect',
#   'audio',
#   'play',
#   'stop',
#   'standard',
#   'avi',
#   'like',
#   'hd',
#   'file',
#   'movi',
#   'work',
#   'digit',
#   'monitor',
#   'comcast',
#   'connect',
#   'drive',
#   'end',
#   'cabl',
#   'watch',
#   'netflix',
#   'flash',
#   '45',
#   'min',
#   'rf',
#   'vga',
#   'cycl',
#   'signal',
#   'higher',
#   'slot',
#   'integr',
#   'wi',
#   'fi',
#   'stream',
#   'speed',
#   'conflict',
#   'dhcp',
#   'hard',
#   'dlna',
#   'enabl',
#   'power'],
#  'Battery': ['batteri',
#   'charg',
#   'life',
#   'charger',
#   'charg',
#   'tone',
#   'longer',
#   'low',
#   'hour',
#   'power',
#   'light',
#   'color',
#   'red',
#   'respond',
#   'merit',
#   'vari',
#   'recharg',
#   'bizarr',
#   'later',
#   'sudden',
#   'dead',
#   'meter',
#   'hold',
#   'thing',
#   'half',
#   'green',
#   'stop',
#   'nokia',
#   'turn',
#   'start',
#   'blackberri',
#   'star',
#   'phone',
#   'good',
#   'day',
#   'cell',
#   'come',
#   'talk',
#   'get',
#   'simpl',
#   'pretti',
#   'love',
#   'better',
#   'easili',
#   'volum',
#   'nois',
#   'time',
#   'work'],
#  'Durability': ['rubber',
#   'qualiti',
#   'use',
#   'buckl',
#   'appear',
#   'heel',
#   'long',
#   'time',
#   'break',
#   'enjoy',
#   'provid',
#   'protect',
#   'clear',
#   'cheapli',
#   'thinner',
#   'barn',
#   'month',
#   'start',
#   'tear',
#   'constant',
#   'fold',
#   'gone',
#   'numer',
#   'decor',
#   'come',
#   'sturdi',
#   'sure',
#   'durabl',
#   'decent',
#   'cheep',
#   'deflat',
#   'daili',
#   'wear',
#   'collaps',
#   'super',
#   'need',
#   'sol',
#   'red',
#   'obvious',
#   'differ',
#   'think',
#   'worn',
#   'abl',
#   'materi',
#   'actual',
#   'pretti',
#   'heavi',
#   'true',
#   'style',
#   'support'],
#  'Comfort': ['comfort',
#   'fit',
#   'foot',
#   'hurt',
#   'ankl',
#   'comfi',
#   'blister',
#   'comfort',
#   'break',
#   'wear',
#   'abl',
#   'extrem',
#   'walk',
#   'sock',
#   'longer',
#   'pain',
#   'perfect',
#   'super',
#   'uncomfort',
#   'light',
#   'weight',
#   'discomfort',
#   'snug',
#   'put',
#   'slide',
#   'sued',
#   'feel',
#   'littl',
#   'time',
#   'narrow',
#   'toe',
#   'minut',
#   'summer',
#   'insid',
#   'short',
#   'long',
#   'wear',
#   'perfect',
#   'list',
#   'doc',
#   'tongu',
#   'moment',
#   'break',
#   'enjoy',
#   'plus',
#   'actual',
#   'loos',
#   'attract',
#   'offic',
#   'environ'],
#  'Materials': ['leather',
#   'insid',
#   'fring',
#   'materi',
#   'heel',
#   'cheaper',
#   'soft',
#   'sole',
#   'buckl',
#   'sued',
#   'true',
#   'rubber',
#   'advertis',
#   'fact',
#   'cloth',
#   'back',
#   'synthet',
#   'finish',
#   'aerosol',
#   'line',
#   'aw',
#   'memori',
#   'foam',
#   'thinner',
#   'barn',
#   'decor',
#   'come',
#   'hang',
#   'unattract',
#   'fashion',
#   'porous',
#   'term',
#   'best',
#   'describ',
#   'let',
#   'penetr',
#   'piec',
#   'elast',
#   'zipper',
#   'friction',
#   'easili',
#   'improv',
#   'fleec',
#   'especi',
#   'superb',
#   'direct',
#   'smooth',
#   'natur',
#   'calm',
#   'hollow'],
#  'Color': ['color',
#   'love',
#   'style',
#   'unbeliev',
#   'gorgeous',
#   'blue',
#   'favorit',
#   'taup',
#   'wonder',
#   'red',
#   'exact',
#   'design',
#   'purchas',
#   'love',
#   'materi',
#   'look',
#   'perfect',
#   'look',
#   'boot'],
#  'Size': ['size',
#   'order',
#   'half',
#   'order',
#   'big',
#   'littl',
#   'bigger',
#   'usual',
#   'narrow',
#   'normal',
#   'width',
#   'true',
#   'run',
#   'small',
#   'size',
#   'larger',
#   'perfect',
#   'fit',
#   'sent',
#   'ankl',
#   'wide',
#   'tight',
#   'baggi',
#   'wise',
#   'tuck',
#   'pant',
#   'follow',
#   'advic',
#   'buyer',
#   'bacaus',
#   'possibl',
#   'joint',
#   'especi',
#   'superb',
#   'beauti',
#   'moccasin',
#   'shame',
#   'sould',
#   'larg',
#   'awar',
#   'length',
#   'tab',
#   'decid',
#   'normal',
#   'option',
#   'shorter',
#   'left',
#   'mayb',
#   'wear',
#   'calf'],
#  'Weather_resistance': ['dri',
#   'waterproof',
#   'rain',
#   'wet',
#   'water',
#   'foot',
#   'soak',
#   'snow',
#   'cold',
#   'puddl',
#   'warm',
#   'got',
#   'chicago',
#   'protect',
#   'suppos',
#   'defect',
#   'item',
#   'traction',
#   'raini',
#   'interest',
#   'ice',
#   'spent',
#   'cub',
#   'scout',
#   'den',
#   'alcatraz',
#   'island',
#   'san',
#   'francisco',
#   'lot',
#   'claim',
#   'stori',
#   'resist',
#   'generous',
#   'porous',
#   'term',
#   'dewi',
#   'grass',
#   'leav',
#   'soak',
#   'let',
#   'penetr',
#   'perform',
#   'repel',
#   'sandal',
#   'stay',
#   'amaz',
#   'outsid',
#   'step',
#   'deep'],
#  'Noise': ['quiet',
#   'noisi',
#   'loud',
#   'power',
#   'nois',
#   'louder',
#   'ear',
#   'loudest',
#   'light',
#   'incred',
#   'deafen',
#   'serious',
#   'actual',
#   'ring',
#   'doggi',
#   'hide',
#   'flee',
#   'powerstick',
#   'earplug',
#   'lose',
#   'bearabl',
#   'block',
#   'pro',
#   'fair',
#   'reason',
#   'direct',
#   'mous',
#   'explod',
#   'silent',
#   'compar',
#   'stylish',
#   'function',
#   'weight',
#   'peopl',
#   'ring',
#   'motor',
#   'awesom',
#   'nozzl',
#   'readi',
#   'sound',
#   'devil',
#   'purchas',
#   'quit',
#   'size',
#   'upright',
#   'star',
#   'heavi',
#   'lightweight',
#   'recommend',
#   'turn'],
#  'Extra_functionality': ['button',
#   'light',
#   'pencil',
#   'volum',
#   'power',
#   'featur',
#   'bright',
#   'mute',
#   'handi',
#   'low',
#   'dark',
#   'blue',
#   'wake',
#   'sleep',
#   'pen',
#   'nice',
#   'quit',
#   'shortcut',
#   'internet',
#   'spillproof',
#   'interest',
#   'vista',
#   'capabl',
#   'support',
#   'shut',
#   'keypress',
#   'pre',
#   'program',
#   'calcul',
#   'mycomput',
#   'custom',
#   'email',
#   'brower',
#   'activ',
#   'music',
#   'special',
#   'disk',
#   'eject',
#   'hold',
#   'remain',
#   'recess',
#   'clutch',
#   'multimedia',
#   'label',
#   'illumin',
#   'programm',
#   'legibl',
#   'dark',
#   'dim',
#   'backlight'],
#  'Layout': ['key',
#   'delet',
#   'backspac',
#   'size',
#   'layout',
#   'end',
#   'insert',
#   'home',
#   'bar',
#   'perfect',
#   'space',
#   'cluster',
#   'squish',
#   'space',
#   'close',
#   'small',
#   'volum',
#   'tini',
#   'place',
#   'arrow',
#   'littl',
#   'tricki',
#   'bigger',
#   'million',
#   'print',
#   'scroll',
#   'paus',
#   'quick',
#   'navig',
#   'difficult',
#   'suppos',
#   'spill',
#   'proof',
#   '104',
#   'negat',
#   'overs',
#   'awkward',
#   'place',
#   'vertic',
#   'horizont',
#   'multimedia',
#   'label',
#   'wider',
#   'impecc',
#   'activ',
#   'chang',
#   'requir',
#   'movement',
#   'wide',
#   'strike'],
#  'Feel_Comfort': ['feel',
#   'comfort',
#   'mushi',
#   'key',
#   'like',
#   'keyboard',
#   'good',
#   'perfect',
#   'press',
#   'wrist',
#   'action',
#   'shallow',
#   'smooth',
#   'finger',
#   'relax',
#   'type',
#   'level',
#   'keystrok',
#   'sit',
#   'type',
#   'quick',
#   'navig',
#   'difficult',
#   'shop',
#   'consist',
#   'respond',
#   'pressur',
#   'sens',
#   'deceler',
#   'quick',
#   'mush',
#   'tap',
#   'regist',
#   'usual',
#   'chicklet',
#   'membran',
#   'stick',
#   'satisfi',
#   'clicki',
#   'ibm',
#   'dissatisfi',
#   'natur',
#   'tension',
#   'impecc',
#   'stylish',
#   'recogn',
#   'signatur',
#   'butteri',
#   'velvet',
#   'feather'],
#  'Build_Quality': ['belt',
#   'broke',
#   'turn',
#   'work',
#   'burn',
#   'electr',
#   'built',
#   'stop',
#   'month',
#   'roller',
#   'time',
#   'minut',
#   'problem',
#   'brush',
#   'design',
#   'easili',
#   'wise',
#   'continu',
#   'break',
#   'fifth',
#   'barley',
#   'bump',
#   '20',
#   'last',
#   'connect',
#   'swivel',
#   'portion',
#   'fail',
#   'constuct',
#   'electron',
#   'construct',
#   'simpli',
#   'quit',
#   'burnt',
#   'miss',
#   'smell',
#   'overheat',
#   'shut',
#   'poor',
#   'attach',
#   'pop',
#   'unannounc',
#   'snapper',
#   'flimsi',
#   'overh',
#   'upper',
#   'run',
#   'turn',
#   'prepar',
#   'sturdi'],
#  'Size_Look': ['size',
#   'big',
#   'bigger',
#   '40',
#   'differ',
#   'screen',
#   'room',
#   'light',
#   '3d',
#   'livingroom',
#   'hardwar',
#   'slim',
#   'cubbyhol',
#   'huge',
#   'weigh',
#   'awkward',
#   'pentil',
#   'matrix',
#   '60',
#   'foot',
#   '65',
#   'consid',
#   'oh',
#   'lightweight',
#   'compact',
#   'suitabl',
#   'live',
#   'ultra',
#   'weigh',
#   'le',
#   'pound',
#   'hindsight',
#   'wonder',
#   'feel',
#   'anticip',
#   'actual',
#   'bedroom',
#   'fit',
#   'perfect',
#   'love',
#   'smaller',
#   'store',
#   'averag',
#   'inch',
#   'view',
#   '32',
#   'perfect',
#   'home',
#   'easili',
#   'get'],
#  'Image': ['pictur',
#   'color',
#   'qualiti',
#   'black',
#   'bright',
#   'nice',
#   'clear',
#   'look',
#   'excel',
#   'crisp',
#   'screen',
#   'right',
#   'dead',
#   'pixel',
#   'trace',
#   'beauti',
#   'vibrant',
#   'sharp',
#   'angl',
#   'display',
#   'dvd',
#   'differ',
#   'corner',
#   'fantast',
#   'hd',
#   'overal',
#   'inch',
#   'imag',
#   'view',
#   'white',
#   'great',
#   'ok',
#   'red',
#   'decent',
#   'struck',
#   'eye',
#   'ear',
#   'definit',
#   'fuzzi',
#   'font',
#   'improv',
#   'expeci',
#   'hubbi',
#   'sleep',
#   'caus',
#   'biggest',
#   'level',
#   'notic',
#   'irrit',
#   'affect'],
#  'Apps_Interface': ['netflix',
#   'user',
#   'file',
#   'hulu',
#   'app',
#   'watch',
#   'flash',
#   'internet',
#   'smart',
#   'video',
#   'stream',
#   'speed',
#   'youtub',
#   'access',
#   'lack',
#   'smart',
#   'download',
#   'brows',
#   'eas',
#   'interfac',
#   'friend',
#   'access',
#   'work',
#   'capabl',
#   'alright',
#   'quit',
#   'mean',
#   'let',
#   'hub',
#   'applic',
#   'terribl',
#   'watch',
#   'plus',
#   'easili',
#   'buy',
#   'week',
#   'right',
#   'featur',
#   'movi',
#   'comput',
#   'cabl',
#   'best',
#   'samsung',
#   'time',
#   'realli',
#   'like',
#   'better'],
#  'Suction_Power': ['suction',
#   'pick',
#   'power',
#   'power',
#   'good',
#   'hair',
#   'carpet',
#   'suck',
#   'quiet',
#   'realli',
#   'perform',
#   'dirt',
#   'tile',
#   'ok',
#   'job',
#   'floor',
#   'perfom',
#   'total',
#   'angl',
#   'attribut',
#   'machin',
#   'main',
#   'simpic',
#   'weak',
#   'object',
#   'bear',
#   'spot',
#   'vacuum',
#   'dosen',
#   'produc',
#   'fault',
#   'unders',
#   'pretti',
#   'essenti',
#   'spin',
#   'spun',
#   'mayb',
#   'pro',
#   'fair',
#   'reason',
#   'loo',
#   'filter',
#   'superb',
#   'grout',
#   'ergorapido',
#   'leav',
#   'plush',
#   'grind',
#   'stylish',
#   'function'],
#  'Weight': ['light',
#   'weight',
#   'lightweight',
#   'heavi',
#   'size',
#   'compact',
#   'maneuv',
#   'guess',
#   'quiet',
#   'quit',
#   'probabl',
#   'cumbersom',
#   'feaur',
#   'reason',
#   'histori',
#   'minor',
#   'heavier',
#   'consid',
#   'compar',
#   'nice',
#   'larg',
#   'need',
#   'especi',
#   'carri',
#   'drawback',
#   'perform',
#   'past',
#   'suppos',
#   'thought',
#   'power',
#   'loud',
#   'price',
#   'easi',
#   'feel',
#   'hardwood',
#   'push',
#   'store',
#   'panason',
#   'vacuum',
#   'bagless',
#   'area',
#   'ok',
#   'purchas',
#   'vaccuum',
#   'small',
#   'hard',
#   'littl',
#   'short',
#   'rug',
#   'canist'],
#  'Customer_Service': ['servic',
#   'contact',
#   'help',
#   'custom',
#   'took',
#   'email',
#   'miel',
#   'hoover',
#   'dealer',
#   'horribl',
#   'multipl',
#   'respond',
#   'chose',
#   'repres',
#   'told',
#   'smell',
#   'lubric',
#   'dissip',
#   'wait',
#   'spent',
#   'hour',
#   'phone',
#   'depart',
#   'contact',
#   'busi',
#   'regist',
#   'late',
#   'gotten',
#   'card',
#   'mail',
#   'ignor',
#   'look',
#   'common',
#   'recent',
#   'respons',
#   'unfortun',
#   'video',
#   'warranti',
#   'useless',
#   'self',
#   'fall',
#   'day',
#   'amazon',
#   'issu',
#   'absolut',
#   'time',
#   'purchas',
#   'problem'],
#  'Accessories': ['filter',
#   'brush',
#   'attach',
#   'roll',
#   'turbo',
#   'easili',
#   'expens',
#   'wide',
#   'turn',
#   'bag',
#   'replac',
#   'typic',
#   'hepa',
#   'cover',
#   'extens',
#   'wonder',
#   'crevic',
#   'reach',
#   'requir',
#   'clean',
#   'duster',
#   'hose',
#   'clean',
#   'way',
#   'noisi',
#   'corner',
#   'hardwood',
#   'empti',
#   'get',
#   'convent',
#   'brushrol',
#   'extra',
#   'rotat',
#   'block',
#   'bag',
#   'scrap',
#   'okay',
#   'basic',
#   'eye',
#   'regular',
#   'sensor',
#   'green',
#   'complet',
#   'instead',
#   'allow',
#   'need',
#   'spinner',
#   'fact',
#   'cup',
#   'onboard']}

# %%
for each_aspect in Aspect_to_seeds:
    print(each_aspect, Aspect_to_seeds[each_aspect].__len__())
# Out:
# Compartments 50
# Price 34
# Handles 50
# Customer_service 50
# Looks 22
# Quality 50
# Protection 49
# Size_Fit 50
# Ease_of_use 50
# Sound 50
# Look 50
# Connectivity 50
# Battery 48
# Durability 50
# Comfort 50
# Materials 50
# Color 19
# Size 50
# Weather_resistance 50
# Noise 50
# Extra_functionality 50
# Layout 50
# Feel_Comfort 50
# Build_Quality 50
# Size_Look 50
# Image 50
# Apps_Interface 47
# Suction_Power 50
# Weight 50
# Customer_Service 48
# Accessories 50

# %%
# tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")

# %%
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")
# model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# %%
# !echo $CUDA_VISIBLE_DEVICES

# %%
model_args = {'seed_samples': 10, 
              'aspect_length':6
             }

# %%
class aspectDataset(Dataset):
    
    def __init__(self, list_data, tokenizer, model_args):
        self.tokenizer = tokenizer
        self.list_data = list_data
        self.seeds_length = model_args['seed_samples']
        self.aspect_length = model_args['aspect_length']
    
    def __len__(self):
        """Return length of dataset."""
        return self.list_data.__len__()

    def __getitem__(self, i):
        """Return sample from dataset at index i."""
        example = self.list_data[i]
        shuffle(example['seeds'])
        sampled_seeds = example['seeds'][:self.seeds_length]
        aspect = " ".join(example["aspect"].split('_'))
#         max_length = self.seeds_length+2
        inputs = tokenizer(", ".join(sampled_seeds), 
                           truncation=True)  
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            padding="max_length", 
#                            truncation=True, 
#                            max_length=max_length)  
        outputs = tokenizer(aspect, 
                            padding="max_length", 
                            truncation=True, 
                            max_length=self.aspect_length)
        
        batch = {}
        batch["input_ids"] = torch.LongTensor(inputs.input_ids)
        batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["decoder_input_ids"] = torch.LongTensor(outputs.input_ids)
#         batch["decoder_attention_mask"] = torch.LongTensor(outputs.attention_mask)
        batch["labels"] = outputs.input_ids.copy()
        batch['labels'] = [batch['labels']]

        # We have to make sure that the PAD token is ignored for calculating the loss
        batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
                           for labels in batch["labels"]]
        batch["labels"] = torch.LongTensor(batch["labels"])
        batch["labels"] = batch["labels"].squeeze(0)
        
        return batch

# %%
train_data = []
for each_key in Aspect_to_seeds:
    train_data.append({"seeds":Aspect_to_seeds[each_key],
                       "aspect":each_key})

# %%
train_dataset = aspectDataset(list_data=train_data, 
                              tokenizer=tokenizer,
                              model_args=model_args
                             )

# %%
train_loader = DataLoader(train_dataset, 
                          batch_size=1, 
                          shuffle=True,
                          num_workers=1)

# %%
model = model.to("cuda")

# %%
# the_encoder = model.get_encoder()
# the_decoder = model.get_decoder()
# last_linear_layer = model.lm_head

# %%
num_epochs = 15
num_training_steps = num_epochs * len(train_data)

loss_fct = CrossEntropyLoss()

optimizer = AdamW(model.parameters(), 
                  lr=2e-7)
warmup_steps = int(0.10*num_training_steps)
lr_scheduler = get_scheduler("linear",
                            optimizer=optimizer,
                            num_warmup_steps=warmup_steps,
                            num_training_steps=num_training_steps
                            )

# %%
all_train_loss = []
for epoch in tqdm(range(num_epochs)):
    training_loss = 0.0
    model.train()
    for ind, batch in enumerate(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        model_op = model(**batch)
        loss = model_op['loss']
        
        training_loss += loss.item()
        
        print('---'*20)
        print('Epoch:', epoch, 'ID:', ind)
        print('---'*20)
        print('Seed words:', tokenizer.batch_decode(batch['input_ids'], 
                                                    skip_special_tokens=True, 
                                                    clean_up_tokenization_spaces=False))
        print('Actual aspect:', tokenizer.batch_decode(batch['labels'][batch['labels']!=-100].unsqueeze(0), 
                                                       skip_special_tokens=True, 
                                                       clean_up_tokenization_spaces=True))
        output_ids = model.generate(batch["input_ids"], 
                                    num_beams=3, 
                                    max_length=6)
        print('Predicted aspect:', tokenizer.batch_decode(output_ids, 
                                                          skip_special_tokens=True, 
                                                          clean_up_tokenization_spaces=True))
        
        loss.backward()
        optimizer.step() 
        lr_scheduler.step() 
        optimizer.zero_grad() 
    training_loss = training_loss / len( train_data )
    all_train_loss.append(training_loss)
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ------------------------------------------------------------
# Epoch: 0 ID: 0
# ------------------------------------------------------------
# Seed words: ['metal, use, hurt, remot, attach, later, felt, left, torn, inevit']
# Actual aspect: ['Handles']
# Predicted aspect: ['metal, use']
# ------------------------------------------------------------
# Epoch: 0 ID: 1
# ------------------------------------------------------------
# Seed words: ['size, bacaus, true, usual, shorter, normal, mayb, perfect, narrow, possibl']
# Actual aspect: ['Size']
# Predicted aspect: ['size, b']
# ------------------------------------------------------------
# Epoch: 0 ID: 2
# ------------------------------------------------------------
# Seed words: ['color, style, look, blue, love, red, boot, materi, look, favorit']
# Actual aspect: ['Color']
# Predicted aspect: ['color, style']
# ------------------------------------------------------------
# Epoch: 0 ID: 3
# ------------------------------------------------------------
# Seed words: ['technician, fact, communic, diagnost, 49, mention, ship, cancel, deliveri, 1500']
# Actual aspect: ['Customer service']
# Predicted aspect: ['technician,']
# ------------------------------------------------------------
# Epoch: 0 ID: 4
# ------------------------------------------------------------
# Seed words: ['respond, phone, red, pretti, work, power, get, blackberri, vari, volum']
# Actual aspect: ['Battery']
# Predicted aspect: ['respond, phone']
# ------------------------------------------------------------
# Epoch: 0 ID: 5
# ------------------------------------------------------------
# Seed words: ['perfect, loos, sued, snug, tongu, slide, light, short, super, ankl']
# Actual aspect: ['Comfort']
# Predicted aspect: ['perfect, loos']
# ------------------------------------------------------------
# Epoch: 0 ID: 6
# ------------------------------------------------------------
# Seed words: ['card, servic, regist, gotten, unfortun, told, issu, useless, late, depart']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['card, servic']
# ------------------------------------------------------------
# Epoch: 0 ID: 7
# ------------------------------------------------------------
# Seed words: ['inch, hp, enorm, 3080us, m1710, dv7, whatnot, book, slight, cabl']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['inch, hp']
# ------------------------------------------------------------
# Epoch: 0 ID: 8
# ------------------------------------------------------------
# Seed words: ['area, heavier, lightweight, littl, reason, price, need, carri, vaccuum, rug']
# Actual aspect: ['Weight']
# Predicted aspect: ['area, heavier']
# ------------------------------------------------------------
# Epoch: 0 ID: 9
# ------------------------------------------------------------
# Seed words: ['spillproof, dark, support, internet, blue, special, custom, remain, shortcut, music']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['spillproof']
# ------------------------------------------------------------
# Epoch: 0 ID: 10
# ------------------------------------------------------------
# Seed words: ['smell, white, poor, peel, crack, strip, zipper, trip, rip, durabl']
# Actual aspect: ['Quality']
# Predicted aspect: ['smell,']
# ------------------------------------------------------------
# Epoch: 0 ID: 11
# ------------------------------------------------------------
# Seed words: ['flash, port, vga, movi, enabl, dhcp, speed, min, conflict, cabl']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['flash, port']
# ------------------------------------------------------------
# Epoch: 0 ID: 12
# ------------------------------------------------------------
# Seed words: ['appear, backlit, lttle, slim, pc, keyboard, longer, like, good, small']
# Actual aspect: ['Looks']
# Predicted aspect: ['appear,']
# ------------------------------------------------------------
# Epoch: 0 ID: 13
# ------------------------------------------------------------
# Seed words: ['bar, movement, print, suppos, space, million, backspac, navig, horizont, chang']
# Actual aspect: ['Layout']
# Predicted aspect: ['bar, movement']
# ------------------------------------------------------------
# Epoch: 0 ID: 14
# ------------------------------------------------------------
# Seed words: ['protect, probabl, sleev, pad, larg, sort, provid, comput, bag, realli']
# Actual aspect: ['Protection']
# Predicted aspect: ['protect, prob']
# ------------------------------------------------------------
# Epoch: 0 ID: 15
# ------------------------------------------------------------
# Seed words: ['electron, overh, barley, upper, fail, flimsi, last, electr, unannounc, burnt']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['electron,']
# ------------------------------------------------------------
# Epoch: 0 ID: 16
# ------------------------------------------------------------
# Seed words: ['francisco, spent, waterproof, got, grass, alcatraz, resist, leav, penetr, wet']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['francisco']
# ------------------------------------------------------------
# Epoch: 0 ID: 17
# ------------------------------------------------------------
# Seed words: ['instead, rotat, get, noisi, way, corner, expens, wonder, spinner, extra']
# Actual aspect: ['Accessories']
# Predicted aspect: ['instead, rot']
# ------------------------------------------------------------
# Epoch: 0 ID: 18
# ------------------------------------------------------------
# Seed words: ['affect, eye, ok, expeci, irrit, improv, fantast, imag, beauti, white']
# Actual aspect: ['Image']
# Predicted aspect: ['affect,']
# ------------------------------------------------------------
# Epoch: 0 ID: 19
# ------------------------------------------------------------
# Seed words: ['satisfi, comfort, action, signatur, good, type, keystrok, sens, mushi, shallow']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['satisfi']
# ------------------------------------------------------------
# Epoch: 0 ID: 20
# ------------------------------------------------------------
# Seed words: ['grey, look, taup, moccasin, degre, ador, concept, weight, shame, pictur']
# Actual aspect: ['Look']
# Predicted aspect: ['grey, look']
# ------------------------------------------------------------
# Epoch: 0 ID: 21
# ------------------------------------------------------------
# Seed words: ['paperwork, player, control, nice, wire, outsid, charger, cabl, cellphon, nois']
# Actual aspect: ['Compartments']
# Predicted aspect: ['paperwork,']
# ------------------------------------------------------------
# Epoch: 0 ID: 22
# ------------------------------------------------------------
# Seed words: ['think, spin, money, paid, expens, twice, 50, worth, spun, cheap']
# Actual aspect: ['Price']
# Predicted aspect: ['think, spin']
# ------------------------------------------------------------
# Epoch: 0 ID: 23
# ------------------------------------------------------------
# Seed words: ['file, like, capabl, plus, interfac, mean, lack, watch, brows, week']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['file, like']
# ------------------------------------------------------------
# Epoch: 0 ID: 24
# ------------------------------------------------------------
# Seed words: ['cord, automat, empti, eas, worst, crevic, nozzl, vacuum, difficult, race']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['cord,']
# ------------------------------------------------------------
# Epoch: 0 ID: 25
# ------------------------------------------------------------
# Seed words: ['cheapest, worthi, good, great, surround, whine, junki, quieter, track, lack']
# Actual aspect: ['Sound']
# Predicted aspect: ['cheapest,']
# ------------------------------------------------------------
# Epoch: 0 ID: 26
# ------------------------------------------------------------
# Seed words: ['buckl, natur, best, soft, improv, true, fashion, especi, cloth, friction']
# Actual aspect: ['Materials']
# Predicted aspect: ['buckl,']
# ------------------------------------------------------------
# Epoch: 0 ID: 27
# ------------------------------------------------------------
# Seed words: ['weak, stylish, fault, spin, function, vacuum, superb, angl, floor, object']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['weak, stylish']
# ------------------------------------------------------------
# Epoch: 0 ID: 28
# ------------------------------------------------------------
# Seed words: ['wonder, size, pentil, averag, easili, view, ultra, consid, slim, cubbyhol']
# Actual aspect: ['Size Look']
# Predicted aspect: ['wonder,']
# ------------------------------------------------------------
# Epoch: 0 ID: 29
# ------------------------------------------------------------
# Seed words: ['cheep, think, numer, obvious, decent, sure, protect, materi, worn, abl']
# Actual aspect: ['Durability']
# Predicted aspect: ['cheep,']
# ------------------------------------------------------------
# Epoch: 0 ID: 30
# ------------------------------------------------------------
# Seed words: ['fair, upright, power, mous, powerstick, silent, peopl, turn, explod, quiet']
# Actual aspect: ['Noise']
# Predicted aspect: ['fair, upright']
#   7%|▋         | 1/15 [00:11<02:34, 11.03s/it]
# Epoch 1:	Training Loss 7.45
# ------------------------------------------------------------
# Epoch: 1 ID: 0
# ------------------------------------------------------------
# Seed words: ['heavi, past, thought, quiet, panason, purchas, ok, size, nice, larg']
# Actual aspect: ['Weight']
# Predicted aspect: ['heavi,']
# ------------------------------------------------------------
# Epoch: 1 ID: 1
# ------------------------------------------------------------
# Seed words: ['joint, pant, superb, perfect, left, larger, true, order, littl, run']
# Actual aspect: ['Size']
# Predicted aspect: ['joint,']
# ------------------------------------------------------------
# Epoch: 1 ID: 2
# ------------------------------------------------------------
# Seed words: ['beauti, origin, attract, laptop, nice, size, feel, lttle, cheap, look']
# Actual aspect: ['Looks']
# Predicted aspect: ['beauti,']
# ------------------------------------------------------------
# Epoch: 1 ID: 3
# ------------------------------------------------------------
# Seed words: ['drive, stop, comput, connect, slot, hdmi, speed, connect, 45, server']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['drive, stop']
# ------------------------------------------------------------
# Epoch: 1 ID: 4
# ------------------------------------------------------------
# Seed words: ['price, money, mayb, like, power, feaur, pricey, vacuum, far, vaccum']
# Actual aspect: ['Price']
# Predicted aspect: ['price, may']
# ------------------------------------------------------------
# Epoch: 1 ID: 5
# ------------------------------------------------------------
# Seed words: ['hurt, remot, torn, short, plastic, month, buckl, broke, control, lift']
# Actual aspect: ['Handles']
# Predicted aspect: ['hurt,']
# ------------------------------------------------------------
# Epoch: 1 ID: 6
# ------------------------------------------------------------
# Seed words: ['stream, internet, easili, like, best, access, interfac, week, let, watch']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['stream, internet']
# ------------------------------------------------------------
# Epoch: 1 ID: 7
# ------------------------------------------------------------
# Seed words: ['durabl, break, true, collaps, heavi, obvious, month, provid, clear, materi']
# Actual aspect: ['Durability']
# Predicted aspect: ['durabl']
# ------------------------------------------------------------
# Epoch: 1 ID: 8
# ------------------------------------------------------------
# Seed words: ['connector, earphon, wire, wish, folder, nice, headphon, nois, flap, charger']
# Actual aspect: ['Compartments']
# Predicted aspect: ['connector,']
# ------------------------------------------------------------
# Epoch: 1 ID: 9
# ------------------------------------------------------------
# Seed words: ['munchi, whatnot, 17inch, accommod, bare, hp, fre, tight, te, dv7']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['munchi']
# ------------------------------------------------------------
# Epoch: 1 ID: 10
# ------------------------------------------------------------
# Seed words: ['hepa, reach, expens, requir, need, attach, duster, green, hose, roll']
# Actual aspect: ['Accessories']
# Predicted aspect: ['hepa,']
# ------------------------------------------------------------
# Epoch: 1 ID: 11
# ------------------------------------------------------------
# Seed words: ['simpic, reason, carpet, angl, perfom, attribut, unders, spot, essenti, loo']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['simpic']
# ------------------------------------------------------------
# Epoch: 1 ID: 12
# ------------------------------------------------------------
# Seed words: ['strike, littl, squish, place, print, tricki, million, horizont, cluster, scroll']
# Actual aspect: ['Layout']
# Predicted aspect: ['strike, l']
# ------------------------------------------------------------
# Epoch: 1 ID: 13
# ------------------------------------------------------------
# Seed words: ['velvet, satisfi, wrist, quick, stylish, good, relax, level, usual, clicki']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['velvet,']
# ------------------------------------------------------------
# Epoch: 1 ID: 14
# ------------------------------------------------------------
# Seed words: ['outsid, ice, san, puddl, protect, cold, soak, water, den, repel']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['outsid,']
# ------------------------------------------------------------
# Epoch: 1 ID: 15
# ------------------------------------------------------------
# Seed words: ['thing, strong, bar, lack, hear, sound, experi, track, trebl, qualiti']
# Actual aspect: ['Sound']
# Predicted aspect: ['thing,']
# ------------------------------------------------------------
# Epoch: 1 ID: 16
# ------------------------------------------------------------
# Seed words: ['style, color, unbeliev, wonder, red, exact, taup, perfect, favorit, love']
# Actual aspect: ['Color']
# Predicted aspect: ['style, color']
# ------------------------------------------------------------
# Epoch: 1 ID: 17
# ------------------------------------------------------------
# Seed words: ['bright, level, differ, pixel, red, fuzzi, excel, look, crisp, sharp']
# Actual aspect: ['Image']
# Predicted aspect: ['bright, level']
# ------------------------------------------------------------
# Epoch: 1 ID: 18
# ------------------------------------------------------------
# Seed words: ['sudden, work, good, later, phone, time, stop, hold, blackberri, recharg']
# Actual aspect: ['Battery']
# Predicted aspect: ['sudden,']
# ------------------------------------------------------------
# Epoch: 1 ID: 19
# ------------------------------------------------------------
# Seed words: ['sued, porous, line, heel, rubber, zipper, best, aerosol, easili, elast']
# Actual aspect: ['Materials']
# Predicted aspect: ['sued,']
# ------------------------------------------------------------
# Epoch: 1 ID: 20
# ------------------------------------------------------------
# Seed words: ['short, hurt, comfort, blister, uncomfort, actual, wear, discomfort, narrow, offic']
# Actual aspect: ['Comfort']
# Predicted aspect: ['short, hurt']
# ------------------------------------------------------------
# Epoch: 1 ID: 21
# ------------------------------------------------------------
# Seed words: ['durabl, direct, comfort, ador, laid, offic, degre, light, calm, absolut']
# Actual aspect: ['Look']
# Predicted aspect: ['durabl']
# ------------------------------------------------------------
# Epoch: 1 ID: 22
# ------------------------------------------------------------
# Seed words: ['design, electr, unannounc, turn, time, easili, swivel, minut, brush, fifth']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['design, electr']
# ------------------------------------------------------------
# Epoch: 1 ID: 23
# ------------------------------------------------------------
# Seed words: ['foot, hindsight, pentil, fit, bedroom, bigger, huge, pound, weigh, easili']
# Actual aspect: ['Size Look']
# Predicted aspect: ['foot, hindsight']
# ------------------------------------------------------------
# Epoch: 1 ID: 24
# ------------------------------------------------------------
# Seed words: ['lightweight, devil, nozzl, recommend, stylish, block, power, louder, quit, fair']
# Actual aspect: ['Noise']
# Predicted aspect: ['lightweight,']
# ------------------------------------------------------------
# Epoch: 1 ID: 25
# ------------------------------------------------------------
# Seed words: ['come, requir, undamag, cancel, replac, bring, arriv, check, fix, mention']
# Actual aspect: ['Customer service']
# Predicted aspect: ['come, requ']
# ------------------------------------------------------------
# Epoch: 1 ID: 26
# ------------------------------------------------------------
# Seed words: ['good, kensington, happen, sort, use, protect, tast, normal, far, provid']
# Actual aspect: ['Protection']
# Predicted aspect: ['good, k']
# ------------------------------------------------------------
# Epoch: 1 ID: 27
# ------------------------------------------------------------
# Seed words: ['furnitur, kink, bog, disassembl, empti, remov, short, nozzl, race, jump']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['ff.']
# ------------------------------------------------------------
# Epoch: 1 ID: 28
# ------------------------------------------------------------
# Seed words: ['day, depart, video, warranti, chose, amazon, unfortun, regist, mail, email']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['day, depart']
# ------------------------------------------------------------
# Epoch: 1 ID: 29
# ------------------------------------------------------------
# Seed words: ['activ, illumin, hold, recess, mute, power, pencil, legibl, wake, volum']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['activ, ill']
# ------------------------------------------------------------
# Epoch: 1 ID: 30
# ------------------------------------------------------------
# Seed words: ['handl, cours, broken, outstand, year, brake, pull, plastic, trip, qualiti']
# Actual aspect: ['Quality']
# Predicted aspect: ['handl,']
#  13%|█▎        | 2/15 [00:20<02:15, 10.39s/it]
# Epoch 2:	Training Loss 7.36
# ------------------------------------------------------------
# Epoch: 2 ID: 0
# ------------------------------------------------------------
# Seed words: ['foam, let, natur, superb, smooth, fring, penetr, fleec, back, hang']
# Actual aspect: ['Materials']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 2 ID: 1
# ------------------------------------------------------------
# Seed words: ['love, purchas, unbeliev, blue, style, taup, materi, look, perfect, red']
# Actual aspect: ['Color']
# Predicted aspect: ['love, purch']
# ------------------------------------------------------------
# Epoch: 2 ID: 2
# ------------------------------------------------------------
# Seed words: ['instead, way, cup, brushrol, crevic, cover, need, eye, expens, green']
# Actual aspect: ['Accessories']
# Predicted aspect: ['instead, way']
# ------------------------------------------------------------
# Epoch: 2 ID: 3
# ------------------------------------------------------------
# Seed words: ['develop, muffl, cool, pitch, adjust, ear, quieter, hear, whine, display']
# Actual aspect: ['Sound']
# Predicted aspect: ['develop, muff']
# ------------------------------------------------------------
# Epoch: 2 ID: 4
# ------------------------------------------------------------
# Seed words: ['shallow, regist, recogn, clicki, finger, action, consist, type, keystrok, ibm']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['shallow,']
# ------------------------------------------------------------
# Epoch: 2 ID: 5
# ------------------------------------------------------------
# Seed words: ['nois, hide, pro, doggi, earplug, size, deafen, loud, lightweight, ring']
# Actual aspect: ['Noise']
# Predicted aspect: ['nois,']
# ------------------------------------------------------------
# Epoch: 2 ID: 6
# ------------------------------------------------------------
# Seed words: ['stream, stop, connect, input, audio, hdmi, enabl, wi, digit, dhcp']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['stream, stop']
# ------------------------------------------------------------
# Epoch: 2 ID: 7
# ------------------------------------------------------------
# Seed words: ['qualiti, pixel, look, improv, crisp, pictur, view, hd, right, caus']
# Actual aspect: ['Image']
# Predicted aspect: ['qualiti,']
# ------------------------------------------------------------
# Epoch: 2 ID: 8
# ------------------------------------------------------------
# Seed words: ['common, useless, gotten, amazon, issu, horribl, miel, dealer, time, took']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['common, useless']
# ------------------------------------------------------------
# Epoch: 2 ID: 9
# ------------------------------------------------------------
# Seed words: ['durabl, thinner, actual, decor, differ, worn, obvious, red, start, buckl']
# Actual aspect: ['Durability']
# Predicted aspect: ['durabl']
# ------------------------------------------------------------
# Epoch: 2 ID: 10
# ------------------------------------------------------------
# Seed words: ['come, stop, bizarr, nokia, sudden, time, charg, light, good, life']
# Actual aspect: ['Battery']
# Predicted aspect: ['come, stop']
# ------------------------------------------------------------
# Epoch: 2 ID: 11
# ------------------------------------------------------------
# Seed words: ['weak, floor, pretti, plush, leav, bear, quiet, carpet, total, angl']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['weak, floor']
# ------------------------------------------------------------
# Epoch: 2 ID: 12
# ------------------------------------------------------------
# Seed words: ['protect, defect, scout, lot, raini, let, waterproof, soak, dewi, term']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['protect, defect']
# ------------------------------------------------------------
# Epoch: 2 ID: 13
# ------------------------------------------------------------
# Seed words: ['imposs, hose, vacuum, wall, flexibl, maneuv, suck, easi, eas, nozzl']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['imposs,']
# ------------------------------------------------------------
# Epoch: 2 ID: 14
# ------------------------------------------------------------
# Seed words: ['zipper, stand, construct, sacrific, durabl, style, daili, tear, cancer, feel']
# Actual aspect: ['Quality']
# Predicted aspect: ['zipper,']
# ------------------------------------------------------------
# Epoch: 2 ID: 15
# ------------------------------------------------------------
# Seed words: ['headset, daytim, jacket, cabl, nice, charger, thing, pocket, fit, wire']
# Actual aspect: ['Compartments']
# Predicted aspect: ['headset,']
# ------------------------------------------------------------
# Epoch: 2 ID: 16
# ------------------------------------------------------------
# Seed words: ['eas, friend, week, smart, buy, video, flash, work, time, like']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['eas, friend']
# ------------------------------------------------------------
# Epoch: 2 ID: 17
# ------------------------------------------------------------
# Seed words: ['weight, doc, wear, ankl, list, plus, snug, fit, enjoy, discomfort']
# Actual aspect: ['Comfort']
# Predicted aspect: [',,,']
# ------------------------------------------------------------
# Epoch: 2 ID: 18
# ------------------------------------------------------------
# Seed words: ['internet, disk, handi, email, calcul, bright, pre, dark, program, pencil']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['internet, disk']
# ------------------------------------------------------------
# Epoch: 2 ID: 19
# ------------------------------------------------------------
# Seed words: ['view, home, actual, get, 40, perfect, 32, bedroom, room, bigger']
# Actual aspect: ['Size Look']
# Predicted aspect: ['view, home']
# ------------------------------------------------------------
# Epoch: 2 ID: 20
# ------------------------------------------------------------
# Seed words: ['100, come, undamag, replac, pilot, latest, help, po, 49, shore']
# Actual aspect: ['Customer service']
# Predicted aspect: ['100, come']
# ------------------------------------------------------------
# Epoch: 2 ID: 21
# ------------------------------------------------------------
# Seed words: ['unattract, comfort, pictur, collaps, absolut, natur, degre, ador, durabl, color']
# Actual aspect: ['Look']
# Predicted aspect: ['unattract']
# ------------------------------------------------------------
# Epoch: 2 ID: 22
# ------------------------------------------------------------
# Seed words: ['narrow, littl, buyer, shorter, larg, run, decid, tight, tab, ankl']
# Actual aspect: ['Size']
# Predicted aspect: ['narrow,']
# ------------------------------------------------------------
# Epoch: 2 ID: 23
# ------------------------------------------------------------
# Seed words: ['munchi, hp, air, pouch, load, cell, book, lot, fit, perfect']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['munchi']
# ------------------------------------------------------------
# Epoch: 2 ID: 24
# ------------------------------------------------------------
# Seed words: ['expens, ok, spin, bag, 50, weight, spend, good, light, duster']
# Actual aspect: ['Price']
# Predicted aspect: ['expens,']
# ------------------------------------------------------------
# Epoch: 2 ID: 25
# ------------------------------------------------------------
# Seed words: ['turn, month, constuct, easili, problem, smell, built, turn, bump, time']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['turn, month']
# ------------------------------------------------------------
# Epoch: 2 ID: 26
# ------------------------------------------------------------
# Seed words: ['size, panason, quiet, rug, ok, consid, cumbersom, probabl, reason, area']
# Actual aspect: ['Weight']
# Predicted aspect: ['size, pan']
# ------------------------------------------------------------
# Epoch: 2 ID: 27
# ------------------------------------------------------------
# Seed words: ['feel, great, slim, look, nice, good, attract, size, keyboard, laptop']
# Actual aspect: ['Looks']
# Predicted aspect: ['feel, great']
# ------------------------------------------------------------
# Epoch: 2 ID: 28
# ------------------------------------------------------------
# Seed words: ['attach, wear, use, hook, later, rip, note, minut, inevit, felt']
# Actual aspect: ['Handles']
# Predicted aspect: ['attach, wear']
# ------------------------------------------------------------
# Epoch: 2 ID: 29
# ------------------------------------------------------------
# Seed words: ['close, space, multimedia, place, tini, chang, size, movement, delet, place']
# Actual aspect: ['Layout']
# Predicted aspect: ['close, space']
# ------------------------------------------------------------
# Epoch: 2 ID: 30
# ------------------------------------------------------------
# Seed words: ['thing, love, protect, happen, feel, second, protect, like, realli, adequ']
# Actual aspect: ['Protection']
# Predicted aspect: ['thing,']
#  20%|██        | 3/15 [00:30<02:00, 10.00s/it]
# Epoch 3:	Training Loss 6.42
# ------------------------------------------------------------
# Epoch: 3 ID: 0
# ------------------------------------------------------------
# Seed words: ['adjust, metal, remot, broke, later, comfort, use, shoulder, swivel, month']
# Actual aspect: ['Handles']
# Predicted aspect: ['adjust, metal']
# ------------------------------------------------------------
# Epoch: 3 ID: 1
# ------------------------------------------------------------
# Seed words: ['like, attract, size, origin, keyboard, appear, lttle, good, decent, longer']
# Actual aspect: ['Looks']
# Predicted aspect: ['like, attract']
# ------------------------------------------------------------
# Epoch: 3 ID: 2
# ------------------------------------------------------------
# Seed words: ['featur, hub, watch, hulu, video, easili, samsung, user, youtub, speed']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['it.']
# ------------------------------------------------------------
# Epoch: 3 ID: 3
# ------------------------------------------------------------
# Seed words: ['inch, nice, definit, differ, excel, ear, corner, screen, angl, affect']
# Actual aspect: ['Image']
# Predicted aspect: ['inch, nice']
# ------------------------------------------------------------
# Epoch: 3 ID: 4
# ------------------------------------------------------------
# Seed words: ['ibm, tension, comfort, good, feel, keyboard, chicklet, navig, mushi, press']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['ibm,']
# ------------------------------------------------------------
# Epoch: 3 ID: 5
# ------------------------------------------------------------
# Seed words: ['terribl, sound, true, pitch, improv, vibrat, eye, develop, good, shippabl']
# Actual aspect: ['Sound']
# Predicted aspect: ['terribl']
# ------------------------------------------------------------
# Epoch: 3 ID: 6
# ------------------------------------------------------------
# Seed words: ['soak, stori, dri, traction, got, step, scout, deep, den, let']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['sososo']
# ------------------------------------------------------------
# Epoch: 3 ID: 7
# ------------------------------------------------------------
# Seed words: ['wise, easili, sturdi, construct, 20, swivel, turn, burnt, continu, month']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['wise, eas']
# ------------------------------------------------------------
# Epoch: 3 ID: 8
# ------------------------------------------------------------
# Seed words: ['label, bar, difficult, suppos, layout, tini, movement, vertic, multimedia, requir']
# Actual aspect: ['Layout']
# Predicted aspect: ['label, bar']
# ------------------------------------------------------------
# Epoch: 3 ID: 9
# ------------------------------------------------------------
# Seed words: ['usb, connect, dhcp, movi, stop, 45, monitor, netflix, hard, dlna']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['usb, connect']
# ------------------------------------------------------------
# Epoch: 3 ID: 10
# ------------------------------------------------------------
# Seed words: ['nozzl, stylish, reason, power, lose, peopl, sound, noisi, powerstick, fair']
# Actual aspect: ['Noise']
# Predicted aspect: ['nozzl']
# ------------------------------------------------------------
# Epoch: 3 ID: 11
# ------------------------------------------------------------
# Seed words: ['love, slim, consid, get, wonder, oh, smaller, pound, 65, livingroom']
# Actual aspect: ['Size Look']
# Predicted aspect: ['love,']
# ------------------------------------------------------------
# Epoch: 3 ID: 12
# ------------------------------------------------------------
# Seed words: ['volum, custom, interest, disk, eject, recess, pre, quit, wake, program']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['volum,']
# ------------------------------------------------------------
# Epoch: 3 ID: 13
# ------------------------------------------------------------
# Seed words: ['love, absolut, unattract, moccasin, ador, fring, offic, hang, pictur, taup']
# Actual aspect: ['Look']
# Predicted aspect: ['love, abs']
# ------------------------------------------------------------
# Epoch: 3 ID: 14
# ------------------------------------------------------------
# Seed words: ['red, star, stop, phone, nois, better, respond, longer, come, later']
# Actual aspect: ['Battery']
# Predicted aspect: ['red, star']
# ------------------------------------------------------------
# Epoch: 3 ID: 15
# ------------------------------------------------------------
# Seed words: ['compar, hard, maneuv, store, hardwood, price, carri, lightweight, feel, ok']
# Actual aspect: ['Weight']
# Predicted aspect: ['compar,']
# ------------------------------------------------------------
# Epoch: 3 ID: 16
# ------------------------------------------------------------
# Seed words: ['far, protect, pencil, normal, perfect, love, secur, kensington, comput, use']
# Actual aspect: ['Protection']
# Predicted aspect: ['far, protect']
# ------------------------------------------------------------
# Epoch: 3 ID: 17
# ------------------------------------------------------------
# Seed words: ['need, open, document, medium, folder, power, raincoat, construct, daytim, nois']
# Actual aspect: ['Compartments']
# Predicted aspect: ['need, open']
# ------------------------------------------------------------
# Epoch: 3 ID: 18
# ------------------------------------------------------------
# Seed words: ['ok, power, vaccum, think, pricey, weight, bag, worth, dyson, price']
# Actual aspect: ['Price']
# Predicted aspect: ['ok, power']
# ------------------------------------------------------------
# Epoch: 3 ID: 19
# ------------------------------------------------------------
# Seed words: ['unbeliev, boot, look, color, style, perfect, taup, materi, blue, purchas']
# Actual aspect: ['Color']
# Predicted aspect: ['unbeliev']
# ------------------------------------------------------------
# Epoch: 3 ID: 20
# ------------------------------------------------------------
# Seed words: ['depart, dissip, lubric, phone, horribl, took, time, respond, problem, self']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['depart,']
# ------------------------------------------------------------
# Epoch: 3 ID: 21
# ------------------------------------------------------------
# Seed words: ['good, produc, floor, mayb, carpet, quiet, perform, total, object, spot']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['good, produ']
# ------------------------------------------------------------
# Epoch: 3 ID: 22
# ------------------------------------------------------------
# Seed words: ['narrow, list, walk, put, summer, fit, short, wear, longer, environ']
# Actual aspect: ['Comfort']
# Predicted aspect: ['narrow,']
# ------------------------------------------------------------
# Epoch: 3 ID: 23
# ------------------------------------------------------------
# Seed words: ['wide, width, especi, tight, awar, mayb, size, perfect, bigger, order']
# Actual aspect: ['Size']
# Predicted aspect: ['widewidewide']
# ------------------------------------------------------------
# Epoch: 3 ID: 24
# ------------------------------------------------------------
# Seed words: ['easili, hang, improv, friction, cloth, leather, fashion, barn, elast, aerosol']
# Actual aspect: ['Materials']
# Predicted aspect: ['easili,']
# ------------------------------------------------------------
# Epoch: 3 ID: 25
# ------------------------------------------------------------
# Seed words: ['power, heavi, eas, corner, car, difficult, pile, short, move, push']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['power, m']
# ------------------------------------------------------------
# Epoch: 3 ID: 26
# ------------------------------------------------------------
# Seed words: ['cancer, trip, wear, style, durabl, later, zipper, broke, excel, year']
# Actual aspect: ['Quality']
# Predicted aspect: ['cancer, trip']
# ------------------------------------------------------------
# Epoch: 3 ID: 27
# ------------------------------------------------------------
# Seed words: ['protect, obvious, enjoy, collaps, break, heel, gone, durabl, qualiti, buckl']
# Actual aspect: ['Durability']
# Predicted aspect: ['protect, obvious']
# ------------------------------------------------------------
# Epoch: 3 ID: 28
# ------------------------------------------------------------
# Seed words: ['bag, turbo, okay, corner, wonder, fact, scrap, rotat, crevic, requir']
# Actual aspect: ['Accessories']
# Predicted aspect: ['bag, turbo']
# ------------------------------------------------------------
# Epoch: 3 ID: 29
# ------------------------------------------------------------
# Seed words: ['replac, fee, paid, 100lb, help, downstair, divx, suppos, use, shore']
# Actual aspect: ['Customer service']
# Predicted aspect: ['replac,']
# ------------------------------------------------------------
# Epoch: 3 ID: 30
# ------------------------------------------------------------
# Seed words: ['te, seat, jacket, perfect, airplan, 3080us, enorm, m1710, bare, bulk']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['te, seat']
#  27%|██▋       | 4/15 [00:40<01:48,  9.89s/it]
# Epoch 4:	Training Loss 6.05
# ------------------------------------------------------------
# Epoch: 4 ID: 0
# ------------------------------------------------------------
# Seed words: ['aerosol, back, zipper, improv, friction, hollow, superb, fact, calm, penetr']
# Actual aspect: ['Materials']
# Predicted aspect: ['aerosol']
# ------------------------------------------------------------
# Epoch: 4 ID: 1
# ------------------------------------------------------------
# Seed words: ['incred, star, bearabl, loud, silent, quit, peopl, ring, flee, pro']
# Actual aspect: ['Noise']
# Predicted aspect: ['incred,']
# ------------------------------------------------------------
# Epoch: 4 ID: 2
# ------------------------------------------------------------
# Seed words: ['key, mushi, respond, feel, deceler, natur, ibm, velvet, finger, usual']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['key, mush']
# ------------------------------------------------------------
# Epoch: 4 ID: 3
# ------------------------------------------------------------
# Seed words: ['vacuum, money, twice, 50, mayb, best, weight, spin, think, like']
# Actual aspect: ['Price']
# Predicted aspect: ['vacuum']
# ------------------------------------------------------------
# Epoch: 4 ID: 4
# ------------------------------------------------------------
# Seed words: ['beauti, bigger, order, small, perfect, order, larg, bacaus, pant, joint']
# Actual aspect: ['Size']
# Predicted aspect: ['beauti,']
# ------------------------------------------------------------
# Epoch: 4 ID: 5
# ------------------------------------------------------------
# Seed words: ['materi, excel, year, style, left, broke, durabl, birth, holiday, broken']
# Actual aspect: ['Quality']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 4 ID: 6
# ------------------------------------------------------------
# Seed words: ['negat, chang, bar, scroll, end, navig, tricki, difficult, layout, tini']
# Actual aspect: ['Layout']
# Predicted aspect: ['negat,']
# ------------------------------------------------------------
# Epoch: 4 ID: 7
# ------------------------------------------------------------
# Seed words: ['dead, star, hour, easili, charg, longer, sudden, phone, merit, talk']
# Actual aspect: ['Battery']
# Predicted aspect: ['dead, star']
# ------------------------------------------------------------
# Epoch: 4 ID: 8
# ------------------------------------------------------------
# Seed words: ['programm, special, brower, dim, volum, label, custom, handi, capabl, shut']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['programm,']
# ------------------------------------------------------------
# Epoch: 4 ID: 9
# ------------------------------------------------------------
# Seed words: ['disassembl, nozzl, constant, worst, roller, car, jump, hard, short, difficult']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['disassembl']
# ------------------------------------------------------------
# Epoch: 4 ID: 10
# ------------------------------------------------------------
# Seed words: ['clear, great, fuzzi, improv, struck, right, imag, caus, expeci, sleep']
# Actual aspect: ['Image']
# Predicted aspect: ['clear, great']
# ------------------------------------------------------------
# Epoch: 4 ID: 11
# ------------------------------------------------------------
# Seed words: ['busi, self, contact, common, respons, spent, gotten, miel, useless, help']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['busi,']
# ------------------------------------------------------------
# Epoch: 4 ID: 12
# ------------------------------------------------------------
# Seed words: ['movi, mean, access, hulu, better, friend, file, right, download, video']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['movi,']
# ------------------------------------------------------------
# Epoch: 4 ID: 13
# ------------------------------------------------------------
# Seed words: ['coverag, stylish, unattract, rest, environ, collaps, taup, moccasin, attract, nice']
# Actual aspect: ['Look']
# Predicted aspect: ['coverag,']
# ------------------------------------------------------------
# Epoch: 4 ID: 14
# ------------------------------------------------------------
# Seed words: ['avi, watch, digit, output, flash, slot, fi, power, higher, connect']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['avi, watch']
# ------------------------------------------------------------
# Epoch: 4 ID: 15
# ------------------------------------------------------------
# Seed words: ['protect, far, let, pad, secur, perfect, larg, trust, weak, thing']
# Actual aspect: ['Protection']
# Predicted aspect: ['protect, far']
# ------------------------------------------------------------
# Epoch: 4 ID: 16
# ------------------------------------------------------------
# Seed words: ['function, plush, weak, pretti, object, floor, perform, angl, hair, good']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['function, plush']
# ------------------------------------------------------------
# Epoch: 4 ID: 17
# ------------------------------------------------------------
# Seed words: ['replac, hepa, green, fact, easili, instead, typic, convent, allow, scrap']
# Actual aspect: ['Accessories']
# Predicted aspect: ['replac,']
# ------------------------------------------------------------
# Epoch: 4 ID: 18
# ------------------------------------------------------------
# Seed words: ['watt, kinda, dinner, tinni, true, display, improv, laptop, adjust, great']
# Actual aspect: ['Sound']
# Predicted aspect: ['watt,']
# ------------------------------------------------------------
# Epoch: 4 ID: 19
# ------------------------------------------------------------
# Seed words: ['break, wear, ankl, comfort, moment, tongu, put, minut, toe, attract']
# Actual aspect: ['Comfort']
# Predicted aspect: ['break, wear']
# ------------------------------------------------------------
# Epoch: 4 ID: 20
# ------------------------------------------------------------
# Seed words: ['rubber, enjoy, heel, decent, differ, pretti, clear, wear, long, deflat']
# Actual aspect: ['Durability']
# Predicted aspect: ['rubber,']
# ------------------------------------------------------------
# Epoch: 4 ID: 21
# ------------------------------------------------------------
# Seed words: ['arriv, requir, bring, deliv, peopl, pilot, glove, help, difficult, week']
# Actual aspect: ['Customer service']
# Predicted aspect: ['arriv,']
# ------------------------------------------------------------
# Epoch: 4 ID: 22
# ------------------------------------------------------------
# Seed words: ['small, construct, power, control, huge, safe, document, remot, paperwork, thing']
# Actual aspect: ['Compartments']
# Predicted aspect: ['small, construct']
# ------------------------------------------------------------
# Epoch: 4 ID: 23
# ------------------------------------------------------------
# Seed words: ['consid, littl, larg, store, past, push, cumbersom, histori, panason, short']
# Actual aspect: ['Weight']
# Predicted aspect: ['consid,']
# ------------------------------------------------------------
# Epoch: 4 ID: 24
# ------------------------------------------------------------
# Seed words: ['love, taup, exact, perfect, unbeliev, look, wonder, color, style, favorit']
# Actual aspect: ['Color']
# Predicted aspect: ['love, t']
# ------------------------------------------------------------
# Epoch: 4 ID: 25
# ------------------------------------------------------------
# Seed words: ['20, last, break, work, burnt, month, broke, run, flimsi, burn']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['20, last']
# ------------------------------------------------------------
# Epoch: 4 ID: 26
# ------------------------------------------------------------
# Seed words: ['suitabl, averag, weigh, feel, oh, big, love, bedroom, store, inch']
# Actual aspect: ['Size Look']
# Predicted aspect: ['suitabl,']
# ------------------------------------------------------------
# Epoch: 4 ID: 27
# ------------------------------------------------------------
# Seed words: ['grass, snow, raini, perform, step, alcatraz, water, item, cold, outsid']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['grass, snow']
# ------------------------------------------------------------
# Epoch: 4 ID: 28
# ------------------------------------------------------------
# Seed words: ['broken, short, handl, rip, plastic, length, torn, hurt, minut, later']
# Actual aspect: ['Handles']
# Predicted aspect: ['broken, short']
# ------------------------------------------------------------
# Epoch: 4 ID: 29
# ------------------------------------------------------------
# Seed words: ['m1710, sure, daytim, size, big, 17inch, te, folder, dv7, raincoat']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['m1710']
# ------------------------------------------------------------
# Epoch: 4 ID: 30
# ------------------------------------------------------------
# Seed words: ['origin, slim, lttle, great, imac, nice, attract, backlit, longer, keyboard']
# Actual aspect: ['Looks']
# Predicted aspect: ['origin, slim']
#  33%|███▎      | 5/15 [00:48<01:34,  9.47s/it]
# Epoch 5:	Training Loss 5.88
# ------------------------------------------------------------
# Epoch: 5 ID: 0
# ------------------------------------------------------------
# Seed words: ['buy, access, lack, hub, like, smart, cabl, mean, download, netflix']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['buy, access']
# ------------------------------------------------------------
# Epoch: 5 ID: 1
# ------------------------------------------------------------
# Seed words: ['let, protect, adequ, comput, weak, realli, count, laptop, love, secur']
# Actual aspect: ['Protection']
# Predicted aspect: ['let, protect']
# ------------------------------------------------------------
# Epoch: 5 ID: 2
# ------------------------------------------------------------
# Seed words: ['carpet, dosen, total, power, leav, bear, spun, simpic, floor, plush']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['carpet']
# ------------------------------------------------------------
# Epoch: 5 ID: 3
# ------------------------------------------------------------
# Seed words: ['interest, activ, hold, music, internet, button, brower, legibl, keypress, power']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['interest, activ']
# ------------------------------------------------------------
# Epoch: 5 ID: 4
# ------------------------------------------------------------
# Seed words: ['biggest, pixel, screen, dead, fuzzi, view, sharp, hubbi, irrit, right']
# Actual aspect: ['Image']
# Predicted aspect: ['biggest,']
# ------------------------------------------------------------
# Epoch: 5 ID: 5
# ------------------------------------------------------------
# Seed words: ['qualiti, super, sturdi, heel, decor, come, collaps, abl, need, style']
# Actual aspect: ['Durability']
# Predicted aspect: ['qualiti,']
# ------------------------------------------------------------
# Epoch: 5 ID: 6
# ------------------------------------------------------------
# Seed words: ['origin, laptop, good, imac, cheap, nice, feel, attract, keyboard, pc']
# Actual aspect: ['Looks']
# Predicted aspect: ['origin, laptop']
# ------------------------------------------------------------
# Epoch: 5 ID: 7
# ------------------------------------------------------------
# Seed words: ['buckl, shorter, situat, addit, use, start, loop, sooner, note, adjust']
# Actual aspect: ['Handles']
# Predicted aspect: ['buckl,']
# ------------------------------------------------------------
# Epoch: 5 ID: 8
# ------------------------------------------------------------
# Seed words: ['unannounc, prepar, sturdi, broke, overh, roller, turn, brush, turn, work']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['unannoun']
# ------------------------------------------------------------
# Epoch: 5 ID: 9
# ------------------------------------------------------------
# Seed words: ['actual, short, long, doc, blister, time, perfect, foot, walk, break']
# Actual aspect: ['Comfort']
# Predicted aspect: ['actual, short']
# ------------------------------------------------------------
# Epoch: 5 ID: 10
# ------------------------------------------------------------
# Seed words: ['problem, purchas, amazon, day, issu, hour, useless, chose, respond, repres']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['problem, purch']
# ...
# Predicted aspect: ['earplug,']
# ------------------------------------------------------------
# Epoch: 13 ID: 7
# ------------------------------------------------------------
# Seed words: ['dinner, pitch, realli, chang, shippabl, surround, laptop, experi, lack, display']
# Actual aspect: ['Sound']
# Predicted aspect: ['dinner,']
# ------------------------------------------------------------
# Epoch: 13 ID: 8
# ------------------------------------------------------------
# Seed words: ['pricey, dyson, far, expect, like, best, weight, spin, worth, need']
# Actual aspect: ['Price']
# Predicted aspect: ['pricey,']
# ------------------------------------------------------------
# Epoch: 13 ID: 9
# ------------------------------------------------------------
# Seed words: ['space, earphon, wish, player, pocket, document, insid, charger, planner, pen']
# Actual aspect: ['Compartments']
# Predicted aspect: ['space,11']
# ------------------------------------------------------------
# Epoch: 13 ID: 10
# ------------------------------------------------------------
# Seed words: ['foam, elast, synthet, finish, porous, materi, come, fleec, smooth, term']
# Actual aspect: ['Materials']
# Predicted aspect: ['foam,']
# ------------------------------------------------------------
# Epoch: 13 ID: 11
# ------------------------------------------------------------
# Seed words: ['get, compact, averag, perfect, smaller, livingroom, feel, bigger, cubbyhol, fit']
# Actual aspect: ['Size Look']
# Predicted aspect: ['get, compact']
# ------------------------------------------------------------
# Epoch: 13 ID: 12
# ------------------------------------------------------------
# Seed words: ['handl, 100, speak, replac, come, use, help, mail, ship, 100lb']
# Actual aspect: ['Customer service']
# Predicted aspect: ['handl,']
# ------------------------------------------------------------
# Epoch: 13 ID: 13
# ------------------------------------------------------------
# Seed words: ['beauti, laptop, lttle, good, cheap, pc, feel, appear, small, attract']
# Actual aspect: ['Looks']
# Predicted aspect: ['beauti,']
# ------------------------------------------------------------
# Epoch: 13 ID: 14
# ------------------------------------------------------------
# Seed words: ['stylish, stick, velvet, smooth, key, signatur, tap, tension, type, regist']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['stylish,']
# ------------------------------------------------------------
# Epoch: 13 ID: 15
# ------------------------------------------------------------
# Seed words: ['attach, construct, prepar, easili, quit, overheat, snapper, smell, work, burnt']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['attach, prepar']
# ------------------------------------------------------------
# Epoch: 13 ID: 16
# ------------------------------------------------------------
# Seed words: ['light, thing, respond, half, green, bizarr, day, red, simpl, life']
# Actual aspect: ['Battery']
# Predicted aspect: ['Light']
# ------------------------------------------------------------
# Epoch: 13 ID: 17
# ------------------------------------------------------------
# Seed words: ['bit, comput, thing, lap, pad, realli, like, kensington, construct, perfect']
# Actual aspect: ['Protection']
# Predicted aspect: ['Bit, comput']
# ------------------------------------------------------------
# Epoch: 13 ID: 18
# ------------------------------------------------------------
# Seed words: ['affect, improv, fuzzi, trace, excel, expeci, hd, notic, right, sleep']
# Actual aspect: ['Image']
# Predicted aspect: ['affect,']
# ------------------------------------------------------------
# Epoch: 13 ID: 19
# ------------------------------------------------------------
# Seed words: ['best, comput, like, access, file, hulu, netflix, better, download, app']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['best, best']
# ------------------------------------------------------------
# Epoch: 13 ID: 20
# ------------------------------------------------------------
# Seed words: ['broken, torn, rip, later, short, hurt, adjust, break, attach, metal']
# Actual aspect: ['Handles']
# Predicted aspect: ['broken, torn']
# ------------------------------------------------------------
# Epoch: 13 ID: 21
# ------------------------------------------------------------
# Seed words: ['perfect, littl, perfect, put, attract, tongu, minut, abl, slide, light']
# Actual aspect: ['Comfort']
# Predicted aspect: ['perfectl,']
# ------------------------------------------------------------
# Epoch: 13 ID: 22
# ------------------------------------------------------------
# Seed words: ['daili, appear, long, rubber, need, sol, decor, support, actual, protect']
# Actual aspect: ['Durability']
# Predicted aspect: ['daili']
# ------------------------------------------------------------
# Epoch: 13 ID: 23
# ------------------------------------------------------------
# Seed words: ['super, unattract, pictur, attract, absolut, crazi, collaps, 360, beauti, color']
# Actual aspect: ['Look']
# Predicted aspect: ['super, unatt']
# ------------------------------------------------------------
# Epoch: 13 ID: 24
# ------------------------------------------------------------
# Seed words: ['machin, simpic, unders, leav, main, suck, dirt, attribut, reason, fault']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['machin']
# ------------------------------------------------------------
# Epoch: 13 ID: 25
# ------------------------------------------------------------
# Seed words: ['stand, birth, asia, durabl, defect, chemic, broke, daili, plastic, rip']
# Actual aspect: ['Quality']
# Predicted aspect: ['stand, birth']
# ------------------------------------------------------------
# Epoch: 13 ID: 26
# ------------------------------------------------------------
# Seed words: ['larg, perfect, shorter, advic, fit, order, true, baggi, follow, sent']
# Actual aspect: ['Size']
# Predicted aspect: ['larg, perfect']
# ------------------------------------------------------------
# Epoch: 13 ID: 27
# ------------------------------------------------------------
# Seed words: ['spill, size, negat, delet, tini, volum, tricki, place, cluster, impecc']
# Actual aspect: ['Layout']
# Predicted aspect: ['spill,']
# ------------------------------------------------------------
# Epoch: 13 ID: 28
# ------------------------------------------------------------
# Seed words: ['crevic, eye, roll, cover, convent, scrap, corner, instead, duster, green']
# Actual aspect: ['Accessories']
# Predicted aspect: ['crevic,']
# ------------------------------------------------------------
# Epoch: 13 ID: 29
# ------------------------------------------------------------
# Seed words: ['earphon, cell, spacious, te, nois, inch, space, snug, enorm, folder']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['earphon']
# ------------------------------------------------------------
# Epoch: 13 ID: 30
# ------------------------------------------------------------
# Seed words: ['hard, propel, maneuv, crevic, hose, move, carpet, flexibl, jump, easier']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['hard, propel']
#  93%|█████████▎| 14/15 [02:19<00:10, 10.23s/it]
# Epoch 14:	Training Loss 4.48
# ------------------------------------------------------------
# Epoch: 14 ID: 0
# ------------------------------------------------------------
# Seed words: ['irrit, pictur, red, white, bright, biggest, caus, vibrant, right, clear']
# Actual aspect: ['Image']
# Predicted aspect: ['irrit,']
# ------------------------------------------------------------
# Epoch: 14 ID: 1
# ------------------------------------------------------------
# Seed words: ['actual, heavi, sol, red, time, support, style, abl, think, durabl']
# Actual aspect: ['Durability']
# Predicted aspect: ['actual, heav']
# ------------------------------------------------------------
# Epoch: 14 ID: 2
# ------------------------------------------------------------
# Seed words: ['flap, pocket, run, jacket, reduct, connector, wallet, paperwork, accessori, thing']
# Actual aspect: ['Compartments']
# Predicted aspect: ['flap,']
# ------------------------------------------------------------
# Epoch: 14 ID: 3
# ------------------------------------------------------------
# Seed words: ['hair, vacuum, total, plush, quiet, floor, tile, produc, ok, simpic']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['hair, vacuum']
# ------------------------------------------------------------
# Epoch: 14 ID: 4
# ------------------------------------------------------------
# Seed words: ['left, big, run, larger, small, larg, usual, moccasin, especi, shame']
# Actual aspect: ['Size']
# Predicted aspect: ['left, big']
# ------------------------------------------------------------
# Epoch: 14 ID: 5
# ------------------------------------------------------------
# Seed words: ['awkward, move, kink, short, eas, simpic, roller, hose, empti, flash']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['awkward,']
# ------------------------------------------------------------
# Epoch: 14 ID: 6
# ------------------------------------------------------------
# Seed words: ['perfect, pavilion, dv7, air, macbook, size, book, tight, accommod, load']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['perfect, pav']
# ------------------------------------------------------------
# Epoch: 14 ID: 7
# ------------------------------------------------------------
# Seed words: ['length, broke, hurt, holiday, rip, plastic, long, start, comfort, control']
# Actual aspect: ['Handles']
# Predicted aspect: ['length, broke']
# ------------------------------------------------------------
# Epoch: 14 ID: 8
# ------------------------------------------------------------
# Seed words: ['shortcut, button, custom, volum, pen, eject, hold, activ, legibl, handi']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['shortcut,']
# ------------------------------------------------------------
# Epoch: 14 ID: 9
# ------------------------------------------------------------
# Seed words: ['feaur, spun, bagless, paid, power, money, mayb, spin, far, pricey']
# Actual aspect: ['Price']
# Predicted aspect: ['feaur,']
# ------------------------------------------------------------
# Epoch: 14 ID: 10
# ------------------------------------------------------------
# Seed words: ['pressur, dissatisfi, mushi, wrist, action, tap, signatur, chicklet, shallow, stylish']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['pressur,']
# ------------------------------------------------------------
# Epoch: 14 ID: 11
# ------------------------------------------------------------
# Seed words: ['desk, difficult, diagnost, help, carri, deliveri, wait, refurbish, servic, undamag']
# Actual aspect: ['Customer service']
# Predicted aspect: ['desk,']
# ------------------------------------------------------------
# Epoch: 14 ID: 12
# ------------------------------------------------------------
# Seed words: ['roll, replac, block, regular, fact, reach, wide, get, instead, way']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Roll, repl']
# ------------------------------------------------------------
# Epoch: 14 ID: 13
# ------------------------------------------------------------
# Seed words: ['half, tone, love, day, color, longer, green, meter, dead, phone']
# Actual aspect: ['Battery']
# Predicted aspect: ['half, tone']
# ------------------------------------------------------------
# Epoch: 14 ID: 14
# ------------------------------------------------------------
# Seed words: ['penetr, spent, deep, generous, island, step, chicago, dri, scout, term']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['penetr,']
# ------------------------------------------------------------
# Epoch: 14 ID: 15
# ------------------------------------------------------------
# Seed words: ['rip, plastic, daili, defect, crack, poor, pull, start, durabl, materi']
# Actual aspect: ['Quality']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 14 ID: 16
# ------------------------------------------------------------
# Seed words: ['lttle, great, imac, nice, appear, feel, keyboard, attract, beauti, small']
# Actual aspect: ['Looks']
# Predicted aspect: ['lttle,']
# ------------------------------------------------------------
# Epoch: 14 ID: 17
# ------------------------------------------------------------
# Seed words: ['easili, watch, watch, friend, internet, netflix, better, buy, smart, user']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['easili,']
# ------------------------------------------------------------
# Epoch: 14 ID: 18
# ------------------------------------------------------------
# Seed words: ['compact, weight, past, purchas, price, reason, panason, need, light, cumbersom']
# Actual aspect: ['Weight']
# Predicted aspect: ['compact,']
# ------------------------------------------------------------
# Epoch: 14 ID: 19
# ------------------------------------------------------------
# Seed words: ['last, poor, wise, stop, portion, easili, electron, turn, electr, broke']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['last, poor']
# ------------------------------------------------------------
# Epoch: 14 ID: 20
# ------------------------------------------------------------
# Seed words: ['tongu, time, snug, doc, sued, long, hurt, weight, list, comfi']
# Actual aspect: ['Comfort']
# Predicted aspect: ['tongu']
# ------------------------------------------------------------
# Epoch: 14 ID: 21
# ------------------------------------------------------------
# Seed words: ['moccasin, durabl, crazi, light, rest, design, taup, nice, absolut, pictur']
# Actual aspect: ['Look']
# Predicted aspect: ['moccasin']
# ------------------------------------------------------------
# Epoch: 14 ID: 22
# ------------------------------------------------------------
# Seed words: ['smell, hour, email, spent, servic, issu, lubric, late, miel, repres']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['smell,']
# ------------------------------------------------------------
# Epoch: 14 ID: 23
# ------------------------------------------------------------
# Seed words: ['higher, enabl, watch, connect, conflict, end, comput, play, 45, digit']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['higher, en']
# ------------------------------------------------------------
# Epoch: 14 ID: 24
# ------------------------------------------------------------
# Seed words: ['look, unbeliev, blue, red, love, style, materi, favorit, gorgeous, color']
# Actual aspect: ['Color']
# Predicted aspect: ['look, blue']
# ------------------------------------------------------------
# Epoch: 14 ID: 25
# ------------------------------------------------------------
# Seed words: ['barn, let, materi, buckl, fleec, fring, direct, synthet, thinner, calm']
# Actual aspect: ['Materials']
# Predicted aspect: ['barn,']
# ------------------------------------------------------------
# Epoch: 14 ID: 26
# ------------------------------------------------------------
# Seed words: ['multimedia, wide, wider, perfect, home, label, million, scroll, print, awkward']
# Actual aspect: ['Layout']
# Predicted aspect: ['multimedia,']
# ------------------------------------------------------------
# Epoch: 14 ID: 27
# ------------------------------------------------------------
# Seed words: ['qualiti, track, eye, develop, experi, watt, thing, terribl, speaker, lack']
# Actual aspect: ['Sound']
# Predicted aspect: ['qualiti,']
# ------------------------------------------------------------
# Epoch: 14 ID: 28
# ------------------------------------------------------------
# Seed words: ['hide, loudest, turn, awesom, nozzl, compar, ear, quit, fair, lose']
# Actual aspect: ['Noise']
# Predicted aspect: ['hide, loud']
# ------------------------------------------------------------
# Epoch: 14 ID: 29
# ------------------------------------------------------------
# Seed words: ['suitabl, lightweight, store, averag, awkward, live, smaller, feel, slim, ultra']
# Actual aspect: ['Size Look']
# Predicted aspect: ['suitabl,']
# ------------------------------------------------------------
# Epoch: 14 ID: 30
# ------------------------------------------------------------
# Seed words: ['sleev, like, weak, use, second, construct, feel, protect, bit, happen']
# Actual aspect: ['Protection']
# Predicted aspect: ['sleev,']
# 100%|██████████| 15/15 [02:30<00:00, 10.01s/it]
# Epoch 15:	Training Loss 4.82

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(all_train_loss, ls='-.', marker = 'X', color='blue')

# %%
stop_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c3998c8be795> in <module>
# ----> 1 stop_
#
# NameError: name 'stop_' is not defined

# %% [markdown]
# ### Generation for the topics of CTM
# --------------------------------------------

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
stemmer = SnowballStemmer(language='english')

# %%
stemmed_electronic_topics = []
for each_topic in electronic_topics:
    tmp_ = [stemmer.stem(x) for x in each_topic]
    stemmed_electronic_topics.append(tmp_)

# %%
model_args['seed_samples']
# Out:
# 10

# %%
model.eval()
for each_topic in stemmed_electronic_topics:
    topic_seeds = each_topic[:model_args['seed_samples']]
    in_tokenized = tokenizer(', '.join(topic_seeds), 
                             truncation=True)  
    in_ids = torch.LongTensor(in_tokenized.input_ids)
    in_ids = in_ids.to('cuda')
    in_ids = in_ids.unsqueeze(0)
    op_ids = model.generate(in_ids, 
                            num_beams=3, 
                            max_length=6)
    print('Seeds:', topic_seeds)
    print('Predicted aspect:', tokenizer.batch_decode(op_ids, 
                                                      skip_special_tokens=True, 
                                                      clean_up_tokenization_spaces=True))
    print('--'*30)
# Out:
# Seeds: ['construct', 'valu', 'exceed', 'outstand', 'light', 'weight', 'attract', 'versatil', 'excel', 'valu']
# Predicted aspect: ['construct, val']
# ------------------------------------------------------------
# Seeds: ['deck', 'patio', 'beach', 'loud', 'camp', 'parti', 'hous', 'everywh', 'portabl', 'backyard']
# Predicted aspect: ['deck, patio']
# ------------------------------------------------------------
# Seeds: ['pick', 'channel', 'local', 'live', 'signal', 'station', 'abl', 'pick', 'recept', 'citi']
# Predicted aspect: ['pick, channel']
# ------------------------------------------------------------
# Seeds: ['instal', 'wall', 'inch', 'hung', 'mount', 'sturdi', 'articul', 'hardwar', 'motion', 'vizio']
# Predicted aspect: ['instal,']
# ------------------------------------------------------------
# Seeds: ['dac', 'pono', 'listen', 'fiio', 'amp', 'hi', 'audio', 'iem', 'hi', 'res']
# Predicted aspect: ['dac,']
# ------------------------------------------------------------
# Seeds: ['usb', 'outlet', 'adapt', 'travel', 'prong', 'usb', 'port', 'port', 'hotel', 'strip']
# Predicted aspect: ['usb, outlet']
# ------------------------------------------------------------
# Seeds: ['voic', 'record', 'mini', 'usb', 'usb', 'micro', 'sd', 'nano', 'button', 'wheel']
# Predicted aspect: ['voic,']
# ------------------------------------------------------------
# Seeds: ['wast', 'money', 'wast', 'money', 'worth', 'money', 'save', 'money', 'spend', 'money']
# Predicted aspect: ['wast,']
# ------------------------------------------------------------
# Seeds: ['adverti', 'earlier', 'exact', 'describ', 'condit', 'descript', 'promi', 'manner', 'sooner', 'right']
# Predicted aspect: ['adverti,']
# ------------------------------------------------------------
# Seeds: ['asid', 'bottom', 'line', 'reflect', 'hope', 'help', 'huge', 'deal', 'www', 'amazon']
# Predicted aspect: ['asid,']
# ------------------------------------------------------------
# Seeds: ['daughter', 'son', 'school', 'trip', 'wife', 'colleg', 'dad', 'brought', 'vacat', 'mom']
# Predicted aspect: ['daughter, son']
# ------------------------------------------------------------
# Seeds: ['volum', 'button', 'anker', 'play', 'clear', 'hour', 'box', 'loud', 'control', 'design']
# Predicted aspect: ['volum,']
# ------------------------------------------------------------
# Seeds: ['discharg', 'aaa', 'charger', 'recharg', 'volt', 'aa', 'mah', 'capac', 'apc', 'voltag']
# Predicted aspect: ['discharg,']
# ------------------------------------------------------------
# Seeds: ['stay', 'fall', 'hurt', 'stay', 'place', 'wear', 'stay', 'put', 'bud', 'uncomfort']
# Predicted aspect: ['stay, fall']
# ------------------------------------------------------------
# Seeds: ['switch', 'disc', 'unit', 'dvd', 'box', 'error', 'softwar', 'issu', 'remot', 'turn']
# Predicted aspect: ['switch, disc']
# ------------------------------------------------------------
# Seeds: ['suction', 'suction', 'cup', 'shower', 'water', 'loud', 'water', 'resist', 'bathroom', 'splash']
# Predicted aspect: ['suction,']
# ------------------------------------------------------------
# Seeds: ['bulb', 'lamp', 'new', 'origin', 'oem', 'smell', 'brand', 'pictur', 'color', 'bright']
# Predicted aspect: ['bulb,']
# ------------------------------------------------------------
# Seeds: ['comfort', 'control', 'headset', 'cord', 'earbud', 'run', 'wear', 'button', 'volum', 'hear']
# Predicted aspect: ['comfort, control']
# ------------------------------------------------------------
# Seeds: ['best', 'ever', 'penni', 'worth', 'everi', 'everi', 'penni', 'ever', 'far', 'best']
# Predicted aspect: ['best, ever']
# ------------------------------------------------------------
# Seeds: ['connector', 'gaug', 'length', 'wire', 'solder', 'femal', 'flexibl', 'gaug', 'wire', 'cord']
# Predicted aspect: ['connector,']
# ------------------------------------------------------------
# Seeds: ['macbook', 'dvd', 'player', 'mac', 'older', 'convert', 'macbook', 'pro', 'laptop', 'monitor']
# Predicted aspect: ['macbook,']
# ------------------------------------------------------------
# Seeds: ['antenna', 'channel', 'signal', 'instal', 'roof', 'attic', 'put', 'mount', 'antenna', 'wall']
# Predicted aspect: ['antenna,']
# ------------------------------------------------------------
# Seeds: ['amazon', 'custom', 'support', 'warranti', 'custom', 'return', 'email', 'sent', 'servic', 'contact']
# Predicted aspect: ['amazon, custom']
# ------------------------------------------------------------
# Seeds: ['hear', 'movi', 'noi', 'aid', 'plane', 'flight', 'watch', 'hear', 'aid', 'block']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Seeds: ['bose', 'beat', 'noi', 'cancel', 'noi', 'cancel', 'earbud', 'comfort', 'amaz', 'plane']
# Predicted aspect: ['bose,']
# ------------------------------------------------------------
# Seeds: ['case', 'sleev', 'zipper', 'cover', 'clean', 'dvd', 'dvds', 'collect', 'zip', 'page']
# Predicted aspect: ['case, sle']
# ------------------------------------------------------------
# Seeds: ['pad', 'foam', 'comfort', 'earpad', 'plastic', 'feel', 'bit', 'tip', 'stock', 'pad']
# Predicted aspect: ['pad, foam']
# ------------------------------------------------------------
# Seeds: ['screw', 'wall', 'mount', 'screen', 'hole', 'put', 'hold', 'tighten', 'drill', 'made']
# Predicted aspect: ['screw,']
# ------------------------------------------------------------
# Seeds: ['remot', 'remot', 'control', 'key', 'program', 'button', 'misplac', 'light', 'origin', 'dig']
# Predicted aspect: ['remot,']
# ------------------------------------------------------------
# Seeds: ['ok', 'wish', 'static', 'tooth', 'volum', 'control', 'blue', 'tooth', 'louder', 'random']
# Predicted aspect: ['ok, wish']
# ------------------------------------------------------------
# Seeds: ['asid', 'www', 'www', 'amazon', 'meant', 'keep', 'mind', 'due', 'fact', 'huge']
# Predicted aspect: ['asid,']
# ------------------------------------------------------------
# Seeds: ['fast', 'deliv', 'faster', 'quick', 'deliveri', 'ship', 'fast', 'ship', 'shipment', 'prompt']
# Predicted aspect: ['fast, del']
# ------------------------------------------------------------
# Seeds: ['cd', 'player', 'cd', 'play', 'folder', 'player', 'song', 'album', 'record', 'cassett']
# Predicted aspect: ['cd, player']
# ------------------------------------------------------------
# Seeds: ['broke', 'within', 'stop', 'left', 'side', 'week', 'broken', 'coupl', 'week', 'within']
# Predicted aspect: ['broke,']
# ------------------------------------------------------------
# Seeds: ['swim', 'lap', 'underwat', 'earbud', 'run', 'waterproof', 'bud', 'stay', 'sweat', 'water']
# Predicted aspect: ['swim,']
# ------------------------------------------------------------
# Seeds: ['control', 'remot', 'system', 'harmoni', 'audio', 'ir', 'app', 'turn', 'sono', 'switch']
# Predicted aspect: ['control, rem']
# ------------------------------------------------------------
# Seeds: ['gold', 'plate', 'connector', 'hdmi', 'gold', 'audio', 'adapt', 'port', 'male', 'splitter']
# Predicted aspect: ['gold, plate']
# ------------------------------------------------------------
# Seeds: ['radio', 'station', 'clock', 'radio', 'station', 'clock', 'radio', 'fm', 'wake', 'emerg']
# Predicted aspect: ['radio, station']
# ------------------------------------------------------------
# Seeds: ['thank', 'seller', 'satisfi', 'servic', 'thank', 'amazon', 'custom', 'servic', 'plea', 'happi']
# Predicted aspect: ['thank, seller']
# ------------------------------------------------------------
# Seeds: ['system', 'sub', 'subwoof', 'room', 'polk', 'bose', 'amp', 'unit', 'woofer', 'watt']
# Predicted aspect: ['system, sub']
# ------------------------------------------------------------

# %%
in_ids.unsqueeze(0).shape
# Out:
# torch.Size([1, 26])

# %%
#         """Return sample from dataset at index i."""
#         example = self.list_data[i]
#         shuffle(example['seeds'])
#         sampled_seeds = example['seeds'][:self.seeds_length]
#         aspect = " ".join(example["aspect"].split('_'))
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            truncation=True)  
#         outputs = tokenizer(aspect, 
#                             padding="max_length", 
#                             truncation=True, 
#                             max_length=self.aspect_length)
        
#         batch = {}
#         batch["input_ids"] = torch.LongTensor(inputs.input_ids)
#         batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["labels"] = outputs.input_ids.copy()
#         batch['labels'] = [batch['labels']]

#         batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
#                            for labels in batch["labels"]]
#         batch["labels"] = torch.LongTensor(batch["labels"])
#         batch["labels"] = batch["labels"].squeeze(0)
        
#         return batch

# %%
# chk_1 =tokenizer('MaterialsComp', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_1['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_2 =tokenizer('Ease of use', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_2['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_ = tokenizer('Compartments', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=4)

# %%
# tokenizer.batch_decode(chk_['input_ids'], 
#                        skip_special_tokens=True, 
#                        clean_up_tokenization_spaces=False)

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
electronic_topics = [x[:20] for x in electronic_topics]

# %%
test_data = []
for each_e_top in electronic_topics:
    test_data.append({'seeds': each_e_top[:20], 'aspect':'TestSet'})

# %%
test_dataset = aspectDataset(list_data=test_data, 
                              tokenizer=tokenizer)

# %%
test_loader = DataLoader(test_dataset, 
                         batch_size=1, 
                         shuffle=True,
                         num_workers=1)

# %%
model.eval()
for ind, batch in enumerate(test_loader):
    batch = {k: v.to('cuda') for k, v in batch.items()}
    model_op = model(**batch)
    print('---'*20)
    print('ID:', ind)
    print('---'*20)
    print('Seed words:', tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    print('Actual aspect:', tokenizer.batch_decode(batch['decoder_input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
    print('Predicted aspect:', tokenizer.batch_decode(output_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True))

# %% [raw]
# 1. Sample 5-10 for each aspect. Get top 50 and then sample 10 each. done
# 2. Start from the bart-large and not cnn. done
# 3. Use very small learning rate (2e-5)| 1e-6 or 5e-7. done
# 4. Put a comma with the words. done
# 5. Stem the training data words. done
#
#
# Run it on our topics.
# -

# %%
model_op['logits'].squeeze(dim=0).shape

# %%
torch.argmax(model_op['logits'].squeeze(dim=0), dim=1)

# %% [markdown]
# ## Orphan Code
# -------------

# %%
print(another_way_to_train)
for epoch in range(num_epochs):
    training_loss = 0.0
    model.train()
    for batch in tqdm(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        # Get the "input's representation"
        encoder_output = the_encoder(input_ids = batch['input_ids'],
                                   attention_mask = batch['attention_mask'])
      
        # Pass the representation + the target summary to the decoder
        decoder_output = the_decoder(input_ids=batch['decoder_input_ids'],
                                   attention_mask=batch['decoder_attention_mask'],
                                   encoder_hidden_states=encoder_output[0],
                                   encoder_attention_mask=batch['attention_mask'])

        # Use the last linear layer to predict the next token
        decoder_output = decoder_output.last_hidden_state
        lm_head_output = last_linear_layer(decoder_output)
        
        # Compute the loss
        loss = loss_fct(lm_head_output.view(-1, model.config.vocab_size),
                      batch['labels'].view(-1))
        training_loss += loss.item()
        
        loss.backward() # Update the weights
        optimizer.step() # Notify optimizer that a batch is done.
        lr_scheduler.step() # Notify the scheduler that a ...
        optimizer.zero_grad() # Reset the optimer
    training_loss = training_loss / len( train_data )
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))

# %%
lm_head_output.view(-1, model.config.vocab_size)
