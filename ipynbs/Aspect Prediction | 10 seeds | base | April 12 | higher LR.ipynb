# %%
import torch
import random
import pandas as pd
import pickle as pkl
from tqdm import tqdm
from os import listdir
from os.path import join
from random import shuffle
from transformers import AdamW
from matplotlib import pyplot as plt
from torch.nn import CrossEntropyLoss
from transformers import get_scheduler
from pdb import set_trace as breakpoint
from nltk.stem.snowball import SnowballStemmer
from torch.utils.data import Dataset, DataLoader
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
# %matplotlib inline

# %%
# folders = ['bags_and_cases', 'bluetooth', 'boots', 'keyboards', 'tv', 'vacuums']

# base_dir = '/mnt/nfs/work1/hongyu/brawat/amzn/oposum/data/seeds'

# list_aspects = []
# Aspect_to_seeds = {}
# stemmer = SnowballStemmer(language='english')
# for each_folder in folders:
#     folder_dir = join(base_dir, each_folder)
#     print('--'*20)
#     print(each_folder)
#     print('--'*20)
#     txt_files = listdir(folder_dir)
#     txt_files = [x for x in txt_files if 'None' not in x]
#     print(txt_files)
#     for each_txt in txt_files:
#         txt_dir = join(folder_dir, each_txt)
#         txt = open(txt_dir).read()
#         txt = txt.split('\n')
#         txt = [x.split(' ')[-1] for x in txt]
#         txt = [x.strip() for x in txt]
#         txt = [stemmer.stem(x) for x in txt]
#         aspect = each_txt.split('.')[1]
#         Aspect_to_seeds[aspect] = txt

# %%
# for each_aspect in Aspect_to_seeds:
#     print(each_aspect, Aspect_to_seeds[each_aspect].__len__())

# %%
# pkl.dump(Aspect_to_seeds, open('Aspect_to_seeds_march19.pkl', 'wb'))

# %%
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))

# %%
for each_aspect in Aspect_to_seeds:
    Aspect_to_seeds[each_aspect] = [x for x in Aspect_to_seeds[each_aspect] if x.__len__()>0]

# %%
Aspect_to_seeds
# Out:
# {'Compartments': ['pocket',
#   'cabl',
#   'compart',
#   'outsid',
#   'lot',
#   'wish',
#   'wallet',
#   'connector',
#   'space',
#   'power',
#   'pen',
#   'folder',
#   'charger',
#   'flap',
#   'mous',
#   'nice',
#   'thing',
#   'insid',
#   'small',
#   'paperwork',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'construct',
#   'medium',
#   'player',
#   'wire',
#   'run',
#   'headphon',
#   'key',
#   'instead',
#   'huge',
#   'need',
#   'open',
#   'fit',
#   'headset',
#   'outer',
#   'planner',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'cellphon',
#   'save',
#   'document'],
#  'Price': ['price',
#   'money',
#   'feaur',
#   'paid',
#   'spin',
#   'spun',
#   'mayb',
#   'cheap',
#   '200',
#   'spend',
#   'right',
#   'vaccum',
#   'twice',
#   'expect',
#   'pricey',
#   '50',
#   'expens',
#   'worth',
#   'far',
#   'wast',
#   'duster',
#   'think',
#   'bagless',
#   'best',
#   'dyson',
#   'need',
#   'ok',
#   'weight',
#   'bag',
#   'power',
#   'light',
#   'like',
#   'good',
#   'vacuum'],
#  'Handles': ['strap',
#   'handl',
#   'shoulder',
#   'broke',
#   'later',
#   'month',
#   'hand',
#   'comfort',
#   'plastic',
#   'wear',
#   'tear',
#   'rip',
#   'start',
#   'attach',
#   'holiday',
#   'left',
#   'lift',
#   'final',
#   'broken',
#   'stand',
#   'inevit',
#   'situat',
#   'firm',
#   'bend',
#   'hurt',
#   'minut',
#   'addit',
#   'note',
#   'buckl',
#   'adjust',
#   'adjust',
#   'short',
#   'shorter',
#   'length',
#   'adjust',
#   'long',
#   'metal',
#   'swivel',
#   'sooner',
#   'break',
#   'felt',
#   'rip',
#   'loop',
#   'hook',
#   'torn',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'use'],
#  'Customer_service': ['paid',
#   'support',
#   'servic',
#   'week',
#   'replac',
#   'mail',
#   'wait',
#   'pay',
#   'ship',
#   '1500',
#   'bring',
#   'deliveri',
#   'come',
#   'use',
#   'peopl',
#   'speak',
#   'technician',
#   'refurbish',
#   'handl',
#   'shore',
#   'communic',
#   'difficult',
#   '49',
#   'diagnost',
#   'fee',
#   '100',
#   'fix',
#   'latest',
#   'divx',
#   'arriv',
#   'undamag',
#   'po',
#   'mention',
#   'desk',
#   'help',
#   'suppos',
#   'later',
#   'cancel',
#   'reschedul',
#   'entir',
#   'glove',
#   'pilot',
#   'deliv',
#   'fact',
#   'clear',
#   'requir',
#   '100lb',
#   'carri',
#   'downstair',
#   'check'],
#  'Looks': ['look',
#   'slim',
#   'origin',
#   'appear',
#   'lttle',
#   'attract',
#   'beauti',
#   'size',
#   'small',
#   'decent',
#   'imac',
#   'backlit',
#   'longer',
#   'pc',
#   'like',
#   'laptop',
#   'nice',
#   'great',
#   'cheap',
#   'keyboard',
#   'good',
#   'feel'],
#  'Quality': ['qualiti',
#   'materi',
#   'handl',
#   'poor',
#   'broke',
#   'durabl',
#   'month',
#   'later',
#   'wear',
#   'tear',
#   'zipper',
#   'chemic',
#   'start',
#   'excel',
#   'terribl',
#   'crack',
#   'strap',
#   'daili',
#   'plastic',
#   'pull',
#   'smell',
#   'edg',
#   'rip',
#   'white',
#   'item',
#   'year',
#   'go',
#   'feel',
#   'attach',
#   'brake',
#   'holiday',
#   'outstand',
#   'strip',
#   'peel',
#   'left',
#   'final',
#   'broken',
#   'stand',
#   'sacrific',
#   'durabl',
#   'style',
#   'cours',
#   'trip',
#   'asia',
#   'rip',
#   'construct',
#   'cancer',
#   'birth',
#   'defect',
#   'reproduct'],
#  'Protection': ['protect',
#   'pad',
#   'protect',
#   'protect',
#   'drop',
#   'lap',
#   'insid',
#   'comput',
#   'laptop',
#   'good',
#   'let',
#   'secur',
#   'damag',
#   'intern',
#   'weak',
#   'tast',
#   'trust',
#   'protect',
#   'construct',
#   'provid',
#   'second',
#   'protect',
#   'count',
#   'sort',
#   'happen',
#   'cushion',
#   'adequ',
#   'thing',
#   'pencil',
#   'heavi',
#   'normal',
#   'kensington',
#   'probabl',
#   'larg',
#   'like',
#   'way',
#   'stylish',
#   'far',
#   'sleev',
#   'pad',
#   'feel',
#   'realli',
#   'perfect',
#   'bit',
#   'littl',
#   'bag',
#   'macbook',
#   'love',
#   'use'],
#  'Size_Fit': ['fit',
#   'size',
#   'macbook',
#   'big',
#   'space',
#   'air',
#   'slight',
#   'lot',
#   'bulk',
#   'perfect',
#   'inch',
#   'laptop',
#   'perfect',
#   '13',
#   'cabl',
#   'folder',
#   'notebook',
#   'sure',
#   'snug',
#   'bit',
#   'te',
#   'seat',
#   'airplan',
#   'fre',
#   'cell',
#   'pouch',
#   'tight',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'enorm',
#   '17inch',
#   'bare',
#   'm1710',
#   'hp',
#   'pavilion',
#   'dv7',
#   '3080us',
#   'disappoint',
#   'cloth',
#   'whatnot',
#   'spacious',
#   'book',
#   'load',
#   'accommod'],
#  'Ease_of_use': ['easi',
#   'cord',
#   'push',
#   'corner',
#   'vacuum',
#   'pile',
#   'maneuv',
#   'nozzl',
#   'awkward',
#   'crevic',
#   'constant',
#   'bog',
#   'imposs',
#   'short',
#   'carpet',
#   'heavi',
#   'roller',
#   'hose',
#   'difficult',
#   'wall',
#   'suck',
#   'remov',
#   'empti',
#   'power',
#   'hard',
#   'jump',
#   'simpic',
#   'automat',
#   'retractor',
#   'retract',
#   'flash',
#   'baseboard',
#   'retract',
#   'easier',
#   'snap',
#   'disassembl',
#   'direct',
#   'propel',
#   'person',
#   'race',
#   'furnitur',
#   'flexibl',
#   'kink',
#   'prefer',
#   'cannist',
#   'car',
#   'refriger',
#   'move',
#   'eas',
#   'worst'],
#  'Sound': ['sound',
#   'speaker',
#   'good',
#   'qualiti',
#   'loud',
#   'tinni',
#   'bass',
#   'hear',
#   'horribl',
#   'trebl',
#   'chang',
#   'realli',
#   'great',
#   'terribl',
#   'bar',
#   'display',
#   'thing',
#   'eye',
#   'ear',
#   'loudest',
#   'volum',
#   'strain',
#   'quieter',
#   'dinner',
#   'lack',
#   'sort',
#   'improv',
#   'surround',
#   'true',
#   'experi',
#   'junki',
#   'mind',
#   'vibrat',
#   'develop',
#   'pitch',
#   'whine',
#   'strong',
#   'track',
#   'cool',
#   'worthi',
#   'shippabl',
#   'adjust',
#   'weird',
#   'kinda',
#   'improv',
#   'cheapest',
#   'laptop',
#   'watt',
#   'muffl',
#   'margin'],
#  'Look': ['cute',
#   'look',
#   'look',
#   'great',
#   'fring',
#   'style',
#   'color',
#   'love',
#   'design',
#   'go',
#   'unattract',
#   'attract',
#   'offic',
#   'environ',
#   'pictur',
#   '360',
#   'degre',
#   'vent',
#   'concept',
#   'coverag',
#   'airi',
#   'hang',
#   'unattract',
#   'durabl',
#   'nice',
#   'casual',
#   'beauti',
#   'moccasin',
#   'shame',
#   'taup',
#   'direct',
#   'smooth',
#   'laid',
#   'rest',
#   'natur',
#   'calm',
#   'absolut',
#   'ador',
#   'pictur',
#   'grey',
#   'wonder',
#   'stylish',
#   'comfort',
#   'boot',
#   'good',
#   'collaps',
#   'super',
#   'crazi',
#   'light',
#   'weight'],
#  'Connectivity': ['hdmi',
#   'port',
#   'comput',
#   'input',
#   'compon',
#   'usb',
#   'internet',
#   'connect',
#   'output',
#   'server',
#   'connect',
#   'audio',
#   'play',
#   'stop',
#   'standard',
#   'avi',
#   'like',
#   'hd',
#   'file',
#   'movi',
#   'work',
#   'digit',
#   'monitor',
#   'comcast',
#   'connect',
#   'drive',
#   'end',
#   'cabl',
#   'watch',
#   'netflix',
#   'flash',
#   '45',
#   'min',
#   'rf',
#   'vga',
#   'cycl',
#   'signal',
#   'higher',
#   'slot',
#   'integr',
#   'wi',
#   'fi',
#   'stream',
#   'speed',
#   'conflict',
#   'dhcp',
#   'hard',
#   'dlna',
#   'enabl',
#   'power'],
#  'Battery': ['batteri',
#   'charg',
#   'life',
#   'charger',
#   'charg',
#   'tone',
#   'longer',
#   'low',
#   'hour',
#   'power',
#   'light',
#   'color',
#   'red',
#   'respond',
#   'merit',
#   'vari',
#   'recharg',
#   'bizarr',
#   'later',
#   'sudden',
#   'dead',
#   'meter',
#   'hold',
#   'thing',
#   'half',
#   'green',
#   'stop',
#   'nokia',
#   'turn',
#   'start',
#   'blackberri',
#   'star',
#   'phone',
#   'good',
#   'day',
#   'cell',
#   'come',
#   'talk',
#   'get',
#   'simpl',
#   'pretti',
#   'love',
#   'better',
#   'easili',
#   'volum',
#   'nois',
#   'time',
#   'work'],
#  'Durability': ['rubber',
#   'qualiti',
#   'use',
#   'buckl',
#   'appear',
#   'heel',
#   'long',
#   'time',
#   'break',
#   'enjoy',
#   'provid',
#   'protect',
#   'clear',
#   'cheapli',
#   'thinner',
#   'barn',
#   'month',
#   'start',
#   'tear',
#   'constant',
#   'fold',
#   'gone',
#   'numer',
#   'decor',
#   'come',
#   'sturdi',
#   'sure',
#   'durabl',
#   'decent',
#   'cheep',
#   'deflat',
#   'daili',
#   'wear',
#   'collaps',
#   'super',
#   'need',
#   'sol',
#   'red',
#   'obvious',
#   'differ',
#   'think',
#   'worn',
#   'abl',
#   'materi',
#   'actual',
#   'pretti',
#   'heavi',
#   'true',
#   'style',
#   'support'],
#  'Comfort': ['comfort',
#   'fit',
#   'foot',
#   'hurt',
#   'ankl',
#   'comfi',
#   'blister',
#   'comfort',
#   'break',
#   'wear',
#   'abl',
#   'extrem',
#   'walk',
#   'sock',
#   'longer',
#   'pain',
#   'perfect',
#   'super',
#   'uncomfort',
#   'light',
#   'weight',
#   'discomfort',
#   'snug',
#   'put',
#   'slide',
#   'sued',
#   'feel',
#   'littl',
#   'time',
#   'narrow',
#   'toe',
#   'minut',
#   'summer',
#   'insid',
#   'short',
#   'long',
#   'wear',
#   'perfect',
#   'list',
#   'doc',
#   'tongu',
#   'moment',
#   'break',
#   'enjoy',
#   'plus',
#   'actual',
#   'loos',
#   'attract',
#   'offic',
#   'environ'],
#  'Materials': ['leather',
#   'insid',
#   'fring',
#   'materi',
#   'heel',
#   'cheaper',
#   'soft',
#   'sole',
#   'buckl',
#   'sued',
#   'true',
#   'rubber',
#   'advertis',
#   'fact',
#   'cloth',
#   'back',
#   'synthet',
#   'finish',
#   'aerosol',
#   'line',
#   'aw',
#   'memori',
#   'foam',
#   'thinner',
#   'barn',
#   'decor',
#   'come',
#   'hang',
#   'unattract',
#   'fashion',
#   'porous',
#   'term',
#   'best',
#   'describ',
#   'let',
#   'penetr',
#   'piec',
#   'elast',
#   'zipper',
#   'friction',
#   'easili',
#   'improv',
#   'fleec',
#   'especi',
#   'superb',
#   'direct',
#   'smooth',
#   'natur',
#   'calm',
#   'hollow'],
#  'Color': ['color',
#   'love',
#   'style',
#   'unbeliev',
#   'gorgeous',
#   'blue',
#   'favorit',
#   'taup',
#   'wonder',
#   'red',
#   'exact',
#   'design',
#   'purchas',
#   'love',
#   'materi',
#   'look',
#   'perfect',
#   'look',
#   'boot'],
#  'Size': ['size',
#   'order',
#   'half',
#   'order',
#   'big',
#   'littl',
#   'bigger',
#   'usual',
#   'narrow',
#   'normal',
#   'width',
#   'true',
#   'run',
#   'small',
#   'size',
#   'larger',
#   'perfect',
#   'fit',
#   'sent',
#   'ankl',
#   'wide',
#   'tight',
#   'baggi',
#   'wise',
#   'tuck',
#   'pant',
#   'follow',
#   'advic',
#   'buyer',
#   'bacaus',
#   'possibl',
#   'joint',
#   'especi',
#   'superb',
#   'beauti',
#   'moccasin',
#   'shame',
#   'sould',
#   'larg',
#   'awar',
#   'length',
#   'tab',
#   'decid',
#   'normal',
#   'option',
#   'shorter',
#   'left',
#   'mayb',
#   'wear',
#   'calf'],
#  'Weather_resistance': ['dri',
#   'waterproof',
#   'rain',
#   'wet',
#   'water',
#   'foot',
#   'soak',
#   'snow',
#   'cold',
#   'puddl',
#   'warm',
#   'got',
#   'chicago',
#   'protect',
#   'suppos',
#   'defect',
#   'item',
#   'traction',
#   'raini',
#   'interest',
#   'ice',
#   'spent',
#   'cub',
#   'scout',
#   'den',
#   'alcatraz',
#   'island',
#   'san',
#   'francisco',
#   'lot',
#   'claim',
#   'stori',
#   'resist',
#   'generous',
#   'porous',
#   'term',
#   'dewi',
#   'grass',
#   'leav',
#   'soak',
#   'let',
#   'penetr',
#   'perform',
#   'repel',
#   'sandal',
#   'stay',
#   'amaz',
#   'outsid',
#   'step',
#   'deep'],
#  'Noise': ['quiet',
#   'noisi',
#   'loud',
#   'power',
#   'nois',
#   'louder',
#   'ear',
#   'loudest',
#   'light',
#   'incred',
#   'deafen',
#   'serious',
#   'actual',
#   'ring',
#   'doggi',
#   'hide',
#   'flee',
#   'powerstick',
#   'earplug',
#   'lose',
#   'bearabl',
#   'block',
#   'pro',
#   'fair',
#   'reason',
#   'direct',
#   'mous',
#   'explod',
#   'silent',
#   'compar',
#   'stylish',
#   'function',
#   'weight',
#   'peopl',
#   'ring',
#   'motor',
#   'awesom',
#   'nozzl',
#   'readi',
#   'sound',
#   'devil',
#   'purchas',
#   'quit',
#   'size',
#   'upright',
#   'star',
#   'heavi',
#   'lightweight',
#   'recommend',
#   'turn'],
#  'Extra_functionality': ['button',
#   'light',
#   'pencil',
#   'volum',
#   'power',
#   'featur',
#   'bright',
#   'mute',
#   'handi',
#   'low',
#   'dark',
#   'blue',
#   'wake',
#   'sleep',
#   'pen',
#   'nice',
#   'quit',
#   'shortcut',
#   'internet',
#   'spillproof',
#   'interest',
#   'vista',
#   'capabl',
#   'support',
#   'shut',
#   'keypress',
#   'pre',
#   'program',
#   'calcul',
#   'mycomput',
#   'custom',
#   'email',
#   'brower',
#   'activ',
#   'music',
#   'special',
#   'disk',
#   'eject',
#   'hold',
#   'remain',
#   'recess',
#   'clutch',
#   'multimedia',
#   'label',
#   'illumin',
#   'programm',
#   'legibl',
#   'dark',
#   'dim',
#   'backlight'],
#  'Layout': ['key',
#   'delet',
#   'backspac',
#   'size',
#   'layout',
#   'end',
#   'insert',
#   'home',
#   'bar',
#   'perfect',
#   'space',
#   'cluster',
#   'squish',
#   'space',
#   'close',
#   'small',
#   'volum',
#   'tini',
#   'place',
#   'arrow',
#   'littl',
#   'tricki',
#   'bigger',
#   'million',
#   'print',
#   'scroll',
#   'paus',
#   'quick',
#   'navig',
#   'difficult',
#   'suppos',
#   'spill',
#   'proof',
#   '104',
#   'negat',
#   'overs',
#   'awkward',
#   'place',
#   'vertic',
#   'horizont',
#   'multimedia',
#   'label',
#   'wider',
#   'impecc',
#   'activ',
#   'chang',
#   'requir',
#   'movement',
#   'wide',
#   'strike'],
#  'Feel_Comfort': ['feel',
#   'comfort',
#   'mushi',
#   'key',
#   'like',
#   'keyboard',
#   'good',
#   'perfect',
#   'press',
#   'wrist',
#   'action',
#   'shallow',
#   'smooth',
#   'finger',
#   'relax',
#   'type',
#   'level',
#   'keystrok',
#   'sit',
#   'type',
#   'quick',
#   'navig',
#   'difficult',
#   'shop',
#   'consist',
#   'respond',
#   'pressur',
#   'sens',
#   'deceler',
#   'quick',
#   'mush',
#   'tap',
#   'regist',
#   'usual',
#   'chicklet',
#   'membran',
#   'stick',
#   'satisfi',
#   'clicki',
#   'ibm',
#   'dissatisfi',
#   'natur',
#   'tension',
#   'impecc',
#   'stylish',
#   'recogn',
#   'signatur',
#   'butteri',
#   'velvet',
#   'feather'],
#  'Build_Quality': ['belt',
#   'broke',
#   'turn',
#   'work',
#   'burn',
#   'electr',
#   'built',
#   'stop',
#   'month',
#   'roller',
#   'time',
#   'minut',
#   'problem',
#   'brush',
#   'design',
#   'easili',
#   'wise',
#   'continu',
#   'break',
#   'fifth',
#   'barley',
#   'bump',
#   '20',
#   'last',
#   'connect',
#   'swivel',
#   'portion',
#   'fail',
#   'constuct',
#   'electron',
#   'construct',
#   'simpli',
#   'quit',
#   'burnt',
#   'miss',
#   'smell',
#   'overheat',
#   'shut',
#   'poor',
#   'attach',
#   'pop',
#   'unannounc',
#   'snapper',
#   'flimsi',
#   'overh',
#   'upper',
#   'run',
#   'turn',
#   'prepar',
#   'sturdi'],
#  'Size_Look': ['size',
#   'big',
#   'bigger',
#   '40',
#   'differ',
#   'screen',
#   'room',
#   'light',
#   '3d',
#   'livingroom',
#   'hardwar',
#   'slim',
#   'cubbyhol',
#   'huge',
#   'weigh',
#   'awkward',
#   'pentil',
#   'matrix',
#   '60',
#   'foot',
#   '65',
#   'consid',
#   'oh',
#   'lightweight',
#   'compact',
#   'suitabl',
#   'live',
#   'ultra',
#   'weigh',
#   'le',
#   'pound',
#   'hindsight',
#   'wonder',
#   'feel',
#   'anticip',
#   'actual',
#   'bedroom',
#   'fit',
#   'perfect',
#   'love',
#   'smaller',
#   'store',
#   'averag',
#   'inch',
#   'view',
#   '32',
#   'perfect',
#   'home',
#   'easili',
#   'get'],
#  'Image': ['pictur',
#   'color',
#   'qualiti',
#   'black',
#   'bright',
#   'nice',
#   'clear',
#   'look',
#   'excel',
#   'crisp',
#   'screen',
#   'right',
#   'dead',
#   'pixel',
#   'trace',
#   'beauti',
#   'vibrant',
#   'sharp',
#   'angl',
#   'display',
#   'dvd',
#   'differ',
#   'corner',
#   'fantast',
#   'hd',
#   'overal',
#   'inch',
#   'imag',
#   'view',
#   'white',
#   'great',
#   'ok',
#   'red',
#   'decent',
#   'struck',
#   'eye',
#   'ear',
#   'definit',
#   'fuzzi',
#   'font',
#   'improv',
#   'expeci',
#   'hubbi',
#   'sleep',
#   'caus',
#   'biggest',
#   'level',
#   'notic',
#   'irrit',
#   'affect'],
#  'Apps_Interface': ['netflix',
#   'user',
#   'file',
#   'hulu',
#   'app',
#   'watch',
#   'flash',
#   'internet',
#   'smart',
#   'video',
#   'stream',
#   'speed',
#   'youtub',
#   'access',
#   'lack',
#   'smart',
#   'download',
#   'brows',
#   'eas',
#   'interfac',
#   'friend',
#   'access',
#   'work',
#   'capabl',
#   'alright',
#   'quit',
#   'mean',
#   'let',
#   'hub',
#   'applic',
#   'terribl',
#   'watch',
#   'plus',
#   'easili',
#   'buy',
#   'week',
#   'right',
#   'featur',
#   'movi',
#   'comput',
#   'cabl',
#   'best',
#   'samsung',
#   'time',
#   'realli',
#   'like',
#   'better'],
#  'Suction_Power': ['suction',
#   'pick',
#   'power',
#   'power',
#   'good',
#   'hair',
#   'carpet',
#   'suck',
#   'quiet',
#   'realli',
#   'perform',
#   'dirt',
#   'tile',
#   'ok',
#   'job',
#   'floor',
#   'perfom',
#   'total',
#   'angl',
#   'attribut',
#   'machin',
#   'main',
#   'simpic',
#   'weak',
#   'object',
#   'bear',
#   'spot',
#   'vacuum',
#   'dosen',
#   'produc',
#   'fault',
#   'unders',
#   'pretti',
#   'essenti',
#   'spin',
#   'spun',
#   'mayb',
#   'pro',
#   'fair',
#   'reason',
#   'loo',
#   'filter',
#   'superb',
#   'grout',
#   'ergorapido',
#   'leav',
#   'plush',
#   'grind',
#   'stylish',
#   'function'],
#  'Weight': ['light',
#   'weight',
#   'lightweight',
#   'heavi',
#   'size',
#   'compact',
#   'maneuv',
#   'guess',
#   'quiet',
#   'quit',
#   'probabl',
#   'cumbersom',
#   'feaur',
#   'reason',
#   'histori',
#   'minor',
#   'heavier',
#   'consid',
#   'compar',
#   'nice',
#   'larg',
#   'need',
#   'especi',
#   'carri',
#   'drawback',
#   'perform',
#   'past',
#   'suppos',
#   'thought',
#   'power',
#   'loud',
#   'price',
#   'easi',
#   'feel',
#   'hardwood',
#   'push',
#   'store',
#   'panason',
#   'vacuum',
#   'bagless',
#   'area',
#   'ok',
#   'purchas',
#   'vaccuum',
#   'small',
#   'hard',
#   'littl',
#   'short',
#   'rug',
#   'canist'],
#  'Customer_Service': ['servic',
#   'contact',
#   'help',
#   'custom',
#   'took',
#   'email',
#   'miel',
#   'hoover',
#   'dealer',
#   'horribl',
#   'multipl',
#   'respond',
#   'chose',
#   'repres',
#   'told',
#   'smell',
#   'lubric',
#   'dissip',
#   'wait',
#   'spent',
#   'hour',
#   'phone',
#   'depart',
#   'contact',
#   'busi',
#   'regist',
#   'late',
#   'gotten',
#   'card',
#   'mail',
#   'ignor',
#   'look',
#   'common',
#   'recent',
#   'respons',
#   'unfortun',
#   'video',
#   'warranti',
#   'useless',
#   'self',
#   'fall',
#   'day',
#   'amazon',
#   'issu',
#   'absolut',
#   'time',
#   'purchas',
#   'problem'],
#  'Accessories': ['filter',
#   'brush',
#   'attach',
#   'roll',
#   'turbo',
#   'easili',
#   'expens',
#   'wide',
#   'turn',
#   'bag',
#   'replac',
#   'typic',
#   'hepa',
#   'cover',
#   'extens',
#   'wonder',
#   'crevic',
#   'reach',
#   'requir',
#   'clean',
#   'duster',
#   'hose',
#   'clean',
#   'way',
#   'noisi',
#   'corner',
#   'hardwood',
#   'empti',
#   'get',
#   'convent',
#   'brushrol',
#   'extra',
#   'rotat',
#   'block',
#   'bag',
#   'scrap',
#   'okay',
#   'basic',
#   'eye',
#   'regular',
#   'sensor',
#   'green',
#   'complet',
#   'instead',
#   'allow',
#   'need',
#   'spinner',
#   'fact',
#   'cup',
#   'onboard']}

# %%
for each_aspect in Aspect_to_seeds:
    print(each_aspect, Aspect_to_seeds[each_aspect].__len__())
# Out:
# Compartments 50
# Price 34
# Handles 50
# Customer_service 50
# Looks 22
# Quality 50
# Protection 49
# Size_Fit 50
# Ease_of_use 50
# Sound 50
# Look 50
# Connectivity 50
# Battery 48
# Durability 50
# Comfort 50
# Materials 50
# Color 19
# Size 50
# Weather_resistance 50
# Noise 50
# Extra_functionality 50
# Layout 50
# Feel_Comfort 50
# Build_Quality 50
# Size_Look 50
# Image 50
# Apps_Interface 47
# Suction_Power 50
# Weight 50
# Customer_Service 48
# Accessories 50

# %%
# tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")

# %%
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")
# model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# %%
# !echo $CUDA_VISIBLE_DEVICES

# %%
model_args = {'seed_samples': 10, 
              'aspect_length':6
             }

# %%
class aspectDataset(Dataset):
    
    def __init__(self, list_data, tokenizer, model_args):
        self.tokenizer = tokenizer
        self.list_data = list_data
        self.seeds_length = model_args['seed_samples']
        self.aspect_length = model_args['aspect_length']
    
    def __len__(self):
        """Return length of dataset."""
        return self.list_data.__len__()

    def __getitem__(self, i):
        """Return sample from dataset at index i."""
        example = self.list_data[i]
        shuffle(example['seeds'])
        sampled_seeds = example['seeds'][:self.seeds_length]
        aspect = " ".join(example["aspect"].split('_'))
#         max_length = self.seeds_length+2
        inputs = tokenizer(", ".join(sampled_seeds), 
                           truncation=True)  
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            padding="max_length", 
#                            truncation=True, 
#                            max_length=max_length)  
        outputs = tokenizer(aspect, 
                            padding="max_length", 
                            truncation=True, 
                            max_length=self.aspect_length)
        
        batch = {}
        batch["input_ids"] = torch.LongTensor(inputs.input_ids)
        batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["decoder_input_ids"] = torch.LongTensor(outputs.input_ids)
#         batch["decoder_attention_mask"] = torch.LongTensor(outputs.attention_mask)
        batch["labels"] = outputs.input_ids.copy()
        batch['labels'] = [batch['labels']]

        # We have to make sure that the PAD token is ignored for calculating the loss
        batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
                           for labels in batch["labels"]]
        batch["labels"] = torch.LongTensor(batch["labels"])
        batch["labels"] = batch["labels"].squeeze(0)
        
        return batch

# %%
train_data = []
for each_key in Aspect_to_seeds:
    train_data.append({"seeds":Aspect_to_seeds[each_key],
                       "aspect":each_key})

# %%
train_dataset = aspectDataset(list_data=train_data, 
                              tokenizer=tokenizer,
                              model_args=model_args
                             )

# %%
train_loader = DataLoader(train_dataset, 
                          batch_size=1, 
                          shuffle=True,
                          num_workers=1)

# %%
model = model.to("cuda")

# %%
# the_encoder = model.get_encoder()
# the_decoder = model.get_decoder()
# last_linear_layer = model.lm_head

# %%
num_epochs = 15
num_training_steps = num_epochs * len(train_data)

loss_fct = CrossEntropyLoss()

optimizer = AdamW(model.parameters(), 
                  lr=2e-5)
warmup_steps = int(0.10*num_training_steps)
lr_scheduler = get_scheduler("linear",
                            optimizer=optimizer,
                            num_warmup_steps=warmup_steps,
                            num_training_steps=num_training_steps
                            )

# %%
all_train_loss = []
for epoch in tqdm(range(num_epochs)):
    training_loss = 0.0
    model.train()
    for ind, batch in enumerate(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        model_op = model(**batch)
        loss = model_op['loss']
        
        training_loss += loss.item()
        
        print('---'*20)
        print('Epoch:', epoch, 'ID:', ind)
        print('---'*20)
        print('Seed words:', tokenizer.batch_decode(batch['input_ids'], 
                                                    skip_special_tokens=True, 
                                                    clean_up_tokenization_spaces=False))
        print('Actual aspect:', tokenizer.batch_decode(batch['labels'][batch['labels']!=-100].unsqueeze(0), 
                                                       skip_special_tokens=True, 
                                                       clean_up_tokenization_spaces=True))
        output_ids = model.generate(batch["input_ids"], 
                                    num_beams=3, 
                                    max_length=6)
        print('Predicted aspect:', tokenizer.batch_decode(output_ids, 
                                                          skip_special_tokens=True, 
                                                          clean_up_tokenization_spaces=True))
        
        loss.backward()
        optimizer.step() 
        lr_scheduler.step() 
        optimizer.zero_grad() 
    training_loss = training_loss / len( train_data )
    all_train_loss.append(training_loss)
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ------------------------------------------------------------
# Epoch: 0 ID: 0
# ------------------------------------------------------------
# Seed words: ['love, live, lightweight, big, matrix, averag, view, suitabl, perfect, le']
# Actual aspect: ['Size Look']
# Predicted aspect: ['love, live']
# ------------------------------------------------------------
# Epoch: 0 ID: 1
# ------------------------------------------------------------
# Seed words: ['latest, downstair, fix, support, mention, ship, 100lb, undamag, check, shore']
# Actual aspect: ['Customer service']
# Predicted aspect: ['latest, down']
# ------------------------------------------------------------
# Epoch: 0 ID: 2
# ------------------------------------------------------------
# Seed words: ['pavilion, earphon, perfect, whatnot, raincoat, cell, sure, jacket, hp, reduct']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['pavilion']
# ------------------------------------------------------------
# Epoch: 0 ID: 3
# ------------------------------------------------------------
# Seed words: ['broken, note, final, torn, loop, lift, plastic, use, break, strap']
# Actual aspect: ['Handles']
# Predicted aspect: ['broken,']
# ------------------------------------------------------------
# Epoch: 0 ID: 4
# ------------------------------------------------------------
# Seed words: ['vacuum, light, feaur, 200, right, mayb, bagless, far, price, think']
# Actual aspect: ['Price']
# Predicted aspect: ['vacuum']
# ------------------------------------------------------------
# Epoch: 0 ID: 5
# ------------------------------------------------------------
# Seed words: ['fold, qualiti, obvious, provid, barn, decor, rubber, worn, need, collaps']
# Actual aspect: ['Durability']
# Predicted aspect: ['fold, qual']
# ------------------------------------------------------------
# Epoch: 0 ID: 6
# ------------------------------------------------------------
# Seed words: ['laptop, size, attract, lttle, decent, great, backlit, cheap, feel, appear']
# Actual aspect: ['Looks']
# Predicted aspect: ['laptop,']
# ------------------------------------------------------------
# Epoch: 0 ID: 7
# ------------------------------------------------------------
# Seed words: ['wear, wise, length, shorter, fit, decid, order, width, littl, order']
# Actual aspect: ['Size']
# Predicted aspect: ['wear, wise']
# ------------------------------------------------------------
# Epoch: 0 ID: 8
# ------------------------------------------------------------
# Seed words: ['lack, interfac, brows, let, realli, applic, movi, user, youtub, time']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['lack,']
# ------------------------------------------------------------
# Epoch: 0 ID: 9
# ------------------------------------------------------------
# Seed words: ['stream, slot, comcast, end, connect, connect, speed, power, higher, hd']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['stream, slot']
# ------------------------------------------------------------
# Epoch: 0 ID: 10
# ------------------------------------------------------------
# Seed words: ['ignor, amazon, smell, wait, recent, contact, email, custom, dealer, chose']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['ignor,']
# ------------------------------------------------------------
# Epoch: 0 ID: 11
# ------------------------------------------------------------
# Seed words: ['love, taup, favorit, purchas, look, gorgeous, boot, perfect, materi, unbeliev']
# Actual aspect: ['Color']
# Predicted aspect: ['love, t']
# ------------------------------------------------------------
# Epoch: 0 ID: 12
# ------------------------------------------------------------
# Seed words: ['hd, overal, clear, level, irrit, improv, ok, qualiti, definit, font']
# Actual aspect: ['Image']
# Predicted aspect: ['hd, over']
# ------------------------------------------------------------
# Epoch: 0 ID: 13
# ------------------------------------------------------------
# Seed words: ['compar, histori, price, heavier, loud, feaur, cumbersom, quiet, maneuv, hardwood']
# Actual aspect: ['Weight']
# Predicted aspect: ['compar,']
# ------------------------------------------------------------
# Epoch: 0 ID: 14
# ------------------------------------------------------------
# Seed words: ['kinda, muffl, true, develop, tinni, worthi, weird, speaker, trebl, dinner']
# Actual aspect: ['Sound']
# Predicted aspect: ['kinda,']
# ------------------------------------------------------------
# Epoch: 0 ID: 15
# ------------------------------------------------------------
# Seed words: ['hang, natur, smooth, sole, elast, piec, best, soft, rubber, friction']
# Actual aspect: ['Materials']
# Predicted aspect: ['hang, n']
# ------------------------------------------------------------
# Epoch: 0 ID: 16
# ------------------------------------------------------------
# Seed words: ['cub, repel, ice, scout, den, san, puddl, outsid, francisco, traction']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['C']
# ------------------------------------------------------------
# Epoch: 0 ID: 17
# ------------------------------------------------------------
# Seed words: ['super, color, attract, love, calm, hang, concept, 360, environ, crazi']
# Actual aspect: ['Look']
# Predicted aspect: ['Super']
# ------------------------------------------------------------
# Epoch: 0 ID: 18
# ------------------------------------------------------------
# Seed words: ['wish, daytim, safe, wallet, remot, adapt, small, power, fit, charger']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Wish']
# ------------------------------------------------------------
# Epoch: 0 ID: 19
# ------------------------------------------------------------
# Seed words: ['arrow, size, insert, quick, place, activ, key, 104, wide, littl']
# Actual aspect: ['Layout']
# Predicted aspect: ['App']
# ------------------------------------------------------------
# Epoch: 0 ID: 20
# ------------------------------------------------------------
# Seed words: ['good, count, weak, sort, lap, protect, sleev, construct, heavi, protect']
# Actual aspect: ['Protection']
# Predicted aspect: ['Slit']
# ------------------------------------------------------------
# Epoch: 0 ID: 21
# ------------------------------------------------------------
# Seed words: ['reach, requir, green, basic, extra, complet, hepa, allow, okay, attach']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Fit']
# ------------------------------------------------------------
# Epoch: 0 ID: 22
# ------------------------------------------------------------
# Seed words: ['job, fair, perfom, vacuum, function, mayb, filter, fault, essenti, leav']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Job']
# ------------------------------------------------------------
# Epoch: 0 ID: 23
# ------------------------------------------------------------
# Seed words: ['edg, peel, zipper, asia, plastic, durabl, stand, reproduct, item, rip']
# Actual aspect: ['Quality']
# Predicted aspect: ['Rep']
# ------------------------------------------------------------
# Epoch: 0 ID: 24
# ------------------------------------------------------------
# Seed words: ['automat, kink, prefer, cord, bog, suck, flexibl, easi, baseboard, retractor']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 0 ID: 25
# ------------------------------------------------------------
# Seed words: ['music, shortcut, keypress, disk, button, low, hold, bright, power, recess']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Music']
# ------------------------------------------------------------
# Epoch: 0 ID: 26
# ------------------------------------------------------------
# Seed words: ['sock, longer, loos, list, pain, super, moment, extrem, doc, perfect']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Flexible']
# ------------------------------------------------------------
# Epoch: 0 ID: 27
# ------------------------------------------------------------
# Seed words: ['upper, smell, bump, flimsi, electr, overheat, continu, easili, miss, connect']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Epoch: 0 ID: 28
# ------------------------------------------------------------
# Seed words: ['quick, tap, mush, like, good, velvet, shop, feel, regist, keystrok']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Fit']
# ------------------------------------------------------------
# Epoch: 0 ID: 29
# ------------------------------------------------------------
# Seed words: ['quit, doggi, devil, recommend, purchas, sound, ring, readi, flee, turn']
# Actual aspect: ['Noise']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Epoch: 0 ID: 30
# ------------------------------------------------------------
# Seed words: ['respond, blackberri, day, longer, green, merit, work, nois, get, good']
# Actual aspect: ['Battery']
# Predicted aspect: ['Work']
#   7%|▋         | 1/15 [00:12<02:49, 12.12s/it]
# Epoch 1:	Training Loss 5.07
# ------------------------------------------------------------
# Epoch: 1 ID: 0
# ------------------------------------------------------------
# Seed words: ['munchi, bulk, jacket, accessori, 3080us, cabl, book, seat, nois, folder']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 1 ID: 1
# ------------------------------------------------------------
# Seed words: ['recent, fall, dealer, busi, look, help, video, dissip, spent, unfortun']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Productivity']
# ------------------------------------------------------------
# Epoch: 1 ID: 2
# ------------------------------------------------------------
# Seed words: ['headphon, player, wallet, raincoat, headset, save, cabl, charger, power, connector']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 1 ID: 3
# ------------------------------------------------------------
# Seed words: ['purchas, boot, materi, exact, love, blue, color, style, gorgeous, red']
# Actual aspect: ['Color']
# Predicted aspect: ['AccessSize']
# ------------------------------------------------------------
# Epoch: 1 ID: 4
# ------------------------------------------------------------
# Seed words: ['start, rip, break, long, loop, hurt, shoulder, torn, broke, safe']
# Actual aspect: ['Handles']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 5
# ------------------------------------------------------------
# Seed words: ['dead, star, nois, merit, start, green, get, work, turn, volum']
# Actual aspect: ['Battery']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 6
# ------------------------------------------------------------
# Seed words: ['rf, speed, watch, digit, integr, compon, enabl, signal, avi, hd']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 1 ID: 7
# ------------------------------------------------------------
# Seed words: ['snug, list, extrem, insid, environ, summer, foot, break, sued, short']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Safety']
# ------------------------------------------------------------
# Epoch: 1 ID: 8
# ------------------------------------------------------------
# Seed words: ['vibrant, right, nice, dvd, eye, differ, struck, overal, level, sharp']
# Actual aspect: ['Image']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 9
# ------------------------------------------------------------
# Seed words: ['super, nice, absolut, degre, pictur, crazi, great, comfort, love, environ']
# Actual aspect: ['Look']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 10
# ------------------------------------------------------------
# Seed words: ['francisco, stori, waterproof, step, puddl, dri, island, let, porous, alcatraz']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Storage']
# ------------------------------------------------------------
# Epoch: 1 ID: 11
# ------------------------------------------------------------
# Seed words: ['beauti, lttle, decent, look, like, appear, attract, great, longer, nice']
# Actual aspect: ['Looks']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 12
# ------------------------------------------------------------
# Seed words: ['clear, provid, cheapli, materi, daili, heel, think, obvious, thinner, sure']
# Actual aspect: ['Durability']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 1 ID: 13
# ------------------------------------------------------------
# Seed words: ['low, remain, dark, internet, support, nice, wake, program, email, calcul']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Epoch: 1 ID: 14
# ------------------------------------------------------------
# Seed words: ['like, expens, spend, pricey, think, bag, right, far, power, price']
# Actual aspect: ['Price']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 1 ID: 15
# ------------------------------------------------------------
# Seed words: ['finger, comfort, keyboard, press, sit, regist, velvet, like, recogn, usual']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 16
# ------------------------------------------------------------
# Seed words: ['insid, intern, love, littl, count, protect, sleev, bag, protect, tast']
# Actual aspect: ['Protection']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 17
# ------------------------------------------------------------
# Seed words: ['snap, short, worst, cannist, heavi, kink, awkward, disassembl, flexibl, constant']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 1 ID: 18
# ------------------------------------------------------------
# Seed words: ['size, fair, ring, nois, deafen, incred, loudest, light, recommend, louder']
# Actual aspect: ['Noise']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 19
# ------------------------------------------------------------
# Seed words: ['speaker, chang, sound, sort, strain, whine, shippabl, qualiti, margin, true']
# Actual aspect: ['Sound']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 20
# ------------------------------------------------------------
# Seed words: ['time, smart, interfac, speed, flash, buy, realli, access, app, applic']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 1 ID: 21
# ------------------------------------------------------------
# Seed words: ['normal, tab, moccasin, size, tight, fit, bigger, shame, tuck, left']
# Actual aspect: ['Size']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 22
# ------------------------------------------------------------
# Seed words: ['green, roll, okay, regular, onboard, rotat, way, hardwood, bag, clean']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 23
# ------------------------------------------------------------
# Seed words: ['movement, impecc, spill, delet, tricki, arrow, littl, paus, size, strike']
# Actual aspect: ['Layout']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 24
# ------------------------------------------------------------
# Seed words: ['fact, paid, 49, undamag, carri, desk, 100, mail, check, deliveri']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 25
# ------------------------------------------------------------
# Seed words: ['heel, penetr, line, superb, decor, sued, porous, especi, piec, unattract']
# Actual aspect: ['Materials']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 26
# ------------------------------------------------------------
# Seed words: ['easili, snapper, time, roller, prepar, electr, minut, broke, built, 20']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 27
# ------------------------------------------------------------
# Seed words: ['zipper, left, peel, feel, asia, item, chemic, month, edg, start']
# Actual aspect: ['Quality']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 28
# ------------------------------------------------------------
# Seed words: ['total, job, machin, pretti, ok, stylish, filter, power, attribut, power']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 1 ID: 29
# ------------------------------------------------------------
# Seed words: ['consid, fit, actual, le, slim, compact, home, hindsight, wonder, smaller']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size Comfort']
# ------------------------------------------------------------
# Epoch: 1 ID: 30
# ------------------------------------------------------------
# Seed words: ['vacuum, small, need, probabl, purchas, compar, compact, store, feaur, minor']
# Actual aspect: ['Weight']
# Predicted aspect: ['Size']
#  13%|█▎        | 2/15 [00:22<02:25, 11.17s/it]
# Epoch 2:	Training Loss 2.45
# ------------------------------------------------------------
# Epoch: 2 ID: 0
# ------------------------------------------------------------
# Seed words: ['lose, nois, louder, ear, silent, loud, awesom, noisi, peopl, power']
# Actual aspect: ['Noise']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 2 ID: 1
# ------------------------------------------------------------
# Seed words: ['sole, decor, describ, zipper, let, materi, piec, direct, porous, soft']
# Actual aspect: ['Materials']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 2 ID: 2
# ------------------------------------------------------------
# Seed words: ['cours, construct, cancer, year, rip, broken, month, durabl, sacrific, final']
# Actual aspect: ['Quality']
# Predicted aspect: ['Durability']
# ------------------------------------------------------------
# Epoch: 2 ID: 3
# ------------------------------------------------------------
# Seed words: ['use, mail, week, shore, 1500, entir, downstair, speak, fee, desk']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 2 ID: 4
# ------------------------------------------------------------
# Seed words: ['fre, te, 13, big, accessori, perfect, bare, lot, cloth, seat']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 2 ID: 5
# ------------------------------------------------------------
# Seed words: ['cellphon, outsid, connector, key, instead, need, planner, pocket, power, outer']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 2 ID: 6
# ------------------------------------------------------------
# Seed words: ['ibm, membran, difficult, quick, relax, butteri, shallow, shop, feather, feel']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Epoch: 2 ID: 7
# ------------------------------------------------------------
# Seed words: ['qualiti, font, decent, inch, crisp, level, angl, caus, color, clear']
# Actual aspect: ['Image']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Epoch: 2 ID: 8
# ------------------------------------------------------------
# Seed words: ['gorgeous, favorit, unbeliev, boot, wonder, purchas, exact, look, blue, design']
# Actual aspect: ['Color']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Epoch: 2 ID: 9
# ------------------------------------------------------------
# Seed words: ['wear, sent, normal, size, length, true, normal, pant, shame, littl']
# Actual aspect: ['Size']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 2 ID: 10
# ------------------------------------------------------------
# Seed words: ['bright, volum, disk, pre, mycomput, remain, support, vista, quit, wake']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Epoch: 2 ID: 11
# ------------------------------------------------------------
# Seed words: ['wear, abl, doc, feel, wear, time, list, moment, hurt, summer']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 2 ID: 12
# ------------------------------------------------------------
# Seed words: ['digit, watch, play, connect, flash, stream, vga, signal, monitor, drive']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 2 ID: 13
# ------------------------------------------------------------
# Seed words: ['item, warm, traction, repel, stori, interest, step, outsid, perform, wet']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 2 ID: 14
# ------------------------------------------------------------
# Seed words: ['comfort, remot, safe, loop, tear, stand, swivel, metal, shoulder, attach']
# Actual aspect: ['Handles']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 2 ID: 15
# ------------------------------------------------------------
# Seed words: ['cheapli, break, start, time, enjoy, durabl, tear, appear, thinner, decent']
# Actual aspect: ['Durability']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 2 ID: 16
# ------------------------------------------------------------
# Seed words: ['cheap, 200, expect, like, vacuum, spin, spend, worth, need, paid']
# Actual aspect: ['Price']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Epoch: 2 ID: 17
# ------------------------------------------------------------
# Seed words: ['nokia, light, respond, charg, better, time, come, hold, later, thing']
# Actual aspect: ['Battery']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 2 ID: 18
# ------------------------------------------------------------
# Seed words: ['hepa, sensor, clean, green, easili, wide, replac, brush, crevic, get']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Epoch: 2 ID: 19
# ------------------------------------------------------------
# Seed words: ['thing, experi, strain, muffl, terribl, track, strong, cool, sort, horribl']
# Actual aspect: ['Sound']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 2 ID: 20
# ------------------------------------------------------------
# Seed words: ['multimedia, scroll, quick, suppos, activ, key, chang, space, littl, negat']
# Actual aspect: ['Layout']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 2 ID: 21
# ------------------------------------------------------------
# Seed words: ['wonder, boot, comfort, nice, airi, collaps, pictur, design, style, moccasin']
# Actual aspect: ['Look']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 2 ID: 22
# ------------------------------------------------------------
# Seed words: ['work, upper, unannounc, shut, time, prepar, 20, break, attach, simpli']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 2 ID: 23
# ------------------------------------------------------------
# Seed words: ['look, origin, nice, laptop, beauti, great, imac, small, feel, slim']
# Actual aspect: ['Looks']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Epoch: 2 ID: 24
# ------------------------------------------------------------
# Seed words: ['light, bigger, differ, oh, foot, home, easili, bedroom, weigh, love']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 2 ID: 25
# ------------------------------------------------------------
# Seed words: ['like, insid, provid, protect, feel, far, construct, pad, happen, heavi']
# Actual aspect: ['Protection']
# Predicted aspect: ['Build']
# ------------------------------------------------------------
# Epoch: 2 ID: 26
# ------------------------------------------------------------
# Seed words: ['eas, retract, imposs, worst, race, hard, jump, cord, carpet, baseboard']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 2 ID: 27
# ------------------------------------------------------------
# Seed words: ['horribl, purchas, amazon, absolut, mail, wait, video, servic, chose, regist']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 2 ID: 28
# ------------------------------------------------------------
# Seed words: ['bear, loo, spun, filter, dirt, pro, vacuum, pick, simpic, good']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 2 ID: 29
# ------------------------------------------------------------
# Seed words: ['video, netflix, stream, file, samsung, eas, applic, mean, quit, internet']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 2 ID: 30
# ------------------------------------------------------------
# Seed words: ['need, drawback, hard, hardwood, minor, histori, past, compact, carri, nice']
# Actual aspect: ['Weight']
# Predicted aspect: ['Connectivity']
#  20%|██        | 3/15 [00:32<02:08, 10.72s/it]
# Epoch 3:	Training Loss 2.02
# ------------------------------------------------------------
# Epoch: 3 ID: 0
# ------------------------------------------------------------
# Seed words: ['safe, adapt, wish, document, wallet, space, jacket, medium, lot, control']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 3 ID: 1
# ------------------------------------------------------------
# Seed words: ['mous, earplug, readi, doggi, weight, loudest, motor, flee, pro, fair']
# Actual aspect: ['Noise']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Epoch: 3 ID: 2
# ------------------------------------------------------------
# Seed words: ['let, speed, best, easili, friend, internet, capabl, watch, quit, user']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Apps']
# ------------------------------------------------------------
# Epoch: 3 ID: 3
# ------------------------------------------------------------
# Seed words: ['laptop, look, feel, slim, pc, great, longer, like, beauti, origin']
# Actual aspect: ['Looks']
# Predicted aspect: ['Look']
# ------------------------------------------------------------
# Epoch: 3 ID: 4
# ------------------------------------------------------------
# Seed words: ['light, wear, toe, slide, perfect, abl, loos, pain, wear, littl']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 3 ID: 5
# ------------------------------------------------------------
# Seed words: ['glove, entir, 100, po, downstair, pay, refurbish, reschedul, 49, carri']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Epoch: 3 ID: 6
# ------------------------------------------------------------
# Seed words: ['soak, term, generous, suppos, island, sandal, amaz, raini, san, rain']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 3 ID: 7
# ------------------------------------------------------------
# Seed words: ['peel, durabl, construct, attach, poor, rip, materi, reproduct, item, asia']
# Actual aspect: ['Quality']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Epoch: 3 ID: 8
# ------------------------------------------------------------
# Seed words: ['strong, terribl, realli, mind, great, worthi, cheapest, whine, loudest, cool']
# Actual aspect: ['Sound']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Epoch: 3 ID: 9
# ------------------------------------------------------------
# Seed words: ['star, come, meter, red, tone, nois, turn, bizarr, phone, charg']
# Actual aspect: ['Battery']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 3 ID: 10
# ------------------------------------------------------------
# Seed words: ['chang, awkward, home, 104, space, movement, negat, paus, activ, quick']
# Actual aspect: ['Layout']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 3 ID: 11
# ------------------------------------------------------------
# Seed words: ['hindsight, suitabl, huge, fit, 65, home, bedroom, averag, anticip, light']
# Actual aspect: ['Size Look']
# Predicted aspect: ['CompCompartments']
# ------------------------------------------------------------
# Epoch: 3 ID: 12
# ------------------------------------------------------------
# Seed words: ['style, gone, qualiti, materi, red, pretti, abl, come, break, worn']
# Actual aspect: ['Durability']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 3 ID: 13
# ------------------------------------------------------------
# Seed words: ['difficult, dissatisfi, usual, quick, relax, sit, key, clicki, pressur, action']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# Epoch: 3 ID: 14
# ------------------------------------------------------------
# Seed words: ['unbeliev, materi, boot, look, love, love, design, color, blue, gorgeous']
# Actual aspect: ['Color']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# Epoch: 3 ID: 15
# ------------------------------------------------------------
# Seed words: ['connect, audio, fi, connect, integr, signal, cycl, play, power, vga']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 3 ID: 16
# ------------------------------------------------------------
# Seed words: ['power, hard, carpet, retractor, hose, flash, furnitur, crevic, move, short']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 3 ID: 17
# ------------------------------------------------------------
# Seed words: ['hook, metal, firm, safe, final, plastic, shorter, hand, attach, long']
# Actual aspect: ['Handles']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 3 ID: 18
# ------------------------------------------------------------
# Seed words: ['slight, cabl, te, lot, sure, snug, pouch, 13, book, munchi']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 3 ID: 19
# ------------------------------------------------------------
# Seed words: ['feaur, canist, probabl, weight, short, suppos, nice, small, compact, power']
# Actual aspect: ['Weight']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 3 ID: 20
# ------------------------------------------------------------
# Seed words: ['eye, decent, black, font, hd, dead, definit, white, overal, pictur']
# Actual aspect: ['Image']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Epoch: 3 ID: 21
# ------------------------------------------------------------
# Seed words: ['natur, memori, porous, fring, describ, back, heel, materi, cloth, direct']
# Actual aspect: ['Materials']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 3 ID: 22
# ------------------------------------------------------------
# Seed words: ['upper, run, broke, easili, smell, prepar, electron, pop, sturdi, barley']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 3 ID: 23
# ------------------------------------------------------------
# Seed words: ['button, capabl, shortcut, support, blue, power, custom, dim, sleep, pen']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 3 ID: 24
# ------------------------------------------------------------
# Seed words: ['function, grind, perfom, filter, pick, suck, perform, superb, ok, bear']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 3 ID: 25
# ------------------------------------------------------------
# Seed words: ['hose, get, expens, spinner, cup, okay, reach, onboard, clean, need']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Size Look']
# ------------------------------------------------------------
# Epoch: 3 ID: 26
# ------------------------------------------------------------
# Seed words: ['mayb, expens, dyson, vacuum, twice, power, far, bagless, wast, expect']
# Actual aspect: ['Price']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 3 ID: 27
# ------------------------------------------------------------
# Seed words: ['360, degre, concept, casual, beauti, moccasin, environ, unattract, weight, look']
# Actual aspect: ['Look']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 3 ID: 28
# ------------------------------------------------------------
# Seed words: ['joint, wear, narrow, ankl, superb, width, larg, size, order, size']
# Actual aspect: ['Size']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 3 ID: 29
# ------------------------------------------------------------
# Seed words: ['common, recent, lubric, purchas, problem, wait, issu, phone, late, told']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 3 ID: 30
# ------------------------------------------------------------
# Seed words: ['protect, protect, intern, let, realli, lap, larg, pad, protect, tast']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection']
#  27%|██▋       | 4/15 [00:42<01:55, 10.50s/it]
# Epoch 4:	Training Loss 1.51
# ------------------------------------------------------------
# Epoch: 4 ID: 0
# ------------------------------------------------------------
# Seed words: ['connect, comput, play, dlna, compon, netflix, conflict, wi, usb, integr']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Epoch: 4 ID: 1
# ------------------------------------------------------------
# Seed words: ['thing, document, wish, planner, remot, cellphon, compart, outer, pocket, jacket']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 4 ID: 2
# ------------------------------------------------------------
# Seed words: ['dewi, got, foot, waterproof, term, repel, island, deep, scout, wet']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# Epoch: 4 ID: 3
# ------------------------------------------------------------
# Seed words: ['fit, view, home, hardwar, size, smaller, pound, awkward, perfect, love']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 4 ID: 4
# ------------------------------------------------------------
# Seed words: ['sharp, hubbi, vibrant, angl, black, qualiti, ok, trace, caus, imag']
# Actual aspect: ['Image']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 4 ID: 5
# ------------------------------------------------------------
# Seed words: ['sensor, block, complet, basic, bag, duster, clean, allow, reach, attach']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 4 ID: 6
# ------------------------------------------------------------
# Seed words: ['tinni, watt, shippabl, sound, good, surround, develop, thing, eye, cool']
# Actual aspect: ['Sound']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 4 ID: 7
# ------------------------------------------------------------
# Seed words: ['cell, light, volum, longer, pretti, turn, vari, bizarr, get, time']
# Actual aspect: ['Battery']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 4 ID: 8
# ------------------------------------------------------------
# Seed words: ['spot, quiet, object, superb, attribut, bear, produc, simpic, machin, hair']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# Epoch: 4 ID: 9
# ------------------------------------------------------------
# Seed words: ['unattract, advertis, fring, fleec, sued, sole, materi, direct, line, synthet']
# Actual aspect: ['Materials']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 4 ID: 10
# ------------------------------------------------------------
# Seed words: ['pretti, rubber, sure, daili, break, deflat, come, heel, think, month']
# Actual aspect: ['Durability']
# Predicted aspect: ['Durability']
# ------------------------------------------------------------
# Epoch: 4 ID: 11
# ------------------------------------------------------------
# Seed words: ['probabl, pad, good, littl, count, protect, let, bag, kensington, trust']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# Epoch: 4 ID: 12
# ------------------------------------------------------------
# Seed words: ['fact, speak, downstair, entir, 49, week, peopl, 100, fee, check']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# Epoch: 4 ID: 13
# ------------------------------------------------------------
# Seed words: ['purchas, fall, spent, issu, look, horribl, problem, dissip, day, regist']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['WeatherWeather']
# ------------------------------------------------------------
# Epoch: 4 ID: 14
# ------------------------------------------------------------
# Seed words: ['spacious, big, space, lot, notebook, bulk, slight, dv7, reduct, snug']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 4 ID: 15
# ------------------------------------------------------------
# Seed words: ['place, strike, horizont, awkward, littl, vertic, proof, spill, bigger, backspac']
# Actual aspect: ['Layout']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# Epoch: 4 ID: 16
# ------------------------------------------------------------
# Seed words: ['snug, perfect, blister, weight, attract, longer, environ, light, break, time']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 4 ID: 17
# ------------------------------------------------------------
# Seed words: ['minut, month, hand, holiday, bend, torn, final, adjust, sooner, shoulder']
# Actual aspect: ['Handles']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 4 ID: 18
# ------------------------------------------------------------
# Seed words: ['vent, super, style, pictur, wonder, degre, comfort, ador, concept, good']
# Actual aspect: ['Look']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Epoch: 4 ID: 19
# ------------------------------------------------------------
# Seed words: ['decent, look, lttle, attract, like, good, cheap, appear, imac, keyboard']
# Actual aspect: ['Looks']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 4 ID: 20
# ------------------------------------------------------------
# Seed words: ['canist, especi, bagless, vacuum, quiet, larg, power, cumbersom, consid, lightweight']
# Actual aspect: ['Weight']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 4 ID: 21
# ------------------------------------------------------------
# Seed words: ['time, work, minut, built, wise, portion, roller, burnt, turn, turn']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Epoch: 4 ID: 22
# ------------------------------------------------------------
# Seed words: ['item, defect, start, year, construct, attach, final, reproduct, outstand, crack']
# Actual aspect: ['Quality']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 4 ID: 23
# ------------------------------------------------------------
# Seed words: ['work, better, smart, featur, watch, right, video, user, friend, app']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 4 ID: 24
# ------------------------------------------------------------
# Seed words: ['perfect, possibl, tab, left, especi, tight, awar, true, calf, width']
# Actual aspect: ['Size']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 4 ID: 25
# ------------------------------------------------------------
# Seed words: ['consist, dissatisfi, satisfi, good, difficult, impecc, comfort, regist, keyboard, mushi']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Epoch: 4 ID: 26
# ------------------------------------------------------------
# Seed words: ['purchas, boot, blue, red, look, style, look, perfect, gorgeous, exact']
# Actual aspect: ['Color']
# Predicted aspect: ['Look']
# ------------------------------------------------------------
# Epoch: 4 ID: 27
# ------------------------------------------------------------
# Seed words: ['wake, support, interest, eject, pre, brower, multimedia, volum, dark, dim']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 4 ID: 28
# ------------------------------------------------------------
# Seed words: ['cannist, snap, power, easier, retractor, crevic, flexibl, move, car, suck']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 4 ID: 29
# ------------------------------------------------------------
# Seed words: ['expect, power, spun, money, expens, cheap, twice, weight, far, mayb']
# Actual aspect: ['Price']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 4 ID: 30
# ------------------------------------------------------------
# Seed words: ['light, flee, awesom, nois, star, deafen, powerstick, turn, purchas, hide']
# Actual aspect: ['Noise']
# Predicted aspect: ['Sound']
#  33%|███▎      | 5/15 [00:53<01:45, 10.59s/it]
# Epoch 5:	Training Loss 2.05
# ------------------------------------------------------------
# Epoch: 5 ID: 0
# ------------------------------------------------------------
# Seed words: ['dealer, warranti, card, custom, problem, recent, spent, wait, unfortun, amazon']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 5 ID: 1
# ------------------------------------------------------------
# Seed words: ['requir, suppos, key, close, chang, strike, layout, wider, bar, million']
# Actual aspect: ['Layout']
# Predicted aspect: ['Layout']
# ------------------------------------------------------------
# Epoch: 5 ID: 2
# ------------------------------------------------------------
# Seed words: ['angl, total, floor, good, bear, job, weak, superb, leav, spin']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 5 ID: 3
# ------------------------------------------------------------
# Seed words: ['tone, time, star, half, sudden, life, vari, phone, power, hour']
# Actual aspect: ['Battery']
# Predicted aspect: ['']
# ------------------------------------------------------------
# Epoch: 5 ID: 4
# ------------------------------------------------------------
# Seed words: ['suppos, especi, quit, price, canist, weight, probabl, small, store, heavi']
# Actual aspect: ['Weight']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 5 ID: 5
# ------------------------------------------------------------
# Seed words: ['let, feel, weak, kensington, count, lap, love, secur, laptop, comput']
# Actual aspect: ['Protection']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 5 ID: 6
# ------------------------------------------------------------
# Seed words: ['quick, usual, pressur, sit, tap, satisfi, action, membran, tension, regist']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Layout']
# ------------------------------------------------------------
# Epoch: 5 ID: 7
# ------------------------------------------------------------
# Seed words: ['narrow, sent, length, order, wide, size, superb, fit, usual, half']
# Actual aspect: ['Size']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 5 ID: 8
# ------------------------------------------------------------
# Seed words: ['lack, shippabl, speaker, sound, whine, strain, surround, margin, horribl, dinner']
# Actual aspect: ['Sound']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 5 ID: 9
# ------------------------------------------------------------
# Seed words: ['black, bright, struck, screen, view, imag, notic, caus, definit, excel']
# Actual aspect: ['Image']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# Epoch: 5 ID: 10
# ------------------------------------------------------------
# Seed words: ['adjust, buckl, sooner, final, rip, inevit, plastic, attach, later, tear']
# Actual aspect: ['Handles']
# Predicted aspect: ['Layout']
# ------------------------------------------------------------
# Epoch: 5 ID: 11
# ------------------------------------------------------------
# Seed words: ['appear, pc, beauti, decent, feel, cheap, longer, lttle, great, laptop']
# Actual aspect: ['Looks']
# Predicted aspect: ['Feel']
# ...
# Epoch: 13 ID: 7
# ------------------------------------------------------------
# Seed words: ['feel, 65, actual, slim, home, pentil, perfect, wonder, size, huge']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 13 ID: 8
# ------------------------------------------------------------
# Seed words: ['onboard, need, turn, okay, instead, wide, spinner, requir, filter, sensor']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 13 ID: 9
# ------------------------------------------------------------
# Seed words: ['compart, planner, control, power, cellphon, remot, munchi, jacket, cabl, adapt']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Epoch: 13 ID: 10
# ------------------------------------------------------------
# Seed words: ['20, continu, fail, stop, wise, easili, overheat, month, poor, smell']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 13 ID: 11
# ------------------------------------------------------------
# Seed words: ['easili, hang, finish, piec, come, buckl, fact, let, improv, calm']
# Actual aspect: ['Materials']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Epoch: 13 ID: 12
# ------------------------------------------------------------
# Seed words: ['protect, heavi, obvious, decor, provid, tear, worn, sure, break, super']
# Actual aspect: ['Durability']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# Epoch: 13 ID: 13
# ------------------------------------------------------------
# Seed words: ['reason, machin, job, ok, fair, filter, pick, pretti, carpet, essenti']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Epoch: 13 ID: 14
# ------------------------------------------------------------
# Seed words: ['pictur, display, look, nice, font, overal, definit, angl, fuzzi, crisp']
# Actual aspect: ['Image']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# Epoch: 13 ID: 15
# ------------------------------------------------------------
# Seed words: ['pavilion, enorm, bit, lot, seat, size, perfect, snug, perfect, load']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size Look']
# ------------------------------------------------------------
# Epoch: 13 ID: 16
# ------------------------------------------------------------
# Seed words: ['good, unattract, design, look, color, shame, weight, laid, durabl, degre']
# Actual aspect: ['Look']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 13 ID: 17
# ------------------------------------------------------------
# Seed words: ['light, expens, twice, vaccum, ok, like, paid, 50, duster, pricey']
# Actual aspect: ['Price']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# Epoch: 13 ID: 18
# ------------------------------------------------------------
# Seed words: ['wonder, look, gorgeous, color, exact, design, purchas, style, blue, perfect']
# Actual aspect: ['Color']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Epoch: 13 ID: 19
# ------------------------------------------------------------
# Seed words: ['decid, option, bacaus, true, especi, tab, usual, mayb, advic, tuck']
# Actual aspect: ['Size']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Epoch: 13 ID: 20
# ------------------------------------------------------------
# Seed words: ['deep, outsid, stori, alcatraz, claim, repel, got, wet, penetr, perform']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# Epoch: 13 ID: 21
# ------------------------------------------------------------
# Seed words: ['start, plastic, defect, strap, pull, trip, excel, birth, construct, style']
# Actual aspect: ['Quality']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# Epoch: 13 ID: 22
# ------------------------------------------------------------
# Seed words: ['carri, handl, cancel, pay, divx, wait, 100, downstair, support, suppos']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 13 ID: 23
# ------------------------------------------------------------
# Seed words: ['secur, count, protect, intern, damag, use, love, stylish, kensington, thing']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# Epoch: 13 ID: 24
# ------------------------------------------------------------
# Seed words: ['cheapest, vibrat, dinner, loud, kinda, improv, thing, loudest, cool, sort']
# Actual aspect: ['Sound']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 13 ID: 25
# ------------------------------------------------------------
# Seed words: ['drive, audio, server, 45, watch, usb, connect, wi, higher, min']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Epoch: 13 ID: 26
# ------------------------------------------------------------
# Seed words: ['spill, proof, place, end, perfect, cluster, size, negat, place, arrow']
# Actual aspect: ['Layout']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Epoch: 13 ID: 27
# ------------------------------------------------------------
# Seed words: ['busi, card, gotten, depart, respond, contact, self, time, smell, contact']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Noise']
# ------------------------------------------------------------
# Epoch: 13 ID: 28
# ------------------------------------------------------------
# Seed words: ['list, break, comfort, super, foot, time, abl, wear, moment, sued']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Epoch: 13 ID: 29
# ------------------------------------------------------------
# Seed words: ['clicki, dissatisfi, difficult, finger, smooth, navig, regist, mushi, feather, satisfi']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# Epoch: 13 ID: 30
# ------------------------------------------------------------
# Seed words: ['origin, laptop, small, great, beauti, like, nice, decent, lttle, appear']
# Actual aspect: ['Looks']
# Predicted aspect: ['Size Look']
#  93%|█████████▎| 14/15 [02:26<00:10, 10.25s/it]
# Epoch 14:	Training Loss 0.78
# ------------------------------------------------------------
# Epoch: 14 ID: 0
# ------------------------------------------------------------
# Seed words: ['perfect, proof, scroll, space, horizont, difficult, million, space, place, tini']
# Actual aspect: ['Layout']
# Predicted aspect: ['Size Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 1
# ------------------------------------------------------------
# Seed words: ['360, moccasin, unattract, taup, wonder, look, color, absolut, vent, laid']
# Actual aspect: ['Look']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Epoch: 14 ID: 2
# ------------------------------------------------------------
# Seed words: ['outer, cabl, earphon, thing, flap, remot, adapt, accessori, lot, planner']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# Epoch: 14 ID: 3
# ------------------------------------------------------------
# Seed words: ['respond, smooth, sit, consist, mushi, shop, stylish, signatur, deceler, tap']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 14 ID: 4
# ------------------------------------------------------------
# Seed words: ['adjust, strong, pitch, muffl, sort, trebl, watt, worthi, experi, weird']
# Actual aspect: ['Sound']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 14 ID: 5
# ------------------------------------------------------------
# Seed words: ['access, mean, brows, friend, cabl, easili, buy, alright, youtub, best']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 14 ID: 6
# ------------------------------------------------------------
# Seed words: ['size, raincoat, space, book, hp, load, munchi, fre, te, fit']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 7
# ------------------------------------------------------------
# Seed words: ['shut, program, light, keypress, wake, vista, label, backlight, pre, programm']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# Epoch: 14 ID: 8
# ------------------------------------------------------------
# Seed words: ['love, style, unbeliev, exact, look, red, gorgeous, boot, color, perfect']
# Actual aspect: ['Color']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Epoch: 14 ID: 9
# ------------------------------------------------------------
# Seed words: ['aw, term, rubber, insid, porous, buckl, finish, memori, best, sued']
# Actual aspect: ['Materials']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Epoch: 14 ID: 10
# ------------------------------------------------------------
# Seed words: ['connect, flash, integr, conflict, audio, comput, digit, cabl, speed, hd']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Epoch: 14 ID: 11
# ------------------------------------------------------------
# Seed words: ['day, help, unfortun, amazon, video, late, useless, look, depart, recent']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 14 ID: 12
# ------------------------------------------------------------
# Seed words: ['weigh, easili, inch, livingroom, foot, suitabl, matrix, view, 65, huge']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 14 ID: 13
# ------------------------------------------------------------
# Seed words: ['cancel, check, suppos, divx, desk, pay, reschedul, wait, clear, support']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 14 ID: 14
# ------------------------------------------------------------
# Seed words: ['long, final, adjust, swivel, note, control, holiday, plastic, month, broken']
# Actual aspect: ['Handles']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# Epoch: 14 ID: 15
# ------------------------------------------------------------
# Seed words: ['use, realli, laptop, protect, count, pencil, sleev, protect, protect, larg']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# Epoch: 14 ID: 16
# ------------------------------------------------------------
# Seed words: ['fail, unannounc, barley, flimsi, pop, connect, overheat, construct, design, fifth']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Epoch: 14 ID: 17
# ------------------------------------------------------------
# Seed words: ['littl, enjoy, walk, light, short, actual, attract, blister, environ, ankl']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Extra functionality']
# ------------------------------------------------------------
# Epoch: 14 ID: 18
# ------------------------------------------------------------
# Seed words: ['difficult, jump, person, maneuv, car, kink, retract, move, cord, flash']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# Epoch: 14 ID: 19
# ------------------------------------------------------------
# Seed words: ['hold, better, come, later, cell, recharg, life, thing, charger, bizarr']
# Actual aspect: ['Battery']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Epoch: 14 ID: 20
# ------------------------------------------------------------
# Seed words: ['buckl, break, actual, constant, need, super, rubber, appear, red, differ']
# Actual aspect: ['Durability']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Epoch: 14 ID: 21
# ------------------------------------------------------------
# Seed words: ['mous, awesom, quiet, lose, lightweight, direct, nois, loud, readi, nozzl']
# Actual aspect: ['Noise']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Epoch: 14 ID: 22
# ------------------------------------------------------------
# Seed words: ['protect, porous, amaz, sandal, cub, stay, perform, stori, puddl, step']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Durability']
# ------------------------------------------------------------
# Epoch: 14 ID: 23
# ------------------------------------------------------------
# Seed words: ['bag, brush, corner, spinner, crevic, hose, duster, expens, basic, regular']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 14 ID: 24
# ------------------------------------------------------------
# Seed words: ['later, month, materi, final, durabl, broken, outstand, terribl, cancer, durabl']
# Actual aspect: ['Quality']
# Predicted aspect: ['Durability']
# ------------------------------------------------------------
# Epoch: 14 ID: 25
# ------------------------------------------------------------
# Seed words: ['small, decent, attract, imac, backlit, laptop, longer, cheap, feel, great']
# Actual aspect: ['Looks']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# Epoch: 14 ID: 26
# ------------------------------------------------------------
# Seed words: ['need, lightweight, purchas, quiet, cumbersom, bagless, consid, past, hard, minor']
# Actual aspect: ['Weight']
# Predicted aspect: ['WeightWeight']
# ------------------------------------------------------------
# Epoch: 14 ID: 27
# ------------------------------------------------------------
# Seed words: ['price, ok, wast, 200, best, duster, cheap, good, expens, twice']
# Actual aspect: ['Price']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# Epoch: 14 ID: 28
# ------------------------------------------------------------
# Seed words: ['pretti, pro, suction, machin, weak, perform, ok, leav, mayb, pick']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Epoch: 14 ID: 29
# ------------------------------------------------------------
# Seed words: ['sharp, biggest, screen, sleep, eye, look, qualiti, clear, red, view']
# Actual aspect: ['Image']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# Epoch: 14 ID: 30
# ------------------------------------------------------------
# Seed words: ['joint, larg, normal, perfect, baggi, bigger, half, left, big, buyer']
# Actual aspect: ['Size']
# Predicted aspect: ['Size']
# 100%|██████████| 15/15 [02:36<00:00, 10.46s/it]
# Epoch 15:	Training Loss 0.67

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(all_train_loss, ls='-.', marker = 'X', color='blue')

# %%
stop_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c3998c8be795> in <module>
# ----> 1 stop_
#
# NameError: name 'stop_' is not defined

# %% [markdown]
# ### Generation for the topics of CTM
# --------------------------------------------

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
stemmer = SnowballStemmer(language='english')

# %%
stemmed_electronic_topics = []
for each_topic in electronic_topics:
    tmp_ = [stemmer.stem(x) for x in each_topic]
    stemmed_electronic_topics.append(tmp_)

# %%
model_args['seed_samples']
# Out:
# 10

# %%
model.eval()
for each_topic in stemmed_electronic_topics:
    topic_seeds = each_topic[:model_args['seed_samples']]
    in_tokenized = tokenizer(', '.join(topic_seeds), 
                             truncation=True)  
    in_ids = torch.LongTensor(in_tokenized.input_ids)
    in_ids = in_ids.to('cuda')
    in_ids = in_ids.unsqueeze(0)
    op_ids = model.generate(in_ids, 
                            num_beams=3, 
                            max_length=6)
    print('Seeds:', topic_seeds)
    print('Predicted aspect:', tokenizer.batch_decode(op_ids, 
                                                      skip_special_tokens=True, 
                                                      clean_up_tokenization_spaces=True))
    print('--'*30)
# Out:
# Seeds: ['construct', 'valu', 'exceed', 'outstand', 'light', 'weight', 'attract', 'versatil', 'excel', 'valu']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Seeds: ['deck', 'patio', 'beach', 'loud', 'camp', 'parti', 'hous', 'everywh', 'portabl', 'backyard']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# Seeds: ['pick', 'channel', 'local', 'live', 'signal', 'station', 'abl', 'pick', 'recept', 'citi']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# Seeds: ['instal', 'wall', 'inch', 'hung', 'mount', 'sturdi', 'articul', 'hardwar', 'motion', 'vizio']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Seeds: ['dac', 'pono', 'listen', 'fiio', 'amp', 'hi', 'audio', 'iem', 'hi', 'res']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['usb', 'outlet', 'adapt', 'travel', 'prong', 'usb', 'port', 'port', 'hotel', 'strip']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['voic', 'record', 'mini', 'usb', 'usb', 'micro', 'sd', 'nano', 'button', 'wheel']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# Seeds: ['wast', 'money', 'wast', 'money', 'worth', 'money', 'save', 'money', 'spend', 'money']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# Seeds: ['adverti', 'earlier', 'exact', 'describ', 'condit', 'descript', 'promi', 'manner', 'sooner', 'right']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Seeds: ['asid', 'bottom', 'line', 'reflect', 'hope', 'help', 'huge', 'deal', 'www', 'amazon']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Seeds: ['daughter', 'son', 'school', 'trip', 'wife', 'colleg', 'dad', 'brought', 'vacat', 'mom']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# Seeds: ['volum', 'button', 'anker', 'play', 'clear', 'hour', 'box', 'loud', 'control', 'design']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['discharg', 'aaa', 'charger', 'recharg', 'volt', 'aa', 'mah', 'capac', 'apc', 'voltag']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# Seeds: ['stay', 'fall', 'hurt', 'stay', 'place', 'wear', 'stay', 'put', 'bud', 'uncomfort']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# Seeds: ['switch', 'disc', 'unit', 'dvd', 'box', 'error', 'softwar', 'issu', 'remot', 'turn']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['suction', 'suction', 'cup', 'shower', 'water', 'loud', 'water', 'resist', 'bathroom', 'splash']
# Predicted aspect: ['Water']
# ------------------------------------------------------------
# Seeds: ['bulb', 'lamp', 'new', 'origin', 'oem', 'smell', 'brand', 'pictur', 'color', 'bright']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# Seeds: ['comfort', 'control', 'headset', 'cord', 'earbud', 'run', 'wear', 'button', 'volum', 'hear']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['best', 'ever', 'penni', 'worth', 'everi', 'everi', 'penni', 'ever', 'far', 'best']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# Seeds: ['connector', 'gaug', 'length', 'wire', 'solder', 'femal', 'flexibl', 'gaug', 'wire', 'cord']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['macbook', 'dvd', 'player', 'mac', 'older', 'convert', 'macbook', 'pro', 'laptop', 'monitor']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# Seeds: ['antenna', 'channel', 'signal', 'instal', 'roof', 'attic', 'put', 'mount', 'antenna', 'wall']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['amazon', 'custom', 'support', 'warranti', 'custom', 'return', 'email', 'sent', 'servic', 'contact']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Seeds: ['hear', 'movi', 'noi', 'aid', 'plane', 'flight', 'watch', 'hear', 'aid', 'block']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['bose', 'beat', 'noi', 'cancel', 'noi', 'cancel', 'earbud', 'comfort', 'amaz', 'plane']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['case', 'sleev', 'zipper', 'cover', 'clean', 'dvd', 'dvds', 'collect', 'zip', 'page']
# Predicted aspect: ['Extra functionality']
# ------------------------------------------------------------
# Seeds: ['pad', 'foam', 'comfort', 'earpad', 'plastic', 'feel', 'bit', 'tip', 'stock', 'pad']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# Seeds: ['screw', 'wall', 'mount', 'screen', 'hole', 'put', 'hold', 'tighten', 'drill', 'made']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# Seeds: ['remot', 'remot', 'control', 'key', 'program', 'button', 'misplac', 'light', 'origin', 'dig']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['ok', 'wish', 'static', 'tooth', 'volum', 'control', 'blue', 'tooth', 'louder', 'random']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['asid', 'www', 'www', 'amazon', 'meant', 'keep', 'mind', 'due', 'fact', 'huge']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Seeds: ['fast', 'deliv', 'faster', 'quick', 'deliveri', 'ship', 'fast', 'ship', 'shipment', 'prompt']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Seeds: ['cd', 'player', 'cd', 'play', 'folder', 'player', 'song', 'album', 'record', 'cassett']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Seeds: ['broke', 'within', 'stop', 'left', 'side', 'week', 'broken', 'coupl', 'week', 'within']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Seeds: ['swim', 'lap', 'underwat', 'earbud', 'run', 'waterproof', 'bud', 'stay', 'sweat', 'water']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# Seeds: ['control', 'remot', 'system', 'harmoni', 'audio', 'ir', 'app', 'turn', 'sono', 'switch']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['gold', 'plate', 'connector', 'hdmi', 'gold', 'audio', 'adapt', 'port', 'male', 'splitter']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['radio', 'station', 'clock', 'radio', 'station', 'clock', 'radio', 'fm', 'wake', 'emerg']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# Seeds: ['thank', 'seller', 'satisfi', 'servic', 'thank', 'amazon', 'custom', 'servic', 'plea', 'happi']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Seeds: ['system', 'sub', 'subwoof', 'room', 'polk', 'bose', 'amp', 'unit', 'woofer', 'watt']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------

# %%
import pickle as pkl
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))
# Aspect_to_seeds.keys()
# [x for x in Aspect_to_seeds if 'weather' in x.lower()]

# %%
[x for x in Aspect_to_seeds if 'build' in x.lower()]
# Out:
# ['Build_Quality']

# %%
#         """Return sample from dataset at index i."""
#         example = self.list_data[i]
#         shuffle(example['seeds'])
#         sampled_seeds = example['seeds'][:self.seeds_length]
#         aspect = " ".join(example["aspect"].split('_'))
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            truncation=True)  
#         outputs = tokenizer(aspect, 
#                             padding="max_length", 
#                             truncation=True, 
#                             max_length=self.aspect_length)
        
#         batch = {}
#         batch["input_ids"] = torch.LongTensor(inputs.input_ids)
#         batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["labels"] = outputs.input_ids.copy()
#         batch['labels'] = [batch['labels']]

#         batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
#                            for labels in batch["labels"]]
#         batch["labels"] = torch.LongTensor(batch["labels"])
#         batch["labels"] = batch["labels"].squeeze(0)
        
#         return batch

# %%
# chk_1 =tokenizer('MaterialsComp', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_1['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_2 =tokenizer('Ease of use', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_2['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_ = tokenizer('Compartments', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=4)

# %%
# tokenizer.batch_decode(chk_['input_ids'], 
#                        skip_special_tokens=True, 
#                        clean_up_tokenization_spaces=False)

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
electronic_topics = [x[:20] for x in electronic_topics]

# %%
test_data = []
for each_e_top in electronic_topics:
    test_data.append({'seeds': each_e_top[:20], 'aspect':'TestSet'})

# %%
test_dataset = aspectDataset(list_data=test_data, 
                              tokenizer=tokenizer)

# %%
test_loader = DataLoader(test_dataset, 
                         batch_size=1, 
                         shuffle=True,
                         num_workers=1)

# %%
model.eval()
for ind, batch in enumerate(test_loader):
    batch = {k: v.to('cuda') for k, v in batch.items()}
    model_op = model(**batch)
    print('---'*20)
    print('ID:', ind)
    print('---'*20)
    print('Seed words:', tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    print('Actual aspect:', tokenizer.batch_decode(batch['decoder_input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
    print('Predicted aspect:', tokenizer.batch_decode(output_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True))

# %% [raw]
# 1. Sample 5-10 for each aspect. Get top 50 and then sample 10 each. done
# 2. Start from the bart-large and not cnn. done
# 3. Use very small learning rate (2e-5)| 1e-6 or 5e-7. done
# 4. Put a comma with the words. done
# 5. Stem the training data words. done
#
#
# Run it on our topics.
# -

# %%
model_op['logits'].squeeze(dim=0).shape

# %%
torch.argmax(model_op['logits'].squeeze(dim=0), dim=1)

# %% [markdown]
# ## Orphan Code
# -------------

# %%
print(another_way_to_train)
for epoch in range(num_epochs):
    training_loss = 0.0
    model.train()
    for batch in tqdm(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        # Get the "input's representation"
        encoder_output = the_encoder(input_ids = batch['input_ids'],
                                   attention_mask = batch['attention_mask'])
      
        # Pass the representation + the target summary to the decoder
        decoder_output = the_decoder(input_ids=batch['decoder_input_ids'],
                                   attention_mask=batch['decoder_attention_mask'],
                                   encoder_hidden_states=encoder_output[0],
                                   encoder_attention_mask=batch['attention_mask'])

        # Use the last linear layer to predict the next token
        decoder_output = decoder_output.last_hidden_state
        lm_head_output = last_linear_layer(decoder_output)
        
        # Compute the loss
        loss = loss_fct(lm_head_output.view(-1, model.config.vocab_size),
                      batch['labels'].view(-1))
        training_loss += loss.item()
        
        loss.backward() # Update the weights
        optimizer.step() # Notify optimizer that a batch is done.
        lr_scheduler.step() # Notify the scheduler that a ...
        optimizer.zero_grad() # Reset the optimer
    training_loss = training_loss / len( train_data )
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))

# %%
lm_head_output.view(-1, model.config.vocab_size)
