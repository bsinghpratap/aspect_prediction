# %%
import torch
import random
import pandas as pd
import pickle as pkl
from tqdm import tqdm
from os import listdir
from os.path import join
from random import shuffle
from transformers import AdamW
from matplotlib import pyplot as plt
from torch.nn import CrossEntropyLoss
from transformers import get_scheduler
from pdb import set_trace as breakpoint
from nltk.stem.snowball import SnowballStemmer
from torch.utils.data import Dataset, DataLoader
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
# %matplotlib inline

# %%
# folders = ['bags_and_cases', 'bluetooth', 'boots', 'keyboards', 'tv', 'vacuums']

# base_dir = '/mnt/nfs/work1/hongyu/brawat/amzn/oposum/data/seeds'

# list_aspects = []
# Aspect_to_seeds = {}
# stemmer = SnowballStemmer(language='english')
# for each_folder in folders:
#     folder_dir = join(base_dir, each_folder)
#     print('--'*20)
#     print(each_folder)
#     print('--'*20)
#     txt_files = listdir(folder_dir)
#     txt_files = [x for x in txt_files if 'None' not in x]
#     print(txt_files)
#     for each_txt in txt_files:
#         txt_dir = join(folder_dir, each_txt)
#         txt = open(txt_dir).read()
#         txt = txt.split('\n')
#         txt = [x.split(' ')[-1] for x in txt]
#         txt = [x.strip() for x in txt]
#         txt = [stemmer.stem(x) for x in txt]
#         aspect = each_txt.split('.')[1]
#         Aspect_to_seeds[aspect] = txt

# %%
# for each_aspect in Aspect_to_seeds:
#     print(each_aspect, Aspect_to_seeds[each_aspect].__len__())

# %%
# pkl.dump(Aspect_to_seeds, open('Aspect_to_seeds_march19.pkl', 'wb'))

# %%
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))

# %%
for each_aspect in Aspect_to_seeds:
    Aspect_to_seeds[each_aspect] = [x for x in Aspect_to_seeds[each_aspect] if x.__len__()>0]

# %%
Aspect_to_seeds
# Out:
# {'Compartments': ['pocket',
#   'cabl',
#   'compart',
#   'outsid',
#   'lot',
#   'wish',
#   'wallet',
#   'connector',
#   'space',
#   'power',
#   'pen',
#   'folder',
#   'charger',
#   'flap',
#   'mous',
#   'nice',
#   'thing',
#   'insid',
#   'small',
#   'paperwork',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'construct',
#   'medium',
#   'player',
#   'wire',
#   'run',
#   'headphon',
#   'key',
#   'instead',
#   'huge',
#   'need',
#   'open',
#   'fit',
#   'headset',
#   'outer',
#   'planner',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'cellphon',
#   'save',
#   'document'],
#  'Price': ['price',
#   'money',
#   'feaur',
#   'paid',
#   'spin',
#   'spun',
#   'mayb',
#   'cheap',
#   '200',
#   'spend',
#   'right',
#   'vaccum',
#   'twice',
#   'expect',
#   'pricey',
#   '50',
#   'expens',
#   'worth',
#   'far',
#   'wast',
#   'duster',
#   'think',
#   'bagless',
#   'best',
#   'dyson',
#   'need',
#   'ok',
#   'weight',
#   'bag',
#   'power',
#   'light',
#   'like',
#   'good',
#   'vacuum'],
#  'Handles': ['strap',
#   'handl',
#   'shoulder',
#   'broke',
#   'later',
#   'month',
#   'hand',
#   'comfort',
#   'plastic',
#   'wear',
#   'tear',
#   'rip',
#   'start',
#   'attach',
#   'holiday',
#   'left',
#   'lift',
#   'final',
#   'broken',
#   'stand',
#   'inevit',
#   'situat',
#   'firm',
#   'bend',
#   'hurt',
#   'minut',
#   'addit',
#   'note',
#   'buckl',
#   'adjust',
#   'adjust',
#   'short',
#   'shorter',
#   'length',
#   'adjust',
#   'long',
#   'metal',
#   'swivel',
#   'sooner',
#   'break',
#   'felt',
#   'rip',
#   'loop',
#   'hook',
#   'torn',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'use'],
#  'Customer_service': ['paid',
#   'support',
#   'servic',
#   'week',
#   'replac',
#   'mail',
#   'wait',
#   'pay',
#   'ship',
#   '1500',
#   'bring',
#   'deliveri',
#   'come',
#   'use',
#   'peopl',
#   'speak',
#   'technician',
#   'refurbish',
#   'handl',
#   'shore',
#   'communic',
#   'difficult',
#   '49',
#   'diagnost',
#   'fee',
#   '100',
#   'fix',
#   'latest',
#   'divx',
#   'arriv',
#   'undamag',
#   'po',
#   'mention',
#   'desk',
#   'help',
#   'suppos',
#   'later',
#   'cancel',
#   'reschedul',
#   'entir',
#   'glove',
#   'pilot',
#   'deliv',
#   'fact',
#   'clear',
#   'requir',
#   '100lb',
#   'carri',
#   'downstair',
#   'check'],
#  'Looks': ['look',
#   'slim',
#   'origin',
#   'appear',
#   'lttle',
#   'attract',
#   'beauti',
#   'size',
#   'small',
#   'decent',
#   'imac',
#   'backlit',
#   'longer',
#   'pc',
#   'like',
#   'laptop',
#   'nice',
#   'great',
#   'cheap',
#   'keyboard',
#   'good',
#   'feel'],
#  'Quality': ['qualiti',
#   'materi',
#   'handl',
#   'poor',
#   'broke',
#   'durabl',
#   'month',
#   'later',
#   'wear',
#   'tear',
#   'zipper',
#   'chemic',
#   'start',
#   'excel',
#   'terribl',
#   'crack',
#   'strap',
#   'daili',
#   'plastic',
#   'pull',
#   'smell',
#   'edg',
#   'rip',
#   'white',
#   'item',
#   'year',
#   'go',
#   'feel',
#   'attach',
#   'brake',
#   'holiday',
#   'outstand',
#   'strip',
#   'peel',
#   'left',
#   'final',
#   'broken',
#   'stand',
#   'sacrific',
#   'durabl',
#   'style',
#   'cours',
#   'trip',
#   'asia',
#   'rip',
#   'construct',
#   'cancer',
#   'birth',
#   'defect',
#   'reproduct'],
#  'Protection': ['protect',
#   'pad',
#   'protect',
#   'protect',
#   'drop',
#   'lap',
#   'insid',
#   'comput',
#   'laptop',
#   'good',
#   'let',
#   'secur',
#   'damag',
#   'intern',
#   'weak',
#   'tast',
#   'trust',
#   'protect',
#   'construct',
#   'provid',
#   'second',
#   'protect',
#   'count',
#   'sort',
#   'happen',
#   'cushion',
#   'adequ',
#   'thing',
#   'pencil',
#   'heavi',
#   'normal',
#   'kensington',
#   'probabl',
#   'larg',
#   'like',
#   'way',
#   'stylish',
#   'far',
#   'sleev',
#   'pad',
#   'feel',
#   'realli',
#   'perfect',
#   'bit',
#   'littl',
#   'bag',
#   'macbook',
#   'love',
#   'use'],
#  'Size_Fit': ['fit',
#   'size',
#   'macbook',
#   'big',
#   'space',
#   'air',
#   'slight',
#   'lot',
#   'bulk',
#   'perfect',
#   'inch',
#   'laptop',
#   'perfect',
#   '13',
#   'cabl',
#   'folder',
#   'notebook',
#   'sure',
#   'snug',
#   'bit',
#   'te',
#   'seat',
#   'airplan',
#   'fre',
#   'cell',
#   'pouch',
#   'tight',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'enorm',
#   '17inch',
#   'bare',
#   'm1710',
#   'hp',
#   'pavilion',
#   'dv7',
#   '3080us',
#   'disappoint',
#   'cloth',
#   'whatnot',
#   'spacious',
#   'book',
#   'load',
#   'accommod'],
#  'Ease_of_use': ['easi',
#   'cord',
#   'push',
#   'corner',
#   'vacuum',
#   'pile',
#   'maneuv',
#   'nozzl',
#   'awkward',
#   'crevic',
#   'constant',
#   'bog',
#   'imposs',
#   'short',
#   'carpet',
#   'heavi',
#   'roller',
#   'hose',
#   'difficult',
#   'wall',
#   'suck',
#   'remov',
#   'empti',
#   'power',
#   'hard',
#   'jump',
#   'simpic',
#   'automat',
#   'retractor',
#   'retract',
#   'flash',
#   'baseboard',
#   'retract',
#   'easier',
#   'snap',
#   'disassembl',
#   'direct',
#   'propel',
#   'person',
#   'race',
#   'furnitur',
#   'flexibl',
#   'kink',
#   'prefer',
#   'cannist',
#   'car',
#   'refriger',
#   'move',
#   'eas',
#   'worst'],
#  'Sound': ['sound',
#   'speaker',
#   'good',
#   'qualiti',
#   'loud',
#   'tinni',
#   'bass',
#   'hear',
#   'horribl',
#   'trebl',
#   'chang',
#   'realli',
#   'great',
#   'terribl',
#   'bar',
#   'display',
#   'thing',
#   'eye',
#   'ear',
#   'loudest',
#   'volum',
#   'strain',
#   'quieter',
#   'dinner',
#   'lack',
#   'sort',
#   'improv',
#   'surround',
#   'true',
#   'experi',
#   'junki',
#   'mind',
#   'vibrat',
#   'develop',
#   'pitch',
#   'whine',
#   'strong',
#   'track',
#   'cool',
#   'worthi',
#   'shippabl',
#   'adjust',
#   'weird',
#   'kinda',
#   'improv',
#   'cheapest',
#   'laptop',
#   'watt',
#   'muffl',
#   'margin'],
#  'Look': ['cute',
#   'look',
#   'look',
#   'great',
#   'fring',
#   'style',
#   'color',
#   'love',
#   'design',
#   'go',
#   'unattract',
#   'attract',
#   'offic',
#   'environ',
#   'pictur',
#   '360',
#   'degre',
#   'vent',
#   'concept',
#   'coverag',
#   'airi',
#   'hang',
#   'unattract',
#   'durabl',
#   'nice',
#   'casual',
#   'beauti',
#   'moccasin',
#   'shame',
#   'taup',
#   'direct',
#   'smooth',
#   'laid',
#   'rest',
#   'natur',
#   'calm',
#   'absolut',
#   'ador',
#   'pictur',
#   'grey',
#   'wonder',
#   'stylish',
#   'comfort',
#   'boot',
#   'good',
#   'collaps',
#   'super',
#   'crazi',
#   'light',
#   'weight'],
#  'Connectivity': ['hdmi',
#   'port',
#   'comput',
#   'input',
#   'compon',
#   'usb',
#   'internet',
#   'connect',
#   'output',
#   'server',
#   'connect',
#   'audio',
#   'play',
#   'stop',
#   'standard',
#   'avi',
#   'like',
#   'hd',
#   'file',
#   'movi',
#   'work',
#   'digit',
#   'monitor',
#   'comcast',
#   'connect',
#   'drive',
#   'end',
#   'cabl',
#   'watch',
#   'netflix',
#   'flash',
#   '45',
#   'min',
#   'rf',
#   'vga',
#   'cycl',
#   'signal',
#   'higher',
#   'slot',
#   'integr',
#   'wi',
#   'fi',
#   'stream',
#   'speed',
#   'conflict',
#   'dhcp',
#   'hard',
#   'dlna',
#   'enabl',
#   'power'],
#  'Battery': ['batteri',
#   'charg',
#   'life',
#   'charger',
#   'charg',
#   'tone',
#   'longer',
#   'low',
#   'hour',
#   'power',
#   'light',
#   'color',
#   'red',
#   'respond',
#   'merit',
#   'vari',
#   'recharg',
#   'bizarr',
#   'later',
#   'sudden',
#   'dead',
#   'meter',
#   'hold',
#   'thing',
#   'half',
#   'green',
#   'stop',
#   'nokia',
#   'turn',
#   'start',
#   'blackberri',
#   'star',
#   'phone',
#   'good',
#   'day',
#   'cell',
#   'come',
#   'talk',
#   'get',
#   'simpl',
#   'pretti',
#   'love',
#   'better',
#   'easili',
#   'volum',
#   'nois',
#   'time',
#   'work'],
#  'Durability': ['rubber',
#   'qualiti',
#   'use',
#   'buckl',
#   'appear',
#   'heel',
#   'long',
#   'time',
#   'break',
#   'enjoy',
#   'provid',
#   'protect',
#   'clear',
#   'cheapli',
#   'thinner',
#   'barn',
#   'month',
#   'start',
#   'tear',
#   'constant',
#   'fold',
#   'gone',
#   'numer',
#   'decor',
#   'come',
#   'sturdi',
#   'sure',
#   'durabl',
#   'decent',
#   'cheep',
#   'deflat',
#   'daili',
#   'wear',
#   'collaps',
#   'super',
#   'need',
#   'sol',
#   'red',
#   'obvious',
#   'differ',
#   'think',
#   'worn',
#   'abl',
#   'materi',
#   'actual',
#   'pretti',
#   'heavi',
#   'true',
#   'style',
#   'support'],
#  'Comfort': ['comfort',
#   'fit',
#   'foot',
#   'hurt',
#   'ankl',
#   'comfi',
#   'blister',
#   'comfort',
#   'break',
#   'wear',
#   'abl',
#   'extrem',
#   'walk',
#   'sock',
#   'longer',
#   'pain',
#   'perfect',
#   'super',
#   'uncomfort',
#   'light',
#   'weight',
#   'discomfort',
#   'snug',
#   'put',
#   'slide',
#   'sued',
#   'feel',
#   'littl',
#   'time',
#   'narrow',
#   'toe',
#   'minut',
#   'summer',
#   'insid',
#   'short',
#   'long',
#   'wear',
#   'perfect',
#   'list',
#   'doc',
#   'tongu',
#   'moment',
#   'break',
#   'enjoy',
#   'plus',
#   'actual',
#   'loos',
#   'attract',
#   'offic',
#   'environ'],
#  'Materials': ['leather',
#   'insid',
#   'fring',
#   'materi',
#   'heel',
#   'cheaper',
#   'soft',
#   'sole',
#   'buckl',
#   'sued',
#   'true',
#   'rubber',
#   'advertis',
#   'fact',
#   'cloth',
#   'back',
#   'synthet',
#   'finish',
#   'aerosol',
#   'line',
#   'aw',
#   'memori',
#   'foam',
#   'thinner',
#   'barn',
#   'decor',
#   'come',
#   'hang',
#   'unattract',
#   'fashion',
#   'porous',
#   'term',
#   'best',
#   'describ',
#   'let',
#   'penetr',
#   'piec',
#   'elast',
#   'zipper',
#   'friction',
#   'easili',
#   'improv',
#   'fleec',
#   'especi',
#   'superb',
#   'direct',
#   'smooth',
#   'natur',
#   'calm',
#   'hollow'],
#  'Color': ['color',
#   'love',
#   'style',
#   'unbeliev',
#   'gorgeous',
#   'blue',
#   'favorit',
#   'taup',
#   'wonder',
#   'red',
#   'exact',
#   'design',
#   'purchas',
#   'love',
#   'materi',
#   'look',
#   'perfect',
#   'look',
#   'boot'],
#  'Size': ['size',
#   'order',
#   'half',
#   'order',
#   'big',
#   'littl',
#   'bigger',
#   'usual',
#   'narrow',
#   'normal',
#   'width',
#   'true',
#   'run',
#   'small',
#   'size',
#   'larger',
#   'perfect',
#   'fit',
#   'sent',
#   'ankl',
#   'wide',
#   'tight',
#   'baggi',
#   'wise',
#   'tuck',
#   'pant',
#   'follow',
#   'advic',
#   'buyer',
#   'bacaus',
#   'possibl',
#   'joint',
#   'especi',
#   'superb',
#   'beauti',
#   'moccasin',
#   'shame',
#   'sould',
#   'larg',
#   'awar',
#   'length',
#   'tab',
#   'decid',
#   'normal',
#   'option',
#   'shorter',
#   'left',
#   'mayb',
#   'wear',
#   'calf'],
#  'Weather_resistance': ['dri',
#   'waterproof',
#   'rain',
#   'wet',
#   'water',
#   'foot',
#   'soak',
#   'snow',
#   'cold',
#   'puddl',
#   'warm',
#   'got',
#   'chicago',
#   'protect',
#   'suppos',
#   'defect',
#   'item',
#   'traction',
#   'raini',
#   'interest',
#   'ice',
#   'spent',
#   'cub',
#   'scout',
#   'den',
#   'alcatraz',
#   'island',
#   'san',
#   'francisco',
#   'lot',
#   'claim',
#   'stori',
#   'resist',
#   'generous',
#   'porous',
#   'term',
#   'dewi',
#   'grass',
#   'leav',
#   'soak',
#   'let',
#   'penetr',
#   'perform',
#   'repel',
#   'sandal',
#   'stay',
#   'amaz',
#   'outsid',
#   'step',
#   'deep'],
#  'Noise': ['quiet',
#   'noisi',
#   'loud',
#   'power',
#   'nois',
#   'louder',
#   'ear',
#   'loudest',
#   'light',
#   'incred',
#   'deafen',
#   'serious',
#   'actual',
#   'ring',
#   'doggi',
#   'hide',
#   'flee',
#   'powerstick',
#   'earplug',
#   'lose',
#   'bearabl',
#   'block',
#   'pro',
#   'fair',
#   'reason',
#   'direct',
#   'mous',
#   'explod',
#   'silent',
#   'compar',
#   'stylish',
#   'function',
#   'weight',
#   'peopl',
#   'ring',
#   'motor',
#   'awesom',
#   'nozzl',
#   'readi',
#   'sound',
#   'devil',
#   'purchas',
#   'quit',
#   'size',
#   'upright',
#   'star',
#   'heavi',
#   'lightweight',
#   'recommend',
#   'turn'],
#  'Extra_functionality': ['button',
#   'light',
#   'pencil',
#   'volum',
#   'power',
#   'featur',
#   'bright',
#   'mute',
#   'handi',
#   'low',
#   'dark',
#   'blue',
#   'wake',
#   'sleep',
#   'pen',
#   'nice',
#   'quit',
#   'shortcut',
#   'internet',
#   'spillproof',
#   'interest',
#   'vista',
#   'capabl',
#   'support',
#   'shut',
#   'keypress',
#   'pre',
#   'program',
#   'calcul',
#   'mycomput',
#   'custom',
#   'email',
#   'brower',
#   'activ',
#   'music',
#   'special',
#   'disk',
#   'eject',
#   'hold',
#   'remain',
#   'recess',
#   'clutch',
#   'multimedia',
#   'label',
#   'illumin',
#   'programm',
#   'legibl',
#   'dark',
#   'dim',
#   'backlight'],
#  'Layout': ['key',
#   'delet',
#   'backspac',
#   'size',
#   'layout',
#   'end',
#   'insert',
#   'home',
#   'bar',
#   'perfect',
#   'space',
#   'cluster',
#   'squish',
#   'space',
#   'close',
#   'small',
#   'volum',
#   'tini',
#   'place',
#   'arrow',
#   'littl',
#   'tricki',
#   'bigger',
#   'million',
#   'print',
#   'scroll',
#   'paus',
#   'quick',
#   'navig',
#   'difficult',
#   'suppos',
#   'spill',
#   'proof',
#   '104',
#   'negat',
#   'overs',
#   'awkward',
#   'place',
#   'vertic',
#   'horizont',
#   'multimedia',
#   'label',
#   'wider',
#   'impecc',
#   'activ',
#   'chang',
#   'requir',
#   'movement',
#   'wide',
#   'strike'],
#  'Feel_Comfort': ['feel',
#   'comfort',
#   'mushi',
#   'key',
#   'like',
#   'keyboard',
#   'good',
#   'perfect',
#   'press',
#   'wrist',
#   'action',
#   'shallow',
#   'smooth',
#   'finger',
#   'relax',
#   'type',
#   'level',
#   'keystrok',
#   'sit',
#   'type',
#   'quick',
#   'navig',
#   'difficult',
#   'shop',
#   'consist',
#   'respond',
#   'pressur',
#   'sens',
#   'deceler',
#   'quick',
#   'mush',
#   'tap',
#   'regist',
#   'usual',
#   'chicklet',
#   'membran',
#   'stick',
#   'satisfi',
#   'clicki',
#   'ibm',
#   'dissatisfi',
#   'natur',
#   'tension',
#   'impecc',
#   'stylish',
#   'recogn',
#   'signatur',
#   'butteri',
#   'velvet',
#   'feather'],
#  'Build_Quality': ['belt',
#   'broke',
#   'turn',
#   'work',
#   'burn',
#   'electr',
#   'built',
#   'stop',
#   'month',
#   'roller',
#   'time',
#   'minut',
#   'problem',
#   'brush',
#   'design',
#   'easili',
#   'wise',
#   'continu',
#   'break',
#   'fifth',
#   'barley',
#   'bump',
#   '20',
#   'last',
#   'connect',
#   'swivel',
#   'portion',
#   'fail',
#   'constuct',
#   'electron',
#   'construct',
#   'simpli',
#   'quit',
#   'burnt',
#   'miss',
#   'smell',
#   'overheat',
#   'shut',
#   'poor',
#   'attach',
#   'pop',
#   'unannounc',
#   'snapper',
#   'flimsi',
#   'overh',
#   'upper',
#   'run',
#   'turn',
#   'prepar',
#   'sturdi'],
#  'Size_Look': ['size',
#   'big',
#   'bigger',
#   '40',
#   'differ',
#   'screen',
#   'room',
#   'light',
#   '3d',
#   'livingroom',
#   'hardwar',
#   'slim',
#   'cubbyhol',
#   'huge',
#   'weigh',
#   'awkward',
#   'pentil',
#   'matrix',
#   '60',
#   'foot',
#   '65',
#   'consid',
#   'oh',
#   'lightweight',
#   'compact',
#   'suitabl',
#   'live',
#   'ultra',
#   'weigh',
#   'le',
#   'pound',
#   'hindsight',
#   'wonder',
#   'feel',
#   'anticip',
#   'actual',
#   'bedroom',
#   'fit',
#   'perfect',
#   'love',
#   'smaller',
#   'store',
#   'averag',
#   'inch',
#   'view',
#   '32',
#   'perfect',
#   'home',
#   'easili',
#   'get'],
#  'Image': ['pictur',
#   'color',
#   'qualiti',
#   'black',
#   'bright',
#   'nice',
#   'clear',
#   'look',
#   'excel',
#   'crisp',
#   'screen',
#   'right',
#   'dead',
#   'pixel',
#   'trace',
#   'beauti',
#   'vibrant',
#   'sharp',
#   'angl',
#   'display',
#   'dvd',
#   'differ',
#   'corner',
#   'fantast',
#   'hd',
#   'overal',
#   'inch',
#   'imag',
#   'view',
#   'white',
#   'great',
#   'ok',
#   'red',
#   'decent',
#   'struck',
#   'eye',
#   'ear',
#   'definit',
#   'fuzzi',
#   'font',
#   'improv',
#   'expeci',
#   'hubbi',
#   'sleep',
#   'caus',
#   'biggest',
#   'level',
#   'notic',
#   'irrit',
#   'affect'],
#  'Apps_Interface': ['netflix',
#   'user',
#   'file',
#   'hulu',
#   'app',
#   'watch',
#   'flash',
#   'internet',
#   'smart',
#   'video',
#   'stream',
#   'speed',
#   'youtub',
#   'access',
#   'lack',
#   'smart',
#   'download',
#   'brows',
#   'eas',
#   'interfac',
#   'friend',
#   'access',
#   'work',
#   'capabl',
#   'alright',
#   'quit',
#   'mean',
#   'let',
#   'hub',
#   'applic',
#   'terribl',
#   'watch',
#   'plus',
#   'easili',
#   'buy',
#   'week',
#   'right',
#   'featur',
#   'movi',
#   'comput',
#   'cabl',
#   'best',
#   'samsung',
#   'time',
#   'realli',
#   'like',
#   'better'],
#  'Suction_Power': ['suction',
#   'pick',
#   'power',
#   'power',
#   'good',
#   'hair',
#   'carpet',
#   'suck',
#   'quiet',
#   'realli',
#   'perform',
#   'dirt',
#   'tile',
#   'ok',
#   'job',
#   'floor',
#   'perfom',
#   'total',
#   'angl',
#   'attribut',
#   'machin',
#   'main',
#   'simpic',
#   'weak',
#   'object',
#   'bear',
#   'spot',
#   'vacuum',
#   'dosen',
#   'produc',
#   'fault',
#   'unders',
#   'pretti',
#   'essenti',
#   'spin',
#   'spun',
#   'mayb',
#   'pro',
#   'fair',
#   'reason',
#   'loo',
#   'filter',
#   'superb',
#   'grout',
#   'ergorapido',
#   'leav',
#   'plush',
#   'grind',
#   'stylish',
#   'function'],
#  'Weight': ['light',
#   'weight',
#   'lightweight',
#   'heavi',
#   'size',
#   'compact',
#   'maneuv',
#   'guess',
#   'quiet',
#   'quit',
#   'probabl',
#   'cumbersom',
#   'feaur',
#   'reason',
#   'histori',
#   'minor',
#   'heavier',
#   'consid',
#   'compar',
#   'nice',
#   'larg',
#   'need',
#   'especi',
#   'carri',
#   'drawback',
#   'perform',
#   'past',
#   'suppos',
#   'thought',
#   'power',
#   'loud',
#   'price',
#   'easi',
#   'feel',
#   'hardwood',
#   'push',
#   'store',
#   'panason',
#   'vacuum',
#   'bagless',
#   'area',
#   'ok',
#   'purchas',
#   'vaccuum',
#   'small',
#   'hard',
#   'littl',
#   'short',
#   'rug',
#   'canist'],
#  'Customer_Service': ['servic',
#   'contact',
#   'help',
#   'custom',
#   'took',
#   'email',
#   'miel',
#   'hoover',
#   'dealer',
#   'horribl',
#   'multipl',
#   'respond',
#   'chose',
#   'repres',
#   'told',
#   'smell',
#   'lubric',
#   'dissip',
#   'wait',
#   'spent',
#   'hour',
#   'phone',
#   'depart',
#   'contact',
#   'busi',
#   'regist',
#   'late',
#   'gotten',
#   'card',
#   'mail',
#   'ignor',
#   'look',
#   'common',
#   'recent',
#   'respons',
#   'unfortun',
#   'video',
#   'warranti',
#   'useless',
#   'self',
#   'fall',
#   'day',
#   'amazon',
#   'issu',
#   'absolut',
#   'time',
#   'purchas',
#   'problem'],
#  'Accessories': ['filter',
#   'brush',
#   'attach',
#   'roll',
#   'turbo',
#   'easili',
#   'expens',
#   'wide',
#   'turn',
#   'bag',
#   'replac',
#   'typic',
#   'hepa',
#   'cover',
#   'extens',
#   'wonder',
#   'crevic',
#   'reach',
#   'requir',
#   'clean',
#   'duster',
#   'hose',
#   'clean',
#   'way',
#   'noisi',
#   'corner',
#   'hardwood',
#   'empti',
#   'get',
#   'convent',
#   'brushrol',
#   'extra',
#   'rotat',
#   'block',
#   'bag',
#   'scrap',
#   'okay',
#   'basic',
#   'eye',
#   'regular',
#   'sensor',
#   'green',
#   'complet',
#   'instead',
#   'allow',
#   'need',
#   'spinner',
#   'fact',
#   'cup',
#   'onboard']}

# %%
for each_aspect in Aspect_to_seeds:
    print(each_aspect, Aspect_to_seeds[each_aspect].__len__())
# Out:
# Compartments 50
# Price 34
# Handles 50
# Customer_service 50
# Looks 22
# Quality 50
# Protection 49
# Size_Fit 50
# Ease_of_use 50
# Sound 50
# Look 50
# Connectivity 50
# Battery 48
# Durability 50
# Comfort 50
# Materials 50
# Color 19
# Size 50
# Weather_resistance 50
# Noise 50
# Extra_functionality 50
# Layout 50
# Feel_Comfort 50
# Build_Quality 50
# Size_Look 50
# Image 50
# Apps_Interface 47
# Suction_Power 50
# Weight 50
# Customer_Service 48
# Accessories 50

# %%
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
# tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")

# %%
# model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# %%
# !echo $CUDA_VISIBLE_DEVICES

# %%
model_args = {'seed_samples': 10, 
              'aspect_length':6
             }

# %%
class aspectDataset(Dataset):
    
    def __init__(self, list_data, tokenizer, model_args):
        self.tokenizer = tokenizer
        self.list_data = list_data
        self.seeds_length = model_args['seed_samples']
        self.aspect_length = model_args['aspect_length']
    
    def __len__(self):
        """Return length of dataset."""
        return self.list_data.__len__()

    def __getitem__(self, i):
        """Return sample from dataset at index i."""
        example = self.list_data[i]
        shuffle(example['seeds'])
        sampled_seeds = example['seeds'][:self.seeds_length]
        aspect = " ".join(example["aspect"].split('_'))
#         max_length = self.seeds_length+2
        inputs = tokenizer(", ".join(sampled_seeds), 
                           truncation=True)  
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            padding="max_length", 
#                            truncation=True, 
#                            max_length=max_length)  
        outputs = tokenizer(aspect, 
                            padding="max_length", 
                            truncation=True, 
                            max_length=self.aspect_length)
        
        batch = {}
        batch["input_ids"] = torch.LongTensor(inputs.input_ids)
        batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["decoder_input_ids"] = torch.LongTensor(outputs.input_ids)
#         batch["decoder_attention_mask"] = torch.LongTensor(outputs.attention_mask)
        batch["labels"] = outputs.input_ids.copy()
        batch['labels'] = [batch['labels']]

        # We have to make sure that the PAD token is ignored for calculating the loss
        batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
                           for labels in batch["labels"]]
        batch["labels"] = torch.LongTensor(batch["labels"])
        batch["labels"] = batch["labels"].squeeze(0)
        
        return batch

# %%
train_data = []
for each_key in Aspect_to_seeds:
    train_data.append({"seeds":Aspect_to_seeds[each_key],
                       "aspect":each_key})

# %%
train_dataset = aspectDataset(list_data=train_data, 
                              tokenizer=tokenizer,
                              model_args=model_args
                             )

# %%
train_loader = DataLoader(train_dataset, 
                          batch_size=1, 
                          shuffle=True,
                          num_workers=1)

# %%
model = model.to("cuda")

# %%
# the_encoder = model.get_encoder()
# the_decoder = model.get_decoder()
# last_linear_layer = model.lm_head

# %%
num_epochs = 15
num_training_steps = num_epochs * len(train_data)

loss_fct = CrossEntropyLoss()

optimizer = AdamW(model.parameters(), 
                  lr=2e-5)
warmup_steps = int(0.10*num_training_steps)
lr_scheduler = get_scheduler("linear",
                            optimizer=optimizer,
                            num_warmup_steps=warmup_steps,
                            num_training_steps=num_training_steps
                            )

# %%
all_train_loss = []
for epoch in tqdm(range(num_epochs)):
    training_loss = 0.0
    model.train()
    for ind, batch in enumerate(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        model_op = model(**batch)
        loss = model_op['loss']
        
        training_loss += loss.item()
        
        print('---'*20)
        print('Epoch:', epoch, 'ID:', ind)
        print('---'*20)
        print('Seed words:', tokenizer.batch_decode(batch['input_ids'], 
                                                    skip_special_tokens=True, 
                                                    clean_up_tokenization_spaces=False))
        print('Actual aspect:', tokenizer.batch_decode(batch['labels'][batch['labels']!=-100].unsqueeze(0), 
                                                       skip_special_tokens=True, 
                                                       clean_up_tokenization_spaces=True))
        output_ids = model.generate(batch["input_ids"], 
                                    num_beams=3, 
                                    max_length=6)
        print('Predicted aspect:', tokenizer.batch_decode(output_ids, 
                                                          skip_special_tokens=True, 
                                                          clean_up_tokenization_spaces=True))
        
        loss.backward()
        optimizer.step() 
        lr_scheduler.step() 
        optimizer.zero_grad() 
    training_loss = training_loss / len( train_data )
    all_train_loss.append(training_loss)
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ------------------------------------------------------------
# Epoch: 0 ID: 0
# ------------------------------------------------------------
# Seed words: ['360, comfort, cute, offic, nice, rest, beauti, taup, pictur, boot']
# Actual aspect: ['Look']
# Predicted aspect: ['360, comfort']
# ------------------------------------------------------------
# Epoch: 0 ID: 1
# ------------------------------------------------------------
# Seed words: ['gorgeous, unbeliev, taup, style, boot, materi, purchas, wonder, color, look']
# Actual aspect: ['Color']
# Predicted aspect: ['gorgeous']
# ------------------------------------------------------------
# Epoch: 0 ID: 2
# ------------------------------------------------------------
# Seed words: ['planner, reduct, outer, daytim, nice, run, cellphon, munchi, space, pen']
# Actual aspect: ['Compartments']
# Predicted aspect: ['planner,']
# ------------------------------------------------------------
# Epoch: 0 ID: 3
# ------------------------------------------------------------
# Seed words: ['develop, horribl, loudest, tinni, pitch, bass, laptop, realli, volum, experi']
# Actual aspect: ['Sound']
# Predicted aspect: ['develop, hor']
# ------------------------------------------------------------
# Epoch: 0 ID: 4
# ------------------------------------------------------------
# Seed words: ['bend, felt, torn, metal, final, broke, use, addit, adapt, lift']
# Actual aspect: ['Handles']
# Predicted aspect: ['bend,']
# ------------------------------------------------------------
# Epoch: 0 ID: 5
# ------------------------------------------------------------
# Seed words: ['aw, synthet, describ, buckl, unattract, easili, back, memori, leather, cheaper']
# Actual aspect: ['Materials']
# Predicted aspect: ['aw, synt']
# ------------------------------------------------------------
# Epoch: 0 ID: 6
# ------------------------------------------------------------
# Seed words: ['perfect, million, insert, close, strike, delet, size, end, overs, vertic']
# Actual aspect: ['Layout']
# Predicted aspect: ['perfect, million']
# ------------------------------------------------------------
# Epoch: 0 ID: 7
# ------------------------------------------------------------
# Seed words: ['bump, belt, flimsi, constuct, turn, overh, unannounc, turn, 20, electr']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['bump,']
# ------------------------------------------------------------
# Epoch: 0 ID: 8
# ------------------------------------------------------------
# Seed words: ['week, deliv, servic, use, pay, deliveri, pilot, divx, 1500, shore']
# Actual aspect: ['Customer service']
# Predicted aspect: ['week, del']
# ------------------------------------------------------------
# Epoch: 0 ID: 9
# ------------------------------------------------------------
# Seed words: ['chicklet, membran, velvet, deceler, wrist, navig, satisfi, quick, consist, shallow']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Chicklet']
# ------------------------------------------------------------
# Epoch: 0 ID: 10
# ------------------------------------------------------------
# Seed words: ['materi, feel, handl, chemic, excel, year, crack, stand, birth, daili']
# Actual aspect: ['Quality']
# Predicted aspect: ['materi']
# ------------------------------------------------------------
# Epoch: 0 ID: 11
# ------------------------------------------------------------
# Seed words: ['wear, protect, long, constant, sure, need, rubber, style, sol, cheep']
# Actual aspect: ['Durability']
# Predicted aspect: ['wear, protect']
# ------------------------------------------------------------
# Epoch: 0 ID: 12
# ------------------------------------------------------------
# Seed words: ['minut, pain, hurt, sock, slide, abl, ankl, time, uncomfort, super']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Sock,']
# ------------------------------------------------------------
# Epoch: 0 ID: 13
# ------------------------------------------------------------
# Seed words: ['65, averag, 60, light, easili, 3d, weigh, suitabl, actual, big']
# Actual aspect: ['Size Look']
# Predicted aspect: ['65, aver']
# ------------------------------------------------------------
# Epoch: 0 ID: 14
# ------------------------------------------------------------
# Seed words: ['realli, mean, lack, hub, comput, download, user, right, hulu, week']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['CNN.com']
# ------------------------------------------------------------
# Epoch: 0 ID: 15
# ------------------------------------------------------------
# Seed words: ['ok, fantast, affect, screen, nice, fuzzi, overal, level, display, beauti']
# Actual aspect: ['Image']
# Predicted aspect: ['The game is']
# ------------------------------------------------------------
# Epoch: 0 ID: 16
# ------------------------------------------------------------
# Seed words: ['hardwood, requir, cover, hepa, wide, expens, eye, need, reach, roll']
# Actual aspect: ['Accessories']
# Predicted aspect: ['The wood grain']
# ------------------------------------------------------------
# Epoch: 0 ID: 17
# ------------------------------------------------------------
# Seed words: ['unfortun, depart, told, self, respond, recent, lubric, contact, video, fall']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Unfortun']
# ------------------------------------------------------------
# Epoch: 0 ID: 18
# ------------------------------------------------------------
# Seed words: ['object, loo, ergorapido, machin, reason, floor, dosen, job, leav, tile']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['The floor is']
# ------------------------------------------------------------
# Epoch: 0 ID: 19
# ------------------------------------------------------------
# Seed words: ['ice, san, let, step, interest, protect, penetr, cold, lot, term']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['. The']
# ------------------------------------------------------------
# Epoch: 0 ID: 20
# ------------------------------------------------------------
# Seed words: ['stream, connect, hard, vga, avi, server, watch, standard, digit, enabl']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# Epoch: 0 ID: 21
# ------------------------------------------------------------
# Seed words: ['200, 50, spun, expect, like, expens, duster, spend, power, wast']
# Actual aspect: ['Price']
# Predicted aspect: [', and']
# ------------------------------------------------------------
# Epoch: 0 ID: 22
# ------------------------------------------------------------
# Seed words: ['big, inch, bulk, nois, pouch, bit, enorm, te, cell, bare']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Packs']
# ------------------------------------------------------------
# Epoch: 0 ID: 23
# ------------------------------------------------------------
# Seed words: ['imposs, eas, wall, race, roller, carpet, disassembl, empti, power, push']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Cush']
# ------------------------------------------------------------
# Epoch: 0 ID: 24
# ------------------------------------------------------------
# Seed words: ['narrow, true, size, normal, awar, option, mayb, fit, length, beauti']
# Actual aspect: ['Size']
# Predicted aspect: ['The dimensions of']
# ------------------------------------------------------------
# Epoch: 0 ID: 25
# ------------------------------------------------------------
# Seed words: ['attract, keyboard, cheap, appear, laptop, nice, beauti, great, imac, backlit']
# Actual aspect: ['Looks']
# Predicted aspect: ['Laptop Reviews']
# ------------------------------------------------------------
# Epoch: 0 ID: 26
# ------------------------------------------------------------
# Seed words: ['macbook, thing, littl, secur, protect, laptop, feel, bag, good, insid']
# Actual aspect: ['Protection']
# Predicted aspect: ['Laptop bag']
# ------------------------------------------------------------
# Epoch: 0 ID: 27
# ------------------------------------------------------------
# Seed words: ['nozzl, awesom, powerstick, quiet, loud, earplug, lightweight, peopl, function, stylish']
# Actual aspect: ['Noise']
# Predicted aspect: ['. Power']
# ------------------------------------------------------------
# Epoch: 0 ID: 28
# ------------------------------------------------------------
# Seed words: ['heavi, feaur, cumbersom, histori, quit, especi, hard, panason, price, ok']
# Actual aspect: ['Weight']
# Predicted aspect: ['Qu']
# ------------------------------------------------------------
# Epoch: 0 ID: 29
# ------------------------------------------------------------
# Seed words: ['custom, featur, vista, email, special, shortcut, volum, programm, calcul, backlight']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# Epoch: 0 ID: 30
# ------------------------------------------------------------
# Seed words: ['phone, tone, easili, longer, time, power, better, get, recharg, half']
# Actual aspect: ['Battery']
# Predicted aspect: ['Get the']
#   7%|▋         | 1/15 [00:11<02:47, 12.00s/it]
# Epoch 1:	Training Loss 4.67
# ------------------------------------------------------------
# Epoch: 1 ID: 0
# ------------------------------------------------------------
# Seed words: ['charger, paperwork, need, headset, key, thing, document, space, folder, instead']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Ports']
# ------------------------------------------------------------
# Epoch: 1 ID: 1
# ------------------------------------------------------------
# Seed words: ['access, quit, comput, hulu, terribl, flash, watch, video, buy, samsung']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Connectivity Connect']
# ------------------------------------------------------------
# Epoch: 1 ID: 2
# ------------------------------------------------------------
# Seed words: ['flash, direct, cannist, kink, maneuv, power, empti, cord, difficult, easier']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Canthus']
# ------------------------------------------------------------
# Epoch: 1 ID: 3
# ------------------------------------------------------------
# Seed words: ['offic, nice, good, comfort, design, absolut, beauti, smooth, unattract, light']
# Actual aspect: ['Look']
# Predicted aspect: ['Beautiful Design']
# ------------------------------------------------------------
# Epoch: 1 ID: 4
# ------------------------------------------------------------
# Seed words: ['earphon, notebook, tight, munchi, seat, daytim, 17inch, enorm, spacious, hp']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Compfortability']
# ------------------------------------------------------------
# Epoch: 1 ID: 5
# ------------------------------------------------------------
# Seed words: ['length, note, adjust, torn, remot, hand, stand, comfort, strap, broken']
# Actual aspect: ['Handles']
# Predicted aspect: ['Size Size Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 6
# ------------------------------------------------------------
# Seed words: ['key, regist, dissatisfi, consist, level, type, velvet, tension, pressur, impecc']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['SizeSizeSize']
# ------------------------------------------------------------
# Epoch: 1 ID: 7
# ------------------------------------------------------------
# Seed words: ['vibrant, bright, trace, excel, crisp, pictur, biggest, fantast, hubbi, overal']
# Actual aspect: ['Image']
# Predicted aspect: ['Compartments and']
# ------------------------------------------------------------
# Epoch: 1 ID: 8
# ------------------------------------------------------------
# Seed words: ['lubric, mail, video, dealer, warranti, look, miel, unfortun, common, late']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Weight Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 9
# ------------------------------------------------------------
# Seed words: ['speak, mention, entir, 100lb, pay, undamag, come, 100, 49, check']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Size Size Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 10
# ------------------------------------------------------------
# Seed words: ['sudden, easili, simpl, merit, bizarr, half, phone, talk, red, star']
# Actual aspect: ['Battery']
# Predicted aspect: ['Size Size Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 11
# ------------------------------------------------------------
# Seed words: ['loud, lose, peopl, doggi, star, nozzl, awesom, incred, serious, ring']
# Actual aspect: ['Noise']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Epoch: 1 ID: 12
# ------------------------------------------------------------
# Seed words: ['sock, short, weight, plus, perfect, light, sued, foot, moment, insid']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 1 ID: 13
# ------------------------------------------------------------
# Seed words: ['buckl, fring, materi, hang, direct, leather, piec, thinner, barn, rubber']
# Actual aspect: ['Materials']
# Predicted aspect: ['Customer service service']
# ------------------------------------------------------------
# Epoch: 1 ID: 14
# ------------------------------------------------------------
# Seed words: ['port, connect, connect, internet, like, usb, fi, rf, hard, avi']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Epoch: 1 ID: 15
# ------------------------------------------------------------
# Seed words: ['expect, price, far, 50, think, mayb, right, money, 200, dyson']
# Actual aspect: ['Price']
# Predicted aspect: ['Customer Service Service']
# ------------------------------------------------------------
# Epoch: 1 ID: 16
# ------------------------------------------------------------
# Seed words: ['cheapest, experi, mind, terribl, whine, qualiti, kinda, weird, thing, ear']
# Actual aspect: ['Sound']
# Predicted aspect: ['Customer']
# ------------------------------------------------------------
# Epoch: 1 ID: 17
# ------------------------------------------------------------
# Seed words: ['bacaus, order, larg, tuck, pant, especi, buyer, order, advic, size']
# Actual aspect: ['Size']
# Predicted aspect: ['Size fit fit']
# ------------------------------------------------------------
# Epoch: 1 ID: 18
# ------------------------------------------------------------
# Seed words: ['intern, pad, good, lap, perfect, tast, feel, larg, pad, pencil']
# Actual aspect: ['Protection']
# Predicted aspect: ['Customer service service']
# ------------------------------------------------------------
# Epoch: 1 ID: 19
# ------------------------------------------------------------
# Seed words: ['backlit, longer, pc, like, lttle, appear, attract, imac, feel, origin']
# Actual aspect: ['Looks']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# Epoch: 1 ID: 20
# ------------------------------------------------------------
# Seed words: ['suppos, push, need, easi, area, store, size, nice, power, canist']
# Actual aspect: ['Weight']
# Predicted aspect: ['Customer service service']
# ------------------------------------------------------------
# Epoch: 1 ID: 21
# ------------------------------------------------------------
# Seed words: ['item, plastic, smell, qualiti, cours, crack, reproduct, durabl, year, brake']
# Actual aspect: ['Quality']
# Predicted aspect: ['Customer service service']
# ------------------------------------------------------------
# Epoch: 1 ID: 22
# ------------------------------------------------------------
# Seed words: ['lightweight, hindsight, hardwar, averag, cubbyhol, bigger, perfect, actual, awkward, pound']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size and function']
# ------------------------------------------------------------
# Epoch: 1 ID: 23
# ------------------------------------------------------------
# Seed words: ['portion, fifth, burnt, burn, pop, work, sturdi, electr, break, time']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Customer service service']
# ------------------------------------------------------------
# Epoch: 1 ID: 24
# ------------------------------------------------------------
# Seed words: ['difficult, space, perfect, volum, key, proof, bar, place, end, insert']
# Actual aspect: ['Layout']
# Predicted aspect: ['Customer service service']
# ------------------------------------------------------------
# Epoch: 1 ID: 25
# ------------------------------------------------------------
# Seed words: ['calcul, multimedia, blue, wake, shortcut, remain, dark, clutch, button, support']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Epoch: 1 ID: 26
# ------------------------------------------------------------
# Seed words: ['francisco, ice, claim, raini, step, snow, den, porous, island, water']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Size Size']
# ------------------------------------------------------------
# Epoch: 12 ID: 14
# ------------------------------------------------------------
# Seed words: ['lift, comfort, left, later, hand, sooner, safe, addit, note, broke']
# Actual aspect: ['Handles']
# Predicted aspect: ['Handles Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 15
# ------------------------------------------------------------
# Seed words: ['break, summer, enjoy, light, sued, discomfort, insid, weight, perfect, super']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Comfort Comfort']
# ------------------------------------------------------------
# Epoch: 12 ID: 16
# ------------------------------------------------------------
# Seed words: ['watch, flash, work, dlna, speed, connect, 45, input, port, connect']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 17
# ------------------------------------------------------------
# Seed words: ['vista, keypress, disk, dark, backlight, eject, email, pre, remain, power']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Extra functionality in']
# ------------------------------------------------------------
# Epoch: 12 ID: 18
# ------------------------------------------------------------
# Seed words: ['unbeliev, gorgeous, purchas, look, color, love, blue, love, style, taup']
# Actual aspect: ['Color']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 12 ID: 19
# ------------------------------------------------------------
# Seed words: ['jump, snap, retract, cannist, constant, wall, eas, person, cord, flexibl']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Ease of']
# ------------------------------------------------------------
# Epoch: 12 ID: 20
# ------------------------------------------------------------
# Seed words: ['feel, cheap, keyboard, attract, look, small, pc, longer, laptop, good']
# Actual aspect: ['Looks']
# Predicted aspect: ['Looks Look Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 21
# ------------------------------------------------------------
# Seed words: ['speak, divx, fact, entir, pilot, clear, glove, po, handl, reschedul']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Handles Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 22
# ------------------------------------------------------------
# Seed words: ['love, stylish, environ, pictur, moccasin, durabl, crazi, direct, comfort, casual']
# Actual aspect: ['Look']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 12 ID: 23
# ------------------------------------------------------------
# Seed words: ['nozzl, mous, quiet, direct, noisi, readi, deafen, lose, function, star']
# Actual aspect: ['Noise']
# Predicted aspect: ['Noise Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 24
# ------------------------------------------------------------
# Seed words: ['especi, nice, light, hard, maneuv, heavier, small, compact, size, rug']
# Actual aspect: ['Weight']
# Predicted aspect: ['Compartments Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 25
# ------------------------------------------------------------
# Seed words: ['construct, tast, protect, protect, good, realli, trust, use, secur, kensington']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 26
# ------------------------------------------------------------
# Seed words: ['thinner, barn, red, sure, long, month, sol, use, time, constant']
# Actual aspect: ['Durability']
# Predicted aspect: ['Weather resistance Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 27
# ------------------------------------------------------------
# Seed words: ['action, mushi, navig, feel, butteri, type, quick, dissatisfi, chicklet, feather']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Feeling Comfort']
# ------------------------------------------------------------
# Epoch: 12 ID: 28
# ------------------------------------------------------------
# Seed words: ['sued, term, easili, best, especi, rubber, barn, elast, decor, natur']
# Actual aspect: ['Materials']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 12 ID: 29
# ------------------------------------------------------------
# Seed words: ['ear, font, screen, affect, ok, irrit, dead, nice, imag, fuzzi']
# Actual aspect: ['Image']
# Predicted aspect: ['Extra functionality Look']
# ------------------------------------------------------------
# Epoch: 12 ID: 30
# ------------------------------------------------------------
# Seed words: ['right, far, weight, ok, money, spin, pricey, cheap, mayb, duster']
# Actual aspect: ['Price']
# Predicted aspect: ['Price Look Look']
#  87%|████████▋ | 13/15 [02:23<00:21, 10.98s/it]
# Epoch 13:	Training Loss 0.40
# ------------------------------------------------------------
# Epoch: 13 ID: 0
# ------------------------------------------------------------
# Seed words: ['origin, lttle, feel, size, attract, imac, keyboard, laptop, good, great']
# Actual aspect: ['Looks']
# Predicted aspect: ['Feel Comfort Comfort']
# ------------------------------------------------------------
# Epoch: 13 ID: 1
# ------------------------------------------------------------
# Seed words: ['great, lack, hear, strong, junki, mind, surround, chang, improv, cool']
# Actual aspect: ['Sound']
# Predicted aspect: ['Comfort Sound']
# ------------------------------------------------------------
# Epoch: 13 ID: 2
# ------------------------------------------------------------
# Seed words: ['broken, addit, buckl, metal, shorter, hand, adjust, long, later, firm']
# Actual aspect: ['Handles']
# Predicted aspect: ['Handles Look']
# ------------------------------------------------------------
# Epoch: 13 ID: 3
# ------------------------------------------------------------
# Seed words: ['sole, aw, fashion, fleec, memori, thinner, finish, describ, sued, best']
# Actual aspect: ['Materials']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 13 ID: 4
# ------------------------------------------------------------
# Seed words: ['like, satisfi, sit, stick, type, tap, dissatisfi, stylish, deceler, velvet']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Epoch: 13 ID: 5
# ------------------------------------------------------------
# Seed words: ['reduct, adapt, player, small, jacket, space, open, run, instead, nois']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Size Fit Look']
# ------------------------------------------------------------
# Epoch: 13 ID: 6
# ------------------------------------------------------------
# Seed words: ['feel, loud, canist, panason, size, power, feaur, quit, bagless, nice']
# Actual aspect: ['Weight']
# Predicted aspect: ['Size Look Look']
# ------------------------------------------------------------
# Epoch: 13 ID: 7
# ------------------------------------------------------------
# Seed words: ['tab, wide, wear, small, littl, perfect, ankl, follow, moccasin, tight']
# Actual aspect: ['Size']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# Epoch: 13 ID: 8
# ------------------------------------------------------------
# Seed words: ['differ, look, irrit, angl, qualiti, sharp, corner, notic, bright, decent']
# Actual aspect: ['Image']
# Predicted aspect: ['Looks look good']
# ------------------------------------------------------------
# Epoch: 13 ID: 9
# ------------------------------------------------------------
# Seed words: ['birth, final, defect, rip, chemic, edg, left, materi, excel, go']
# Actual aspect: ['Quality']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Epoch: 13 ID: 10
# ------------------------------------------------------------
# Seed words: ['place, arrow, overs, insert, space, movement, horizont, proof, place, strike']
# Actual aspect: ['Layout']
# Predicted aspect: ['Handles of']
# ------------------------------------------------------------
# Epoch: 13 ID: 11
# ------------------------------------------------------------
# Seed words: ['airi, light, laid, coverag, absolut, cute, color, pictur, concept, fring']
# Actual aspect: ['Look']
# Predicted aspect: ['Color Look Look']
# ------------------------------------------------------------
# Epoch: 13 ID: 12
# ------------------------------------------------------------
# Seed words: ['illumin, power, activ, recess, nice, vista, dark, music, featur, backlight']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Extra functionality in']
# ------------------------------------------------------------
# Epoch: 13 ID: 13
# ------------------------------------------------------------
# Seed words: ['accommod, seat, big, 13, air, pouch, tight, hp, lot, 3080us']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size Look Look']
# ------------------------------------------------------------
# Epoch: 13 ID: 14
# ------------------------------------------------------------
# Seed words: ['summer, time, attract, insid, tongu, short, toe, break, list, ankl']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# Epoch: 13 ID: 15
# ------------------------------------------------------------
# Seed words: ['ultra, perfect, suitabl, easili, live, pentil, pound, livingroom, feel, foot']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size Look Look']
# ------------------------------------------------------------
# Epoch: 13 ID: 16
# ------------------------------------------------------------
# Seed words: ['regist, video, hoover, fall, took, dealer, lubric, problem, common, busi']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer serviceCustomer']
# ------------------------------------------------------------
# Epoch: 13 ID: 17
# ------------------------------------------------------------
# Seed words: ['dirt, fault, grind, machin, quiet, spin, perfom, bear, attribut, ergorapido']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Build Quality Quality']
# ------------------------------------------------------------
# Epoch: 13 ID: 18
# ------------------------------------------------------------
# Seed words: ['pile, wall, carpet, worst, easi, automat, race, retract, cord, snap']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Ease of']
# ------------------------------------------------------------
# Epoch: 13 ID: 19
# ------------------------------------------------------------
# Seed words: ['pricey, expens, 50, spend, power, duster, think, twice, 200, bag']
# Actual aspect: ['Price']
# Predicted aspect: ['Customer Service Service']
# ------------------------------------------------------------
# Epoch: 13 ID: 20
# ------------------------------------------------------------
# Seed words: ['alright, youtub, flash, featur, download, watch, movi, smart, right, hulu']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Apps Interface Interface']
# ------------------------------------------------------------
# Epoch: 13 ID: 21
# ------------------------------------------------------------
# Seed words: ['light, block, loud, powerstick, sound, actual, star, noisi, direct, bearabl']
# Actual aspect: ['Noise']
# Predicted aspect: ['Noise Power']
# ------------------------------------------------------------
# Epoch: 13 ID: 22
# ------------------------------------------------------------
# Seed words: ['step, repel, den, perform, rain, defect, deep, warm, let, penetr']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Weather resistance.']
# ------------------------------------------------------------
# Epoch: 13 ID: 23
# ------------------------------------------------------------
# Seed words: ['power, digit, stop, drive, cabl, comcast, speed, hd, output, hdmi']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Compressories']
# ------------------------------------------------------------
# Epoch: 13 ID: 24
# ------------------------------------------------------------
# Seed words: ['sure, materi, thinner, actual, cheep, start, constant, provid, obvious, protect']
# Actual aspect: ['Durability']
# Predicted aspect: ['Protection Service']
# ------------------------------------------------------------
# Epoch: 13 ID: 25
# ------------------------------------------------------------
# Seed words: ['replac, roll, wide, eye, bag, complet, attach, clean, expens, spinner']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Accessories Interface']
# ------------------------------------------------------------
# Epoch: 13 ID: 26
# ------------------------------------------------------------
# Seed words: ['carri, shore, difficult, help, technician, communic, servic, arriv, check, pilot']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer service Service']
# ------------------------------------------------------------
# Epoch: 13 ID: 27
# ------------------------------------------------------------
# Seed words: ['unbeliev, boot, love, style, purchas, perfect, taup, blue, design, exact']
# Actual aspect: ['Color']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 13 ID: 28
# ------------------------------------------------------------
# Seed words: ['charg, love, power, batteri, turn, thing, volum, nokia, charger, simpl']
# Actual aspect: ['Battery']
# Predicted aspect: ['Noise Power']
# ------------------------------------------------------------
# Epoch: 13 ID: 29
# ------------------------------------------------------------
# Seed words: ['wise, burnt, burn, overh, prepar, poor, roller, pop, broke, electron']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Build Quality Fit']
# ------------------------------------------------------------
# Epoch: 13 ID: 30
# ------------------------------------------------------------
# Seed words: ['laptop, weak, sleev, happen, comput, count, bag, protect, feel, intern']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection Look']
#  93%|█████████▎| 14/15 [02:33<00:10, 10.82s/it]
# Epoch 14:	Training Loss 0.33
# ------------------------------------------------------------
# Epoch: 14 ID: 0
# ------------------------------------------------------------
# Seed words: ['nokia, come, blackberri, charg, easili, red, later, dead, longer, time']
# Actual aspect: ['Battery']
# Predicted aspect: ['Ease of']
# ------------------------------------------------------------
# Epoch: 14 ID: 1
# ------------------------------------------------------------
# Seed words: ['absolut, amazon, late, servic, time, recent, horribl, custom, multipl, regist']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer service Service']
# ------------------------------------------------------------
# Epoch: 14 ID: 2
# ------------------------------------------------------------
# Seed words: ['like, brows, best, movi, download, eas, hulu, quit, time, access']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Ease of']
# ------------------------------------------------------------
# Epoch: 14 ID: 3
# ------------------------------------------------------------
# Seed words: ['view, look, fantast, definit, hd, improv, affect, pictur, irrit, screen']
# Actual aspect: ['Image']
# Predicted aspect: ['Image Look Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 4
# ------------------------------------------------------------
# Seed words: ['lightweight, hardwood, area, perform, quiet, store, guess, weight, purchas, vacuum']
# Actual aspect: ['Weight']
# Predicted aspect: ['Noise Noise']
# ------------------------------------------------------------
# Epoch: 14 ID: 5
# ------------------------------------------------------------
# Seed words: ['comfort, beauti, shame, 360, concept, grey, unattract, taup, attract, offic']
# Actual aspect: ['Look']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 14 ID: 6
# ------------------------------------------------------------
# Seed words: ['burnt, burn, upper, continu, construct, easili, portion, turn, built, overheat']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Build Quality Fit']
# ------------------------------------------------------------
# Epoch: 14 ID: 7
# ------------------------------------------------------------
# Seed words: ['deliv, carri, communic, speak, 1500, latest, mention, fix, bring, downstair']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer service.']
# ------------------------------------------------------------
# Epoch: 14 ID: 8
# ------------------------------------------------------------
# Seed words: ['worst, simpic, snap, empti, person, retract, easi, maneuv, eas, cord']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Ease of']
# ------------------------------------------------------------
# Epoch: 14 ID: 9
# ------------------------------------------------------------
# Seed words: ['fre, space, cabl, air, folder, seat, tight, bulk, bare, enorm']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size Fit Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 10
# ------------------------------------------------------------
# Seed words: ['fashion, unattract, describ, materi, leather, sole, improv, piec, decor, cloth']
# Actual aspect: ['Materials']
# Predicted aspect: ['Accessories Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 11
# ------------------------------------------------------------
# Seed words: ['expect, power, light, good, weight, bag, twice, vacuum, dyson, 200']
# Actual aspect: ['Price']
# Predicted aspect: ['Weight Fit Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 12
# ------------------------------------------------------------
# Seed words: ['way, second, like, lap, perfect, bit, damag, sort, littl, good']
# Actual aspect: ['Protection']
# Predicted aspect: ['Build Quality Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 13
# ------------------------------------------------------------
# Seed words: ['blister, light, comfort, tongu, insid, snug, super, narrow, wear, break']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Comfort Comfort']
# ------------------------------------------------------------
# Epoch: 14 ID: 14
# ------------------------------------------------------------
# Seed words: ['power, perfom, quiet, attribut, mayb, stylish, hair, spot, plush, essenti']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 14 ID: 15
# ------------------------------------------------------------
# Seed words: ['mute, interest, pre, pen, programm, quit, brower, remain, clutch, capabl']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 14 ID: 16
# ------------------------------------------------------------
# Seed words: ['chang, good, weird, kinda, surround, terribl, ear, thing, develop, junki']
# Actual aspect: ['Sound']
# Predicted aspect: ['Comfort Comfort']
# ------------------------------------------------------------
# Epoch: 14 ID: 17
# ------------------------------------------------------------
# Seed words: ['love, design, wonder, boot, favorit, color, red, purchas, look, unbeliev']
# Actual aspect: ['Color']
# Predicted aspect: [' look.']
# ------------------------------------------------------------
# Epoch: 14 ID: 18
# ------------------------------------------------------------
# Seed words: ['run, folder, fit, space, safe, player, flap, headset, huge, daytim']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Size Fit Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 19
# ------------------------------------------------------------
# Seed words: ['stylish, difficult, type, deceler, chicklet, impecc, consist, quick, keystrok, dissatisfi']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Feel Comfort Comfort']
# ------------------------------------------------------------
# Epoch: 14 ID: 20
# ------------------------------------------------------------
# Seed words: ['connect, drive, comcast, conflict, slot, speed, signal, watch, higher, stop']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Customer Service Interface']
# ------------------------------------------------------------
# Epoch: 14 ID: 21
# ------------------------------------------------------------
# Seed words: ['imac, pc, longer, attract, origin, like, small, decent, nice, feel']
# Actual aspect: ['Looks']
# Predicted aspect: ['Compartments Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 22
# ------------------------------------------------------------
# Seed words: ['terribl, feel, trip, year, wear, construct, materi, rip, qualiti, excel']
# Actual aspect: ['Quality']
# Predicted aspect: ['Build Quality Quality']
# ------------------------------------------------------------
# Epoch: 14 ID: 23
# ------------------------------------------------------------
# Seed words: ['thinner, numer, clear, appear, buckl, cheapli, style, protect, durabl, differ']
# Actual aspect: ['Durability']
# Predicted aspect: ['Durability Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 24
# ------------------------------------------------------------
# Seed words: ['francisco, protect, cold, term, penetr, foot, scout, repel, raini, warm']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Weather resistance.']
# ------------------------------------------------------------
# Epoch: 14 ID: 25
# ------------------------------------------------------------
# Seed words: ['compact, 32, awkward, slim, store, live, room, screen, suitabl, 40']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size Look Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 26
# ------------------------------------------------------------
# Seed words: ['powerstick, serious, mous, reason, earplug, explod, turn, ring, motor, lightweight']
# Actual aspect: ['Noise']
# Predicted aspect: ['ction Power']
# ------------------------------------------------------------
# Epoch: 14 ID: 27
# ------------------------------------------------------------
# Seed words: ['clean, brush, extens, eye, instead, expens, spinner, clean, cover, duster']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Epoch: 14 ID: 28
# ------------------------------------------------------------
# Seed words: ['especi, sould, run, joint, buyer, normal, wide, superb, calf, length']
# Actual aspect: ['Size']
# Predicted aspect: ['. Look']
# ------------------------------------------------------------
# Epoch: 14 ID: 29
# ------------------------------------------------------------
# Seed words: ['inevit, broken, loop, comfort, handl, holiday, break, bend, rip, control']
# Actual aspect: ['Handles']
# Predicted aspect: ['Ease of']
# ------------------------------------------------------------
# Epoch: 14 ID: 30
# ------------------------------------------------------------
# Seed words: ['perfect, layout, wider, impecc, place, scroll, home, wide, delet, print']
# Actual aspect: ['Layout']
# Predicted aspect: ['. Look']
# 100%|██████████| 15/15 [02:43<00:00, 10.91s/it]
# Epoch 15:	Training Loss 0.37

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(all_train_loss, ls='-.', marker = 'X', color='blue')

# %% [markdown]
# ### Generation for the topics of CTM
# --------------------------------------------

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
stemmer = SnowballStemmer(language='english')

# %%
stemmed_electronic_topics = []
for each_topic in electronic_topics:
    tmp_ = [stemmer.stem(x) for x in each_topic]
    stemmed_electronic_topics.append(tmp_)

# %%
model_args['seed_samples']
# Out:
# 10

# %%
model.eval()
for each_topic in stemmed_electronic_topics:
    topic_seeds = each_topic[:model_args['seed_samples']]
    in_tokenized = tokenizer(', '.join(topic_seeds), 
                             truncation=True)  
    in_ids = torch.LongTensor(in_tokenized.input_ids)
    in_ids = in_ids.to('cuda')
    in_ids = in_ids.unsqueeze(0)
    op_ids = model.generate(in_ids, 
                            num_beams=3, 
                            max_length=6)
    print('Seeds:', topic_seeds)
    print('Predicted aspect:', tokenizer.batch_decode(op_ids, 
                                                      skip_special_tokens=True, 
                                                      clean_up_tokenization_spaces=True))
    print('--'*30)
# Out:
# Seeds: ['construct', 'valu', 'exceed', 'outstand', 'light', 'weight', 'attract', 'versatil', 'excel', 'valu']
# Predicted aspect: [' of life']
# ------------------------------------------------------------
# Seeds: ['deck', 'patio', 'beach', 'loud', 'camp', 'parti', 'hous', 'everywh', 'portabl', 'backyard']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['pick', 'channel', 'local', 'live', 'signal', 'station', 'abl', 'pick', 'recept', 'citi']
# Predicted aspect: ['Apps']
# ------------------------------------------------------------
# Seeds: ['instal', 'wall', 'inch', 'hung', 'mount', 'sturdi', 'articul', 'hardwar', 'motion', 'vizio']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# Seeds: ['dac', 'pono', 'listen', 'fiio', 'amp', 'hi', 'audio', 'iem', 'hi', 'res']
# Predicted aspect: ['. Look']
# ------------------------------------------------------------
# Seeds: ['usb', 'outlet', 'adapt', 'travel', 'prong', 'usb', 'port', 'port', 'hotel', 'strip']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['voic', 'record', 'mini', 'usb', 'usb', 'micro', 'sd', 'nano', 'button', 'wheel']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['wast', 'money', 'wast', 'money', 'worth', 'money', 'save', 'money', 'spend', 'money']
# Predicted aspect: ['Money']
# ------------------------------------------------------------
# Seeds: ['adverti', 'earlier', 'exact', 'describ', 'condit', 'descript', 'promi', 'manner', 'sooner', 'right']
# Predicted aspect: ['. Look']
# ------------------------------------------------------------
# Seeds: ['asid', 'bottom', 'line', 'reflect', 'hope', 'help', 'huge', 'deal', 'www', 'amazon']
# Predicted aspect: [' service.']
# ------------------------------------------------------------
# Seeds: ['daughter', 'son', 'school', 'trip', 'wife', 'colleg', 'dad', 'brought', 'vacat', 'mom']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# Seeds: ['volum', 'button', 'anker', 'play', 'clear', 'hour', 'box', 'loud', 'control', 'design']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# Seeds: ['discharg', 'aaa', 'charger', 'recharg', 'volt', 'aa', 'mah', 'capac', 'apc', 'voltag']
# Predicted aspect: ['. Power']
# ------------------------------------------------------------
# Seeds: ['stay', 'fall', 'hurt', 'stay', 'place', 'wear', 'stay', 'put', 'bud', 'uncomfort']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Seeds: ['switch', 'disc', 'unit', 'dvd', 'box', 'error', 'softwar', 'issu', 'remot', 'turn']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# Seeds: ['suction', 'suction', 'cup', 'shower', 'water', 'loud', 'water', 'resist', 'bathroom', 'splash']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# Seeds: ['bulb', 'lamp', 'new', 'origin', 'oem', 'smell', 'brand', 'pictur', 'color', 'bright']
# Predicted aspect: ['. Look']
# ------------------------------------------------------------
# Seeds: ['comfort', 'control', 'headset', 'cord', 'earbud', 'run', 'wear', 'button', 'volum', 'hear']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Seeds: ['best', 'ever', 'penni', 'worth', 'everi', 'everi', 'penni', 'ever', 'far', 'best']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# Seeds: ['connector', 'gaug', 'length', 'wire', 'solder', 'femal', 'flexibl', 'gaug', 'wire', 'cord']
# Predicted aspect: ['Connect']
# ------------------------------------------------------------
# Seeds: ['macbook', 'dvd', 'player', 'mac', 'older', 'convert', 'macbook', 'pro', 'laptop', 'monitor']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# Seeds: ['antenna', 'channel', 'signal', 'instal', 'roof', 'attic', 'put', 'mount', 'antenna', 'wall']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['amazon', 'custom', 'support', 'warranti', 'custom', 'return', 'email', 'sent', 'servic', 'contact']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Seeds: ['hear', 'movi', 'noi', 'aid', 'plane', 'flight', 'watch', 'hear', 'aid', 'block']
# Predicted aspect: ['Noise']
# ------------------------------------------------------------
# Seeds: ['bose', 'beat', 'noi', 'cancel', 'noi', 'cancel', 'earbud', 'comfort', 'amaz', 'plane']
# Predicted aspect: ['Noise']
# ------------------------------------------------------------
# Seeds: ['case', 'sleev', 'zipper', 'cover', 'clean', 'dvd', 'dvds', 'collect', 'zip', 'page']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# Seeds: ['pad', 'foam', 'comfort', 'earpad', 'plastic', 'feel', 'bit', 'tip', 'stock', 'pad']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# Seeds: ['screw', 'wall', 'mount', 'screen', 'hole', 'put', 'hold', 'tighten', 'drill', 'made']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# Seeds: ['remot', 'remot', 'control', 'key', 'program', 'button', 'misplac', 'light', 'origin', 'dig']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['ok', 'wish', 'static', 'tooth', 'volum', 'control', 'blue', 'tooth', 'louder', 'random']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# Seeds: ['asid', 'www', 'www', 'amazon', 'meant', 'keep', 'mind', 'due', 'fact', 'huge']
# Predicted aspect: [' power.']
# ------------------------------------------------------------
# Seeds: ['fast', 'deliv', 'faster', 'quick', 'deliveri', 'ship', 'fast', 'ship', 'shipment', 'prompt']
# Predicted aspect: ['Customer']
# ------------------------------------------------------------
# Seeds: ['cd', 'player', 'cd', 'play', 'folder', 'player', 'song', 'album', 'record', 'cassett']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# Seeds: ['broke', 'within', 'stop', 'left', 'side', 'week', 'broken', 'coupl', 'week', 'within']
# Predicted aspect: ['Customer']
# ------------------------------------------------------------
# Seeds: ['swim', 'lap', 'underwat', 'earbud', 'run', 'waterproof', 'bud', 'stay', 'sweat', 'water']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# Seeds: ['control', 'remot', 'system', 'harmoni', 'audio', 'ir', 'app', 'turn', 'sono', 'switch']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# Seeds: ['gold', 'plate', 'connector', 'hdmi', 'gold', 'audio', 'adapt', 'port', 'male', 'splitter']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# Seeds: ['radio', 'station', 'clock', 'radio', 'station', 'clock', 'radio', 'fm', 'wake', 'emerg']
# Predicted aspect: ['Radio']
# ------------------------------------------------------------
# Seeds: ['thank', 'seller', 'satisfi', 'servic', 'thank', 'amazon', 'custom', 'servic', 'plea', 'happi']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# Seeds: ['system', 'sub', 'subwoof', 'room', 'polk', 'bose', 'amp', 'unit', 'woofer', 'watt']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------

# %%
Aspect_to_seeds.keys()
# Out:
# dict_keys(['Compartments', 'Price', 'Handles', 'Customer_service', 'Looks', 'Quality', 'Protection', 'Size_Fit', 'Ease_of_use', 'Sound', 'Look', 'Connectivity', 'Battery', 'Durability', 'Comfort', 'Materials', 'Color', 'Size', 'Weather_resistance', 'Noise', 'Extra_functionality', 'Layout', 'Feel_Comfort', 'Build_Quality', 'Size_Look', 'Image', 'Apps_Interface', 'Suction_Power', 'Weight', 'Customer_Service', 'Accessories'])

# %%
import pickle as pkl
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))
# Aspect_to_seeds.keys()
# [x for x in Aspect_to_seeds if 'weather' in x.lower()]

# %%
[x for x in Aspect_to_seeds if 'weather' in x.lower()]
# Out:
# ['Weather_resistance']

# %%
Aspect_to_seeds['Weather_resistance']
# Out:
# ['dri',
#  'waterproof',
#  'rain',
#  'wet',
#  'water',
#  'foot',
#  'soak',
#  'snow',
#  'cold',
#  'puddl',
#  'warm',
#  'got',
#  'chicago',
#  'protect',
#  'suppos',
#  'defect',
#  'item',
#  'traction',
#  'raini',
#  'interest',
#  'ice',
#  'spent',
#  'cub',
#  'scout',
#  'den',
#  'alcatraz',
#  'island',
#  'san',
#  'francisco',
#  'lot',
#  'claim',
#  'stori',
#  'resist',
#  'generous',
#  'porous',
#  'term',
#  'dewi',
#  'grass',
#  'leav',
#  'soak',
#  'let',
#  'penetr',
#  'perform',
#  'repel',
#  'sandal',
#  'stay',
#  'amaz',
#  'outsid',
#  'step',
#  'deep',
#  '']

# %%
#         """Return sample from dataset at index i."""
#         example = self.list_data[i]
#         shuffle(example['seeds'])
#         sampled_seeds = example['seeds'][:self.seeds_length]
#         aspect = " ".join(example["aspect"].split('_'))
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            truncation=True)  
#         outputs = tokenizer(aspect, 
#                             padding="max_length", 
#                             truncation=True, 
#                             max_length=self.aspect_length)
        
#         batch = {}
#         batch["input_ids"] = torch.LongTensor(inputs.input_ids)
#         batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["labels"] = outputs.input_ids.copy()
#         batch['labels'] = [batch['labels']]

#         batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
#                            for labels in batch["labels"]]
#         batch["labels"] = torch.LongTensor(batch["labels"])
#         batch["labels"] = batch["labels"].squeeze(0)
        
#         return batch

# %%
# chk_1 =tokenizer('MaterialsComp', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_1['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_2 =tokenizer('Ease of use', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_2['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_ = tokenizer('Compartments', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=4)

# %%
# tokenizer.batch_decode(chk_['input_ids'], 
#                        skip_special_tokens=True, 
#                        clean_up_tokenization_spaces=False)

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
electronic_topics = [x[:20] for x in electronic_topics]

# %%
test_data = []
for each_e_top in electronic_topics:
    test_data.append({'seeds': each_e_top[:20], 'aspect':'TestSet'})

# %%
test_dataset = aspectDataset(list_data=test_data, 
                              tokenizer=tokenizer)

# %%
test_loader = DataLoader(test_dataset, 
                         batch_size=1, 
                         shuffle=True,
                         num_workers=1)

# %%
model.eval()
for ind, batch in enumerate(test_loader):
    batch = {k: v.to('cuda') for k, v in batch.items()}
    model_op = model(**batch)
    print('---'*20)
    print('ID:', ind)
    print('---'*20)
    print('Seed words:', tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    print('Actual aspect:', tokenizer.batch_decode(batch['decoder_input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
    print('Predicted aspect:', tokenizer.batch_decode(output_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True))

# %% [raw]
# 1. Sample 5-10 for each aspect. Get top 50 and then sample 10 each. done
# 2. Start from the bart-large and not cnn. done
# 3. Use very small learning rate (2e-5)| 1e-6 or 5e-7. done
# 4. Put a comma with the words. done
# 5. Stem the training data words. done
#
#
# Run it on our topics.
# -

# %%
model_op['logits'].squeeze(dim=0).shape

# %%
torch.argmax(model_op['logits'].squeeze(dim=0), dim=1)

# %% [markdown]
# ## Orphan Code
# -------------

# %%
print(another_way_to_train)
for epoch in range(num_epochs):
    training_loss = 0.0
    model.train()
    for batch in tqdm(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        # Get the "input's representation"
        encoder_output = the_encoder(input_ids = batch['input_ids'],
                                   attention_mask = batch['attention_mask'])
      
        # Pass the representation + the target summary to the decoder
        decoder_output = the_decoder(input_ids=batch['decoder_input_ids'],
                                   attention_mask=batch['decoder_attention_mask'],
                                   encoder_hidden_states=encoder_output[0],
                                   encoder_attention_mask=batch['attention_mask'])

        # Use the last linear layer to predict the next token
        decoder_output = decoder_output.last_hidden_state
        lm_head_output = last_linear_layer(decoder_output)
        
        # Compute the loss
        loss = loss_fct(lm_head_output.view(-1, model.config.vocab_size),
                      batch['labels'].view(-1))
        training_loss += loss.item()
        
        loss.backward() # Update the weights
        optimizer.step() # Notify optimizer that a batch is done.
        lr_scheduler.step() # Notify the scheduler that a ...
        optimizer.zero_grad() # Reset the optimer
    training_loss = training_loss / len( train_data )
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))

# %%
lm_head_output.view(-1, model.config.vocab_size)
