# %%
import torch
import random
import pandas as pd
import pickle as pkl
from tqdm import tqdm
from os import listdir
from os.path import join
from random import shuffle
from transformers import AdamW
from matplotlib import pyplot as plt
from torch.nn import CrossEntropyLoss
from transformers import get_scheduler
from pdb import set_trace as breakpoint
from nltk.stem.snowball import SnowballStemmer
from torch.utils.data import Dataset, DataLoader
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
# %matplotlib inline

# %%
# folders = ['bags_and_cases', 'bluetooth', 'boots', 'keyboards', 'tv', 'vacuums']

# base_dir = '/mnt/nfs/work1/hongyu/brawat/amzn/oposum/data/seeds'

# list_aspects = []
# Aspect_to_seeds = {}
# stemmer = SnowballStemmer(language='english')
# for each_folder in folders:
#     folder_dir = join(base_dir, each_folder)
#     print('--'*20)
#     print(each_folder)
#     print('--'*20)
#     txt_files = listdir(folder_dir)
#     txt_files = [x for x in txt_files if 'None' not in x]
#     print(txt_files)
#     for each_txt in txt_files:
#         txt_dir = join(folder_dir, each_txt)
#         txt = open(txt_dir).read()
#         txt = txt.split('\n')
#         txt = [x.split(' ')[-1] for x in txt]
#         txt = [x.strip() for x in txt]
#         txt = [stemmer.stem(x) for x in txt]
#         aspect = each_txt.split('.')[1]
#         Aspect_to_seeds[aspect] = txt

# %%
# for each_aspect in Aspect_to_seeds:
#     print(each_aspect, Aspect_to_seeds[each_aspect].__len__())

# %%
# pkl.dump(Aspect_to_seeds, open('Aspect_to_seeds_march19.pkl', 'wb'))

# %%
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))

# %%
Aspect_to_seeds
# Out:
# {'Compartments': ['pocket',
#   'cabl',
#   'compart',
#   'outsid',
#   'lot',
#   'wish',
#   'wallet',
#   'connector',
#   'space',
#   'power',
#   'pen',
#   'folder',
#   'charger',
#   'flap',
#   'mous',
#   'nice',
#   'thing',
#   'insid',
#   'small',
#   'paperwork',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'construct',
#   'medium',
#   'player',
#   'wire',
#   'run',
#   'headphon',
#   'key',
#   'instead',
#   'huge',
#   'need',
#   'open',
#   'fit',
#   'headset',
#   'outer',
#   'planner',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'cellphon',
#   'save',
#   'document',
#   ''],
#  'Price': ['price',
#   'money',
#   'feaur',
#   'paid',
#   'spin',
#   'spun',
#   'mayb',
#   'cheap',
#   '200',
#   'spend',
#   'right',
#   'vaccum',
#   'twice',
#   'expect',
#   'pricey',
#   '50',
#   'expens',
#   'worth',
#   'far',
#   'wast',
#   'duster',
#   'think',
#   'bagless',
#   'best',
#   'dyson',
#   'need',
#   'ok',
#   'weight',
#   'bag',
#   'power',
#   'light',
#   'like',
#   'good',
#   'vacuum',
#   ''],
#  'Handles': ['strap',
#   'handl',
#   'shoulder',
#   'broke',
#   'later',
#   'month',
#   'hand',
#   'comfort',
#   'plastic',
#   'wear',
#   'tear',
#   'rip',
#   'start',
#   'attach',
#   'holiday',
#   'left',
#   'lift',
#   'final',
#   'broken',
#   'stand',
#   'inevit',
#   'situat',
#   'firm',
#   'bend',
#   'hurt',
#   'minut',
#   'addit',
#   'note',
#   'buckl',
#   'adjust',
#   'adjust',
#   'short',
#   'shorter',
#   'length',
#   'adjust',
#   'long',
#   'metal',
#   'swivel',
#   'sooner',
#   'break',
#   'felt',
#   'rip',
#   'loop',
#   'hook',
#   'torn',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'use',
#   ''],
#  'Customer_service': ['paid',
#   'support',
#   'servic',
#   'week',
#   'replac',
#   'mail',
#   'wait',
#   'pay',
#   'ship',
#   '1500',
#   'bring',
#   'deliveri',
#   'come',
#   'use',
#   'peopl',
#   'speak',
#   'technician',
#   'refurbish',
#   'handl',
#   'shore',
#   'communic',
#   'difficult',
#   '49',
#   'diagnost',
#   'fee',
#   '100',
#   'fix',
#   'latest',
#   'divx',
#   'arriv',
#   'undamag',
#   'po',
#   'mention',
#   'desk',
#   'help',
#   'suppos',
#   'later',
#   'cancel',
#   'reschedul',
#   'entir',
#   'glove',
#   'pilot',
#   'deliv',
#   'fact',
#   'clear',
#   'requir',
#   '100lb',
#   'carri',
#   'downstair',
#   'check',
#   ''],
#  'Looks': ['look',
#   'slim',
#   'origin',
#   'appear',
#   'lttle',
#   'attract',
#   'beauti',
#   'size',
#   'small',
#   'decent',
#   'imac',
#   'backlit',
#   'longer',
#   'pc',
#   'like',
#   'laptop',
#   'nice',
#   'great',
#   'cheap',
#   'keyboard',
#   'good',
#   'feel',
#   ''],
#  'Quality': ['qualiti',
#   'materi',
#   'handl',
#   'poor',
#   'broke',
#   'durabl',
#   'month',
#   'later',
#   'wear',
#   'tear',
#   'zipper',
#   'chemic',
#   'start',
#   'excel',
#   'terribl',
#   'crack',
#   'strap',
#   'daili',
#   'plastic',
#   'pull',
#   'smell',
#   'edg',
#   'rip',
#   'white',
#   'item',
#   'year',
#   'go',
#   'feel',
#   'attach',
#   'brake',
#   'holiday',
#   'outstand',
#   'strip',
#   'peel',
#   'left',
#   'final',
#   'broken',
#   'stand',
#   'sacrific',
#   'durabl',
#   'style',
#   'cours',
#   'trip',
#   'asia',
#   'rip',
#   'construct',
#   'cancer',
#   'birth',
#   'defect',
#   'reproduct',
#   ''],
#  'Protection': ['protect',
#   'pad',
#   'protect',
#   'protect',
#   'drop',
#   'lap',
#   'insid',
#   'comput',
#   'laptop',
#   'good',
#   'let',
#   'secur',
#   'damag',
#   'intern',
#   'weak',
#   'tast',
#   'trust',
#   'protect',
#   'construct',
#   'provid',
#   'second',
#   'protect',
#   'count',
#   'sort',
#   'happen',
#   'cushion',
#   'adequ',
#   'thing',
#   'pencil',
#   'heavi',
#   'normal',
#   'kensington',
#   'probabl',
#   'larg',
#   'like',
#   'way',
#   'stylish',
#   'far',
#   'sleev',
#   'pad',
#   'feel',
#   'realli',
#   'perfect',
#   'bit',
#   'littl',
#   'bag',
#   'macbook',
#   'love',
#   'use',
#   ''],
#  'Size_Fit': ['fit',
#   'size',
#   'macbook',
#   'big',
#   'space',
#   'air',
#   'slight',
#   'lot',
#   'bulk',
#   'perfect',
#   'inch',
#   'laptop',
#   'perfect',
#   '13',
#   'cabl',
#   'folder',
#   'notebook',
#   'sure',
#   'snug',
#   'bit',
#   'te',
#   'seat',
#   'airplan',
#   'fre',
#   'cell',
#   'pouch',
#   'tight',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'enorm',
#   '17inch',
#   'bare',
#   'm1710',
#   'hp',
#   'pavilion',
#   'dv7',
#   '3080us',
#   'disappoint',
#   'cloth',
#   'whatnot',
#   'spacious',
#   'book',
#   'load',
#   'accommod',
#   ''],
#  'Ease_of_use': ['easi',
#   'cord',
#   'push',
#   'corner',
#   'vacuum',
#   'pile',
#   'maneuv',
#   'nozzl',
#   'awkward',
#   'crevic',
#   'constant',
#   'bog',
#   'imposs',
#   'short',
#   'carpet',
#   'heavi',
#   'roller',
#   'hose',
#   'difficult',
#   'wall',
#   'suck',
#   'remov',
#   'empti',
#   'power',
#   'hard',
#   'jump',
#   'simpic',
#   'automat',
#   'retractor',
#   'retract',
#   'flash',
#   'baseboard',
#   'retract',
#   'easier',
#   'snap',
#   'disassembl',
#   'direct',
#   'propel',
#   'person',
#   'race',
#   'furnitur',
#   'flexibl',
#   'kink',
#   'prefer',
#   'cannist',
#   'car',
#   'refriger',
#   'move',
#   'eas',
#   'worst',
#   ''],
#  'Sound': ['sound',
#   'speaker',
#   'good',
#   'qualiti',
#   'loud',
#   'tinni',
#   'bass',
#   'hear',
#   'horribl',
#   'trebl',
#   'chang',
#   'realli',
#   'great',
#   'terribl',
#   'bar',
#   'display',
#   'thing',
#   'eye',
#   'ear',
#   'loudest',
#   'volum',
#   'strain',
#   'quieter',
#   'dinner',
#   'lack',
#   'sort',
#   'improv',
#   'surround',
#   'true',
#   'experi',
#   'junki',
#   'mind',
#   'vibrat',
#   'develop',
#   'pitch',
#   'whine',
#   'strong',
#   'track',
#   'cool',
#   'worthi',
#   'shippabl',
#   'adjust',
#   'weird',
#   'kinda',
#   'improv',
#   'cheapest',
#   'laptop',
#   'watt',
#   'muffl',
#   'margin',
#   ''],
#  'Look': ['cute',
#   'look',
#   'look',
#   'great',
#   'fring',
#   'style',
#   'color',
#   'love',
#   'design',
#   'go',
#   'unattract',
#   'attract',
#   'offic',
#   'environ',
#   'pictur',
#   '360',
#   'degre',
#   'vent',
#   'concept',
#   'coverag',
#   'airi',
#   'hang',
#   'unattract',
#   'durabl',
#   'nice',
#   'casual',
#   'beauti',
#   'moccasin',
#   'shame',
#   'taup',
#   'direct',
#   'smooth',
#   'laid',
#   'rest',
#   'natur',
#   'calm',
#   'absolut',
#   'ador',
#   'pictur',
#   'grey',
#   'wonder',
#   'stylish',
#   'comfort',
#   'boot',
#   'good',
#   'collaps',
#   'super',
#   'crazi',
#   'light',
#   'weight',
#   ''],
#  'Connectivity': ['hdmi',
#   'port',
#   'comput',
#   'input',
#   'compon',
#   'usb',
#   'internet',
#   'connect',
#   'output',
#   'server',
#   'connect',
#   'audio',
#   'play',
#   'stop',
#   'standard',
#   'avi',
#   'like',
#   'hd',
#   'file',
#   'movi',
#   'work',
#   'digit',
#   'monitor',
#   'comcast',
#   'connect',
#   'drive',
#   'end',
#   'cabl',
#   'watch',
#   'netflix',
#   'flash',
#   '45',
#   'min',
#   'rf',
#   'vga',
#   'cycl',
#   'signal',
#   'higher',
#   'slot',
#   'integr',
#   'wi',
#   'fi',
#   'stream',
#   'speed',
#   'conflict',
#   'dhcp',
#   'hard',
#   'dlna',
#   'enabl',
#   'power',
#   ''],
#  'Battery': ['batteri',
#   'charg',
#   'life',
#   'charger',
#   'charg',
#   'tone',
#   'longer',
#   'low',
#   'hour',
#   'power',
#   'light',
#   'color',
#   'red',
#   'respond',
#   'merit',
#   'vari',
#   'recharg',
#   'bizarr',
#   'later',
#   'sudden',
#   'dead',
#   'meter',
#   'hold',
#   'thing',
#   'half',
#   'green',
#   'stop',
#   'nokia',
#   'turn',
#   'start',
#   'blackberri',
#   'star',
#   'phone',
#   'good',
#   'day',
#   'cell',
#   'come',
#   'talk',
#   'get',
#   'simpl',
#   'pretti',
#   'love',
#   'better',
#   'easili',
#   'volum',
#   'nois',
#   'time',
#   'work',
#   ''],
#  'Durability': ['rubber',
#   'qualiti',
#   'use',
#   'buckl',
#   'appear',
#   'heel',
#   'long',
#   'time',
#   'break',
#   'enjoy',
#   'provid',
#   'protect',
#   'clear',
#   'cheapli',
#   'thinner',
#   'barn',
#   'month',
#   'start',
#   'tear',
#   'constant',
#   'fold',
#   'gone',
#   'numer',
#   'decor',
#   'come',
#   'sturdi',
#   'sure',
#   'durabl',
#   'decent',
#   'cheep',
#   'deflat',
#   'daili',
#   'wear',
#   'collaps',
#   'super',
#   'need',
#   'sol',
#   'red',
#   'obvious',
#   'differ',
#   'think',
#   'worn',
#   'abl',
#   'materi',
#   'actual',
#   'pretti',
#   'heavi',
#   'true',
#   'style',
#   'support',
#   ''],
#  'Comfort': ['comfort',
#   'fit',
#   'foot',
#   'hurt',
#   'ankl',
#   'comfi',
#   'blister',
#   'comfort',
#   'break',
#   'wear',
#   'abl',
#   'extrem',
#   'walk',
#   'sock',
#   'longer',
#   'pain',
#   'perfect',
#   'super',
#   'uncomfort',
#   'light',
#   'weight',
#   'discomfort',
#   'snug',
#   'put',
#   'slide',
#   'sued',
#   'feel',
#   'littl',
#   'time',
#   'narrow',
#   'toe',
#   'minut',
#   'summer',
#   'insid',
#   'short',
#   'long',
#   'wear',
#   'perfect',
#   'list',
#   'doc',
#   'tongu',
#   'moment',
#   'break',
#   'enjoy',
#   'plus',
#   'actual',
#   'loos',
#   'attract',
#   'offic',
#   'environ',
#   ''],
#  'Materials': ['leather',
#   'insid',
#   'fring',
#   'materi',
#   'heel',
#   'cheaper',
#   'soft',
#   'sole',
#   'buckl',
#   'sued',
#   'true',
#   'rubber',
#   'advertis',
#   'fact',
#   'cloth',
#   'back',
#   'synthet',
#   'finish',
#   'aerosol',
#   'line',
#   'aw',
#   'memori',
#   'foam',
#   'thinner',
#   'barn',
#   'decor',
#   'come',
#   'hang',
#   'unattract',
#   'fashion',
#   'porous',
#   'term',
#   'best',
#   'describ',
#   'let',
#   'penetr',
#   'piec',
#   'elast',
#   'zipper',
#   'friction',
#   'easili',
#   'improv',
#   'fleec',
#   'especi',
#   'superb',
#   'direct',
#   'smooth',
#   'natur',
#   'calm',
#   'hollow',
#   ''],
#  'Color': ['color',
#   'love',
#   'style',
#   'unbeliev',
#   'gorgeous',
#   'blue',
#   'favorit',
#   'taup',
#   'wonder',
#   'red',
#   'exact',
#   'design',
#   'purchas',
#   'love',
#   'materi',
#   'look',
#   'perfect',
#   'look',
#   'boot',
#   ''],
#  'Size': ['size',
#   'order',
#   'half',
#   'order',
#   'big',
#   'littl',
#   'bigger',
#   'usual',
#   'narrow',
#   'normal',
#   'width',
#   'true',
#   'run',
#   'small',
#   'size',
#   'larger',
#   'perfect',
#   'fit',
#   'sent',
#   'ankl',
#   'wide',
#   'tight',
#   'baggi',
#   'wise',
#   'tuck',
#   'pant',
#   'follow',
#   'advic',
#   'buyer',
#   'bacaus',
#   'possibl',
#   'joint',
#   'especi',
#   'superb',
#   'beauti',
#   'moccasin',
#   'shame',
#   'sould',
#   'larg',
#   'awar',
#   'length',
#   'tab',
#   'decid',
#   'normal',
#   'option',
#   'shorter',
#   'left',
#   'mayb',
#   'wear',
#   'calf',
#   ''],
#  'Weather_resistance': ['dri',
#   'waterproof',
#   'rain',
#   'wet',
#   'water',
#   'foot',
#   'soak',
#   'snow',
#   'cold',
#   'puddl',
#   'warm',
#   'got',
#   'chicago',
#   'protect',
#   'suppos',
#   'defect',
#   'item',
#   'traction',
#   'raini',
#   'interest',
#   'ice',
#   'spent',
#   'cub',
#   'scout',
#   'den',
#   'alcatraz',
#   'island',
#   'san',
#   'francisco',
#   'lot',
#   'claim',
#   'stori',
#   'resist',
#   'generous',
#   'porous',
#   'term',
#   'dewi',
#   'grass',
#   'leav',
#   'soak',
#   'let',
#   'penetr',
#   'perform',
#   'repel',
#   'sandal',
#   'stay',
#   'amaz',
#   'outsid',
#   'step',
#   'deep',
#   ''],
#  'Noise': ['quiet',
#   'noisi',
#   'loud',
#   'power',
#   'nois',
#   'louder',
#   'ear',
#   'loudest',
#   'light',
#   'incred',
#   'deafen',
#   'serious',
#   'actual',
#   'ring',
#   'doggi',
#   'hide',
#   'flee',
#   'powerstick',
#   'earplug',
#   'lose',
#   'bearabl',
#   'block',
#   'pro',
#   'fair',
#   'reason',
#   'direct',
#   'mous',
#   'explod',
#   'silent',
#   'compar',
#   'stylish',
#   'function',
#   'weight',
#   'peopl',
#   'ring',
#   'motor',
#   'awesom',
#   'nozzl',
#   'readi',
#   'sound',
#   'devil',
#   'purchas',
#   'quit',
#   'size',
#   'upright',
#   'star',
#   'heavi',
#   'lightweight',
#   'recommend',
#   'turn',
#   ''],
#  'Extra_functionality': ['button',
#   'light',
#   'pencil',
#   'volum',
#   'power',
#   'featur',
#   'bright',
#   'mute',
#   'handi',
#   'low',
#   'dark',
#   'blue',
#   'wake',
#   'sleep',
#   'pen',
#   'nice',
#   'quit',
#   'shortcut',
#   'internet',
#   'spillproof',
#   'interest',
#   'vista',
#   'capabl',
#   'support',
#   'shut',
#   'keypress',
#   'pre',
#   'program',
#   'calcul',
#   'mycomput',
#   'custom',
#   'email',
#   'brower',
#   'activ',
#   'music',
#   'special',
#   'disk',
#   'eject',
#   'hold',
#   'remain',
#   'recess',
#   'clutch',
#   'multimedia',
#   'label',
#   'illumin',
#   'programm',
#   'legibl',
#   'dark',
#   'dim',
#   'backlight',
#   ''],
#  'Layout': ['key',
#   'delet',
#   'backspac',
#   'size',
#   'layout',
#   'end',
#   'insert',
#   'home',
#   'bar',
#   'perfect',
#   'space',
#   'cluster',
#   'squish',
#   'space',
#   'close',
#   'small',
#   'volum',
#   'tini',
#   'place',
#   'arrow',
#   'littl',
#   'tricki',
#   'bigger',
#   'million',
#   'print',
#   'scroll',
#   'paus',
#   'quick',
#   'navig',
#   'difficult',
#   'suppos',
#   'spill',
#   'proof',
#   '104',
#   'negat',
#   'overs',
#   'awkward',
#   'place',
#   'vertic',
#   'horizont',
#   'multimedia',
#   'label',
#   'wider',
#   'impecc',
#   'activ',
#   'chang',
#   'requir',
#   'movement',
#   'wide',
#   'strike',
#   ''],
#  'Feel_Comfort': ['feel',
#   'comfort',
#   'mushi',
#   'key',
#   'like',
#   'keyboard',
#   'good',
#   'perfect',
#   'press',
#   'wrist',
#   'action',
#   'shallow',
#   'smooth',
#   'finger',
#   'relax',
#   'type',
#   'level',
#   'keystrok',
#   'sit',
#   'type',
#   'quick',
#   'navig',
#   'difficult',
#   'shop',
#   'consist',
#   'respond',
#   'pressur',
#   'sens',
#   'deceler',
#   'quick',
#   'mush',
#   'tap',
#   'regist',
#   'usual',
#   'chicklet',
#   'membran',
#   'stick',
#   'satisfi',
#   'clicki',
#   'ibm',
#   'dissatisfi',
#   'natur',
#   'tension',
#   'impecc',
#   'stylish',
#   'recogn',
#   'signatur',
#   'butteri',
#   'velvet',
#   'feather',
#   ''],
#  'Build_Quality': ['belt',
#   'broke',
#   'turn',
#   'work',
#   'burn',
#   'electr',
#   'built',
#   'stop',
#   'month',
#   'roller',
#   'time',
#   'minut',
#   'problem',
#   'brush',
#   'design',
#   'easili',
#   'wise',
#   'continu',
#   'break',
#   'fifth',
#   'barley',
#   'bump',
#   '20',
#   'last',
#   'connect',
#   'swivel',
#   'portion',
#   'fail',
#   'constuct',
#   'electron',
#   'construct',
#   'simpli',
#   'quit',
#   'burnt',
#   'miss',
#   'smell',
#   'overheat',
#   'shut',
#   'poor',
#   'attach',
#   'pop',
#   'unannounc',
#   'snapper',
#   'flimsi',
#   'overh',
#   'upper',
#   'run',
#   'turn',
#   'prepar',
#   'sturdi',
#   ''],
#  'Size_Look': ['size',
#   'big',
#   'bigger',
#   '40',
#   'differ',
#   'screen',
#   'room',
#   'light',
#   '3d',
#   'livingroom',
#   'hardwar',
#   'slim',
#   'cubbyhol',
#   'huge',
#   'weigh',
#   'awkward',
#   'pentil',
#   'matrix',
#   '60',
#   'foot',
#   '65',
#   'consid',
#   'oh',
#   'lightweight',
#   'compact',
#   'suitabl',
#   'live',
#   'ultra',
#   'weigh',
#   'le',
#   'pound',
#   'hindsight',
#   'wonder',
#   'feel',
#   'anticip',
#   'actual',
#   'bedroom',
#   'fit',
#   'perfect',
#   'love',
#   'smaller',
#   'store',
#   'averag',
#   'inch',
#   'view',
#   '32',
#   'perfect',
#   'home',
#   'easili',
#   'get',
#   ''],
#  'Image': ['pictur',
#   'color',
#   'qualiti',
#   'black',
#   'bright',
#   'nice',
#   'clear',
#   'look',
#   'excel',
#   'crisp',
#   'screen',
#   'right',
#   'dead',
#   'pixel',
#   'trace',
#   'beauti',
#   'vibrant',
#   'sharp',
#   'angl',
#   'display',
#   'dvd',
#   'differ',
#   'corner',
#   'fantast',
#   'hd',
#   'overal',
#   'inch',
#   'imag',
#   'view',
#   'white',
#   'great',
#   'ok',
#   'red',
#   'decent',
#   'struck',
#   'eye',
#   'ear',
#   'definit',
#   'fuzzi',
#   'font',
#   'improv',
#   'expeci',
#   'hubbi',
#   'sleep',
#   'caus',
#   'biggest',
#   'level',
#   'notic',
#   'irrit',
#   'affect',
#   ''],
#  'Apps_Interface': ['netflix',
#   'user',
#   'file',
#   'hulu',
#   'app',
#   'watch',
#   'flash',
#   'internet',
#   'smart',
#   'video',
#   'stream',
#   'speed',
#   'youtub',
#   'access',
#   'lack',
#   'smart',
#   'download',
#   'brows',
#   'eas',
#   'interfac',
#   'friend',
#   'access',
#   'work',
#   'capabl',
#   'alright',
#   'quit',
#   'mean',
#   'let',
#   'hub',
#   'applic',
#   'terribl',
#   'watch',
#   'plus',
#   'easili',
#   'buy',
#   'week',
#   'right',
#   'featur',
#   'movi',
#   'comput',
#   'cabl',
#   'best',
#   'samsung',
#   'time',
#   'realli',
#   'like',
#   'better',
#   ''],
#  'Suction_Power': ['suction',
#   'pick',
#   'power',
#   'power',
#   'good',
#   'hair',
#   'carpet',
#   'suck',
#   'quiet',
#   'realli',
#   'perform',
#   'dirt',
#   'tile',
#   'ok',
#   'job',
#   'floor',
#   'perfom',
#   'total',
#   'angl',
#   'attribut',
#   'machin',
#   'main',
#   'simpic',
#   'weak',
#   'object',
#   'bear',
#   'spot',
#   'vacuum',
#   'dosen',
#   'produc',
#   'fault',
#   'unders',
#   'pretti',
#   'essenti',
#   'spin',
#   'spun',
#   'mayb',
#   'pro',
#   'fair',
#   'reason',
#   'loo',
#   'filter',
#   'superb',
#   'grout',
#   'ergorapido',
#   'leav',
#   'plush',
#   'grind',
#   'stylish',
#   'function',
#   ''],
#  'Weight': ['light',
#   'weight',
#   'lightweight',
#   'heavi',
#   'size',
#   'compact',
#   'maneuv',
#   'guess',
#   'quiet',
#   'quit',
#   'probabl',
#   'cumbersom',
#   'feaur',
#   'reason',
#   'histori',
#   'minor',
#   'heavier',
#   'consid',
#   'compar',
#   'nice',
#   'larg',
#   'need',
#   'especi',
#   'carri',
#   'drawback',
#   'perform',
#   'past',
#   'suppos',
#   'thought',
#   'power',
#   'loud',
#   'price',
#   'easi',
#   'feel',
#   'hardwood',
#   'push',
#   'store',
#   'panason',
#   'vacuum',
#   'bagless',
#   'area',
#   'ok',
#   'purchas',
#   'vaccuum',
#   'small',
#   'hard',
#   'littl',
#   'short',
#   'rug',
#   'canist',
#   ''],
#  'Customer_Service': ['servic',
#   'contact',
#   'help',
#   'custom',
#   'took',
#   'email',
#   'miel',
#   'hoover',
#   'dealer',
#   'horribl',
#   'multipl',
#   'respond',
#   'chose',
#   'repres',
#   'told',
#   'smell',
#   'lubric',
#   'dissip',
#   'wait',
#   'spent',
#   'hour',
#   'phone',
#   'depart',
#   'contact',
#   'busi',
#   'regist',
#   'late',
#   'gotten',
#   'card',
#   'mail',
#   'ignor',
#   'look',
#   'common',
#   'recent',
#   'respons',
#   'unfortun',
#   'video',
#   'warranti',
#   'useless',
#   'self',
#   'fall',
#   'day',
#   'amazon',
#   'issu',
#   'absolut',
#   'time',
#   'purchas',
#   'problem',
#   ''],
#  'Accessories': ['filter',
#   'brush',
#   'attach',
#   'roll',
#   'turbo',
#   'easili',
#   'expens',
#   'wide',
#   'turn',
#   'bag',
#   'replac',
#   'typic',
#   'hepa',
#   'cover',
#   'extens',
#   'wonder',
#   'crevic',
#   'reach',
#   'requir',
#   'clean',
#   'duster',
#   'hose',
#   'clean',
#   'way',
#   'noisi',
#   'corner',
#   'hardwood',
#   'empti',
#   'get',
#   'convent',
#   'brushrol',
#   'extra',
#   'rotat',
#   'block',
#   'bag',
#   'scrap',
#   'okay',
#   'basic',
#   'eye',
#   'regular',
#   'sensor',
#   'green',
#   'complet',
#   'instead',
#   'allow',
#   'need',
#   'spinner',
#   'fact',
#   'cup',
#   'onboard',
#   '']}

# %%
for each_aspect in Aspect_to_seeds:
    print(each_aspect, Aspect_to_seeds[each_aspect].__len__())
# Out:
# Compartments 51
# Price 35
# Handles 51
# Customer_service 51
# Looks 23
# Quality 51
# Protection 50
# Size_Fit 51
# Ease_of_use 51
# Sound 51
# Look 51
# Connectivity 51
# Battery 49
# Durability 51
# Comfort 51
# Materials 51
# Color 20
# Size 51
# Weather_resistance 51
# Noise 51
# Extra_functionality 51
# Layout 51
# Feel_Comfort 51
# Build_Quality 51
# Size_Look 51
# Image 51
# Apps_Interface 48
# Suction_Power 51
# Weight 51
# Customer_Service 49
# Accessories 51

# %%
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
# tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")

# %%
# model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# %%
# !echo $CUDA_VISIBLE_DEVICES

# %%
model_args = {'seed_samples': 10, 
              'aspect_length':6
             }

# %%
class aspectDataset(Dataset):
    
    def __init__(self, list_data, tokenizer, model_args):
        self.tokenizer = tokenizer
        self.list_data = list_data
        self.seeds_length = model_args['seed_samples']
        self.aspect_length = model_args['aspect_length']
    
    def __len__(self):
        """Return length of dataset."""
        return self.list_data.__len__()

    def __getitem__(self, i):
        """Return sample from dataset at index i."""
        example = self.list_data[i]
        shuffle(example['seeds'])
        sampled_seeds = example['seeds'][:self.seeds_length]
        aspect = " ".join(example["aspect"].split('_'))
#         max_length = self.seeds_length+2
        inputs = tokenizer(", ".join(sampled_seeds), 
                           truncation=True)  
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            padding="max_length", 
#                            truncation=True, 
#                            max_length=max_length)  
        outputs = tokenizer(aspect, 
                            padding="max_length", 
                            truncation=True, 
                            max_length=self.aspect_length)
        
        batch = {}
        batch["input_ids"] = torch.LongTensor(inputs.input_ids)
        batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
        batch["decoder_input_ids"] = torch.LongTensor(outputs.input_ids)
        batch["decoder_attention_mask"] = torch.LongTensor(outputs.attention_mask)
        batch["labels"] = outputs.input_ids.copy()
        batch['labels'] = [batch['labels']]

        # We have to make sure that the PAD token is ignored for calculating the loss
        batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
                           for labels in batch["labels"]]
        batch["labels"] = torch.LongTensor(batch["labels"])
        
        return batch

# %%
train_data = []
for each_key in Aspect_to_seeds:
    train_data.append({"seeds":Aspect_to_seeds[each_key],
                       "aspect":each_key})

# %%
train_dataset = aspectDataset(list_data=train_data, 
                              tokenizer=tokenizer,
                              model_args=model_args
                             )

# %%
train_loader = DataLoader(train_dataset, 
                          batch_size=1, 
                          shuffle=True,
                          num_workers=1)

# %%
model = model.to("cuda")

# %%
# the_encoder = model.get_encoder()
# the_decoder = model.get_decoder()
# last_linear_layer = model.lm_head

# %%
num_epochs = 15
num_training_steps = num_epochs * len(train_data)

loss_fct = CrossEntropyLoss()

optimizer = AdamW(model.parameters(), 
                  lr=1e-6)
warmup_steps = int(0.10*num_training_steps)
lr_scheduler = get_scheduler("linear",
                            optimizer=optimizer,
                            num_warmup_steps=warmup_steps,
                            num_training_steps=num_training_steps
                            )

# %%
all_train_loss = []
for epoch in tqdm(range(num_epochs)):
    training_loss = 0.0
    model.train()
    for ind, batch in enumerate(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        model_op = model(**batch)
        loss = model_op['loss']
        
        training_loss += loss.item()
        
        print('---'*20)
        print('ID:', ind)
        print('---'*20)
        print('Seed words:', tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
        print('Actual aspect:', tokenizer.batch_decode(batch['decoder_input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
        output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
        print('Predicted aspect:', tokenizer.batch_decode(output_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True))
        
        loss.backward()
        optimizer.step() 
        lr_scheduler.step() 
        optimizer.zero_grad() 
    training_loss = training_loss / len( train_data )
    all_train_loss.append(training_loss)
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['basic, complet, sensor, clean, regular, way, replac, instead, bag, rotat']
# Actual aspect: ['Accessories']
# Predicted aspect: ['basic, comple']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['bit, nois, seat, enorm, bare, m1710, te, hp, cabl, space']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['bit, no']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['disk, handi, sleep, low, label, brower, recess, program, custom, multimedia']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['disk, hand']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['short, carpet, imposs, difficult, hose, corner, refriger, flexibl, flash, jump']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['short, carpet']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['small, rug, probabl, panason, feel, hardwood, vacuum, past, thought, heavi']
# Actual aspect: ['Weight']
# Predicted aspect: ['small, rug']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['protect, tast, normal, pencil, larg, realli, sort, laptop, macbook, probabl']
# Actual aspect: ['Protection']
# Predicted aspect: ['protect, tast']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['pen, safe, construct, save, daytim, pocket, folder, space, planner, need']
# Actual aspect: ['Compartments']
# Predicted aspect: ['pen, safe']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['label, 104, cluster, , place, volum, strike, perfect, tini, paus']
# Actual aspect: ['Layout']
# Predicted aspect: ['label, cluster']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['flee, pro, peopl, nois, , compar, doggi, serious, devil, incred']
# Actual aspect: ['Noise']
# Predicted aspect: ['flee,']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['bigger, narrow, especi, size, tab, fit, option, size, moccasin, true']
# Actual aspect: ['Size']
# Predicted aspect: ['bigger,']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['crack, strip, poor, qualiti, white, asia, excel, outstand, materi, durabl']
# Actual aspect: ['Quality']
# Predicted aspect: ['crack,']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['huge, view, weigh, cubbyhol, live, slim, 65, love, pentil, hindsight']
# Actual aspect: ['Size Look']
# Predicted aspect: ['huge, view']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['sturdi, deflat, heel, , gone, red, worn, decor, actual, appear']
# Actual aspect: ['Durability']
# Predicted aspect: ['sturdi']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['porous, suppos, spent, stori, soak, generous, soak, outsid, amaz, claim']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['porous,']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['min, integr, dhcp, conflict, internet, digit, file, flash, stop, speed']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['min, integ']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['rip, hand, buckl, firm, month, broke, control, inevit, final, comfort']
# Actual aspect: ['Handles']
# Predicted aspect: ['rip, hand']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['like, wrist, clicki, consist, comfort, shallow, membran, level, butteri, finger']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['like, wrist']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['thing, loudest, display, dinner, shippabl, terribl, ear, eye, quieter, laptop']
# Actual aspect: ['Sound']
# Predicted aspect: ['thing, loud']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['ok, fault, grind, suck, perform, good, loo, simpic, spot, machin']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['ok, fault']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['comfi, time, ankl, actual, longer, minut, walk, sock, break, sued']
# Actual aspect: ['Comfort']
# Predicted aspect: ['.com']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['fleec, zipper, describ, fact, sole, buckl, memori, penetr, piec, insid']
# Actual aspect: ['Materials']
# Predicted aspect: ['fleec,']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['purchas, favorit, perfect, boot, unbeliev, exact, design, color, love, taup']
# Actual aspect: ['Color']
# Predicted aspect: ['Purchas']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['hub, plus, youtub, app, best, lack, featur, video, interfac, better']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['hub, plus']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['paid, good, twice, light, money, feaur, , vacuum, need, expens']
# Actual aspect: ['Price']
# Predicted aspect: ['paid, good']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['snapper, upper, continu, fail, poor, overh, bump, unannounc, work, electr']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['snapper,']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['stop, green, pretti, meter, life, nois, batteri, love, merit, star']
# Actual aspect: ['Battery']
# Predicted aspect: ['stop, green']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['peopl, pilot, difficult, reschedul, replac, wait, check, diagnost, week, po']
# Actual aspect: ['Customer service']
# Predicted aspect: ['peopl,']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['color, notic, improv, differ, white, screen, sleep, biggest, ear, pixel']
# Actual aspect: ['Image']
# Predicted aspect: ['color, not']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['small, , keyboard, pc, cheap, lttle, size, look, laptop, great']
# Actual aspect: ['Looks']
# Predicted aspect: ['small,,']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['video, horribl, phone, look, absolut, card, dissip, common, unfortun, told']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['video, hor']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['attract, nice, look, style, airi, smooth, grey, offic, fring, hang']
# Actual aspect: ['Look']
# Predicted aspect: ['attract,']
#   7%|▋         | 1/15 [00:13<03:15, 13.97s/it]
# Epoch 1:	Training Loss 4.97
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['cubbyhol, actual, smaller, big, livingroom, perfect, hardwar, 32, light, 60']
# Actual aspect: ['Size Look']
# Predicted aspect: ['cubbyhol']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['spill, layout, size, , insert, impecc, chang, horizont, multimedia, bar']
# Actual aspect: ['Layout']
# Predicted aspect: ['spill,']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['broken, adapt, month, comfort, torn, minut, loop, short, buckl, lift']
# Actual aspect: ['Handles']
# Predicted aspect: ['broken, adapt']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['sound, quit, deafen, silent, recommend, pro, light, nozzl, compar, doggi']
# Actual aspect: ['Noise']
# Predicted aspect: ['sound,']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['sleev, thing, insid, love, protect, normal, macbook, protect, pencil, let']
# Actual aspect: ['Protection']
# Predicted aspect: ['sleev,']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['unbeliev, color, boot, perfect, blue, exact, design, look, gorgeous, ']
# Actual aspect: ['Color']
# Predicted aspect: ['unbeliev']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['come, cheapli, need, , protect, tear, clear, enjoy, decent, fold']
# Actual aspect: ['Durability']
# Predicted aspect: ['come, che']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['let, featur, movi, quit, user, realli, like, mean, samsung, buy']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['let, feat']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: [', small, compart, safe, wire, cellphon, fit, outer, medium, space']
# Actual aspect: ['Compartments']
# Predicted aspect: [', small,']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['flash, furnitur, baseboard, kink, crevic, imposs, retract, bog, retractor, easier']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['flash, furn']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['pencil, keypress, legibl, blue, custom, volum, capabl, sleep, disk, dark']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['pencil,']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['weight, expens, spun, far, dyson, like, power, bagless, ok, ']
# Actual aspect: ['Price']
# Predicted aspect: ['weight, exp']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['stay, wet, repel, island, protect, spent, porous, raini, cub, water']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['stay, wet']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['nice, push, light, size, perform, easi, ok, drawback, vaccuum, maneuv']
# Actual aspect: ['Weight']
# Predicted aspect: ['nice, push']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['collaps, environ, color, crazi, absolut, stylish, comfort, nice, offic, laid']
# Actual aspect: ['Look']
# Predicted aspect: ['collaps,']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['handl, zipper, strap, chemic, peel, left, defect, broke, feel, cours']
# Actual aspect: ['Quality']
# Predicted aspect: ['handl,']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['roller, bump, fail, problem, flimsi, last, stop, turn, turn, 20']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['roller, bump']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['sit, , type, membran, navig, regist, quick, mush, difficult, tension']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['sit,,']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['decent, color, hd, notic, vibrant, nice, beauti, display, ear, crisp']
# Actual aspect: ['Image']
# Predicted aspect: ['decent,']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['busi, absolut, issu, help, lubric, video, ignor, dissip, amazon, unfortun']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['busi,']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['hurt, break, sued, fit, uncomfort, offic, loos, sock, slide, extrem']
# Actual aspect: ['Comfort']
# Predicted aspect: ['hurt,']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['wonder, corner, requir, empti, filter, onboard, brushrol, , extra, bag']
# Actual aspect: ['Accessories']
# Predicted aspect: ['wonder']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['suction, spin, perform, pro, machin, weak, grind, tile, spot, ok']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['suction,']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['reduct, sure, fre, notebook, earphon, accessori, cabl, pavilion, enorm, laptop']
# Actual aspect: ['Size Fit']
# Predicted aspect: [' is a']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['comput, stream, connect, cabl, movi, vga, like, server, enabl, connect']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['comput,']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['decid, order, sent, buyer, width, tuck, , awar, ankl, baggi']
# Actual aspect: ['Size']
# Predicted aspect: ['decid,']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['beauti, size, pc, cheap, keyboard, like, backlit, attract, feel, laptop']
# Actual aspect: ['Looks']
# Predicted aspect: ['beauti']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['charger, star, tone, bizarr, get, pretti, recharg, nois, talk, light']
# Actual aspect: ['Battery']
# Predicted aspect: ['charger']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['aerosol, let, piec, especi, soft, unattract, term, describ, penetr, insid']
# Actual aspect: ['Materials']
# Predicted aspect: ['aerosol']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['support, use, carri, fee, servic, bring, fact, paid, handl, shore']
# Actual aspect: ['Customer service']
# Predicted aspect: ['support, use']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['bar, watt, worthi, strain, junki, speaker, tinni, dinner, quieter, sound']
# Actual aspect: ['Sound']
# Predicted aspect: ['bar, watt']
#  13%|█▎        | 2/15 [00:26<02:46, 12.83s/it]
# Epoch 2:	Training Loss 3.08
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['got, cold, den, soak, soak, spent, defect, item, ice, grass']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['got, cold']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['let, best, especi, penetr, superb, elast, fashion, friction, rubber, aerosol']
# Actual aspect: ['Materials']
# Predicted aspect: ['let, best']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['month, easili, overh, time, unannounc, built, break, fail, pop, roller']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['month, eas']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['power, kink, maneuv, short, eas, prefer, heavi, wall, hard, easier']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['power, k']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['ankl, possibl, beauti, narrow, option, sent, superb, pant, true, normal']
# Actual aspect: ['Size']
# Predicted aspect: ['ankl,']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['life, hold, better, volum, green, dead, start, longer, phone, time']
# Actual aspect: ['Battery']
# Predicted aspect: ['life, hold']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['applic, file, lack, video, right, brows, access, mean, cabl, comput']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['applic,']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['3d, 60, , store, foot, suitabl, cubbyhol, weigh, actual, le']
# Actual aspect: ['Size Look']
# Predicted aspect: ['3d,']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: [', run, daytim, mous, space, nice, open, connector, pocket, outsid']
# Actual aspect: ['Compartments']
# Predicted aspect: ['M']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['protect, drop, protect, bit, love, normal, weak, insid, sort, stylish']
# Actual aspect: ['Protection']
# Predicted aspect: ['protect, drop']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['later, remot, situat, note, firm, bend, tear, wear, short, strap']
# Actual aspect: ['Handles']
# Predicted aspect: ['later,']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['rip, outstand, holiday, strap, durabl, plastic, pull, asia, edg, reproduct']
# Actual aspect: ['Quality']
# Predicted aspect: ['rip, out']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['longer, comfi, list, wear, ankl, enjoy, snug, sock, perfect, slide']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Longer,']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['favorit, boot, materi, unbeliev, gorgeous, purchas, blue, style, look, look']
# Actual aspect: ['Color']
# Predicted aspect: ['Favorit']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['fix, difficult, communic, latest, speak, pay, use, peopl, , check']
# Actual aspect: ['Customer service']
# Predicted aspect: ['fix, difficult']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['folder, raincoat, airplan, pouch, m1710, 17inch, book, nois, big, cloth']
# Actual aspect: ['Size Fit']
# Predicted aspect: [' folder,']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['strike, wide, tini, insert, quick, small, difficult, label, squish, bigger']
# Actual aspect: ['Layout']
# Predicted aspect: ['strike, wide']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['wake, vista, special, pen, pencil, multimedia, recess, custom, handi, bright']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['wake']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['volum, worthi, ear, vibrat, mind, good, , tinni, strong, develop']
# Actual aspect: ['Sound']
# Predicted aspect: ['volum,']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['press, mushi, comfort, tap, satisfi, feather, relax, ibm, difficult, navig']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['press, mush']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['bag, money, feaur, wast, expens, mayb, price, need, light, spend']
# Actual aspect: ['Price']
# Predicted aspect: ['bag,']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['sure, rubber, worn, actual, long, time, durabl, , protect, sturdi']
# Actual aspect: ['Durability']
# Predicted aspect: ['sure, rubber']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['reason, stylish, earplug, sound, powerstick, motor, serious, peopl, quiet, light']
# Actual aspect: ['Noise']
# Predicted aspect: ['reason, stylish']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['fall, useless, absolut, custom, video, unfortun, amazon, contact, wait, time']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['fall, useless']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['noisi, clean, extens, hardwood, scrap, rotat, requir, filter, roll, green']
# Actual aspect: ['Accessories']
# Predicted aspect: ['noisi']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['level, eye, right, red, sleep, beauti, improv, ear, decent, great']
# Actual aspect: ['Image']
# Predicted aspect: ['level, eye']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['fring, collaps, good, pictur, nice, concept, shame, stylish, unattract, pictur']
# Actual aspect: ['Look']
# Predicted aspect: ['fring,']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['ok, push, maneuv, need, canist, small, quiet, larg, histori, past']
# Actual aspect: ['Weight']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['great, slim, keyboard, imac, lttle, size, , decent, appear, feel']
# Actual aspect: ['Looks']
# Predicted aspect: ['great, slim']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['realli, leav, grind, pretti, spun, simpic, good, attribut, power, stylish']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['realli,']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['dhcp, watch, play, input, integr, hard, connect, end, comcast, connect']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['dhcp,']
#  20%|██        | 3/15 [00:37<02:26, 12.17s/it]
# Epoch 3:	Training Loss 2.11
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['look, blue, love, style, unbeliev, red, , perfect, wonder, favorit']
# Actual aspect: ['Color']
# Predicted aspect: ['look,']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['laptop, origin, imac, backlit, beauti, appear, keyboard, decent, look, feel']
# Actual aspect: ['Looks']
# Predicted aspect: ['laptop,']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['heavi, loud, compar, especi, quit, vacuum, feel, consid, vaccuum, hard']
# Actual aspect: ['Weight']
# Predicted aspect: ['heavi,']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['struck, corner, right, hd, expeci, look, bright, angl, notic, screen']
# Actual aspect: ['Image']
# Predicted aspect: ['struck,']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['interest, generous, got, alcatraz, rain, sandal, defect, resist, puddl, deep']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['interest, generous']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['go, style, rest, pictur, good, color, offic, weight, hang, comfort']
# Actual aspect: ['Look']
# Predicted aspect: ['go, style']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['work, min, rf, connect, file, dlna, 45, slot, signal, power']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['work, min']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['snapper, overheat, month, quit, wise, sturdi, roller, belt, broke, electr']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['snapper,']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['easili, differ, foot, 60, perfect, 32, feel, consid, actual, huge']
# Actual aspect: ['Size Look']
# Predicted aspect: ['easili,']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['superb, produc, realli, leav, carpet, unders, fault, angl, loo, main']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['. Super']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['like, bagless, need, duster, weight, spun, spin, paid, right, light']
# Actual aspect: ['Price']
# Predicted aspect: ['like, bag']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['come, diagnost, , po, mail, reschedul, glove, check, requir, downstair']
# Actual aspect: ['Customer service']
# Predicted aspect: [',']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['joint, wise, especi, decid, tuck, order, baggi, shorter, run, pant']
# Actual aspect: ['Size']
# Predicted aspect: ['Joint,']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['barn, elast, rubber, advertis, cloth, porous, memori, unattract, foam, line']
# Actual aspect: ['Materials']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['broken, left, tear, torn, felt, hand, remot, buckl, hook, strap']
# Actual aspect: ['Handles']
# Predicted aspect: ['broken,']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['better, start, come, talk, turn, cell, bizarr, low, sudden, hold']
# Actual aspect: ['Battery']
# Predicted aspect: ['better, start']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['document, folder, mous, nois, earphon, connector, nice, charger, open, medium']
# Actual aspect: ['Compartments']
# Predicted aspect: ['document, folder']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['heavi, car, hard, simpic, roller, suck, refriger, imposs, corner, move']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['heavi,']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['incred, power, fair, nozzl, flee, upright, doggi, turn, size, purchas']
# Actual aspect: ['Noise']
# Predicted aspect: ['incred,']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['brower, custom, keypress, low, bright, shut, support, multimedia, clutch, volum']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['brow']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['phone, day, multipl, told, busi, absolut, issu, lubric, purchas, contact']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['phone, day']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['speed, watch, realli, access, friend, movi, , eas, time, app']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['speed, watch']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['feel, defect, reproduct, pull, poor, plastic, go, outstand, birth, stand']
# Actual aspect: ['Quality']
# Predicted aspect: ['feel, defect']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['label, bar, place, horizont, delet, navig, space, awkward, size, perfect']
# Actual aspect: ['Layout']
# Predicted aspect: ['label, bar']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['larg, realli, protect, pad, heavi, protect, trust, way, comput, drop']
# Actual aspect: ['Protection']
# Predicted aspect: ['larg, re']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['13, accessori, fit, hp, seat, airplan, cloth, 3080us, enorm, macbook']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['13,']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['keystrok, sit, tap, stick, comfort, stylish, mushi, shallow, consist, regist']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['keystrok']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['thing, surround, experi, realli, qualiti, chang, whine, terribl, great, speaker']
# Actual aspect: ['Sound']
# Predicted aspect: ['thing, surround']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['materi, super, worn, true, fold, numer, support, tear, provid, come']
# Actual aspect: ['Durability']
# Predicted aspect: ['materi']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['green, convent, brush, hose, eye, , get, empti, onboard, turbo']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Green']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['snug, longer, time, wear, foot, comfi, insid, light, , uncomfort']
# Actual aspect: ['Comfort']
# Predicted aspect: ['snug']
#  27%|██▋       | 4/15 [00:48<02:07, 11.61s/it]
# Epoch 4:	Training Loss 1.34
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['comput, let, stream, like, samsung, speed, featur, netflix, friend, easili']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['comput,']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['nokia, charger, charg, sudden, turn, get, star, bizarr, pretti, red']
# Actual aspect: ['Battery']
# Predicted aspect: ['nokia,']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['perfom, pretti, good, power, hair, object, attribut, reason, plush, suck']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['perf']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['dewi, wet, generous, spent, puddl, warm, got, san, repel, leav']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['dewi']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['digit, min, stream, input, standard, end, , slot, play, hard']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['digit, min']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['chose, card, multipl, fall, lubric, , spent, hour, email, contact']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Chose']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['discomfort, feel, fit, comfort, doc, minut, hurt, foot, short, littl']
# Actual aspect: ['Comfort']
# Predicted aspect: ['discomfort,']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['pictur, screen, ear, black, , white, view, eye, decent, right']
# Actual aspect: ['Image']
# Predicted aspect: ['pictur,']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['pricey, 200, ok, cheap, bag, money, power, like, feaur, good']
# Actual aspect: ['Price']
# Predicted aspect: ['Pricey,']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['count, damag, cushion, probabl, larg, love, construct, pad, bag, trust']
# Actual aspect: ['Protection']
# Predicted aspect: ['count, dam']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['green, easili, crevic, complet, fact, cup, okay, cover, requir, noisi']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Green is']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['long, strap, handl, broke, comfort, addit, adapt, swivel, metal, torn']
# Actual aspect: ['Handles']
# Predicted aspect: ['long, strap']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['environ, style, pictur, unattract, durabl, natur, smooth, 360, look, laid']
# Actual aspect: ['Look']
# Predicted aspect: ['environ,']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['hindsight, pound, consid, ultra, oh, live, weigh, pentil, averag, screen']
# Actual aspect: ['Size Look']
# Predicted aspect: ['hindsight']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['diagnost, servic, 1500, refurbish, 49, reschedul, po, check, downstair, ship']
# Actual aspect: ['Customer service']
# Predicted aspect: ['diagnost']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['pavilion, raincoat, reduct, enorm, m1710, cabl, munchi, perfect, air, 13']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Pavilion']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['constant, nozzl, short, cannist, kink, suck, flash, power, maneuv, flexibl']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['constant,']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['flimsi, turn, electr, brush, turn, minut, work, burnt, broke, problem']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['flim']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['loud, cool, loudest, mind, qualiti, improv, strong, ear, dinner, display']
# Actual aspect: ['Sound']
# Predicted aspect: ['loud']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['action, type, signatur, stick, usual, velvet, stylish, consist, shop, feel']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['action, type']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['low, sleep, dark, pre, button, bright, light, mute, illumin, nice']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['low, sleep']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['blue, design, love, unbeliev, purchas, , materi, perfect, exact, boot']
# Actual aspect: ['Color']
# Predicted aspect: ['blue, design']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['materi, need, cheapli, pretti, provid, cheep, actual, style, tear, sure']
# Actual aspect: ['Durability']
# Predicted aspect: ['mater']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['accessori, raincoat, player, pen, connector, wallet, reduct, earphon, cabl, fit']
# Actual aspect: ['Compartments']
# Predicted aspect: ['accessori,']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['keyboard, pc, imac, slim, lttle, backlit, , like, laptop, longer']
# Actual aspect: ['Looks']
# Predicted aspect: ['keyboard,']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['panason, consid, bagless, heavi, need, quiet, purchas, carri, quit, area']
# Actual aspect: ['Weight']
# Predicted aspect: ['panason,']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['space, movement, label, overs, place, difficult, space, perfect, volum, awkward']
# Actual aspect: ['Layout']
# Predicted aspect: ['space,']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['quiet, size, fair, star, reason, loud, doggi, upright, loudest, explod']
# Actual aspect: ['Noise']
# Predicted aspect: ['quiet, size']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['penetr, hang, , materi, memori, heel, porous, calm, decor, foam']
# Actual aspect: ['Materials']
# Predicted aspect: ['penetr,']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['terribl, rip, peel, stand, feel, rip, trip, edg, , daili']
# Actual aspect: ['Quality']
# Predicted aspect: ['terrib']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['big, baggi, joint, decid, calf, tight, bacaus, advic, ankl, size']
# Actual aspect: ['Size']
# Predicted aspect: ['big,']
#  33%|███▎      | 5/15 [00:59<01:53, 11.38s/it]
# Epoch 5:	Training Loss 1.22
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['strong, terribl, tinni, qualiti, volum, , vibrat, display, eye, muffl']
# Actual aspect: ['Sound']
# Predicted aspect: ['strong,']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['later, good, simpl, vari, recharg, charg, cell, charg, dead, start']
# Actual aspect: ['Battery']
# Predicted aspect: ['later, good']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['amazon, unfortun, gotten, wait, told, smell, issu, purchas, hour, help']
# Actual aspect: ['Customer Service']
# Predicted aspect: [', purch']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['impecc, proof, space, volum, littl, bigger, quick, squish, place, tricki']
# Actual aspect: ['Layout']
# Predicted aspect: ['impecc']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['size, area, maneuv, heavi, quit, vaccuum, especi, hardwood, rug, consid']
# Actual aspect: ['Weight']
# Predicted aspect: ['size, area']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['list, comfi, attract, toe, perfect, uncomfort, offic, narrow, longer, environ']
# Actual aspect: ['Comfort']
# Predicted aspect: ['list,']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['noisi, roll, block, complet, okay, get, regular, bag, , onboard']
# Actual aspect: ['Accessories']
# Predicted aspect: ['noisi,']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['outer, need, paperwork, nois, wire, connector, space, remot, flap, compart']
# Actual aspect: ['Compartments']
# Predicted aspect: ['outer, need']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['constuct, overheat, sturdi, overh, pop, burn, attach, connect, broke, flimsi']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['constuct,']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['attract, great, lttle, cheap, decent, size, , imac, backlit, like']
# Actual aspect: ['Looks']
# Predicted aspect: ['attract,']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['bag, like, best, mayb, money, feaur, worth, spun, vaccum, far']
# Actual aspect: ['Price']
# Predicted aspect: ['bag,']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['turn, pro, stylish, reason, readi, fair, power, bearabl, noisi, ring']
# Actual aspect: ['Noise']
# Predicted aspect: ['turn, pro']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['communic, po, 1500, refurbish, later, speak, arriv, come, undamag, suppos']
# Actual aspect: ['Customer service']
# Predicted aspect: ['communic,']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['claim, stori, perform, let, cold, step, francisco, , outsid, defect']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['claim, st']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['adjust, plastic, lift, break, left, sooner, length, broken, rip, start']
# Actual aspect: ['Handles']
# Predicted aspect: ['adjust, plastic']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: [', qualiti, left, rip, edg, pull, strap, strip, asia, broken']
# Actual aspect: ['Quality']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['direct, hang, taup, durabl, weight, great, collaps, comfort, look, stylish']
# Actual aspect: ['Look']
# Predicted aspect: ['direct,']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['perfect, especi, usual, beauti, sould, bigger, shorter, follow, big, true']
# Actual aspect: ['Size']
# ...
# Seed words: ['love, life, come, meter, pretti, nokia, bizarr, phone, low, talk']
# Actual aspect: ['Battery']
# Predicted aspect: ['love, life']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['min, netflix, output, 45, connect, connect, watch, input, audio, comcast']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['min,']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['flash, retract, short, crevic, heavi, eas, kink, difficult, remov, hard']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['flash, retract']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['bit, accessori, raincoat, 17inch, accommod, bulk, 13, sure, folder, pavilion']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['bit, access']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['level, biggest, beauti, differ, , ok, angl, red, fantast, white']
# Actual aspect: ['Image']
# Predicted aspect: ['level, biggest']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['joint, pant, shame, left, decid, follow, moccasin, order, tight, width']
# Actual aspect: ['Size']
# Predicted aspect: ['joint,']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['card, purchas, amazon, horribl, mail, regist, warranti, recent, dissip, servic']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['card, purch']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['perfect, love, purchas, look, wonder, red, , design, love, style']
# Actual aspect: ['Color']
# Predicted aspect: ['perfect, love']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['type, natur, key, quick, ibm, wrist, clicki, pressur, action, dissatisfi']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['type, n']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['wise, fail, problem, attach, simpli, overheat, poor, connect, work, smell']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['wise, fail']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['adjust, tinni, strong, loudest, cool, sound, quieter, pitch, strain, ']
# Actual aspect: ['Sound']
# Predicted aspect: ['adjust, t']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['uncomfort, sock, walk, feel, pain, fit, minut, longer, enjoy, time']
# Actual aspect: ['Comfort']
# Predicted aspect: ['uncomfort,']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['chemic, broken, start, month, smell, broke, feel, , go, asia']
# Actual aspect: ['Quality']
# Predicted aspect: ['chemic,']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['realli, perfect, pencil, feel, second, damag, sort, way, let, protect']
# Actual aspect: ['Protection']
# Predicted aspect: ['realli']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['bedroom, fit, home, 40, lightweight, ultra, feel, 65, view, matrix']
# Actual aspect: ['Size Look']
# Predicted aspect: ['bedroom, fit']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['right, mean, watch, smart, best, internet, smart, alright, netflix, work']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Right, mean']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['chicago, resist, francisco, porous, cold, cub, alcatraz, got, leav, scout']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Chicag']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['fact, wait, reschedul, handl, paid, , check, po, technician, servic']
# Actual aspect: ['Customer service']
# Predicted aspect: ['fact,']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['thinner, gone, decent, barn, time, buckl, heel, wear, use, differ']
# Actual aspect: ['Durability']
# Predicted aspect: ['thinner,']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['true, best, let, heel, fring, hollow, decor, aerosol, fashion, cloth']
# Actual aspect: ['Materials']
# Predicted aspect: ['true, best']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['ok, pretti, machin, produc, fault, main, angl, ergorapido, fair, unders']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['ok,']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['comfort, rest, pictur, look, grey, laid, go, attract, , absolut']
# Actual aspect: ['Look']
# Predicted aspect: ['comfort,']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['loop, , final, strap, adjust, stand, control, adapt, wear, comfort']
# Actual aspect: ['Handles']
# Predicted aspect: ['loop']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['feaur, cheap, money, , need, bag, worth, price, twice, paid']
# Actual aspect: ['Price']
# Predicted aspect: ['feaur,']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['crevic, spinner, convent, sensor, duster, hose, noisi, green, okay, bag']
# Actual aspect: ['Accessories']
# Predicted aspect: ['crevic,']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['larg, small, compact, hard, size, heavier, perform, push, light, power']
# Actual aspect: ['Weight']
# Predicted aspect: ['larg,']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['quiet, light, silent, turn, reason, louder, bearabl, loudest, awesom, direct']
# Actual aspect: ['Noise']
# Predicted aspect: ['quiet, light']
#  93%|█████████▎| 14/15 [02:30<00:09,  9.83s/it]
# Epoch 14:	Training Loss 0.42
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['key, bigger, overs, wide, negat, spill, squish, impecc, backspac, million']
# Actual aspect: ['Layout']
# Predicted aspect: ['key,']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['half, ankl, tight, advic, beauti, tuck, awar, sould, possibl, perfect']
# Actual aspect: ['Size']
# Predicted aspect: ['half,']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['broke, sturdi, miss, turn, stop, electr, continu, swivel, time, overh']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['broke,']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['materi, , birth, broken, defect, holiday, sacrific, style, handl, final']
# Actual aspect: ['Quality']
# Predicted aspect: ['materi']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['absolut, go, look, concept, shame, fring, look, hang, direct, stylish']
# Actual aspect: ['Look']
# Predicted aspect: ['absolut']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['perfect, enjoy, insid, minut, foot, attract, longer, wear, pain, list']
# Actual aspect: ['Comfort']
# Predicted aspect: ['perfect, enjoy']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['improv, mind, dinner, muffl, lack, track, watt, improv, surround, terribl']
# Actual aspect: ['Sound']
# Predicted aspect: ['improv,']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['100lb, desk, communic, peopl, refurbish, replac, requir, ship, week, support']
# Actual aspect: ['Customer service']
# Predicted aspect: ['100lb,']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['angl, fault, leav, fair, grind, spin, grout, reason, perform, floor']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['angl,']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['pile, hose, person, corner, direct, roller, flash, simpic, difficult, suck']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['pile,']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['internet, integr, audio, connect, drive, flash, like, netflix, dhcp, enabl']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['internet, integ']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['cloth, te, 3080us, , perfect, fre, jacket, lot, book, 13']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['cloth']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['look, boot, gorgeous, favorit, love, exact, design, blue, , materi']
# Actual aspect: ['Color']
# Predicted aspect: ['look']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['block, eye, bag, turn, scrap, empti, reach, brush, hardwood, get']
# Actual aspect: ['Accessories']
# Predicted aspect: ['block,']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['light, heavi, flee, ear, compar, , block, doggi, recommend, upright']
# Actual aspect: ['Noise']
# Predicted aspect: ['light, heav']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['level, keyboard, membran, good, velvet, keystrok, shop, deceler, finger, recogn']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['level, keyboard']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['right, vacuum, dyson, bag, feaur, expens, expect, twice, think, spin']
# Actual aspect: ['Price']
# Predicted aspect: ['right, vacuum']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['decent, clear, differ, rubber, heavi, buckl, use, month, sure, true']
# Actual aspect: ['Durability']
# Predicted aspect: ['decent,']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['decor, natur, come, zipper, elast, let, leather, improv, aerosol, heel']
# Actual aspect: ['Materials']
# Predicted aspect: ['decor']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['ignor, spent, amazon, miel, recent, respond, purchas, absolut, day, dissip']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['ignor,']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['adapt, fit, remot, reduct, construct, save, insid, small, need, cabl']
# Actual aspect: ['Compartments']
# Predicted aspect: ['adapt,']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['spillproof, dark, program, legibl, disk, keypress, featur, handi, wake, quit']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['spillproof']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['probabl, ok, vaccuum, nice, push, drawback, compact, littl, need, perform']
# Actual aspect: ['Weight']
# Predicted aspect: ['Probabl']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: [', friend, watch, applic, download, featur, let, smart, right, comput']
# Actual aspect: ['Apps Interface']
# Predicted aspect: [', friend,']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['claim, rain, got, item, raini, wet, den, cold, lot, ice']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['claim, rain']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['way, pencil, provid, heavi, tast, laptop, adequ, far, larg, drop']
# Actual aspect: ['Protection']
# Predicted aspect: [',']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['appear, lttle, slim, beauti, longer, attract, nice, small, decent, laptop']
# Actual aspect: ['Looks']
# Predicted aspect: ['app']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['loop, month, shoulder, shorter, sooner, left, metal, later, torn, felt']
# Actual aspect: ['Handles']
# Predicted aspect: ['loop']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['pound, weigh, perfect, easili, anticip, light, hindsight, pentil, perfect, screen']
# Actual aspect: ['Size Look']
# Predicted aspect: ['pound,']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['longer, come, start, sudden, hold, power, day, stop, red, merit']
# Actual aspect: ['Battery']
# Predicted aspect: ['longer,']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['font, view, crisp, caus, decent, clear, inch, black, sleep, vibrant']
# Actual aspect: ['Image']
# Predicted aspect: ['font, view']
# 100%|██████████| 15/15 [02:40<00:00, 10.71s/it]
# Epoch 15:	Training Loss 0.39

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(all_train_loss, ls='-.', marker = 'X', color='blue')

# %%
stop_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-c3998c8be795> in <module>
# ----> 1 stop_
#
# NameError: name 'stop_' is not defined

# %%
# chk_1 =tokenizer('MaterialsComp', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_1['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_2 =tokenizer('Ease of use', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_2['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_ = tokenizer('Compartments', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=4)

# %%
# tokenizer.batch_decode(chk_['input_ids'], 
#                        skip_special_tokens=True, 
#                        clean_up_tokenization_spaces=False)

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

# %%
electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

# %%
electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
electronic_topics = [x[:20] for x in electronic_topics]

# %%
test_data = []
for each_e_top in electronic_topics:
    test_data.append({'seeds': each_e_top[:20], 'aspect':'TestSet'})

# %%
test_dataset = aspectDataset(list_data=test_data, 
                              tokenizer=tokenizer)

# %%
test_loader = DataLoader(test_dataset, 
                         batch_size=1, 
                         shuffle=True,
                         num_workers=1)

# %%
model.eval()
for ind, batch in enumerate(test_loader):
    batch = {k: v.to('cuda') for k, v in batch.items()}
    model_op = model(**batch)
    print('---'*20)
    print('ID:', ind)
    print('---'*20)
    print('Seed words:', tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    print('Actual aspect:', tokenizer.batch_decode(batch['decoder_input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
    print('Predicted aspect:', tokenizer.batch_decode(output_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True))

# %% [raw]
# 1. Sample 5-10 for each aspect. Get top 50 and then sample 10 each. done
# 2. Start from the bart-large and not cnn. done
# 3. Use very small learning rate (2e-5)| 1e-6 or 5e-7. done
# 4. Put a comma with the words. done
# 5. Stem the training data words. done

# %%
model_op['logits'].squeeze(dim=0).shape

# %%
torch.argmax(model_op['logits'].squeeze(dim=0), dim=1)

# %% [markdown]
# ## Orphan Code
# -------------

# %%
print(another_way_to_train)
for epoch in range(num_epochs):
    training_loss = 0.0
    model.train()
    for batch in tqdm(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        # Get the "input's representation"
        encoder_output = the_encoder(input_ids = batch['input_ids'],
                                   attention_mask = batch['attention_mask'])
      
        # Pass the representation + the target summary to the decoder
        decoder_output = the_decoder(input_ids=batch['decoder_input_ids'],
                                   attention_mask=batch['decoder_attention_mask'],
                                   encoder_hidden_states=encoder_output[0],
                                   encoder_attention_mask=batch['attention_mask'])

        # Use the last linear layer to predict the next token
        decoder_output = decoder_output.last_hidden_state
        lm_head_output = last_linear_layer(decoder_output)
        
        # Compute the loss
        loss = loss_fct(lm_head_output.view(-1, model.config.vocab_size),
                      batch['labels'].view(-1))
        training_loss += loss.item()
        
        loss.backward() # Update the weights
        optimizer.step() # Notify optimizer that a batch is done.
        lr_scheduler.step() # Notify the scheduler that a ...
        optimizer.zero_grad() # Reset the optimer
    training_loss = training_loss / len( train_data )
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))

# %%
lm_head_output.view(-1, model.config.vocab_size)
