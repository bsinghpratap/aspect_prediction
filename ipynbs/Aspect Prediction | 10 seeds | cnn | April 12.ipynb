# %%
import torch
import random
import pandas as pd
import pickle as pkl
from tqdm import tqdm
from os import listdir
from os.path import join
from random import shuffle
from transformers import AdamW
from matplotlib import pyplot as plt
from torch.nn import CrossEntropyLoss
from transformers import get_scheduler
from pdb import set_trace as breakpoint
from nltk.stem.snowball import SnowballStemmer
from torch.utils.data import Dataset, DataLoader
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
# %matplotlib inline

# %%
# folders = ['bags_and_cases', 'bluetooth', 'boots', 'keyboards', 'tv', 'vacuums']

# base_dir = '/mnt/nfs/work1/hongyu/brawat/amzn/oposum/data/seeds'

# list_aspects = []
# Aspect_to_seeds = {}
# stemmer = SnowballStemmer(language='english')
# for each_folder in folders:
#     folder_dir = join(base_dir, each_folder)
#     print('--'*20)
#     print(each_folder)
#     print('--'*20)
#     txt_files = listdir(folder_dir)
#     txt_files = [x for x in txt_files if 'None' not in x]
#     print(txt_files)
#     for each_txt in txt_files:
#         txt_dir = join(folder_dir, each_txt)
#         txt = open(txt_dir).read()
#         txt = txt.split('\n')
#         txt = [x.split(' ')[-1] for x in txt]
#         txt = [x.strip() for x in txt]
#         txt = [stemmer.stem(x) for x in txt]
#         aspect = each_txt.split('.')[1]
#         Aspect_to_seeds[aspect] = txt

# %%
# for each_aspect in Aspect_to_seeds:
#     print(each_aspect, Aspect_to_seeds[each_aspect].__len__())

# %%
# pkl.dump(Aspect_to_seeds, open('Aspect_to_seeds_march19.pkl', 'wb'))

# %%
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))

# %%
for each_aspect in Aspect_to_seeds:
    Aspect_to_seeds[each_aspect] = [x for x in Aspect_to_seeds[each_aspect] if x.__len__()>0]

# %%
Aspect_to_seeds
# Out:
# {'Compartments': ['pocket',
#   'cabl',
#   'compart',
#   'outsid',
#   'lot',
#   'wish',
#   'wallet',
#   'connector',
#   'space',
#   'power',
#   'pen',
#   'folder',
#   'charger',
#   'flap',
#   'mous',
#   'nice',
#   'thing',
#   'insid',
#   'small',
#   'paperwork',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'construct',
#   'medium',
#   'player',
#   'wire',
#   'run',
#   'headphon',
#   'key',
#   'instead',
#   'huge',
#   'need',
#   'open',
#   'fit',
#   'headset',
#   'outer',
#   'planner',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'cellphon',
#   'save',
#   'document'],
#  'Price': ['price',
#   'money',
#   'feaur',
#   'paid',
#   'spin',
#   'spun',
#   'mayb',
#   'cheap',
#   '200',
#   'spend',
#   'right',
#   'vaccum',
#   'twice',
#   'expect',
#   'pricey',
#   '50',
#   'expens',
#   'worth',
#   'far',
#   'wast',
#   'duster',
#   'think',
#   'bagless',
#   'best',
#   'dyson',
#   'need',
#   'ok',
#   'weight',
#   'bag',
#   'power',
#   'light',
#   'like',
#   'good',
#   'vacuum'],
#  'Handles': ['strap',
#   'handl',
#   'shoulder',
#   'broke',
#   'later',
#   'month',
#   'hand',
#   'comfort',
#   'plastic',
#   'wear',
#   'tear',
#   'rip',
#   'start',
#   'attach',
#   'holiday',
#   'left',
#   'lift',
#   'final',
#   'broken',
#   'stand',
#   'inevit',
#   'situat',
#   'firm',
#   'bend',
#   'hurt',
#   'minut',
#   'addit',
#   'note',
#   'buckl',
#   'adjust',
#   'adjust',
#   'short',
#   'shorter',
#   'length',
#   'adjust',
#   'long',
#   'metal',
#   'swivel',
#   'sooner',
#   'break',
#   'felt',
#   'rip',
#   'loop',
#   'hook',
#   'torn',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'use'],
#  'Customer_service': ['paid',
#   'support',
#   'servic',
#   'week',
#   'replac',
#   'mail',
#   'wait',
#   'pay',
#   'ship',
#   '1500',
#   'bring',
#   'deliveri',
#   'come',
#   'use',
#   'peopl',
#   'speak',
#   'technician',
#   'refurbish',
#   'handl',
#   'shore',
#   'communic',
#   'difficult',
#   '49',
#   'diagnost',
#   'fee',
#   '100',
#   'fix',
#   'latest',
#   'divx',
#   'arriv',
#   'undamag',
#   'po',
#   'mention',
#   'desk',
#   'help',
#   'suppos',
#   'later',
#   'cancel',
#   'reschedul',
#   'entir',
#   'glove',
#   'pilot',
#   'deliv',
#   'fact',
#   'clear',
#   'requir',
#   '100lb',
#   'carri',
#   'downstair',
#   'check'],
#  'Looks': ['look',
#   'slim',
#   'origin',
#   'appear',
#   'lttle',
#   'attract',
#   'beauti',
#   'size',
#   'small',
#   'decent',
#   'imac',
#   'backlit',
#   'longer',
#   'pc',
#   'like',
#   'laptop',
#   'nice',
#   'great',
#   'cheap',
#   'keyboard',
#   'good',
#   'feel'],
#  'Quality': ['qualiti',
#   'materi',
#   'handl',
#   'poor',
#   'broke',
#   'durabl',
#   'month',
#   'later',
#   'wear',
#   'tear',
#   'zipper',
#   'chemic',
#   'start',
#   'excel',
#   'terribl',
#   'crack',
#   'strap',
#   'daili',
#   'plastic',
#   'pull',
#   'smell',
#   'edg',
#   'rip',
#   'white',
#   'item',
#   'year',
#   'go',
#   'feel',
#   'attach',
#   'brake',
#   'holiday',
#   'outstand',
#   'strip',
#   'peel',
#   'left',
#   'final',
#   'broken',
#   'stand',
#   'sacrific',
#   'durabl',
#   'style',
#   'cours',
#   'trip',
#   'asia',
#   'rip',
#   'construct',
#   'cancer',
#   'birth',
#   'defect',
#   'reproduct'],
#  'Protection': ['protect',
#   'pad',
#   'protect',
#   'protect',
#   'drop',
#   'lap',
#   'insid',
#   'comput',
#   'laptop',
#   'good',
#   'let',
#   'secur',
#   'damag',
#   'intern',
#   'weak',
#   'tast',
#   'trust',
#   'protect',
#   'construct',
#   'provid',
#   'second',
#   'protect',
#   'count',
#   'sort',
#   'happen',
#   'cushion',
#   'adequ',
#   'thing',
#   'pencil',
#   'heavi',
#   'normal',
#   'kensington',
#   'probabl',
#   'larg',
#   'like',
#   'way',
#   'stylish',
#   'far',
#   'sleev',
#   'pad',
#   'feel',
#   'realli',
#   'perfect',
#   'bit',
#   'littl',
#   'bag',
#   'macbook',
#   'love',
#   'use'],
#  'Size_Fit': ['fit',
#   'size',
#   'macbook',
#   'big',
#   'space',
#   'air',
#   'slight',
#   'lot',
#   'bulk',
#   'perfect',
#   'inch',
#   'laptop',
#   'perfect',
#   '13',
#   'cabl',
#   'folder',
#   'notebook',
#   'sure',
#   'snug',
#   'bit',
#   'te',
#   'seat',
#   'airplan',
#   'fre',
#   'cell',
#   'pouch',
#   'tight',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'enorm',
#   '17inch',
#   'bare',
#   'm1710',
#   'hp',
#   'pavilion',
#   'dv7',
#   '3080us',
#   'disappoint',
#   'cloth',
#   'whatnot',
#   'spacious',
#   'book',
#   'load',
#   'accommod'],
#  'Ease_of_use': ['easi',
#   'cord',
#   'push',
#   'corner',
#   'vacuum',
#   'pile',
#   'maneuv',
#   'nozzl',
#   'awkward',
#   'crevic',
#   'constant',
#   'bog',
#   'imposs',
#   'short',
#   'carpet',
#   'heavi',
#   'roller',
#   'hose',
#   'difficult',
#   'wall',
#   'suck',
#   'remov',
#   'empti',
#   'power',
#   'hard',
#   'jump',
#   'simpic',
#   'automat',
#   'retractor',
#   'retract',
#   'flash',
#   'baseboard',
#   'retract',
#   'easier',
#   'snap',
#   'disassembl',
#   'direct',
#   'propel',
#   'person',
#   'race',
#   'furnitur',
#   'flexibl',
#   'kink',
#   'prefer',
#   'cannist',
#   'car',
#   'refriger',
#   'move',
#   'eas',
#   'worst'],
#  'Sound': ['sound',
#   'speaker',
#   'good',
#   'qualiti',
#   'loud',
#   'tinni',
#   'bass',
#   'hear',
#   'horribl',
#   'trebl',
#   'chang',
#   'realli',
#   'great',
#   'terribl',
#   'bar',
#   'display',
#   'thing',
#   'eye',
#   'ear',
#   'loudest',
#   'volum',
#   'strain',
#   'quieter',
#   'dinner',
#   'lack',
#   'sort',
#   'improv',
#   'surround',
#   'true',
#   'experi',
#   'junki',
#   'mind',
#   'vibrat',
#   'develop',
#   'pitch',
#   'whine',
#   'strong',
#   'track',
#   'cool',
#   'worthi',
#   'shippabl',
#   'adjust',
#   'weird',
#   'kinda',
#   'improv',
#   'cheapest',
#   'laptop',
#   'watt',
#   'muffl',
#   'margin'],
#  'Look': ['cute',
#   'look',
#   'look',
#   'great',
#   'fring',
#   'style',
#   'color',
#   'love',
#   'design',
#   'go',
#   'unattract',
#   'attract',
#   'offic',
#   'environ',
#   'pictur',
#   '360',
#   'degre',
#   'vent',
#   'concept',
#   'coverag',
#   'airi',
#   'hang',
#   'unattract',
#   'durabl',
#   'nice',
#   'casual',
#   'beauti',
#   'moccasin',
#   'shame',
#   'taup',
#   'direct',
#   'smooth',
#   'laid',
#   'rest',
#   'natur',
#   'calm',
#   'absolut',
#   'ador',
#   'pictur',
#   'grey',
#   'wonder',
#   'stylish',
#   'comfort',
#   'boot',
#   'good',
#   'collaps',
#   'super',
#   'crazi',
#   'light',
#   'weight'],
#  'Connectivity': ['hdmi',
#   'port',
#   'comput',
#   'input',
#   'compon',
#   'usb',
#   'internet',
#   'connect',
#   'output',
#   'server',
#   'connect',
#   'audio',
#   'play',
#   'stop',
#   'standard',
#   'avi',
#   'like',
#   'hd',
#   'file',
#   'movi',
#   'work',
#   'digit',
#   'monitor',
#   'comcast',
#   'connect',
#   'drive',
#   'end',
#   'cabl',
#   'watch',
#   'netflix',
#   'flash',
#   '45',
#   'min',
#   'rf',
#   'vga',
#   'cycl',
#   'signal',
#   'higher',
#   'slot',
#   'integr',
#   'wi',
#   'fi',
#   'stream',
#   'speed',
#   'conflict',
#   'dhcp',
#   'hard',
#   'dlna',
#   'enabl',
#   'power'],
#  'Battery': ['batteri',
#   'charg',
#   'life',
#   'charger',
#   'charg',
#   'tone',
#   'longer',
#   'low',
#   'hour',
#   'power',
#   'light',
#   'color',
#   'red',
#   'respond',
#   'merit',
#   'vari',
#   'recharg',
#   'bizarr',
#   'later',
#   'sudden',
#   'dead',
#   'meter',
#   'hold',
#   'thing',
#   'half',
#   'green',
#   'stop',
#   'nokia',
#   'turn',
#   'start',
#   'blackberri',
#   'star',
#   'phone',
#   'good',
#   'day',
#   'cell',
#   'come',
#   'talk',
#   'get',
#   'simpl',
#   'pretti',
#   'love',
#   'better',
#   'easili',
#   'volum',
#   'nois',
#   'time',
#   'work'],
#  'Durability': ['rubber',
#   'qualiti',
#   'use',
#   'buckl',
#   'appear',
#   'heel',
#   'long',
#   'time',
#   'break',
#   'enjoy',
#   'provid',
#   'protect',
#   'clear',
#   'cheapli',
#   'thinner',
#   'barn',
#   'month',
#   'start',
#   'tear',
#   'constant',
#   'fold',
#   'gone',
#   'numer',
#   'decor',
#   'come',
#   'sturdi',
#   'sure',
#   'durabl',
#   'decent',
#   'cheep',
#   'deflat',
#   'daili',
#   'wear',
#   'collaps',
#   'super',
#   'need',
#   'sol',
#   'red',
#   'obvious',
#   'differ',
#   'think',
#   'worn',
#   'abl',
#   'materi',
#   'actual',
#   'pretti',
#   'heavi',
#   'true',
#   'style',
#   'support'],
#  'Comfort': ['comfort',
#   'fit',
#   'foot',
#   'hurt',
#   'ankl',
#   'comfi',
#   'blister',
#   'comfort',
#   'break',
#   'wear',
#   'abl',
#   'extrem',
#   'walk',
#   'sock',
#   'longer',
#   'pain',
#   'perfect',
#   'super',
#   'uncomfort',
#   'light',
#   'weight',
#   'discomfort',
#   'snug',
#   'put',
#   'slide',
#   'sued',
#   'feel',
#   'littl',
#   'time',
#   'narrow',
#   'toe',
#   'minut',
#   'summer',
#   'insid',
#   'short',
#   'long',
#   'wear',
#   'perfect',
#   'list',
#   'doc',
#   'tongu',
#   'moment',
#   'break',
#   'enjoy',
#   'plus',
#   'actual',
#   'loos',
#   'attract',
#   'offic',
#   'environ'],
#  'Materials': ['leather',
#   'insid',
#   'fring',
#   'materi',
#   'heel',
#   'cheaper',
#   'soft',
#   'sole',
#   'buckl',
#   'sued',
#   'true',
#   'rubber',
#   'advertis',
#   'fact',
#   'cloth',
#   'back',
#   'synthet',
#   'finish',
#   'aerosol',
#   'line',
#   'aw',
#   'memori',
#   'foam',
#   'thinner',
#   'barn',
#   'decor',
#   'come',
#   'hang',
#   'unattract',
#   'fashion',
#   'porous',
#   'term',
#   'best',
#   'describ',
#   'let',
#   'penetr',
#   'piec',
#   'elast',
#   'zipper',
#   'friction',
#   'easili',
#   'improv',
#   'fleec',
#   'especi',
#   'superb',
#   'direct',
#   'smooth',
#   'natur',
#   'calm',
#   'hollow'],
#  'Color': ['color',
#   'love',
#   'style',
#   'unbeliev',
#   'gorgeous',
#   'blue',
#   'favorit',
#   'taup',
#   'wonder',
#   'red',
#   'exact',
#   'design',
#   'purchas',
#   'love',
#   'materi',
#   'look',
#   'perfect',
#   'look',
#   'boot'],
#  'Size': ['size',
#   'order',
#   'half',
#   'order',
#   'big',
#   'littl',
#   'bigger',
#   'usual',
#   'narrow',
#   'normal',
#   'width',
#   'true',
#   'run',
#   'small',
#   'size',
#   'larger',
#   'perfect',
#   'fit',
#   'sent',
#   'ankl',
#   'wide',
#   'tight',
#   'baggi',
#   'wise',
#   'tuck',
#   'pant',
#   'follow',
#   'advic',
#   'buyer',
#   'bacaus',
#   'possibl',
#   'joint',
#   'especi',
#   'superb',
#   'beauti',
#   'moccasin',
#   'shame',
#   'sould',
#   'larg',
#   'awar',
#   'length',
#   'tab',
#   'decid',
#   'normal',
#   'option',
#   'shorter',
#   'left',
#   'mayb',
#   'wear',
#   'calf'],
#  'Weather_resistance': ['dri',
#   'waterproof',
#   'rain',
#   'wet',
#   'water',
#   'foot',
#   'soak',
#   'snow',
#   'cold',
#   'puddl',
#   'warm',
#   'got',
#   'chicago',
#   'protect',
#   'suppos',
#   'defect',
#   'item',
#   'traction',
#   'raini',
#   'interest',
#   'ice',
#   'spent',
#   'cub',
#   'scout',
#   'den',
#   'alcatraz',
#   'island',
#   'san',
#   'francisco',
#   'lot',
#   'claim',
#   'stori',
#   'resist',
#   'generous',
#   'porous',
#   'term',
#   'dewi',
#   'grass',
#   'leav',
#   'soak',
#   'let',
#   'penetr',
#   'perform',
#   'repel',
#   'sandal',
#   'stay',
#   'amaz',
#   'outsid',
#   'step',
#   'deep'],
#  'Noise': ['quiet',
#   'noisi',
#   'loud',
#   'power',
#   'nois',
#   'louder',
#   'ear',
#   'loudest',
#   'light',
#   'incred',
#   'deafen',
#   'serious',
#   'actual',
#   'ring',
#   'doggi',
#   'hide',
#   'flee',
#   'powerstick',
#   'earplug',
#   'lose',
#   'bearabl',
#   'block',
#   'pro',
#   'fair',
#   'reason',
#   'direct',
#   'mous',
#   'explod',
#   'silent',
#   'compar',
#   'stylish',
#   'function',
#   'weight',
#   'peopl',
#   'ring',
#   'motor',
#   'awesom',
#   'nozzl',
#   'readi',
#   'sound',
#   'devil',
#   'purchas',
#   'quit',
#   'size',
#   'upright',
#   'star',
#   'heavi',
#   'lightweight',
#   'recommend',
#   'turn'],
#  'Extra_functionality': ['button',
#   'light',
#   'pencil',
#   'volum',
#   'power',
#   'featur',
#   'bright',
#   'mute',
#   'handi',
#   'low',
#   'dark',
#   'blue',
#   'wake',
#   'sleep',
#   'pen',
#   'nice',
#   'quit',
#   'shortcut',
#   'internet',
#   'spillproof',
#   'interest',
#   'vista',
#   'capabl',
#   'support',
#   'shut',
#   'keypress',
#   'pre',
#   'program',
#   'calcul',
#   'mycomput',
#   'custom',
#   'email',
#   'brower',
#   'activ',
#   'music',
#   'special',
#   'disk',
#   'eject',
#   'hold',
#   'remain',
#   'recess',
#   'clutch',
#   'multimedia',
#   'label',
#   'illumin',
#   'programm',
#   'legibl',
#   'dark',
#   'dim',
#   'backlight'],
#  'Layout': ['key',
#   'delet',
#   'backspac',
#   'size',
#   'layout',
#   'end',
#   'insert',
#   'home',
#   'bar',
#   'perfect',
#   'space',
#   'cluster',
#   'squish',
#   'space',
#   'close',
#   'small',
#   'volum',
#   'tini',
#   'place',
#   'arrow',
#   'littl',
#   'tricki',
#   'bigger',
#   'million',
#   'print',
#   'scroll',
#   'paus',
#   'quick',
#   'navig',
#   'difficult',
#   'suppos',
#   'spill',
#   'proof',
#   '104',
#   'negat',
#   'overs',
#   'awkward',
#   'place',
#   'vertic',
#   'horizont',
#   'multimedia',
#   'label',
#   'wider',
#   'impecc',
#   'activ',
#   'chang',
#   'requir',
#   'movement',
#   'wide',
#   'strike'],
#  'Feel_Comfort': ['feel',
#   'comfort',
#   'mushi',
#   'key',
#   'like',
#   'keyboard',
#   'good',
#   'perfect',
#   'press',
#   'wrist',
#   'action',
#   'shallow',
#   'smooth',
#   'finger',
#   'relax',
#   'type',
#   'level',
#   'keystrok',
#   'sit',
#   'type',
#   'quick',
#   'navig',
#   'difficult',
#   'shop',
#   'consist',
#   'respond',
#   'pressur',
#   'sens',
#   'deceler',
#   'quick',
#   'mush',
#   'tap',
#   'regist',
#   'usual',
#   'chicklet',
#   'membran',
#   'stick',
#   'satisfi',
#   'clicki',
#   'ibm',
#   'dissatisfi',
#   'natur',
#   'tension',
#   'impecc',
#   'stylish',
#   'recogn',
#   'signatur',
#   'butteri',
#   'velvet',
#   'feather'],
#  'Build_Quality': ['belt',
#   'broke',
#   'turn',
#   'work',
#   'burn',
#   'electr',
#   'built',
#   'stop',
#   'month',
#   'roller',
#   'time',
#   'minut',
#   'problem',
#   'brush',
#   'design',
#   'easili',
#   'wise',
#   'continu',
#   'break',
#   'fifth',
#   'barley',
#   'bump',
#   '20',
#   'last',
#   'connect',
#   'swivel',
#   'portion',
#   'fail',
#   'constuct',
#   'electron',
#   'construct',
#   'simpli',
#   'quit',
#   'burnt',
#   'miss',
#   'smell',
#   'overheat',
#   'shut',
#   'poor',
#   'attach',
#   'pop',
#   'unannounc',
#   'snapper',
#   'flimsi',
#   'overh',
#   'upper',
#   'run',
#   'turn',
#   'prepar',
#   'sturdi'],
#  'Size_Look': ['size',
#   'big',
#   'bigger',
#   '40',
#   'differ',
#   'screen',
#   'room',
#   'light',
#   '3d',
#   'livingroom',
#   'hardwar',
#   'slim',
#   'cubbyhol',
#   'huge',
#   'weigh',
#   'awkward',
#   'pentil',
#   'matrix',
#   '60',
#   'foot',
#   '65',
#   'consid',
#   'oh',
#   'lightweight',
#   'compact',
#   'suitabl',
#   'live',
#   'ultra',
#   'weigh',
#   'le',
#   'pound',
#   'hindsight',
#   'wonder',
#   'feel',
#   'anticip',
#   'actual',
#   'bedroom',
#   'fit',
#   'perfect',
#   'love',
#   'smaller',
#   'store',
#   'averag',
#   'inch',
#   'view',
#   '32',
#   'perfect',
#   'home',
#   'easili',
#   'get'],
#  'Image': ['pictur',
#   'color',
#   'qualiti',
#   'black',
#   'bright',
#   'nice',
#   'clear',
#   'look',
#   'excel',
#   'crisp',
#   'screen',
#   'right',
#   'dead',
#   'pixel',
#   'trace',
#   'beauti',
#   'vibrant',
#   'sharp',
#   'angl',
#   'display',
#   'dvd',
#   'differ',
#   'corner',
#   'fantast',
#   'hd',
#   'overal',
#   'inch',
#   'imag',
#   'view',
#   'white',
#   'great',
#   'ok',
#   'red',
#   'decent',
#   'struck',
#   'eye',
#   'ear',
#   'definit',
#   'fuzzi',
#   'font',
#   'improv',
#   'expeci',
#   'hubbi',
#   'sleep',
#   'caus',
#   'biggest',
#   'level',
#   'notic',
#   'irrit',
#   'affect'],
#  'Apps_Interface': ['netflix',
#   'user',
#   'file',
#   'hulu',
#   'app',
#   'watch',
#   'flash',
#   'internet',
#   'smart',
#   'video',
#   'stream',
#   'speed',
#   'youtub',
#   'access',
#   'lack',
#   'smart',
#   'download',
#   'brows',
#   'eas',
#   'interfac',
#   'friend',
#   'access',
#   'work',
#   'capabl',
#   'alright',
#   'quit',
#   'mean',
#   'let',
#   'hub',
#   'applic',
#   'terribl',
#   'watch',
#   'plus',
#   'easili',
#   'buy',
#   'week',
#   'right',
#   'featur',
#   'movi',
#   'comput',
#   'cabl',
#   'best',
#   'samsung',
#   'time',
#   'realli',
#   'like',
#   'better'],
#  'Suction_Power': ['suction',
#   'pick',
#   'power',
#   'power',
#   'good',
#   'hair',
#   'carpet',
#   'suck',
#   'quiet',
#   'realli',
#   'perform',
#   'dirt',
#   'tile',
#   'ok',
#   'job',
#   'floor',
#   'perfom',
#   'total',
#   'angl',
#   'attribut',
#   'machin',
#   'main',
#   'simpic',
#   'weak',
#   'object',
#   'bear',
#   'spot',
#   'vacuum',
#   'dosen',
#   'produc',
#   'fault',
#   'unders',
#   'pretti',
#   'essenti',
#   'spin',
#   'spun',
#   'mayb',
#   'pro',
#   'fair',
#   'reason',
#   'loo',
#   'filter',
#   'superb',
#   'grout',
#   'ergorapido',
#   'leav',
#   'plush',
#   'grind',
#   'stylish',
#   'function'],
#  'Weight': ['light',
#   'weight',
#   'lightweight',
#   'heavi',
#   'size',
#   'compact',
#   'maneuv',
#   'guess',
#   'quiet',
#   'quit',
#   'probabl',
#   'cumbersom',
#   'feaur',
#   'reason',
#   'histori',
#   'minor',
#   'heavier',
#   'consid',
#   'compar',
#   'nice',
#   'larg',
#   'need',
#   'especi',
#   'carri',
#   'drawback',
#   'perform',
#   'past',
#   'suppos',
#   'thought',
#   'power',
#   'loud',
#   'price',
#   'easi',
#   'feel',
#   'hardwood',
#   'push',
#   'store',
#   'panason',
#   'vacuum',
#   'bagless',
#   'area',
#   'ok',
#   'purchas',
#   'vaccuum',
#   'small',
#   'hard',
#   'littl',
#   'short',
#   'rug',
#   'canist'],
#  'Customer_Service': ['servic',
#   'contact',
#   'help',
#   'custom',
#   'took',
#   'email',
#   'miel',
#   'hoover',
#   'dealer',
#   'horribl',
#   'multipl',
#   'respond',
#   'chose',
#   'repres',
#   'told',
#   'smell',
#   'lubric',
#   'dissip',
#   'wait',
#   'spent',
#   'hour',
#   'phone',
#   'depart',
#   'contact',
#   'busi',
#   'regist',
#   'late',
#   'gotten',
#   'card',
#   'mail',
#   'ignor',
#   'look',
#   'common',
#   'recent',
#   'respons',
#   'unfortun',
#   'video',
#   'warranti',
#   'useless',
#   'self',
#   'fall',
#   'day',
#   'amazon',
#   'issu',
#   'absolut',
#   'time',
#   'purchas',
#   'problem'],
#  'Accessories': ['filter',
#   'brush',
#   'attach',
#   'roll',
#   'turbo',
#   'easili',
#   'expens',
#   'wide',
#   'turn',
#   'bag',
#   'replac',
#   'typic',
#   'hepa',
#   'cover',
#   'extens',
#   'wonder',
#   'crevic',
#   'reach',
#   'requir',
#   'clean',
#   'duster',
#   'hose',
#   'clean',
#   'way',
#   'noisi',
#   'corner',
#   'hardwood',
#   'empti',
#   'get',
#   'convent',
#   'brushrol',
#   'extra',
#   'rotat',
#   'block',
#   'bag',
#   'scrap',
#   'okay',
#   'basic',
#   'eye',
#   'regular',
#   'sensor',
#   'green',
#   'complet',
#   'instead',
#   'allow',
#   'need',
#   'spinner',
#   'fact',
#   'cup',
#   'onboard']}

# %%
for each_aspect in Aspect_to_seeds:
    print(each_aspect, Aspect_to_seeds[each_aspect].__len__())
# Out:
# Compartments 50
# Price 34
# Handles 50
# Customer_service 50
# Looks 22
# Quality 50
# Protection 49
# Size_Fit 50
# Ease_of_use 50
# Sound 50
# Look 50
# Connectivity 50
# Battery 48
# Durability 50
# Comfort 50
# Materials 50
# Color 19
# Size 50
# Weather_resistance 50
# Noise 50
# Extra_functionality 50
# Layout 50
# Feel_Comfort 50
# Build_Quality 50
# Size_Look 50
# Image 50
# Apps_Interface 47
# Suction_Power 50
# Weight 50
# Customer_Service 48
# Accessories 50

# %%
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
# tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")

# %%
# model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# %%
# !echo $CUDA_VISIBLE_DEVICES

# %%
model_args = {'seed_samples': 10, 
              'aspect_length':6
             }

# %%
class aspectDataset(Dataset):
    
    def __init__(self, list_data, tokenizer, model_args):
        self.tokenizer = tokenizer
        self.list_data = list_data
        self.seeds_length = model_args['seed_samples']
        self.aspect_length = model_args['aspect_length']
    
    def __len__(self):
        """Return length of dataset."""
        return self.list_data.__len__()

    def __getitem__(self, i):
        """Return sample from dataset at index i."""
        example = self.list_data[i]
        shuffle(example['seeds'])
        sampled_seeds = example['seeds'][:self.seeds_length]
        aspect = " ".join(example["aspect"].split('_'))
#         max_length = self.seeds_length+2
        inputs = tokenizer(", ".join(sampled_seeds), 
                           truncation=True)  
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            padding="max_length", 
#                            truncation=True, 
#                            max_length=max_length)  
        outputs = tokenizer(aspect, 
                            padding="max_length", 
                            truncation=True, 
                            max_length=self.aspect_length)
        
        batch = {}
        batch["input_ids"] = torch.LongTensor(inputs.input_ids)
        batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["decoder_input_ids"] = torch.LongTensor(outputs.input_ids)
#         batch["decoder_attention_mask"] = torch.LongTensor(outputs.attention_mask)
        batch["labels"] = outputs.input_ids.copy()
        batch['labels'] = [batch['labels']]

        # We have to make sure that the PAD token is ignored for calculating the loss
        batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
                           for labels in batch["labels"]]
        batch["labels"] = torch.LongTensor(batch["labels"])
        batch["labels"] = batch["labels"].squeeze(0)
        
        return batch

# %%
train_data = []
for each_key in Aspect_to_seeds:
    train_data.append({"seeds":Aspect_to_seeds[each_key],
                       "aspect":each_key})

# %%
train_dataset = aspectDataset(list_data=train_data, 
                              tokenizer=tokenizer,
                              model_args=model_args
                             )

# %%
train_loader = DataLoader(train_dataset, 
                          batch_size=1, 
                          shuffle=True,
                          num_workers=1)

# %%
model = model.to("cuda")

# %%
# the_encoder = model.get_encoder()
# the_decoder = model.get_decoder()
# last_linear_layer = model.lm_head

# %%
num_epochs = 15
num_training_steps = num_epochs * len(train_data)

loss_fct = CrossEntropyLoss()

optimizer = AdamW(model.parameters(), 
                  lr=2e-7)
warmup_steps = int(0.10*num_training_steps)
lr_scheduler = get_scheduler("linear",
                            optimizer=optimizer,
                            num_warmup_steps=warmup_steps,
                            num_training_steps=num_training_steps
                            )

# %%
all_train_loss = []
for epoch in tqdm(range(num_epochs)):
    training_loss = 0.0
    model.train()
    for ind, batch in enumerate(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        model_op = model(**batch)
        loss = model_op['loss']
        
        training_loss += loss.item()
        
        print('---'*20)
        print('Epoch:', epoch, 'ID:', ind)
        print('---'*20)
        print('Seed words:', tokenizer.batch_decode(batch['input_ids'], 
                                                    skip_special_tokens=True, 
                                                    clean_up_tokenization_spaces=False))
        print('Actual aspect:', tokenizer.batch_decode(batch['labels'][batch['labels']!=-100].unsqueeze(0), 
                                                       skip_special_tokens=True, 
                                                       clean_up_tokenization_spaces=True))
        output_ids = model.generate(batch["input_ids"], 
                                    num_beams=3, 
                                    max_length=6)
        print('Predicted aspect:', tokenizer.batch_decode(output_ids, 
                                                          skip_special_tokens=True, 
                                                          clean_up_tokenization_spaces=True))
        
        loss.backward()
        optimizer.step() 
        lr_scheduler.step() 
        optimizer.zero_grad() 
    training_loss = training_loss / len( train_data )
    all_train_loss.append(training_loss)
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ------------------------------------------------------------
# Epoch: 0 ID: 0
# ------------------------------------------------------------
# Seed words: ['perfect, consid, 60, fit, weigh, get, livingroom, anticip, huge, bedroom']
# Actual aspect: ['Size Look']
# Predicted aspect: ['perfect, cons']
# ------------------------------------------------------------
# Epoch: 0 ID: 1
# ------------------------------------------------------------
# Seed words: ['moment, littl, environ, foot, pain, super, perfect, minut, actual, put']
# Actual aspect: ['Comfort']
# Predicted aspect: ['moment,']
# ------------------------------------------------------------
# Epoch: 0 ID: 2
# ------------------------------------------------------------
# Seed words: ['direct, absolut, boot, degre, great, crazi, hang, super, concept, comfort']
# Actual aspect: ['Look']
# Predicted aspect: ['direct, abs']
# ------------------------------------------------------------
# Epoch: 0 ID: 3
# ------------------------------------------------------------
# Seed words: ['zipper, daili, cours, white, rip, broke, outstand, durabl, smell, rip']
# Actual aspect: ['Quality']
# Predicted aspect: ['zipper,']
# ------------------------------------------------------------
# Epoch: 0 ID: 4
# ------------------------------------------------------------
# Seed words: ['let, app, brows, access, file, watch, better, week, best, netflix']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['let, app']
# ------------------------------------------------------------
# Epoch: 0 ID: 5
# ------------------------------------------------------------
# Seed words: ['kink, worst, direct, crevic, nozzl, race, retract, hose, flash, pile']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['kink,']
# ------------------------------------------------------------
# Epoch: 0 ID: 6
# ------------------------------------------------------------
# Seed words: ['vacuum, light, spin, worth, 50, spun, best, duster, far, expect']
# Actual aspect: ['Price']
# Predicted aspect: ['vacuum']
# ------------------------------------------------------------
# Epoch: 0 ID: 7
# ------------------------------------------------------------
# Seed words: ['true, awar, beauti, sould, decid, size, normal, order, length, moccasin']
# Actual aspect: ['Size']
# Predicted aspect: ['true, aw']
# ------------------------------------------------------------
# Epoch: 0 ID: 8
# ------------------------------------------------------------
# Seed words: ['purchas, exact, color, red, love, look, design, gorgeous, favorit, taup']
# Actual aspect: ['Color']
# Predicted aspect: ['purchas']
# ------------------------------------------------------------
# Epoch: 0 ID: 9
# ------------------------------------------------------------
# Seed words: ['drive, vga, input, integr, hdmi, standard, rf, digit, higher, wi']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['drive, v']
# ------------------------------------------------------------
# Epoch: 0 ID: 10
# ------------------------------------------------------------
# Seed words: ['origin, small, beauti, like, longer, size, nice, pc, backlit, laptop']
# Actual aspect: ['Looks']
# Predicted aspect: ['origin, small']
# ------------------------------------------------------------
# Epoch: 0 ID: 11
# ------------------------------------------------------------
# Seed words: ['past, cumbersom, suppos, consid, perform, need, lightweight, heavi, larg, canist']
# Actual aspect: ['Weight']
# Predicted aspect: ['past,']
# ------------------------------------------------------------
# Epoch: 0 ID: 12
# ------------------------------------------------------------
# Seed words: ['bear, floor, dosen, job, attribut, pretti, spot, pick, ergorapido, pro']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['bear, floor']
# ------------------------------------------------------------
# Epoch: 0 ID: 13
# ------------------------------------------------------------
# Seed words: ['eye, hose, attach, easili, wonder, brush, turbo, noisi, empti, rotat']
# Actual aspect: ['Accessories']
# Predicted aspect: ['eye, hose']
# ------------------------------------------------------------
# Epoch: 0 ID: 14
# ------------------------------------------------------------
# Seed words: ['lot, ice, cub, let, water, san, dewi, repel, puddl, protect']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['lot, ice']
# ------------------------------------------------------------
# Epoch: 0 ID: 15
# ------------------------------------------------------------
# Seed words: ['right, corner, black, pictur, struck, biggest, definit, dead, ear, decent']
# Actual aspect: ['Image']
# Predicted aspect: ['right, corner']
# ------------------------------------------------------------
# Epoch: 0 ID: 16
# ------------------------------------------------------------
# Seed words: ['104, multimedia, vertic, impecc, home, space, difficult, end, delet, place']
# Actual aspect: ['Layout']
# Predicted aspect: ['104, multimedia']
# ------------------------------------------------------------
# Epoch: 0 ID: 17
# ------------------------------------------------------------
# Seed words: ['enorm, reduct, space, tight, pouch, m1710, sure, size, whatnot, cabl']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['enorm,']
# ------------------------------------------------------------
# Epoch: 0 ID: 18
# ------------------------------------------------------------
# Seed words: ['mushi, natur, type, signatur, relax, difficult, tap, type, key, recogn']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['mushi,']
# ------------------------------------------------------------
# Epoch: 0 ID: 19
# ------------------------------------------------------------
# Seed words: ['worthi, pitch, vibrat, muffl, hear, lack, laptop, chang, volum, mind']
# Actual aspect: ['Sound']
# Predicted aspect: ['worthi,']
# ------------------------------------------------------------
# Epoch: 0 ID: 20
# ------------------------------------------------------------
# Seed words: ['featur, spillproof, mycomput, button, brower, capabl, handi, interest, power, quit']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['featur,']
# ------------------------------------------------------------
# Epoch: 0 ID: 21
# ------------------------------------------------------------
# Seed words: ['fleec, hang, foam, improv, friction, barn, aerosol, natur, aw, sole']
# Actual aspect: ['Materials']
# Predicted aspect: ['fleec,']
# ------------------------------------------------------------
# Epoch: 0 ID: 22
# ------------------------------------------------------------
# Seed words: ['fee, arriv, undamag, cancel, use, replac, difficult, ship, shore, servic']
# Actual aspect: ['Customer service']
# Predicted aspect: ['fee, arri']
# ------------------------------------------------------------
# Epoch: 0 ID: 23
# ------------------------------------------------------------
# Seed words: ['folder, small, accessori, earphon, nois, need, nice, instead, pocket, wish']
# Actual aspect: ['Compartments']
# Predicted aspect: [' folder, small']
# ------------------------------------------------------------
# Epoch: 0 ID: 24
# ------------------------------------------------------------
# Seed words: ['cheapli, true, break, month, daili, long, wear, tear, abl, use']
# Actual aspect: ['Durability']
# Predicted aspect: ['cheapl']
# ------------------------------------------------------------
# Epoch: 0 ID: 25
# ------------------------------------------------------------
# Seed words: ['reason, powerstick, compar, silent, ear, function, stylish, quiet, pro, power']
# Actual aspect: ['Noise']
# Predicted aspect: ['reason, power']
# ------------------------------------------------------------
# Epoch: 0 ID: 26
# ------------------------------------------------------------
# Seed words: ['sleev, pad, secur, count, protect, comput, happen, drop, protect, good']
# Actual aspect: ['Protection']
# Predicted aspect: ['sleev,']
# ------------------------------------------------------------
# Epoch: 0 ID: 27
# ------------------------------------------------------------
# Seed words: ['love, sudden, pretti, red, bizarr, come, half, talk, life, nokia']
# Actual aspect: ['Battery']
# Predicted aspect: ['love, sudden']
# ------------------------------------------------------------
# Epoch: 0 ID: 28
# ------------------------------------------------------------
# Seed words: ['swivel, felt, sooner, length, shoulder, short, broke, long, use, plastic']
# Actual aspect: ['Handles']
# Predicted aspect: ['swivel']
# ------------------------------------------------------------
# Epoch: 0 ID: 29
# ------------------------------------------------------------
# Seed words: ['time, horribl, phone, absolut, contact, mail, gotten, ignor, contact, look']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['time, hor']
# ------------------------------------------------------------
# Epoch: 0 ID: 30
# ------------------------------------------------------------
# Seed words: ['attach, design, overheat, last, built, brush, swivel, barley, electron, break']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['attach, design']
#   7%|▋         | 1/15 [00:10<02:31, 10.84s/it]
# Epoch 1:	Training Loss 7.00
# ------------------------------------------------------------
# Epoch: 1 ID: 0
# ------------------------------------------------------------
# Seed words: ['last, fail, burn, miss, snapper, overh, sturdi, barley, roller, 20']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['last, fail']
# ------------------------------------------------------------
# Epoch: 1 ID: 1
# ------------------------------------------------------------
# Seed words: ['quieter, trebl, worthi, experi, strain, shippabl, bass, cheapest, muffl, kinda']
# Actual aspect: ['Sound']
# Predicted aspect: ['quieter,']
# ------------------------------------------------------------
# Epoch: 1 ID: 2
# ------------------------------------------------------------
# Seed words: ['alright, quit, interfac, access, friend, like, realli, samsung, applic, terribl']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['alright,']
# ------------------------------------------------------------
# Epoch: 1 ID: 3
# ------------------------------------------------------------
# Seed words: ['speak, fact, help, ship, peopl, servic, requir, use, divx, technician']
# Actual aspect: ['Customer service']
# Predicted aspect: ['speak, fact']
# ------------------------------------------------------------
# Epoch: 1 ID: 4
# ------------------------------------------------------------
# Seed words: ['amazon, busi, respons, time, unfortun, help, told, dealer, wait, dissip']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['amazon, bus']
# ------------------------------------------------------------
# Epoch: 1 ID: 5
# ------------------------------------------------------------
# Seed words: ['cycl, hdmi, connect, output, speed, internet, stop, server, avi, like']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['cycl, h']
# ------------------------------------------------------------
# Epoch: 1 ID: 6
# ------------------------------------------------------------
# Seed words: ['adjust, handl, long, left, comfort, adjust, sooner, start, situat, hurt']
# Actual aspect: ['Handles']
# Predicted aspect: ['adjust, hand']
# ------------------------------------------------------------
# Epoch: 1 ID: 7
# ------------------------------------------------------------
# Seed words: ['superb, come, hang, calm, barn, insid, buckl, friction, especi, fleec']
# Actual aspect: ['Materials']
# Predicted aspect: ['superb,']
# ------------------------------------------------------------
# Epoch: 1 ID: 8
# ------------------------------------------------------------
# Seed words: ['baseboard, push, disassembl, hard, retractor, eas, carpet, simpic, person, imposs']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['baseboard,']
# ------------------------------------------------------------
# Epoch: 1 ID: 9
# ------------------------------------------------------------
# Seed words: ['provid, support, break, style, protect, obvious, appear, start, materi, think']
# Actual aspect: ['Durability']
# Predicted aspect: ['provid,']
# ------------------------------------------------------------
# Epoch: 1 ID: 10
# ------------------------------------------------------------
# Seed words: ['grass, let, raini, deep, warm, alcatraz, sandal, rain, puddl, water']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['grass, let']
# ------------------------------------------------------------
# Epoch: 1 ID: 11
# ------------------------------------------------------------
# Seed words: ['3d, lightweight, hindsight, slim, easili, screen, cubbyhol, matrix, oh, size']
# Actual aspect: ['Size Look']
# Predicted aspect: ['3d,']
# ------------------------------------------------------------
# Epoch: 1 ID: 12
# ------------------------------------------------------------
# Seed words: ['birth, feel, attach, brake, peel, style, holiday, strap, crack, item']
# Actual aspect: ['Quality']
# Predicted aspect: ['birth, feel']
# ------------------------------------------------------------
# Epoch: 1 ID: 13
# ------------------------------------------------------------
# Seed words: ['filter, superb, bear, loo, grout, ergorapido, produc, hair, dirt, leav']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['filter, superb']
# ------------------------------------------------------------
# Epoch: 1 ID: 14
# ------------------------------------------------------------
# Seed words: ['grey, durabl, crazi, natur, smooth, love, attract, hang, offic, great']
# Actual aspect: ['Look']
# Predicted aspect: ['grey, dur']
# ------------------------------------------------------------
# Epoch: 1 ID: 15
# ------------------------------------------------------------
# Seed words: ['macbook, bit, folder, 17inch, fre, 13, air, spacious, earphon, size']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['macbook,']
# ------------------------------------------------------------
# Epoch: 1 ID: 16
# ------------------------------------------------------------
# Seed words: ['keyboard, origin, like, backlit, lttle, imac, beauti, cheap, small, good']
# Actual aspect: ['Looks']
# Predicted aspect: ['keyboard,']
# ------------------------------------------------------------
# Epoch: 1 ID: 17
# ------------------------------------------------------------
# Seed words: ['navig, delet, bar, paus, activ, littl, layout, difficult, home, overs']
# Actual aspect: ['Layout']
# Predicted aspect: ['navig,']
# ------------------------------------------------------------
# Epoch: 1 ID: 18
# ------------------------------------------------------------
# Seed words: ['discomfort, doc, actual, snug, time, long, extrem, foot, narrow, moment']
# Actual aspect: ['Comfort']
# Predicted aspect: ['discomfort,']
# ------------------------------------------------------------
# Epoch: 1 ID: 19
# ------------------------------------------------------------
# Seed words: ['sould, pant, wide, tight, wise, awar, fit, normal, half, perfect']
# Actual aspect: ['Size']
# Predicted aspect: ['sould,']
# ------------------------------------------------------------
# Epoch: 1 ID: 20
# ------------------------------------------------------------
# Seed words: ['rotat, hepa, basic, crevic, attach, get, sensor, extens, okay, instead']
# Actual aspect: ['Accessories']
# Predicted aspect: ['rotat,']
# ------------------------------------------------------------
# Epoch: 1 ID: 21
# ------------------------------------------------------------
# Seed words: ['awesom, flee, purchas, lightweight, silent, hide, ring, quit, ring, bearabl']
# Actual aspect: ['Noise']
# Predicted aspect: ['awesom']
# ------------------------------------------------------------
# Epoch: 1 ID: 22
# ------------------------------------------------------------
# Seed words: ['programm, hold, eject, volum, disk, clutch, illumin, low, sleep, capabl']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['programm,']
# ------------------------------------------------------------
# Epoch: 1 ID: 23
# ------------------------------------------------------------
# Seed words: ['power, need, area, compact, heavier, larg, maneuv, compar, canist, reason']
# Actual aspect: ['Weight']
# Predicted aspect: ['power, need']
# ------------------------------------------------------------
# Epoch: 1 ID: 24
# ------------------------------------------------------------
# Seed words: ['deceler, satisfi, smooth, type, chicklet, keystrok, level, signatur, type, stick']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['deceler,']
# ------------------------------------------------------------
# Epoch: 1 ID: 25
# ------------------------------------------------------------
# Seed words: ['mous, connector, space, wish, jacket, power, paperwork, adapt, pocket, thing']
# Actual aspect: ['Compartments']
# Predicted aspect: ['mous,']
# ------------------------------------------------------------
# Epoch: 1 ID: 26
# ------------------------------------------------------------
# Seed words: ['bag, power, paid, dyson, need, vaccum, mayb, cheap, bagless, pricey']
# Actual aspect: ['Price']
# Predicted aspect: ['Bags,']
# ------------------------------------------------------------
# Epoch: 1 ID: 27
# ------------------------------------------------------------
# Seed words: ['red, love, wonder, favorit, love, color, gorgeous, perfect, look, taup']
# Actual aspect: ['Color']
# Predicted aspect: ['red, love']
# ------------------------------------------------------------
# Epoch: 1 ID: 28
# ------------------------------------------------------------
# Seed words: ['pixel, font, dvd, clear, expeci, biggest, sharp, imag, angl, differ']
# Actual aspect: ['Image']
# Predicted aspect: ['pixel, font']
# ------------------------------------------------------------
# Epoch: 1 ID: 29
# ------------------------------------------------------------
# Seed words: ['better, start, talk, simpl, meter, charger, hold, vari, stop, volum']
# Actual aspect: ['Battery']
# Predicted aspect: ['better, start']
# ------------------------------------------------------------
# Epoch: 1 ID: 30
# ------------------------------------------------------------
# Seed words: ['laptop, good, pad, comput, pencil, perfect, tast, weak, protect, pad']
# Actual aspect: ['Protection']
# Predicted aspect: ['laptop,']
#  13%|█▎        | 2/15 [00:20<02:12, 10.21s/it]
# Epoch 2:	Training Loss 6.47
# ------------------------------------------------------------
# Epoch: 2 ID: 0
# ------------------------------------------------------------
# Seed words: ['watch, eas, hulu, access, brows, user, capabl, comput, internet, right']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['watch,']
# ------------------------------------------------------------
# Epoch: 2 ID: 1
# ------------------------------------------------------------
# Seed words: ['laptop, bit, 13, size, enorm, accommod, dv7, tight, load, reduct']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Laptops']
# ------------------------------------------------------------
# Epoch: 2 ID: 2
# ------------------------------------------------------------
# Seed words: ['bright, hd, great, definit, imag, dvd, beauti, excel, decent, screen']
# Actual aspect: ['Image']
# Predicted aspect: ['The film is']
# ------------------------------------------------------------
# Epoch: 2 ID: 3
# ------------------------------------------------------------
# Seed words: ['pressur, dissatisfi, key, deceler, clicki, press, keyboard, ibm, natur, chicklet']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['pressur,']
# ------------------------------------------------------------
# Epoch: 2 ID: 4
# ------------------------------------------------------------
# Seed words: ['margin, weird, bass, mind, bar, lack, laptop, quieter, hear, ear']
# Actual aspect: ['Sound']
# Predicted aspect: ['margin, weird']
# ------------------------------------------------------------
# Epoch: 2 ID: 5
# ------------------------------------------------------------
# Seed words: ['power, littl, easi, guess, minor, past, compact, vacuum, compar, perform']
# Actual aspect: ['Weight']
# Predicted aspect: ['power, l']
# ------------------------------------------------------------
# Epoch: 2 ID: 6
# ------------------------------------------------------------
# Seed words: ['tight, beauti, order, normal, normal, half, ankl, tab, awar, bacaus']
# Actual aspect: ['Size']
# Predicted aspect: ['tight, beaut']
# ------------------------------------------------------------
# Epoch: 2 ID: 7
# ------------------------------------------------------------
# Seed words: ['cell, power, life, come, phone, batteri, red, love, pretti, charg']
# Actual aspect: ['Battery']
# Predicted aspect: ['cell, power']
# ------------------------------------------------------------
# Epoch: 2 ID: 8
# ------------------------------------------------------------
# Seed words: ['watch, end, compon, signal, fi, 45, output, stop, cycl, server']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['watch, end']
# ------------------------------------------------------------
# Epoch: 2 ID: 9
# ------------------------------------------------------------
# Seed words: ['look, good, keyboard, small, attract, pc, appear, lttle, imac, longer']
# Actual aspect: ['Looks']
# Predicted aspect: ['look, good']
# ------------------------------------------------------------
# Epoch: 2 ID: 10
# ------------------------------------------------------------
# Seed words: ['cubbyhol, smaller, room, store, inch, wonder, suitabl, huge, lightweight, light']
# Actual aspect: ['Size Look']
# Predicted aspect: ['cubbyhol']
# ------------------------------------------------------------
# Epoch: 2 ID: 11
# ------------------------------------------------------------
# Seed words: ['paus, activ, space, littl, size, home, space, wide, backspac, spill']
# Actual aspect: ['Layout']
# Predicted aspect: ['paus,']
# ------------------------------------------------------------
# Epoch: 2 ID: 12
# ------------------------------------------------------------
# Seed words: ['good, weight, crazi, grey, style, fring, direct, attract, durabl, rest']
# Actual aspect: ['Look']
# Predicted aspect: ['good, weight']
# ------------------------------------------------------------
# Epoch: 2 ID: 13
# ------------------------------------------------------------
# Seed words: ['perfect, exact, boot, color, wonder, favorit, blue, love, look, gorgeous']
# Actual aspect: ['Color']
# Predicted aspect: ['perfect, exact']
# ------------------------------------------------------------
# Epoch: 2 ID: 14
# ------------------------------------------------------------
# Seed words: ['pen, multimedia, mute, program, featur, email, illumin, music, button, capabl']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['pen, multimedia']
# ------------------------------------------------------------
# Epoch: 2 ID: 15
# ------------------------------------------------------------
# Seed words: ['connect, burn, constuct, overheat, run, attach, burnt, construct, month, shut']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['connect, burn']
# ------------------------------------------------------------
# Epoch: 2 ID: 16
# ------------------------------------------------------------
# Seed words: ['miel, respond, recent, horribl, repres, time, amazon, mail, respons, day']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['miel,']
# ------------------------------------------------------------
# Epoch: 2 ID: 17
# ------------------------------------------------------------
# Seed words: ['stylish, size, noisi, louder, ring, powerstick, flee, devil, pro, fair']
# Actual aspect: ['Noise']
# Predicted aspect: ['stylish,']
# ------------------------------------------------------------
# Epoch: 2 ID: 18
# ------------------------------------------------------------
# Seed words: ['abl, feel, snug, break, time, plus, attract, moment, walk, toe']
# Actual aspect: ['Comfort']
# Predicted aspect: ['abl, feel']
# ------------------------------------------------------------
# Epoch: 2 ID: 19
# ------------------------------------------------------------
# Seed words: ['turbo, need, convent, instead, clean, bag, roll, turn, allow, corner']
# Actual aspect: ['Accessories']
# Predicted aspect: ['turbo,']
# ------------------------------------------------------------
# Epoch: 2 ID: 20
# ------------------------------------------------------------
# Seed words: ['fold, constant, cheep, sol, barn, need, worn, decent, think, qualiti']
# Actual aspect: ['Durability']
# Predicted aspect: ['fold, constant']
# ------------------------------------------------------------
# Epoch: 2 ID: 21
# ------------------------------------------------------------
# Seed words: ['let, protect, lap, perfect, protect, secur, adequ, realli, damag, weak']
# Actual aspect: ['Protection']
# Predicted aspect: ['let, protect']
# ------------------------------------------------------------
# Epoch: 2 ID: 22
# ------------------------------------------------------------
# Seed words: ['foam, fashion, leather, hang, smooth, superb, come, calm, fring, aw']
# Actual aspect: ['Materials']
# Predicted aspect: ['foam,']
# ------------------------------------------------------------
# Epoch: 2 ID: 23
# ------------------------------------------------------------
# Seed words: ['let, island, warm, perform, dewi, got, den, amaz, san, puddl']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['let, island']
# ------------------------------------------------------------
# Epoch: 2 ID: 24
# ------------------------------------------------------------
# Seed words: ['po, paid, support, check, requir, desk, fee, reschedul, 100, deliveri']
# Actual aspect: ['Customer service']
# Predicted aspect: ['po, paid']
# ------------------------------------------------------------
# Epoch: 2 ID: 25
# ------------------------------------------------------------
# Seed words: ['comfort, remot, adjust, hook, holiday, addit, swivel, inevit, later, broke']
# Actual aspect: ['Handles']
# Predicted aspect: ['comfort, rem']
# ------------------------------------------------------------
# Epoch: 2 ID: 26
# ------------------------------------------------------------
# Seed words: ['constant, bog, nozzl, imposs, difficult, pile, maneuv, push, simpic, automat']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['constant,']
# ------------------------------------------------------------
# Epoch: 2 ID: 27
# ------------------------------------------------------------
# Seed words: ['dyson, like, cheap, bagless, twice, think, money, far, ok, expens']
# Actual aspect: ['Price']
# Predicted aspect: ['dyson,']
# ------------------------------------------------------------
# Epoch: 2 ID: 28
# ------------------------------------------------------------
# Seed words: ['wire, nois, space, safe, power, open, compart, munchi, accessori, key']
# Actual aspect: ['Compartments']
# Predicted aspect: ['wire, no']
# ------------------------------------------------------------
# Epoch: 2 ID: 29
# ------------------------------------------------------------
# Seed words: ['suction, floor, pick, unders, perform, ergorapido, produc, tile, perfom, power']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['suction,']
# ------------------------------------------------------------
# Epoch: 2 ID: 30
# ------------------------------------------------------------
# Seed words: ['strap, item, edg, terribl, final, rip, excel, plastic, construct, wear']
# Actual aspect: ['Quality']
# Predicted aspect: ['strap, item']
#  20%|██        | 3/15 [00:30<02:02, 10.17s/it]
# Epoch 3:	Training Loss 5.99
# ------------------------------------------------------------
# Epoch: 3 ID: 0
# ------------------------------------------------------------
# Seed words: ['probabl, consid, lightweight, area, thought, compar, heavi, purchas, vaccuum, canist']
# Actual aspect: ['Weight']
# Predicted aspect: ['Probabl']
# ------------------------------------------------------------
# Epoch: 3 ID: 1
# ------------------------------------------------------------
# Seed words: ['look, nice, pc, small, great, beauti, imac, good, cheap, laptop']
# Actual aspect: ['Looks']
# Predicted aspect: ['look, nice']
# ------------------------------------------------------------
# Epoch: 3 ID: 2
# ------------------------------------------------------------
# Seed words: ['sharp, eye, look, crisp, notic, affect, level, inch, ear, dead']
# Actual aspect: ['Image']
# Predicted aspect: ['sharp, eye']
# ------------------------------------------------------------
# Epoch: 3 ID: 3
# ------------------------------------------------------------
# Seed words: ['big, compact, perfect, pound, hardwar, foot, consid, livingroom, 60, home']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Big, compact']
# ------------------------------------------------------------
# Epoch: 3 ID: 4
# ------------------------------------------------------------
# Seed words: ['usual, stylish, smooth, feel, level, pressur, key, relax, regist, respond']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['usual, stylish']
# ------------------------------------------------------------
# Epoch: 3 ID: 5
# ------------------------------------------------------------
# Seed words: ['m1710, seat, load, inch, big, cabl, bare, cell, size, fre']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['m1710']
# ------------------------------------------------------------
# Epoch: 3 ID: 6
# ------------------------------------------------------------
# Seed words: ['barn, gone, break, enjoy, obvious, durabl, sol, heel, pretti, rubber']
# Actual aspect: ['Durability']
# Predicted aspect: ['barn,']
# ------------------------------------------------------------
# Epoch: 3 ID: 7
# ------------------------------------------------------------
# Seed words: ['width, moccasin, advic, beauti, option, wise, shorter, tab, normal, fit']
# Actual aspect: ['Size']
# Predicted aspect: ['width, m']
# ------------------------------------------------------------
# Epoch: 3 ID: 8
# ------------------------------------------------------------
# Seed words: ['unders, grout, spun, plush, perfom, pro, attribut, filter, grind, main']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['unders, gr']
# ------------------------------------------------------------
# Epoch: 3 ID: 9
# ------------------------------------------------------------
# Seed words: ['swivel, poor, constuct, turn, quit, month, upper, miss, run, 20']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['swivel']
# ------------------------------------------------------------
# Epoch: 3 ID: 10
# ------------------------------------------------------------
# Seed words: ['bigger, strike, 104, movement, arrow, space, paus, label, chang, spill']
# Actual aspect: ['Layout']
# Predicted aspect: ['bigger,']
# ------------------------------------------------------------
# Epoch: 3 ID: 11
# ------------------------------------------------------------
# Seed words: ['vista, email, internet, volum, light, multimedia, quit, handi, shut, wake']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['vista,']
# ------------------------------------------------------------
# Epoch: 3 ID: 12
# ------------------------------------------------------------
# Seed words: ['nois, charger, safe, pocket, outsid, earphon, player, need, flap, headset']
# Actual aspect: ['Compartments']
# Predicted aspect: ['nois,']
# ------------------------------------------------------------
# Epoch: 3 ID: 13
# ------------------------------------------------------------
# Seed words: ['break, hurt, tongu, abl, enjoy, summer, long, insid, longer, toe']
# Actual aspect: ['Comfort']
# Predicted aspect: ['break, hurt']
# ------------------------------------------------------------
# Epoch: 3 ID: 14
# ------------------------------------------------------------
# Seed words: ['absolut, rest, offic, taup, super, smooth, light, direct, grey, pictur']
# Actual aspect: ['Look']
# Predicted aspect: ['absolut']
# ------------------------------------------------------------
# Epoch: 3 ID: 15
# ------------------------------------------------------------
# Seed words: ['adjust, strap, plastic, loop, broken, control, broke, hand, rip, sooner']
# Actual aspect: ['Handles']
# Predicted aspect: ['adjust, strap']
# ------------------------------------------------------------
# Epoch: 3 ID: 16
# ------------------------------------------------------------
# Seed words: ['smell, warranti, wait, hour, common, absolut, respons, purchas, gotten, miel']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['smell,']
# ------------------------------------------------------------
# Epoch: 3 ID: 17
# ------------------------------------------------------------
# Seed words: ['let, interest, lot, dewi, item, soak, cold, ice, chicago, foot']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['let, interest']
# ------------------------------------------------------------
# Epoch: 3 ID: 18
# ------------------------------------------------------------
# Seed words: ['peopl, entir, latest, help, pilot, 1500, week, 49, paid, check']
# Actual aspect: ['Customer service']
# Predicted aspect: ['peopl,']
# ------------------------------------------------------------
# Epoch: 3 ID: 19
# ------------------------------------------------------------
# Seed words: ['bag, clean, sensor, cup, requir, bag, onboard, regular, convent, filter']
# Actual aspect: ['Accessories']
# Predicted aspect: ['bag, clean']
# ------------------------------------------------------------
# Epoch: 3 ID: 20
# ------------------------------------------------------------
# Seed words: ['penetr, true, porous, cheaper, piec, memori, cloth, direct, soft, heel']
# Actual aspect: ['Materials']
# Predicted aspect: ['penetr,']
# ------------------------------------------------------------
# Epoch: 3 ID: 21
# ------------------------------------------------------------
# Seed words: ['littl, sleev, sort, pad, count, provid, adequ, feel, protect, pencil']
# Actual aspect: ['Protection']
# Predicted aspect: ['littl']
# ------------------------------------------------------------
# Epoch: 3 ID: 22
# ------------------------------------------------------------
# Seed words: ['power, motor, block, compar, flee, nozzl, nois, powerstick, weight, serious']
# Actual aspect: ['Noise']
# Predicted aspect: ['power, motor']
# ------------------------------------------------------------
# Epoch: 3 ID: 23
# ------------------------------------------------------------
# Seed words: ['move, propel, suck, person, retractor, easier, imposs, cannist, short, prefer']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['move, propel']
# ------------------------------------------------------------
# Epoch: 3 ID: 24
# ------------------------------------------------------------
# Seed words: ['access, eas, access, lack, speed, user, featur, internet, terribl, cabl']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['access,']
# ------------------------------------------------------------
# Epoch: 3 ID: 25
# ------------------------------------------------------------
# Seed words: ['pull, zipper, later, left, construct, stand, strip, tear, final, go']
# Actual aspect: ['Quality']
# Predicted aspect: ['pull, zipper']
# ------------------------------------------------------------
# Epoch: 3 ID: 26
# ------------------------------------------------------------
# Seed words: ['turn, meter, start, charg, simpl, sudden, life, talk, dead, day']
# Actual aspect: ['Battery']
# Predicted aspect: ['turn, meter']
# ------------------------------------------------------------
# Epoch: 3 ID: 27
# ------------------------------------------------------------
# Seed words: ['feaur, think, bag, cheap, spend, duster, worth, light, power, mayb']
# Actual aspect: ['Price']
# Predicted aspect: ['feaur,']
# ------------------------------------------------------------
# Epoch: 3 ID: 28
# ------------------------------------------------------------
# Seed words: ['signal, internet, file, movi, drive, port, min, speed, vga, netflix']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['signal,']
# ------------------------------------------------------------
# Epoch: 3 ID: 29
# ------------------------------------------------------------
# Seed words: ['design, taup, red, materi, look, wonder, love, love, favorit, exact']
# Actual aspect: ['Color']
# Predicted aspect: ['design, t']
# ------------------------------------------------------------
# Epoch: 3 ID: 30
# ------------------------------------------------------------
# Seed words: ['develop, true, good, weird, great, ear, display, bar, loudest, speaker']
# Actual aspect: ['Sound']
# Predicted aspect: ['develop, true']
#  27%|██▋       | 4/15 [00:40<01:51, 10.16s/it]
# Epoch 4:	Training Loss 5.73
# ------------------------------------------------------------
# Epoch: 4 ID: 0
# ------------------------------------------------------------
# Seed words: ['stick, tap, relax, velvet, type, level, smooth, stylish, butteri, navig']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['stick, tap']
# ------------------------------------------------------------
# Epoch: 4 ID: 1
# ------------------------------------------------------------
# Seed words: ['put, discomfort, tongu, actual, list, abl, insid, offic, short, blister']
# Actual aspect: ['Comfort']
# Predicted aspect: ['put, discomfort']
# ------------------------------------------------------------
# Epoch: 4 ID: 2
# ------------------------------------------------------------
# Seed words: ['thought, purchas, compact, compar, power, suppos, minor, nice, price, maneuv']
# Actual aspect: ['Weight']
# Predicted aspect: ['thought, purch']
# ------------------------------------------------------------
# Epoch: 4 ID: 3
# ------------------------------------------------------------
# Seed words: ['miss, simpli, bump, turn, continu, electr, broke, wise, shut, flimsi']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['miss, simpl']
# ------------------------------------------------------------
# Epoch: 4 ID: 4
# ------------------------------------------------------------
# Seed words: ['let, happen, trust, provid, use, littl, larg, way, macbook, intern']
# Actual aspect: ['Protection']
# Predicted aspect: ['let, happen']
# ------------------------------------------------------------
# Epoch: 4 ID: 5
# ------------------------------------------------------------
# Seed words: ['mycomput, mute, blue, sleep, calcul, bright, pen, capabl, handi, recess']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['mycomput']
# ------------------------------------------------------------
# Epoch: 4 ID: 6
# ------------------------------------------------------------
# Seed words: ['swivel, loop, inevit, attach, felt, adjust, use, bend, break, rip']
# Actual aspect: ['Handles']
# Predicted aspect: ['swivel']
# ------------------------------------------------------------
# Epoch: 4 ID: 7
# ------------------------------------------------------------
# Seed words: ['clean, wide, block, bag, hose, brush, roll, empti, rotat, onboard']
# Actual aspect: ['Accessories']
# Predicted aspect: ['clean, wide']
# ------------------------------------------------------------
# Epoch: 4 ID: 8
# ------------------------------------------------------------
# Seed words: ['volum, vertic, horizont, suppos, layout, space, movement, navig, perfect, impecc']
# Actual aspect: ['Layout']
# Predicted aspect: ['volum,']
# ------------------------------------------------------------
# Epoch: 4 ID: 9
# ------------------------------------------------------------
# Seed words: ['merit, batteri, simpl, nois, low, hold, volum, longer, star, green']
# Actual aspect: ['Battery']
# Predicted aspect: ['merit,']
# ------------------------------------------------------------
# Epoch: 4 ID: 10
# ------------------------------------------------------------
# Seed words: ['blue, gorgeous, materi, taup, look, wonder, design, favorit, color, look']
# Actual aspect: ['Color']
# Predicted aspect: ['blue, gorgeous']
# ------------------------------------------------------------
# Epoch: 4 ID: 11
# ------------------------------------------------------------
# Seed words: ['angl, hubbi, fantast, pictur, dead, ear, level, hd, bright, white']
# Actual aspect: ['Image']
# Predicted aspect: ['angl,']
# ------------------------------------------------------------
# Epoch: 4 ID: 12
# ------------------------------------------------------------
# Seed words: ['pilot, cancel, peopl, reschedul, latest, week, technician, arriv, 49, support']
# Actual aspect: ['Customer service']
# Predicted aspect: ['pilot,']
# ------------------------------------------------------------
# Epoch: 4 ID: 13
# ------------------------------------------------------------
# Seed words: ['duster, money, right, bag, like, expect, bagless, twice, ok, feaur']
# Actual aspect: ['Price']
# Predicted aspect: ['duster,']
# ------------------------------------------------------------
# Epoch: 4 ID: 14
# ------------------------------------------------------------
# Seed words: ['reduct, 17inch, lot, raincoat, big, hp, spacious, seat, fre, cell']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['reduct,']
# ------------------------------------------------------------
# Epoch: 4 ID: 15
# ------------------------------------------------------------
# Seed words: ['appear, nice, lttle, like, attract, look, good, backlit, size, great']
# Actual aspect: ['Looks']
# Predicted aspect: ['appear,']
# ------------------------------------------------------------
# Epoch: 4 ID: 16
# ------------------------------------------------------------
# Seed words: ['red, pretti, rubber, long, obvious, provid, worn, true, wear, numer']
# Actual aspect: ['Durability']
# Predicted aspect: ['red, pre']
# ------------------------------------------------------------
# Epoch: 4 ID: 17
# ------------------------------------------------------------
# Seed words: ['rip, year, materi, outstand, later, feel, smell, reproduct, brake, construct']
# Actual aspect: ['Quality']
# Predicted aspect: ['rip, year']
# ------------------------------------------------------------
# Epoch: 4 ID: 18
# ------------------------------------------------------------
# Seed words: ['ring, flee, peopl, readi, awesom, quiet, loud, ring, light, nois']
# Actual aspect: ['Noise']
# Predicted aspect: ['ring, flee']
# ------------------------------------------------------------
# Epoch: 4 ID: 19
# ------------------------------------------------------------
# Seed words: ['matrix, hindsight, wonder, light, 40, ultra, slim, inch, home, averag']
# Actual aspect: ['Size Look']
# Predicted aspect: ['matrix,']
# ------------------------------------------------------------
# Epoch: 4 ID: 20
# ------------------------------------------------------------
# Seed words: ['bar, dinner, ear, sound, eye, loud, display, bass, shippabl, adjust']
# Actual aspect: ['Sound']
# Predicted aspect: ['bar, dinner']
# ------------------------------------------------------------
# Epoch: 4 ID: 21
# ------------------------------------------------------------
# Seed words: ['cabl, port, netflix, hard, conflict, compon, file, min, slot, like']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['cabl,']
# ------------------------------------------------------------
# Epoch: 4 ID: 22
# ------------------------------------------------------------
# Seed words: ['tile, ok, spin, grout, attribut, spun, spot, fault, machin, leav']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['tile, ok']
# ------------------------------------------------------------
# Epoch: 4 ID: 23
# ------------------------------------------------------------
# Seed words: ['help, spent, late, self, problem, chose, purchas, hour, look, dissip']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['help, spent']
# ------------------------------------------------------------
# Epoch: 4 ID: 24
# ------------------------------------------------------------
# Seed words: ['pant, true, tab, wear, awar, narrow, tight, length, size, option']
# Actual aspect: ['Size']
# Predicted aspect: ['pant,']
# ------------------------------------------------------------
# Epoch: 4 ID: 25
# ------------------------------------------------------------
# Seed words: ['true, sued, foam, rubber, improv, porous, fleec, sole, friction, thinner']
# Actual aspect: ['Materials']
# Predicted aspect: ['true, sued']
# ------------------------------------------------------------
# Epoch: 4 ID: 26
# ------------------------------------------------------------
# Seed words: ['corner, push, remov, hose, race, prefer, worst, propel, refriger, easier']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Corner,']
# ------------------------------------------------------------
# Epoch: 4 ID: 27
# ------------------------------------------------------------
# Seed words: ['file, applic, netflix, hub, cabl, work, watch, user, plus, video']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['The full']
# ------------------------------------------------------------
# Epoch: 4 ID: 28
# ------------------------------------------------------------
# Seed words: ['jacket, nice, cellphon, key, daytim, wire, control, wallet, paperwork, construct']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Jacket,']
# ------------------------------------------------------------
# Epoch: 4 ID: 29
# ------------------------------------------------------------
# Seed words: ['perform, repel, warm, lot, snow, wet, francisco, resist, alcatraz, defect']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['The word "']
# ------------------------------------------------------------
# Epoch: 4 ID: 30
# ------------------------------------------------------------
# Seed words: ['calm, good, super, love, smooth, fring, concept, look, pictur, weight']
# Actual aspect: ['Look']
# Predicted aspect: ['calm,']
#  33%|███▎      | 5/15 [00:51<01:42, 10.23s/it]
# Epoch 5:	Training Loss 5.41
# ------------------------------------------------------------
# Epoch: 5 ID: 0
# ------------------------------------------------------------
# Seed words: ['hide, compar, quiet, explod, incred, doggi, direct, size, readi, weight']
# Actual aspect: ['Noise']
# Predicted aspect: ['hide, compar']
# ------------------------------------------------------------
# Epoch: 5 ID: 1
# ------------------------------------------------------------
# Seed words: ['reach, hardwood, wide, wonder, bag, extra, requir, sensor, filter, roll']
# Actual aspect: ['Accessories']
# Predicted aspect: ['reach, hard']
# ------------------------------------------------------------
# Epoch: 5 ID: 2
# ------------------------------------------------------------
# Seed words: ['perfect, feel, action, finger, quick, difficult, like, signatur, type, satisfi']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['perfect, feel']
# ------------------------------------------------------------
# Epoch: 5 ID: 3
# ------------------------------------------------------------
# Seed words: ['horribl, strong, sound, hear, chang, laptop, muffl, qualiti, strain, surround']
# Actual aspect: ['Sound']
# Predicted aspect: ['Horrib']
# ------------------------------------------------------------
# Epoch: 5 ID: 4
# ------------------------------------------------------------
# Seed words: ['smell, depart, hour, self, day, look, phone, help, told, useless']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Smell,']
# ------------------------------------------------------------
# Epoch: 5 ID: 5
# ------------------------------------------------------------
# Seed words: ['superb, calf, decid, wise, option, joint, width, fit, perfect, normal']
# Actual aspect: ['Size']
# Predicted aspect: ['Superb is']
# ------------------------------------------------------------
# Epoch: 5 ID: 6
# ------------------------------------------------------------
# Seed words: ['vacuum, vaccum, worth, expect, pricey, best, ok, twice, mayb, 50']
# Actual aspect: ['Price']
# Predicted aspect: ['Vacuum']
# ------------------------------------------------------------
# Epoch: 5 ID: 7
# ------------------------------------------------------------
# Seed words: ['short, tear, addit, bend, final, stand, note, length, later, rip']
# Actual aspect: ['Handles']
# Predicted aspect: ['short, tear']
# ------------------------------------------------------------
# Epoch: 5 ID: 8
# ------------------------------------------------------------
# Seed words: ['thinner, rubber, fashion, especi, aerosol, penetr, hang, unattract, natur, sole']
# Actual aspect: ['Materials']
# Predicted aspect: ['Fashion is']
# ------------------------------------------------------------
# Epoch: 5 ID: 9
# ------------------------------------------------------------
# Seed words: ['charg, color, blackberri, nokia, meter, batteri, power, nois, merit, easili']
# Actual aspect: ['Battery']
# Predicted aspect: ["Nokia's"]
# ------------------------------------------------------------
# Epoch: 5 ID: 10
# ------------------------------------------------------------
# Seed words: ['movi, monitor, play, end, usb, flash, server, signal, internet, connect']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['movi.']
# ------------------------------------------------------------
# Epoch: 5 ID: 11
# ------------------------------------------------------------
# ...
# Actual aspect: ['Size']
# Predicted aspect: ['Wear,']
# ------------------------------------------------------------
# Epoch: 13 ID: 7
# ------------------------------------------------------------
# Seed words: ['wonder, look, design, love, perfect, exact, style, look, blue, purchas']
# Actual aspect: ['Color']
# Predicted aspect: ['Designers love']
# ------------------------------------------------------------
# Epoch: 13 ID: 8
# ------------------------------------------------------------
# Seed words: ['pro, superb, machin, bear, main, pick, weak, ergorapido, stylish, leav']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Pro']
# ------------------------------------------------------------
# Epoch: 13 ID: 9
# ------------------------------------------------------------
# Seed words: ['work, snapper, portion, brush, miss, quit, attach, belt, unannounc, stop']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Actions']
# ------------------------------------------------------------
# Epoch: 13 ID: 10
# ------------------------------------------------------------
# Seed words: ['compon, drive, play, netflix, rf, stop, port, movi, audio, integr']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Epoch: 13 ID: 11
# ------------------------------------------------------------
# Seed words: ['price, perform, need, rug, cumbersom, maneuv, suppos, littl, quiet, larg']
# Actual aspect: ['Weight']
# Predicted aspect: ['Price, perform']
# ------------------------------------------------------------
# Epoch: 13 ID: 12
# ------------------------------------------------------------
# Seed words: ['buy, movi, watch, capabl, cabl, interfac, watch, like, hub, best']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Watching a']
# ------------------------------------------------------------
# Epoch: 13 ID: 13
# ------------------------------------------------------------
# Seed words: ['navig, place, key, home, negat, spill, backspac, space, label, awkward']
# Actual aspect: ['Layout']
# Predicted aspect: ['navig,']
# ------------------------------------------------------------
# Epoch: 13 ID: 14
# ------------------------------------------------------------
# Seed words: ['charger, outer, flap, cabl, lot, insid, key, player, outsid, connector']
# Actual aspect: ['Compartments']
# Predicted aspect: ['charger,']
# ------------------------------------------------------------
# Epoch: 13 ID: 15
# ------------------------------------------------------------
# Seed words: ['360, degre, natur, love, style, crazi, rest, moccasin, concept, design']
# Actual aspect: ['Look']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Epoch: 13 ID: 16
# ------------------------------------------------------------
# Seed words: ['longer, backlit, size, attract, laptop, like, imac, feel, slim, lttle']
# Actual aspect: ['Looks']
# Predicted aspect: ['Laptops']
# ------------------------------------------------------------
# Epoch: 13 ID: 17
# ------------------------------------------------------------
# Seed words: ['smooth, advertis, come, describ, buckl, decor, aw, heel, hollow, back']
# Actual aspect: ['Materials']
# Predicted aspect: ['Smooth']
# ------------------------------------------------------------
# Epoch: 13 ID: 18
# ------------------------------------------------------------
# Seed words: ['tinni, muffl, watt, realli, loudest, experi, improv, sound, surround, sort']
# Actual aspect: ['Sound']
# Predicted aspect: ['Tinni']
# ------------------------------------------------------------
# Epoch: 13 ID: 19
# ------------------------------------------------------------
# Seed words: ['start, holiday, attach, plastic, chemic, final, item, broken, cancer, rip']
# Actual aspect: ['Quality']
# Predicted aspect: ['Start, holiday']
# ------------------------------------------------------------
# Epoch: 13 ID: 20
# ------------------------------------------------------------
# Seed words: ['action, ibm, tap, sit, relax, impecc, chicklet, feather, signatur, stick']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['action, ib']
# ------------------------------------------------------------
# Epoch: 13 ID: 21
# ------------------------------------------------------------
# Seed words: ['sock, littl, perfect, attract, feel, toe, time, wear, abl, comfort']
# Actual aspect: ['Comfort']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# Epoch: 13 ID: 22
# ------------------------------------------------------------
# Seed words: ['long, strap, rip, firm, final, torn, later, metal, shorter, broken']
# Actual aspect: ['Handles']
# Predicted aspect: ['long, strap']
# ------------------------------------------------------------
# Epoch: 13 ID: 23
# ------------------------------------------------------------
# Seed words: ['instead, scrap, hardwood, eye, basic, replac, roll, fact, cover, hepa']
# Actual aspect: ['Accessories']
# Predicted aspect: ['instead of scrap']
# ------------------------------------------------------------
# Epoch: 13 ID: 24
# ------------------------------------------------------------
# Seed words: ['grass, waterproof, spent, cold, defect, alcatraz, protect, step, dri, lot']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Epoch: 13 ID: 25
# ------------------------------------------------------------
# Seed words: ['heel, time, provid, enjoy, break, think, gone, start, worn, appear']
# Actual aspect: ['Durability']
# Predicted aspect: ['heel']
# ------------------------------------------------------------
# Epoch: 13 ID: 26
# ------------------------------------------------------------
# Seed words: ['right, 50, duster, bagless, weight, ok, think, expect, paid, bag']
# Actual aspect: ['Price']
# Predicted aspect: ['Right, 50']
# ------------------------------------------------------------
# Epoch: 13 ID: 27
# ------------------------------------------------------------
# Seed words: ['hd, differ, hubbi, excel, vibrant, font, struck, beauti, view, fantast']
# Actual aspect: ['Image']
# Predicted aspect: ['hd, differ']
# ------------------------------------------------------------
# Epoch: 13 ID: 28
# ------------------------------------------------------------
# Seed words: ['recent, dealer, purchas, respond, useless, custom, told, email, amazon, chose']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['recent, dealer']
# ------------------------------------------------------------
# Epoch: 13 ID: 29
# ------------------------------------------------------------
# Seed words: ['hose, easi, easier, power, awkward, disassembl, imposs, eas, person, jump']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Easily']
# ------------------------------------------------------------
# Epoch: 13 ID: 30
# ------------------------------------------------------------
# Seed words: ['help, arriv, 100lb, clear, come, undamag, later, support, use, divx']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Help, arri']
#  93%|█████████▎| 14/15 [02:24<00:10, 10.23s/it]
# Epoch 14:	Training Loss 3.84
# ------------------------------------------------------------
# Epoch: 14 ID: 0
# ------------------------------------------------------------
# Seed words: ['wake, bright, pencil, dark, dim, email, volum, illumin, remain, multimedia']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Wake']
# ------------------------------------------------------------
# Epoch: 14 ID: 1
# ------------------------------------------------------------
# Seed words: ['pictur, look, bright, expeci, color, biggest, right, pixel, dvd, black']
# Actual aspect: ['Image']
# Predicted aspect: ['Pictur,']
# ------------------------------------------------------------
# Epoch: 14 ID: 2
# ------------------------------------------------------------
# Seed words: ['explod, ring, hide, nozzl, ear, nois, silent, incred, actual, turn']
# Actual aspect: ['Noise']
# Predicted aspect: ['explod,']
# ------------------------------------------------------------
# Epoch: 14 ID: 3
# ------------------------------------------------------------
# Seed words: ['easili, flash, friend, featur, video, hulu, capabl, work, app, buy']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Easili']
# ------------------------------------------------------------
# Epoch: 14 ID: 4
# ------------------------------------------------------------
# Seed words: ['wonder, design, favorit, exact, taup, love, style, gorgeous, blue, color']
# Actual aspect: ['Color']
# Predicted aspect: ['Taup']
# ------------------------------------------------------------
# Epoch: 14 ID: 5
# ------------------------------------------------------------
# Seed words: ['paperwork, safe, document, pocket, compart, pen, planner, cellphon, remot, folder']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Paperwork']
# ------------------------------------------------------------
# Epoch: 14 ID: 6
# ------------------------------------------------------------
# Seed words: ['cool, kinda, quieter, cheapest, strain, great, bar, loud, pitch, dinner']
# Actual aspect: ['Sound']
# Predicted aspect: ['cool, kinda']
# ------------------------------------------------------------
# Epoch: 14 ID: 7
# ------------------------------------------------------------
# Seed words: ['technician, deliveri, paid, carri, mail, shore, handl, difficult, deliv, diagnost']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Technician']
# ------------------------------------------------------------
# Epoch: 14 ID: 8
# ------------------------------------------------------------
# Seed words: ['spin, vaccum, 200, paid, mayb, expect, 50, power, weight, bag']
# Actual aspect: ['Price']
# Predicted aspect: ['spin, vacc']
# ------------------------------------------------------------
# Epoch: 14 ID: 9
# ------------------------------------------------------------
# Seed words: ['bulk, 17inch, sure, disappoint, hp, nois, bit, accessori, airplan, air']
# Actual aspect: ['Size Fit']
# Predicted aspect: [', air']
# ------------------------------------------------------------
# Epoch: 14 ID: 10
# ------------------------------------------------------------
# Seed words: ['larg, small, rug, ok, size, price, power, hard, guess, push']
# Actual aspect: ['Weight']
# Predicted aspect: ['Lux']
# ------------------------------------------------------------
# Epoch: 14 ID: 11
# ------------------------------------------------------------
# Seed words: ['problem, late, common, chose, took, amazon, hoover, issu, told, purchas']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['problem, late']
# ------------------------------------------------------------
# Epoch: 14 ID: 12
# ------------------------------------------------------------
# Seed words: ['hindsight, weigh, weigh, differ, matrix, screen, pound, livingroom, big, fit']
# Actual aspect: ['Size Look']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Epoch: 14 ID: 13
# ------------------------------------------------------------
# Seed words: ['pad, drop, probabl, sleev, feel, realli, comput, protect, sort, love']
# Actual aspect: ['Protection']
# Predicted aspect: ['pad,']
# ------------------------------------------------------------
# Epoch: 14 ID: 14
# ------------------------------------------------------------
# Seed words: ['laid, boot, durabl, casual, look, absolut, concept, 360, light, weight']
# Actual aspect: ['Look']
# Predicted aspect: ['Luxury']
# ------------------------------------------------------------
# Epoch: 14 ID: 15
# ------------------------------------------------------------
# Seed words: ['sturdi, sol, think, rubber, clear, heel, enjoy, numer, collaps, protect']
# Actual aspect: ['Durability']
# Predicted aspect: ['Sturdi']
# ------------------------------------------------------------
# Epoch: 14 ID: 16
# ------------------------------------------------------------
# Seed words: ['longer, origin, size, nice, laptop, keyboard, pc, lttle, appear, decent']
# Actual aspect: ['Looks']
# Predicted aspect: ['Longer,']
# ------------------------------------------------------------
# Epoch: 14 ID: 17
# ------------------------------------------------------------
# Seed words: ['retractor, snap, nozzl, worst, flexibl, eas, pile, automat, imposs, direct']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Retractor']
# ------------------------------------------------------------
# Epoch: 14 ID: 18
# ------------------------------------------------------------
# Seed words: ['sock, blister, insid, extrem, actual, snug, perfect, perfect, slide, comfort']
# Actual aspect: ['Comfort']
# Predicted aspect: ['sock,']
# ------------------------------------------------------------
# Epoch: 14 ID: 19
# ------------------------------------------------------------
# Seed words: ['enabl, monitor, standard, flash, power, dhcp, cycl, like, comcast, internet']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Comcast is']
# ------------------------------------------------------------
# Epoch: 14 ID: 20
# ------------------------------------------------------------
# Seed words: ['bacaus, fit, width, small, narrow, half, especi, normal, follow, wear']
# Actual aspect: ['Size']
# Predicted aspect: ['Wear size']
# ------------------------------------------------------------
# Epoch: 14 ID: 21
# ------------------------------------------------------------
# Seed words: ['volum, get, tone, phone, color, love, start, respond, stop, day']
# Actual aspect: ['Battery']
# Predicted aspect: ['Volum']
# ------------------------------------------------------------
# Epoch: 14 ID: 22
# ------------------------------------------------------------
# Seed words: ['delet, bigger, scroll, chang, requir, home, spill, print, wider, suppos']
# Actual aspect: ['Layout']
# Predicted aspect: ['delet,']
# ------------------------------------------------------------
# Epoch: 14 ID: 23
# ------------------------------------------------------------
# Seed words: ['unannounc, broke, stop, roller, burnt, prepar, 20, break, smell, problem']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['unannoun']
# ------------------------------------------------------------
# Epoch: 14 ID: 24
# ------------------------------------------------------------
# Seed words: ['term, protect, lot, interest, deep, suppos, cold, spent, wet, traction']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Term']
# ------------------------------------------------------------
# Epoch: 14 ID: 25
# ------------------------------------------------------------
# Seed words: ['duster, turn, green, eye, corner, scrap, requir, brushrol, get, clean']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Duster,']
# ------------------------------------------------------------
# Epoch: 14 ID: 26
# ------------------------------------------------------------
# Seed words: ['cancer, year, tear, later, handl, peel, holiday, stand, item, durabl']
# Actual aspect: ['Quality']
# Predicted aspect: ['Cancer,']
# ------------------------------------------------------------
# Epoch: 14 ID: 27
# ------------------------------------------------------------
# Seed words: ['adapt, minut, handl, hand, note, buckl, start, felt, inevit, rip']
# Actual aspect: ['Handles']
# Predicted aspect: ['adapt, min']
# ------------------------------------------------------------
# Epoch: 14 ID: 28
# ------------------------------------------------------------
# Seed words: ['mush, satisfi, difficult, good, quick, press, smooth, feather, quick, type']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['mush,']
# ------------------------------------------------------------
# Epoch: 14 ID: 29
# ------------------------------------------------------------
# Seed words: ['fashion, cloth, buckl, thinner, superb, barn, come, materi, natur, synthet']
# Actual aspect: ['Materials']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Epoch: 14 ID: 30
# ------------------------------------------------------------
# Seed words: ['pretti, mayb, good, ergorapido, bear, floor, vacuum, dosen, power, realli']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['pretti,']
# 100%|██████████| 15/15 [02:35<00:00, 10.34s/it]
# Epoch 15:	Training Loss 3.58

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(all_train_loss, ls='-.', marker = 'X', color='blue')

# %%
stop_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c3998c8be795> in <module>
# ----> 1 stop_
#
# NameError: name 'stop_' is not defined

# %% [markdown]
# ### Generation for the topics of CTM
# --------------------------------------------

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
stemmer = SnowballStemmer(language='english')

# %%
stemmed_electronic_topics = []
for each_topic in electronic_topics:
    tmp_ = [stemmer.stem(x) for x in each_topic]
    stemmed_electronic_topics.append(tmp_)

# %%
model_args['seed_samples']
# Out:
# 10

# %%
model.eval()
for each_topic in stemmed_electronic_topics:
    topic_seeds = each_topic[:model_args['seed_samples']]
    in_tokenized = tokenizer(', '.join(topic_seeds), 
                             truncation=True)  
    in_ids = torch.LongTensor(in_tokenized.input_ids)
    in_ids = in_ids.to('cuda')
    in_ids = in_ids.unsqueeze(0)
    op_ids = model.generate(in_ids, 
                            num_beams=3, 
                            max_length=6)
    print('Seeds:', topic_seeds)
    print('Predicted aspect:', tokenizer.batch_decode(op_ids, 
                                                      skip_special_tokens=True, 
                                                      clean_up_tokenization_spaces=True))
    print('--'*30)
# Out:
# Seeds: ['construct', 'valu', 'exceed', 'outstand', 'light', 'weight', 'attract', 'versatil', 'excel', 'valu']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['deck', 'patio', 'beach', 'loud', 'camp', 'parti', 'hous', 'everywh', 'portabl', 'backyard']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['pick', 'channel', 'local', 'live', 'signal', 'station', 'abl', 'pick', 'recept', 'citi']
# Predicted aspect: ['Pick']
# ------------------------------------------------------------
# Seeds: ['instal', 'wall', 'inch', 'hung', 'mount', 'sturdi', 'articul', 'hardwar', 'motion', 'vizio']
# Predicted aspect: ['Instal']
# ------------------------------------------------------------
# Seeds: ['dac', 'pono', 'listen', 'fiio', 'amp', 'hi', 'audio', 'iem', 'hi', 'res']
# Predicted aspect: ['.com']
# ------------------------------------------------------------
# Seeds: ['usb', 'outlet', 'adapt', 'travel', 'prong', 'usb', 'port', 'port', 'hotel', 'strip']
# Predicted aspect: ['USB']
# ------------------------------------------------------------
# Seeds: ['voic', 'record', 'mini', 'usb', 'usb', 'micro', 'sd', 'nano', 'button', 'wheel']
# Predicted aspect: ['voic,']
# ------------------------------------------------------------
# Seeds: ['wast', 'money', 'wast', 'money', 'worth', 'money', 'save', 'money', 'spend', 'money']
# Predicted aspect: ['W']
# ------------------------------------------------------------
# Seeds: ['adverti', 'earlier', 'exact', 'describ', 'condit', 'descript', 'promi', 'manner', 'sooner', 'right']
# Predicted aspect: ['adverti,']
# ------------------------------------------------------------
# Seeds: ['asid', 'bottom', 'line', 'reflect', 'hope', 'help', 'huge', 'deal', 'www', 'amazon']
# Predicted aspect: ['.com']
# ------------------------------------------------------------
# Seeds: ['daughter', 'son', 'school', 'trip', 'wife', 'colleg', 'dad', 'brought', 'vacat', 'mom']
# Predicted aspect: ['daughter, son']
# ------------------------------------------------------------
# Seeds: ['volum', 'button', 'anker', 'play', 'clear', 'hour', 'box', 'loud', 'control', 'design']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['discharg', 'aaa', 'charger', 'recharg', 'volt', 'aa', 'mah', 'capac', 'apc', 'voltag']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['stay', 'fall', 'hurt', 'stay', 'place', 'wear', 'stay', 'put', 'bud', 'uncomfort']
# Predicted aspect: ['stay, fall']
# ------------------------------------------------------------
# Seeds: ['switch', 'disc', 'unit', 'dvd', 'box', 'error', 'softwar', 'issu', 'remot', 'turn']
# Predicted aspect: ['switch, disc']
# ------------------------------------------------------------
# Seeds: ['suction', 'suction', 'cup', 'shower', 'water', 'loud', 'water', 'resist', 'bathroom', 'splash']
# Predicted aspect: ['suction']
# ------------------------------------------------------------
# Seeds: ['bulb', 'lamp', 'new', 'origin', 'oem', 'smell', 'brand', 'pictur', 'color', 'bright']
# Predicted aspect: ['Lamps']
# ------------------------------------------------------------
# Seeds: ['comfort', 'control', 'headset', 'cord', 'earbud', 'run', 'wear', 'button', 'volum', 'hear']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['best', 'ever', 'penni', 'worth', 'everi', 'everi', 'penni', 'ever', 'far', 'best']
# Predicted aspect: ['Best']
# ------------------------------------------------------------
# Seeds: ['connector', 'gaug', 'length', 'wire', 'solder', 'femal', 'flexibl', 'gaug', 'wire', 'cord']
# Predicted aspect: ['Connect']
# ------------------------------------------------------------
# Seeds: ['macbook', 'dvd', 'player', 'mac', 'older', 'convert', 'macbook', 'pro', 'laptop', 'monitor']
# Predicted aspect: ['macbook']
# ------------------------------------------------------------
# Seeds: ['antenna', 'channel', 'signal', 'instal', 'roof', 'attic', 'put', 'mount', 'antenna', 'wall']
# Predicted aspect: ['antenna,']
# ------------------------------------------------------------
# Seeds: ['amazon', 'custom', 'support', 'warranti', 'custom', 'return', 'email', 'sent', 'servic', 'contact']
# Predicted aspect: ['Amazon']
# ------------------------------------------------------------
# Seeds: ['hear', 'movi', 'noi', 'aid', 'plane', 'flight', 'watch', 'hear', 'aid', 'block']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['bose', 'beat', 'noi', 'cancel', 'noi', 'cancel', 'earbud', 'comfort', 'amaz', 'plane']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['case', 'sleev', 'zipper', 'cover', 'clean', 'dvd', 'dvds', 'collect', 'zip', 'page']
# Predicted aspect: ['Case, sle']
# ------------------------------------------------------------
# Seeds: ['pad', 'foam', 'comfort', 'earpad', 'plastic', 'feel', 'bit', 'tip', 'stock', 'pad']
# Predicted aspect: ['pad, foam']
# ------------------------------------------------------------
# Seeds: ['screw', 'wall', 'mount', 'screen', 'hole', 'put', 'hold', 'tighten', 'drill', 'made']
# Predicted aspect: ['Screw']
# ------------------------------------------------------------
# Seeds: ['remot', 'remot', 'control', 'key', 'program', 'button', 'misplac', 'light', 'origin', 'dig']
# Predicted aspect: ['Rem']
# ------------------------------------------------------------
# Seeds: ['ok', 'wish', 'static', 'tooth', 'volum', 'control', 'blue', 'tooth', 'louder', 'random']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['asid', 'www', 'www', 'amazon', 'meant', 'keep', 'mind', 'due', 'fact', 'huge']
# Predicted aspect: ['.']
# ------------------------------------------------------------
# Seeds: ['fast', 'deliv', 'faster', 'quick', 'deliveri', 'ship', 'fast', 'ship', 'shipment', 'prompt']
# Predicted aspect: ['Fast']
# ------------------------------------------------------------
# Seeds: ['cd', 'player', 'cd', 'play', 'folder', 'player', 'song', 'album', 'record', 'cassett']
# Predicted aspect: ['cd, player']
# ------------------------------------------------------------
# Seeds: ['broke', 'within', 'stop', 'left', 'side', 'week', 'broken', 'coupl', 'week', 'within']
# Predicted aspect: ['Broke']
# ------------------------------------------------------------
# Seeds: ['swim', 'lap', 'underwat', 'earbud', 'run', 'waterproof', 'bud', 'stay', 'sweat', 'water']
# Predicted aspect: ['The']
# ------------------------------------------------------------
# Seeds: ['control', 'remot', 'system', 'harmoni', 'audio', 'ir', 'app', 'turn', 'sono', 'switch']
# Predicted aspect: ['control, rem']
# ------------------------------------------------------------
# Seeds: ['gold', 'plate', 'connector', 'hdmi', 'gold', 'audio', 'adapt', 'port', 'male', 'splitter']
# Predicted aspect: ['gold, plate']
# ------------------------------------------------------------
# Seeds: ['radio', 'station', 'clock', 'radio', 'station', 'clock', 'radio', 'fm', 'wake', 'emerg']
# Predicted aspect: ['Radio']
# ------------------------------------------------------------
# Seeds: ['thank', 'seller', 'satisfi', 'servic', 'thank', 'amazon', 'custom', 'servic', 'plea', 'happi']
# Predicted aspect: ['Thank']
# ------------------------------------------------------------
# Seeds: ['system', 'sub', 'subwoof', 'room', 'polk', 'bose', 'amp', 'unit', 'woofer', 'watt']
# Predicted aspect: ['System']
# ------------------------------------------------------------

# %%
import pickle as pkl
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))
# Aspect_to_seeds.keys()
# [x for x in Aspect_to_seeds if 'weather' in x.lower()]

# %%
[x for x in Aspect_to_seeds if 'weather' in x.lower()]

# %%
#         """Return sample from dataset at index i."""
#         example = self.list_data[i]
#         shuffle(example['seeds'])
#         sampled_seeds = example['seeds'][:self.seeds_length]
#         aspect = " ".join(example["aspect"].split('_'))
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            truncation=True)  
#         outputs = tokenizer(aspect, 
#                             padding="max_length", 
#                             truncation=True, 
#                             max_length=self.aspect_length)
        
#         batch = {}
#         batch["input_ids"] = torch.LongTensor(inputs.input_ids)
#         batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["labels"] = outputs.input_ids.copy()
#         batch['labels'] = [batch['labels']]

#         batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
#                            for labels in batch["labels"]]
#         batch["labels"] = torch.LongTensor(batch["labels"])
#         batch["labels"] = batch["labels"].squeeze(0)
        
#         return batch

# %%
# chk_1 =tokenizer('MaterialsComp', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_1['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_2 =tokenizer('Ease of use', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_2['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_ = tokenizer('Compartments', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=4)

# %%
# tokenizer.batch_decode(chk_['input_ids'], 
#                        skip_special_tokens=True, 
#                        clean_up_tokenization_spaces=False)

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
electronic_topics = [x[:20] for x in electronic_topics]

# %%
test_data = []
for each_e_top in electronic_topics:
    test_data.append({'seeds': each_e_top[:20], 'aspect':'TestSet'})

# %%
test_dataset = aspectDataset(list_data=test_data, 
                              tokenizer=tokenizer)

# %%
test_loader = DataLoader(test_dataset, 
                         batch_size=1, 
                         shuffle=True,
                         num_workers=1)

# %%
model.eval()
for ind, batch in enumerate(test_loader):
    batch = {k: v.to('cuda') for k, v in batch.items()}
    model_op = model(**batch)
    print('---'*20)
    print('ID:', ind)
    print('---'*20)
    print('Seed words:', tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    print('Actual aspect:', tokenizer.batch_decode(batch['decoder_input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
    print('Predicted aspect:', tokenizer.batch_decode(output_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True))

# %% [raw]
# 1. Sample 5-10 for each aspect. Get top 50 and then sample 10 each. done
# 2. Start from the bart-large and not cnn. done
# 3. Use very small learning rate (2e-5)| 1e-6 or 5e-7. done
# 4. Put a comma with the words. done
# 5. Stem the training data words. done
#
#
# Run it on our topics.
# -

# %%
model_op['logits'].squeeze(dim=0).shape

# %%
torch.argmax(model_op['logits'].squeeze(dim=0), dim=1)

# %% [markdown]
# ## Orphan Code
# -------------

# %%
print(another_way_to_train)
for epoch in range(num_epochs):
    training_loss = 0.0
    model.train()
    for batch in tqdm(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        # Get the "input's representation"
        encoder_output = the_encoder(input_ids = batch['input_ids'],
                                   attention_mask = batch['attention_mask'])
      
        # Pass the representation + the target summary to the decoder
        decoder_output = the_decoder(input_ids=batch['decoder_input_ids'],
                                   attention_mask=batch['decoder_attention_mask'],
                                   encoder_hidden_states=encoder_output[0],
                                   encoder_attention_mask=batch['attention_mask'])

        # Use the last linear layer to predict the next token
        decoder_output = decoder_output.last_hidden_state
        lm_head_output = last_linear_layer(decoder_output)
        
        # Compute the loss
        loss = loss_fct(lm_head_output.view(-1, model.config.vocab_size),
                      batch['labels'].view(-1))
        training_loss += loss.item()
        
        loss.backward() # Update the weights
        optimizer.step() # Notify optimizer that a batch is done.
        lr_scheduler.step() # Notify the scheduler that a ...
        optimizer.zero_grad() # Reset the optimer
    training_loss = training_loss / len( train_data )
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))

# %%
lm_head_output.view(-1, model.config.vocab_size)
