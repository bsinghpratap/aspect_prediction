# %%
import torch
import random
import pandas as pd
import pickle as pkl
from tqdm import tqdm
from os import listdir
from os.path import join
from random import shuffle
from transformers import AdamW
from matplotlib import pyplot as plt
from torch.nn import CrossEntropyLoss
from transformers import get_scheduler
from pdb import set_trace as breakpoint
from nltk.stem.snowball import SnowballStemmer
from torch.utils.data import Dataset, DataLoader
from transformers import BartTokenizer, BartForConditionalGeneration

# %%
# %matplotlib inline

# %%
# folders = ['bags_and_cases', 'bluetooth', 'boots', 'keyboards', 'tv', 'vacuums']

# base_dir = '/mnt/nfs/work1/hongyu/brawat/amzn/oposum/data/seeds'

# list_aspects = []
# Aspect_to_seeds = {}
# stemmer = SnowballStemmer(language='english')
# for each_folder in folders:
#     folder_dir = join(base_dir, each_folder)
#     print('--'*20)
#     print(each_folder)
#     print('--'*20)
#     txt_files = listdir(folder_dir)
#     txt_files = [x for x in txt_files if 'None' not in x]
#     print(txt_files)
#     for each_txt in txt_files:
#         txt_dir = join(folder_dir, each_txt)
#         txt = open(txt_dir).read()
#         txt = txt.split('\n')
#         txt = [x.split(' ')[-1] for x in txt]
#         txt = [x.strip() for x in txt]
#         txt = [stemmer.stem(x) for x in txt]
#         aspect = each_txt.split('.')[1]
#         Aspect_to_seeds[aspect] = txt

# %%
# for each_aspect in Aspect_to_seeds:
#     print(each_aspect, Aspect_to_seeds[each_aspect].__len__())

# %%
# pkl.dump(Aspect_to_seeds, open('Aspect_to_seeds_march19.pkl', 'wb'))

# %%
Aspect_to_seeds = pkl.load(open('Aspect_to_seeds_march19.pkl', 'rb'))

# %%
for each_aspect in Aspect_to_seeds:
    Aspect_to_seeds[each_aspect] = [x for x in Aspect_to_seeds[each_aspect] if x.__len__()>0]

# %%
Aspect_to_seeds
# Out:
# {'Compartments': ['pocket',
#   'cabl',
#   'compart',
#   'outsid',
#   'lot',
#   'wish',
#   'wallet',
#   'connector',
#   'space',
#   'power',
#   'pen',
#   'folder',
#   'charger',
#   'flap',
#   'mous',
#   'nice',
#   'thing',
#   'insid',
#   'small',
#   'paperwork',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'construct',
#   'medium',
#   'player',
#   'wire',
#   'run',
#   'headphon',
#   'key',
#   'instead',
#   'huge',
#   'need',
#   'open',
#   'fit',
#   'headset',
#   'outer',
#   'planner',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'cellphon',
#   'save',
#   'document'],
#  'Price': ['price',
#   'money',
#   'feaur',
#   'paid',
#   'spin',
#   'spun',
#   'mayb',
#   'cheap',
#   '200',
#   'spend',
#   'right',
#   'vaccum',
#   'twice',
#   'expect',
#   'pricey',
#   '50',
#   'expens',
#   'worth',
#   'far',
#   'wast',
#   'duster',
#   'think',
#   'bagless',
#   'best',
#   'dyson',
#   'need',
#   'ok',
#   'weight',
#   'bag',
#   'power',
#   'light',
#   'like',
#   'good',
#   'vacuum'],
#  'Handles': ['strap',
#   'handl',
#   'shoulder',
#   'broke',
#   'later',
#   'month',
#   'hand',
#   'comfort',
#   'plastic',
#   'wear',
#   'tear',
#   'rip',
#   'start',
#   'attach',
#   'holiday',
#   'left',
#   'lift',
#   'final',
#   'broken',
#   'stand',
#   'inevit',
#   'situat',
#   'firm',
#   'bend',
#   'hurt',
#   'minut',
#   'addit',
#   'note',
#   'buckl',
#   'adjust',
#   'adjust',
#   'short',
#   'shorter',
#   'length',
#   'adjust',
#   'long',
#   'metal',
#   'swivel',
#   'sooner',
#   'break',
#   'felt',
#   'rip',
#   'loop',
#   'hook',
#   'torn',
#   'safe',
#   'adapt',
#   'remot',
#   'control',
#   'use'],
#  'Customer_service': ['paid',
#   'support',
#   'servic',
#   'week',
#   'replac',
#   'mail',
#   'wait',
#   'pay',
#   'ship',
#   '1500',
#   'bring',
#   'deliveri',
#   'come',
#   'use',
#   'peopl',
#   'speak',
#   'technician',
#   'refurbish',
#   'handl',
#   'shore',
#   'communic',
#   'difficult',
#   '49',
#   'diagnost',
#   'fee',
#   '100',
#   'fix',
#   'latest',
#   'divx',
#   'arriv',
#   'undamag',
#   'po',
#   'mention',
#   'desk',
#   'help',
#   'suppos',
#   'later',
#   'cancel',
#   'reschedul',
#   'entir',
#   'glove',
#   'pilot',
#   'deliv',
#   'fact',
#   'clear',
#   'requir',
#   '100lb',
#   'carri',
#   'downstair',
#   'check'],
#  'Looks': ['look',
#   'slim',
#   'origin',
#   'appear',
#   'lttle',
#   'attract',
#   'beauti',
#   'size',
#   'small',
#   'decent',
#   'imac',
#   'backlit',
#   'longer',
#   'pc',
#   'like',
#   'laptop',
#   'nice',
#   'great',
#   'cheap',
#   'keyboard',
#   'good',
#   'feel'],
#  'Quality': ['qualiti',
#   'materi',
#   'handl',
#   'poor',
#   'broke',
#   'durabl',
#   'month',
#   'later',
#   'wear',
#   'tear',
#   'zipper',
#   'chemic',
#   'start',
#   'excel',
#   'terribl',
#   'crack',
#   'strap',
#   'daili',
#   'plastic',
#   'pull',
#   'smell',
#   'edg',
#   'rip',
#   'white',
#   'item',
#   'year',
#   'go',
#   'feel',
#   'attach',
#   'brake',
#   'holiday',
#   'outstand',
#   'strip',
#   'peel',
#   'left',
#   'final',
#   'broken',
#   'stand',
#   'sacrific',
#   'durabl',
#   'style',
#   'cours',
#   'trip',
#   'asia',
#   'rip',
#   'construct',
#   'cancer',
#   'birth',
#   'defect',
#   'reproduct'],
#  'Protection': ['protect',
#   'pad',
#   'protect',
#   'protect',
#   'drop',
#   'lap',
#   'insid',
#   'comput',
#   'laptop',
#   'good',
#   'let',
#   'secur',
#   'damag',
#   'intern',
#   'weak',
#   'tast',
#   'trust',
#   'protect',
#   'construct',
#   'provid',
#   'second',
#   'protect',
#   'count',
#   'sort',
#   'happen',
#   'cushion',
#   'adequ',
#   'thing',
#   'pencil',
#   'heavi',
#   'normal',
#   'kensington',
#   'probabl',
#   'larg',
#   'like',
#   'way',
#   'stylish',
#   'far',
#   'sleev',
#   'pad',
#   'feel',
#   'realli',
#   'perfect',
#   'bit',
#   'littl',
#   'bag',
#   'macbook',
#   'love',
#   'use'],
#  'Size_Fit': ['fit',
#   'size',
#   'macbook',
#   'big',
#   'space',
#   'air',
#   'slight',
#   'lot',
#   'bulk',
#   'perfect',
#   'inch',
#   'laptop',
#   'perfect',
#   '13',
#   'cabl',
#   'folder',
#   'notebook',
#   'sure',
#   'snug',
#   'bit',
#   'te',
#   'seat',
#   'airplan',
#   'fre',
#   'cell',
#   'pouch',
#   'tight',
#   'accessori',
#   'daytim',
#   'jacket',
#   'raincoat',
#   'nois',
#   'reduct',
#   'earphon',
#   'munchi',
#   'enorm',
#   '17inch',
#   'bare',
#   'm1710',
#   'hp',
#   'pavilion',
#   'dv7',
#   '3080us',
#   'disappoint',
#   'cloth',
#   'whatnot',
#   'spacious',
#   'book',
#   'load',
#   'accommod'],
#  'Ease_of_use': ['easi',
#   'cord',
#   'push',
#   'corner',
#   'vacuum',
#   'pile',
#   'maneuv',
#   'nozzl',
#   'awkward',
#   'crevic',
#   'constant',
#   'bog',
#   'imposs',
#   'short',
#   'carpet',
#   'heavi',
#   'roller',
#   'hose',
#   'difficult',
#   'wall',
#   'suck',
#   'remov',
#   'empti',
#   'power',
#   'hard',
#   'jump',
#   'simpic',
#   'automat',
#   'retractor',
#   'retract',
#   'flash',
#   'baseboard',
#   'retract',
#   'easier',
#   'snap',
#   'disassembl',
#   'direct',
#   'propel',
#   'person',
#   'race',
#   'furnitur',
#   'flexibl',
#   'kink',
#   'prefer',
#   'cannist',
#   'car',
#   'refriger',
#   'move',
#   'eas',
#   'worst'],
#  'Sound': ['sound',
#   'speaker',
#   'good',
#   'qualiti',
#   'loud',
#   'tinni',
#   'bass',
#   'hear',
#   'horribl',
#   'trebl',
#   'chang',
#   'realli',
#   'great',
#   'terribl',
#   'bar',
#   'display',
#   'thing',
#   'eye',
#   'ear',
#   'loudest',
#   'volum',
#   'strain',
#   'quieter',
#   'dinner',
#   'lack',
#   'sort',
#   'improv',
#   'surround',
#   'true',
#   'experi',
#   'junki',
#   'mind',
#   'vibrat',
#   'develop',
#   'pitch',
#   'whine',
#   'strong',
#   'track',
#   'cool',
#   'worthi',
#   'shippabl',
#   'adjust',
#   'weird',
#   'kinda',
#   'improv',
#   'cheapest',
#   'laptop',
#   'watt',
#   'muffl',
#   'margin'],
#  'Look': ['cute',
#   'look',
#   'look',
#   'great',
#   'fring',
#   'style',
#   'color',
#   'love',
#   'design',
#   'go',
#   'unattract',
#   'attract',
#   'offic',
#   'environ',
#   'pictur',
#   '360',
#   'degre',
#   'vent',
#   'concept',
#   'coverag',
#   'airi',
#   'hang',
#   'unattract',
#   'durabl',
#   'nice',
#   'casual',
#   'beauti',
#   'moccasin',
#   'shame',
#   'taup',
#   'direct',
#   'smooth',
#   'laid',
#   'rest',
#   'natur',
#   'calm',
#   'absolut',
#   'ador',
#   'pictur',
#   'grey',
#   'wonder',
#   'stylish',
#   'comfort',
#   'boot',
#   'good',
#   'collaps',
#   'super',
#   'crazi',
#   'light',
#   'weight'],
#  'Connectivity': ['hdmi',
#   'port',
#   'comput',
#   'input',
#   'compon',
#   'usb',
#   'internet',
#   'connect',
#   'output',
#   'server',
#   'connect',
#   'audio',
#   'play',
#   'stop',
#   'standard',
#   'avi',
#   'like',
#   'hd',
#   'file',
#   'movi',
#   'work',
#   'digit',
#   'monitor',
#   'comcast',
#   'connect',
#   'drive',
#   'end',
#   'cabl',
#   'watch',
#   'netflix',
#   'flash',
#   '45',
#   'min',
#   'rf',
#   'vga',
#   'cycl',
#   'signal',
#   'higher',
#   'slot',
#   'integr',
#   'wi',
#   'fi',
#   'stream',
#   'speed',
#   'conflict',
#   'dhcp',
#   'hard',
#   'dlna',
#   'enabl',
#   'power'],
#  'Battery': ['batteri',
#   'charg',
#   'life',
#   'charger',
#   'charg',
#   'tone',
#   'longer',
#   'low',
#   'hour',
#   'power',
#   'light',
#   'color',
#   'red',
#   'respond',
#   'merit',
#   'vari',
#   'recharg',
#   'bizarr',
#   'later',
#   'sudden',
#   'dead',
#   'meter',
#   'hold',
#   'thing',
#   'half',
#   'green',
#   'stop',
#   'nokia',
#   'turn',
#   'start',
#   'blackberri',
#   'star',
#   'phone',
#   'good',
#   'day',
#   'cell',
#   'come',
#   'talk',
#   'get',
#   'simpl',
#   'pretti',
#   'love',
#   'better',
#   'easili',
#   'volum',
#   'nois',
#   'time',
#   'work'],
#  'Durability': ['rubber',
#   'qualiti',
#   'use',
#   'buckl',
#   'appear',
#   'heel',
#   'long',
#   'time',
#   'break',
#   'enjoy',
#   'provid',
#   'protect',
#   'clear',
#   'cheapli',
#   'thinner',
#   'barn',
#   'month',
#   'start',
#   'tear',
#   'constant',
#   'fold',
#   'gone',
#   'numer',
#   'decor',
#   'come',
#   'sturdi',
#   'sure',
#   'durabl',
#   'decent',
#   'cheep',
#   'deflat',
#   'daili',
#   'wear',
#   'collaps',
#   'super',
#   'need',
#   'sol',
#   'red',
#   'obvious',
#   'differ',
#   'think',
#   'worn',
#   'abl',
#   'materi',
#   'actual',
#   'pretti',
#   'heavi',
#   'true',
#   'style',
#   'support'],
#  'Comfort': ['comfort',
#   'fit',
#   'foot',
#   'hurt',
#   'ankl',
#   'comfi',
#   'blister',
#   'comfort',
#   'break',
#   'wear',
#   'abl',
#   'extrem',
#   'walk',
#   'sock',
#   'longer',
#   'pain',
#   'perfect',
#   'super',
#   'uncomfort',
#   'light',
#   'weight',
#   'discomfort',
#   'snug',
#   'put',
#   'slide',
#   'sued',
#   'feel',
#   'littl',
#   'time',
#   'narrow',
#   'toe',
#   'minut',
#   'summer',
#   'insid',
#   'short',
#   'long',
#   'wear',
#   'perfect',
#   'list',
#   'doc',
#   'tongu',
#   'moment',
#   'break',
#   'enjoy',
#   'plus',
#   'actual',
#   'loos',
#   'attract',
#   'offic',
#   'environ'],
#  'Materials': ['leather',
#   'insid',
#   'fring',
#   'materi',
#   'heel',
#   'cheaper',
#   'soft',
#   'sole',
#   'buckl',
#   'sued',
#   'true',
#   'rubber',
#   'advertis',
#   'fact',
#   'cloth',
#   'back',
#   'synthet',
#   'finish',
#   'aerosol',
#   'line',
#   'aw',
#   'memori',
#   'foam',
#   'thinner',
#   'barn',
#   'decor',
#   'come',
#   'hang',
#   'unattract',
#   'fashion',
#   'porous',
#   'term',
#   'best',
#   'describ',
#   'let',
#   'penetr',
#   'piec',
#   'elast',
#   'zipper',
#   'friction',
#   'easili',
#   'improv',
#   'fleec',
#   'especi',
#   'superb',
#   'direct',
#   'smooth',
#   'natur',
#   'calm',
#   'hollow'],
#  'Color': ['color',
#   'love',
#   'style',
#   'unbeliev',
#   'gorgeous',
#   'blue',
#   'favorit',
#   'taup',
#   'wonder',
#   'red',
#   'exact',
#   'design',
#   'purchas',
#   'love',
#   'materi',
#   'look',
#   'perfect',
#   'look',
#   'boot'],
#  'Size': ['size',
#   'order',
#   'half',
#   'order',
#   'big',
#   'littl',
#   'bigger',
#   'usual',
#   'narrow',
#   'normal',
#   'width',
#   'true',
#   'run',
#   'small',
#   'size',
#   'larger',
#   'perfect',
#   'fit',
#   'sent',
#   'ankl',
#   'wide',
#   'tight',
#   'baggi',
#   'wise',
#   'tuck',
#   'pant',
#   'follow',
#   'advic',
#   'buyer',
#   'bacaus',
#   'possibl',
#   'joint',
#   'especi',
#   'superb',
#   'beauti',
#   'moccasin',
#   'shame',
#   'sould',
#   'larg',
#   'awar',
#   'length',
#   'tab',
#   'decid',
#   'normal',
#   'option',
#   'shorter',
#   'left',
#   'mayb',
#   'wear',
#   'calf'],
#  'Weather_resistance': ['dri',
#   'waterproof',
#   'rain',
#   'wet',
#   'water',
#   'foot',
#   'soak',
#   'snow',
#   'cold',
#   'puddl',
#   'warm',
#   'got',
#   'chicago',
#   'protect',
#   'suppos',
#   'defect',
#   'item',
#   'traction',
#   'raini',
#   'interest',
#   'ice',
#   'spent',
#   'cub',
#   'scout',
#   'den',
#   'alcatraz',
#   'island',
#   'san',
#   'francisco',
#   'lot',
#   'claim',
#   'stori',
#   'resist',
#   'generous',
#   'porous',
#   'term',
#   'dewi',
#   'grass',
#   'leav',
#   'soak',
#   'let',
#   'penetr',
#   'perform',
#   'repel',
#   'sandal',
#   'stay',
#   'amaz',
#   'outsid',
#   'step',
#   'deep'],
#  'Noise': ['quiet',
#   'noisi',
#   'loud',
#   'power',
#   'nois',
#   'louder',
#   'ear',
#   'loudest',
#   'light',
#   'incred',
#   'deafen',
#   'serious',
#   'actual',
#   'ring',
#   'doggi',
#   'hide',
#   'flee',
#   'powerstick',
#   'earplug',
#   'lose',
#   'bearabl',
#   'block',
#   'pro',
#   'fair',
#   'reason',
#   'direct',
#   'mous',
#   'explod',
#   'silent',
#   'compar',
#   'stylish',
#   'function',
#   'weight',
#   'peopl',
#   'ring',
#   'motor',
#   'awesom',
#   'nozzl',
#   'readi',
#   'sound',
#   'devil',
#   'purchas',
#   'quit',
#   'size',
#   'upright',
#   'star',
#   'heavi',
#   'lightweight',
#   'recommend',
#   'turn'],
#  'Extra_functionality': ['button',
#   'light',
#   'pencil',
#   'volum',
#   'power',
#   'featur',
#   'bright',
#   'mute',
#   'handi',
#   'low',
#   'dark',
#   'blue',
#   'wake',
#   'sleep',
#   'pen',
#   'nice',
#   'quit',
#   'shortcut',
#   'internet',
#   'spillproof',
#   'interest',
#   'vista',
#   'capabl',
#   'support',
#   'shut',
#   'keypress',
#   'pre',
#   'program',
#   'calcul',
#   'mycomput',
#   'custom',
#   'email',
#   'brower',
#   'activ',
#   'music',
#   'special',
#   'disk',
#   'eject',
#   'hold',
#   'remain',
#   'recess',
#   'clutch',
#   'multimedia',
#   'label',
#   'illumin',
#   'programm',
#   'legibl',
#   'dark',
#   'dim',
#   'backlight'],
#  'Layout': ['key',
#   'delet',
#   'backspac',
#   'size',
#   'layout',
#   'end',
#   'insert',
#   'home',
#   'bar',
#   'perfect',
#   'space',
#   'cluster',
#   'squish',
#   'space',
#   'close',
#   'small',
#   'volum',
#   'tini',
#   'place',
#   'arrow',
#   'littl',
#   'tricki',
#   'bigger',
#   'million',
#   'print',
#   'scroll',
#   'paus',
#   'quick',
#   'navig',
#   'difficult',
#   'suppos',
#   'spill',
#   'proof',
#   '104',
#   'negat',
#   'overs',
#   'awkward',
#   'place',
#   'vertic',
#   'horizont',
#   'multimedia',
#   'label',
#   'wider',
#   'impecc',
#   'activ',
#   'chang',
#   'requir',
#   'movement',
#   'wide',
#   'strike'],
#  'Feel_Comfort': ['feel',
#   'comfort',
#   'mushi',
#   'key',
#   'like',
#   'keyboard',
#   'good',
#   'perfect',
#   'press',
#   'wrist',
#   'action',
#   'shallow',
#   'smooth',
#   'finger',
#   'relax',
#   'type',
#   'level',
#   'keystrok',
#   'sit',
#   'type',
#   'quick',
#   'navig',
#   'difficult',
#   'shop',
#   'consist',
#   'respond',
#   'pressur',
#   'sens',
#   'deceler',
#   'quick',
#   'mush',
#   'tap',
#   'regist',
#   'usual',
#   'chicklet',
#   'membran',
#   'stick',
#   'satisfi',
#   'clicki',
#   'ibm',
#   'dissatisfi',
#   'natur',
#   'tension',
#   'impecc',
#   'stylish',
#   'recogn',
#   'signatur',
#   'butteri',
#   'velvet',
#   'feather'],
#  'Build_Quality': ['belt',
#   'broke',
#   'turn',
#   'work',
#   'burn',
#   'electr',
#   'built',
#   'stop',
#   'month',
#   'roller',
#   'time',
#   'minut',
#   'problem',
#   'brush',
#   'design',
#   'easili',
#   'wise',
#   'continu',
#   'break',
#   'fifth',
#   'barley',
#   'bump',
#   '20',
#   'last',
#   'connect',
#   'swivel',
#   'portion',
#   'fail',
#   'constuct',
#   'electron',
#   'construct',
#   'simpli',
#   'quit',
#   'burnt',
#   'miss',
#   'smell',
#   'overheat',
#   'shut',
#   'poor',
#   'attach',
#   'pop',
#   'unannounc',
#   'snapper',
#   'flimsi',
#   'overh',
#   'upper',
#   'run',
#   'turn',
#   'prepar',
#   'sturdi'],
#  'Size_Look': ['size',
#   'big',
#   'bigger',
#   '40',
#   'differ',
#   'screen',
#   'room',
#   'light',
#   '3d',
#   'livingroom',
#   'hardwar',
#   'slim',
#   'cubbyhol',
#   'huge',
#   'weigh',
#   'awkward',
#   'pentil',
#   'matrix',
#   '60',
#   'foot',
#   '65',
#   'consid',
#   'oh',
#   'lightweight',
#   'compact',
#   'suitabl',
#   'live',
#   'ultra',
#   'weigh',
#   'le',
#   'pound',
#   'hindsight',
#   'wonder',
#   'feel',
#   'anticip',
#   'actual',
#   'bedroom',
#   'fit',
#   'perfect',
#   'love',
#   'smaller',
#   'store',
#   'averag',
#   'inch',
#   'view',
#   '32',
#   'perfect',
#   'home',
#   'easili',
#   'get'],
#  'Image': ['pictur',
#   'color',
#   'qualiti',
#   'black',
#   'bright',
#   'nice',
#   'clear',
#   'look',
#   'excel',
#   'crisp',
#   'screen',
#   'right',
#   'dead',
#   'pixel',
#   'trace',
#   'beauti',
#   'vibrant',
#   'sharp',
#   'angl',
#   'display',
#   'dvd',
#   'differ',
#   'corner',
#   'fantast',
#   'hd',
#   'overal',
#   'inch',
#   'imag',
#   'view',
#   'white',
#   'great',
#   'ok',
#   'red',
#   'decent',
#   'struck',
#   'eye',
#   'ear',
#   'definit',
#   'fuzzi',
#   'font',
#   'improv',
#   'expeci',
#   'hubbi',
#   'sleep',
#   'caus',
#   'biggest',
#   'level',
#   'notic',
#   'irrit',
#   'affect'],
#  'Apps_Interface': ['netflix',
#   'user',
#   'file',
#   'hulu',
#   'app',
#   'watch',
#   'flash',
#   'internet',
#   'smart',
#   'video',
#   'stream',
#   'speed',
#   'youtub',
#   'access',
#   'lack',
#   'smart',
#   'download',
#   'brows',
#   'eas',
#   'interfac',
#   'friend',
#   'access',
#   'work',
#   'capabl',
#   'alright',
#   'quit',
#   'mean',
#   'let',
#   'hub',
#   'applic',
#   'terribl',
#   'watch',
#   'plus',
#   'easili',
#   'buy',
#   'week',
#   'right',
#   'featur',
#   'movi',
#   'comput',
#   'cabl',
#   'best',
#   'samsung',
#   'time',
#   'realli',
#   'like',
#   'better'],
#  'Suction_Power': ['suction',
#   'pick',
#   'power',
#   'power',
#   'good',
#   'hair',
#   'carpet',
#   'suck',
#   'quiet',
#   'realli',
#   'perform',
#   'dirt',
#   'tile',
#   'ok',
#   'job',
#   'floor',
#   'perfom',
#   'total',
#   'angl',
#   'attribut',
#   'machin',
#   'main',
#   'simpic',
#   'weak',
#   'object',
#   'bear',
#   'spot',
#   'vacuum',
#   'dosen',
#   'produc',
#   'fault',
#   'unders',
#   'pretti',
#   'essenti',
#   'spin',
#   'spun',
#   'mayb',
#   'pro',
#   'fair',
#   'reason',
#   'loo',
#   'filter',
#   'superb',
#   'grout',
#   'ergorapido',
#   'leav',
#   'plush',
#   'grind',
#   'stylish',
#   'function'],
#  'Weight': ['light',
#   'weight',
#   'lightweight',
#   'heavi',
#   'size',
#   'compact',
#   'maneuv',
#   'guess',
#   'quiet',
#   'quit',
#   'probabl',
#   'cumbersom',
#   'feaur',
#   'reason',
#   'histori',
#   'minor',
#   'heavier',
#   'consid',
#   'compar',
#   'nice',
#   'larg',
#   'need',
#   'especi',
#   'carri',
#   'drawback',
#   'perform',
#   'past',
#   'suppos',
#   'thought',
#   'power',
#   'loud',
#   'price',
#   'easi',
#   'feel',
#   'hardwood',
#   'push',
#   'store',
#   'panason',
#   'vacuum',
#   'bagless',
#   'area',
#   'ok',
#   'purchas',
#   'vaccuum',
#   'small',
#   'hard',
#   'littl',
#   'short',
#   'rug',
#   'canist'],
#  'Customer_Service': ['servic',
#   'contact',
#   'help',
#   'custom',
#   'took',
#   'email',
#   'miel',
#   'hoover',
#   'dealer',
#   'horribl',
#   'multipl',
#   'respond',
#   'chose',
#   'repres',
#   'told',
#   'smell',
#   'lubric',
#   'dissip',
#   'wait',
#   'spent',
#   'hour',
#   'phone',
#   'depart',
#   'contact',
#   'busi',
#   'regist',
#   'late',
#   'gotten',
#   'card',
#   'mail',
#   'ignor',
#   'look',
#   'common',
#   'recent',
#   'respons',
#   'unfortun',
#   'video',
#   'warranti',
#   'useless',
#   'self',
#   'fall',
#   'day',
#   'amazon',
#   'issu',
#   'absolut',
#   'time',
#   'purchas',
#   'problem'],
#  'Accessories': ['filter',
#   'brush',
#   'attach',
#   'roll',
#   'turbo',
#   'easili',
#   'expens',
#   'wide',
#   'turn',
#   'bag',
#   'replac',
#   'typic',
#   'hepa',
#   'cover',
#   'extens',
#   'wonder',
#   'crevic',
#   'reach',
#   'requir',
#   'clean',
#   'duster',
#   'hose',
#   'clean',
#   'way',
#   'noisi',
#   'corner',
#   'hardwood',
#   'empti',
#   'get',
#   'convent',
#   'brushrol',
#   'extra',
#   'rotat',
#   'block',
#   'bag',
#   'scrap',
#   'okay',
#   'basic',
#   'eye',
#   'regular',
#   'sensor',
#   'green',
#   'complet',
#   'instead',
#   'allow',
#   'need',
#   'spinner',
#   'fact',
#   'cup',
#   'onboard']}

# %%
for each_aspect in Aspect_to_seeds:
    print(each_aspect, Aspect_to_seeds[each_aspect].__len__())
# Out:
# Compartments 50
# Price 34
# Handles 50
# Customer_service 50
# Looks 22
# Quality 50
# Protection 49
# Size_Fit 50
# Ease_of_use 50
# Sound 50
# Look 50
# Connectivity 50
# Battery 48
# Durability 50
# Comfort 50
# Materials 50
# Color 19
# Size 50
# Weather_resistance 50
# Noise 50
# Extra_functionality 50
# Layout 50
# Feel_Comfort 50
# Build_Quality 50
# Size_Look 50
# Image 50
# Apps_Interface 47
# Suction_Power 50
# Weight 50
# Customer_Service 48
# Accessories 50

# %%
# tokenizer = BartTokenizer.from_pretrained("facebook/bart-large-cnn")
tokenizer = BartTokenizer.from_pretrained("facebook/bart-large")

# %%
model = BartForConditionalGeneration.from_pretrained("facebook/bart-large")
# model = BartForConditionalGeneration.from_pretrained("facebook/bart-large-cnn")

# %%
# !echo $CUDA_VISIBLE_DEVICES

# %%
model_args = {'seed_samples': 10, 
              'aspect_length':6
             }

# %%
class aspectDataset(Dataset):
    
    def __init__(self, list_data, tokenizer, model_args):
        self.tokenizer = tokenizer
        self.list_data = list_data
        self.seeds_length = model_args['seed_samples']
        self.aspect_length = model_args['aspect_length']
    
    def __len__(self):
        """Return length of dataset."""
        return self.list_data.__len__()

    def __getitem__(self, i):
        """Return sample from dataset at index i."""
        example = self.list_data[i]
        shuffle(example['seeds'])
        sampled_seeds = example['seeds'][:self.seeds_length]
        aspect = " ".join(example["aspect"].split('_'))
#         max_length = self.seeds_length+2
        inputs = tokenizer(", ".join(sampled_seeds), 
                           truncation=True)  
#         inputs = tokenizer(", ".join(sampled_seeds), 
#                            padding="max_length", 
#                            truncation=True, 
#                            max_length=max_length)  
        outputs = tokenizer(aspect, 
                            padding="max_length", 
                            truncation=True, 
                            max_length=self.aspect_length)
        
        batch = {}
        batch["input_ids"] = torch.LongTensor(inputs.input_ids)
        batch["attention_mask"] = torch.LongTensor(inputs.attention_mask)
#         batch["decoder_input_ids"] = torch.LongTensor(outputs.input_ids)
#         batch["decoder_attention_mask"] = torch.LongTensor(outputs.attention_mask)
        batch["labels"] = outputs.input_ids.copy()
        batch['labels'] = [batch['labels']]

        # We have to make sure that the PAD token is ignored for calculating the loss
        batch["labels"] = [[-100 if token == tokenizer.pad_token_id else token for token in labels] 
                           for labels in batch["labels"]]
        batch["labels"] = torch.LongTensor(batch["labels"])
        batch["labels"] = batch["labels"].squeeze(0)
        
        return batch

# %%
train_data = []
for each_key in Aspect_to_seeds:
    train_data.append({"seeds":Aspect_to_seeds[each_key],
                       "aspect":each_key})

# %%
train_dataset = aspectDataset(list_data=train_data, 
                              tokenizer=tokenizer,
                              model_args=model_args
                             )

# %%
train_loader = DataLoader(train_dataset, 
                          batch_size=1, 
                          shuffle=True,
                          num_workers=1)

# %%
model = model.to("cuda")

# %%
# the_encoder = model.get_encoder()
# the_decoder = model.get_decoder()
# last_linear_layer = model.lm_head

# %%
num_epochs = 15
num_training_steps = num_epochs * len(train_data)

loss_fct = CrossEntropyLoss()

optimizer = AdamW(model.parameters(), 
                  lr=2e-5)
warmup_steps = int(0.10*num_training_steps)
lr_scheduler = get_scheduler("linear",
                            optimizer=optimizer,
                            num_warmup_steps=warmup_steps,
                            num_training_steps=num_training_steps
                            )

# %%
all_train_loss = []
for epoch in tqdm(range(num_epochs)):
    training_loss = 0.0
    model.train()
    for ind, batch in enumerate(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        model_op = model(**batch)
        loss = model_op['loss']
        
        training_loss += loss.item()
        
        print('---'*20)
        print('Epoch:', epoch, 'ID:', ind)
        print('---'*20)
        print('Seed words:', tokenizer.batch_decode(batch['input_ids'], 
                                                    skip_special_tokens=True, 
                                                    clean_up_tokenization_spaces=False))
        print('Actual aspect:', tokenizer.batch_decode(batch['labels'][batch['labels']!=-100].unsqueeze(0), 
                                                       skip_special_tokens=True, 
                                                       clean_up_tokenization_spaces=True))
        output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
        print('Predicted aspect:', tokenizer.batch_decode(output_ids, 
                                                          skip_special_tokens=True, 
                                                          clean_up_tokenization_spaces=True))
        
        loss.backward()
        optimizer.step() 
        lr_scheduler.step() 
        optimizer.zero_grad() 
    training_loss = training_loss / len( train_data )
    all_train_loss.append(training_loss)
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['raini, soak, amaz, foot, suppos, let, puddl, den, protect, generous']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['raini,']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['swivel, burn, sturdi, broke, bump, quit, burnt, turn, work, continu']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['swivel']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['rest, casual, beauti, durabl, absolut, environ, nice, comfort, airi, cute']
# Actual aspect: ['Look']
# Predicted aspect: ['rest, casual']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['panason, nice, easi, weight, especi, larg, compact, store, lightweight, price']
# Actual aspect: ['Weight']
# Predicted aspect: ['panason,']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['late, recent, help, busi, self, depart, issu, horribl, hour, hoover']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['late, recent']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['feel, small, great, backlit, lttle, good, imac, keyboard, beauti, cheap']
# Actual aspect: ['Looks']
# Predicted aspect: ['feel, small']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['suck, bear, vacuum, floor, power, essenti, filter, spun, reason, fault']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['suck,']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['fit, weigh, room, anticip, 32, smaller, weigh, light, 40, home']
# Actual aspect: ['Size Look']
# Predicted aspect: ['fit, weigh']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['run, nice, pen, connector, mous, construct, thing, save, instead, cabl']
# Actual aspect: ['Compartments']
# Predicted aspect: ['run, nice']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['end, stream, movi, monitor, avi, usb, comput, comcast, stop, play']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['end, stream']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['actual, abl, differ, style, need, true, clear, use, protect, provid']
# Actual aspect: ['Durability']
# Predicted aspect: ['actual, abl']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['left, tear, strap, minut, start, control, adjust, final, shorter, metal']
# Actual aspect: ['Handles']
# Predicted aspect: ['left, tear']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['muffl, speaker, sound, improv, bass, cheapest, cool, ear, laptop, strain']
# Actual aspect: ['Sound']
# Predicted aspect: ['muffl']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['narrow, left, superb, width, tuck, size, wide, normal, moccasin, small']
# Actual aspect: ['Size']
# Predicted aspect: ['narrow,']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['light, super, comfort, snug, slide, pain, narrow, discomfort, summer, break']
# Actual aspect: ['Comfort']
# Predicted aspect: ['light, super']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['normal, way, secur, kensington, bit, insid, realli, pad, protect, comput']
# Actual aspect: ['Protection']
# Predicted aspect: ['normal, way']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['quick, butteri, feather, regist, tap, membran, stylish, stick, type, finger']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Quick, butter']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['advertis, aw, finish, decor, true, fashion, friction, fact, smooth, heel']
# Actual aspect: ['Materials']
# Predicted aspect: ['Ad']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['holiday, peel, cours, tear, poor, final, materi, broken, cancer, trip']
# Actual aspect: ['Quality']
# Predicted aspect: ['holiday, peel']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['inch, space, munchi, air, pouch, sure, accessori, pavilion, disappoint, reduct']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['The Best']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['nokia, red, charg, low, get, blackberri, longer, star, charger, hold']
# Actual aspect: ['Battery']
# Predicted aspect: ['nokia,']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['recommend, ring, nozzl, quit, serious, turn, light, mous, powerstick, block']
# Actual aspect: ['Noise']
# Predicted aspect: ['Power']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['buy, file, hub, watch, download, app, time, watch, featur, smart']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Smart']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['difficult, fee, clear, handl, mention, latest, servic, undamag, communic, divx']
# Actual aspect: ['Customer service']
# Predicted aspect: ['difficult,']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['good, price, mayb, paid, need, feaur, bagless, weight, dyson, power']
# Actual aspect: ['Price']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['extra, typic, hepa, rotat, basic, hardwood, get, brush, sensor, complet']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Vintage']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['clear, vibrant, great, fuzzi, improv, overal, color, ok, dvd, display']
# Actual aspect: ['Image']
# Predicted aspect: ['Audio']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['tini, size, suppos, arrow, layout, bigger, tricki, requir, bar, insert']
# Actual aspect: ['Layout']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['label, shut, button, pre, clutch, mycomput, program, activ, programm, internet']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Control']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['short, retractor, race, constant, furnitur, prefer, retract, kink, simpic, snap']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['boot, style, taup, red, purchas, gorgeous, look, materi, blue, wonder']
# Actual aspect: ['Color']
# Predicted aspect: ['Design']
#   7%|▋         | 1/15 [00:11<02:44, 11.74s/it]
# Epoch 1:	Training Loss 4.72
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['taup, smooth, comfort, environ, nice, collaps, beauti, look, crazi, love']
# Actual aspect: ['Look']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['true, calm, fact, cheaper, fleec, unattract, easili, advertis, friction, especi']
# Actual aspect: ['Materials']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['stop, nokia, charg, light, come, pretti, work, color, life, hold']
# Actual aspect: ['Battery']
# Predicted aspect: ['Nokia']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['ok, minor, need, bagless, size, consid, feaur, vacuum, maneuv, past']
# Actual aspect: ['Weight']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['inch, dv7, 17inch, perfect, reduct, airplan, big, 3080us, whatnot, spacious']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['unfortun, chose, hoover, dealer, spent, miel, hour, help, servic, smell']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['mention, communic, paid, wait, deliv, peopl, deliveri, undamag, handl, check']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['pro, main, ergorapido, perfom, vacuum, filter, power, produc, tile, dosen']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['muffl, vibrat, develop, experi, strong, display, whine, loud, strain, dinner']
# Actual aspect: ['Sound']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['stylish, protect, laptop, damag, way, insid, larg, tast, weak, protect']
# Actual aspect: ['Protection']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['stay, item, suppos, den, deep, resist, scout, let, water, waterproof']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['space, folder, adapt, open, run, wallet, wire, headphon, player, nice']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['wonder, gorgeous, blue, materi, favorit, look, red, color, perfect, unbeliev']
# Actual aspect: ['Color']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['bag, extens, way, typic, okay, convent, empti, fact, reach, need']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['deafen, function, pro, incred, doggi, actual, flee, purchas, loud, hide']
# Actual aspect: ['Noise']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['heel, heavi, enjoy, thinner, long, fold, actual, differ, daili, sol']
# Actual aspect: ['Durability']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['difficult, type, finger, feel, key, pressur, ibm, satisfi, recogn, regist']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['legibl, nice, dim, wake, mute, recess, light, featur, pre, dark']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['great, longer, pc, lttle, small, good, imac, appear, cheap, slim']
# Actual aspect: ['Looks']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['terribl, lack, smart, let, capabl, best, week, easili, app, download']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['matrix, consid, smaller, store, 3d, 65, light, compact, suitabl, foot']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['cabl, integr, internet, wi, like, hdmi, monitor, connect, dhcp, movi']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['far, power, mayb, expect, vacuum, worth, twice, 200, expens, light']
# Actual aspect: ['Price']
# Predicted aspect: ['Power supply']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['final, lift, adjust, adapt, strap, adjust, month, holiday, comfort, broke']
# Actual aspect: ['Handles']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['snapper, upper, easili, simpli, electr, shut, attach, 20, barley, turn']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['ComAccessories']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['retractor, baseboard, imposs, refriger, pile, vacuum, power, bog, direct, worst']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['perfect, littl, doc, minut, longer, slide, light, sued, loos, feel']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['red, display, crisp, notic, fantast, right, vibrant, corner, pixel, beauti']
# Actual aspect: ['Image']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['proof, negat, tricki, quick, movement, chang, scroll, suppos, overs, end']
# Actual aspect: ['Layout']
# Predicted aspect: ['Movement Comfort']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['bigger, width, narrow, perfect, follow, sent, option, decid, pant, length']
# Actual aspect: ['Size']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['stand, cours, zipper, construct, item, white, rip, month, chemic, style']
# Actual aspect: ['Quality']
# Predicted aspect: ['Sizeability']
#  13%|█▎        | 2/15 [00:22<02:22, 10.94s/it]
# Epoch 2:	Training Loss 2.68
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['million, impecc, awkward, home, space, horizont, tini, wide, delet, backspac']
# Actual aspect: ['Layout']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['talk, turn, good, thing, get, volum, come, phone, start, red']
# Actual aspect: ['Battery']
# Predicted aspect: ['Look']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['corner, reach, block, allow, filter, extens, rotat, attach, fact, roll']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['great, crisp, white, sleep, fuzzi, ok, fantast, view, black, font']
# Actual aspect: ['Image']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['look, nice, great, pc, size, attract, keyboard, laptop, origin, cheap']
# Actual aspect: ['Looks']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['larger, moccasin, sould, mayb, superb, decid, small, littl, tab, joint']
# Actual aspect: ['Size']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['length, minut, start, adjust, hurt, adjust, metal, swivel, situat, inevit']
# Actual aspect: ['Handles']
# Predicted aspect: ['Me']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['sound, lose, light, stylish, actual, block, flee, ring, explod, heavi']
# Actual aspect: ['Noise']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['go, final, cancer, broken, month, asia, trip, sacrific, strap, rip']
# Actual aspect: ['Quality']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['strong, loudest, quieter, loud, trebl, ear, strain, weird, mind, chang']
# Actual aspect: ['Sound']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['best, feaur, expens, bag, wast, spin, 50, ok, spun, vaccum']
# Actual aspect: ['Price']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['natur, like, membran, dissatisfi, respond, stylish, ibm, feather, regist, key']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Look']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['perform, canist, hardwood, ok, thought, compar, price, carri, easi, vaccuum']
# Actual aspect: ['Weight']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['need, clear, pretti, think, qualiti, heavi, constant, cheep, true, protect']
# Actual aspect: ['Durability']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['blue, purchas, perfect, taup, look, love, wonder, style, color, red']
# Actual aspect: ['Color']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['servic, shore, wait, deliv, desk, support, 100, requir, help, refurbish']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['respond, lubric, issu, phone, multipl, hoover, hour, servic, smell, chose']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['like, friend, interfac, comput, buy, access, better, let, hub, time']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['kensington, insid, comput, drop, perfect, realli, trust, thing, larg, bit']
# Actual aspect: ['Protection']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['sandal, rain, amaz, perform, generous, protect, alcatraz, foot, san, den']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['dim, eject, wake, nice, music, bright, legibl, shortcut, programm, keypress']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['attract, wonder, ador, crazi, design, unattract, cute, concept, moccasin, pictur']
# Actual aspect: ['Look']
# Predicted aspect: ['Design']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['sued, direct, decor, penetr, best, advertis, come, hang, rubber, natur']
# Actual aspect: ['Materials']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['light, averag, huge, foot, matrix, screen, perfect, size, love, live']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['carpet, heavi, baseboard, furnitur, nozzl, disassembl, push, car, empti, flexibl']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['foot, discomfort, insid, sock, time, perfect, minut, feel, pain, longer']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Feelability']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['realli, perfom, ok, loo, bear, suction, floor, simpic, vacuum, superb']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['time, broke, portion, overheat, attach, prepar, easili, upper, brush, 20']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['compon, port, usb, movi, netflix, digit, audio, rf, fi, flash']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Sound Quality']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['small, save, space, reduct, power, outsid, folder, accessori, cellphon, remot']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['load, big, bit, folder, inch, cabl, earphon, jacket, 17inch, tight']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size']
#  20%|██        | 3/15 [00:32<02:10, 10.85s/it]
# Epoch 3:	Training Loss 2.69
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['short, moment, comfort, abl, feel, littl, tongu, loos, break, ankl']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['kink, retract, eas, automat, roller, direct, snap, propel, power, imposs']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['love, purchas, look, materi, color, exact, taup, love, red, boot']
# Actual aspect: ['Color']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['unattract, airi, pictur, boot, weight, attract, natur, 360, shame, collaps']
# Actual aspect: ['Look']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['left, handl, start, break, strap, safe, swivel, sooner, stand, inevit']
# Actual aspect: ['Handles']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['get, day, power, start, charg, merit, good, volum, color, come']
# Actual aspect: ['Battery']
# Predicted aspect: ['Look']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['cheep, need, clear, style, enjoy, heavi, worn, start, decor, provid']
# Actual aspect: ['Durability']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['sturdi, burnt, easili, break, attach, last, miss, poor, overheat, fifth']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['ability']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['muffl, improv, horribl, chang, dinner, surround, trebl, strong, vibrat, sound']
# Actual aspect: ['Sound']
# Predicted aspect: ['Sound Quality']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['superb, suction, grind, pro, spun, pick, attribut, floor, main, reason']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['medium, small, adapt, daytim, safe, cabl, earphon, key, headset, nice']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['glove, desk, difficult, suppos, fact, po, wait, downstair, use, 1500']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer serviceivity']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['inch, airplan, 17inch, 3080us, daytim, size, pavilion, perfect, bulk, jacket']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['foam, aw, improv, cloth, synthet, direct, barn, term, superb, back']
# Actual aspect: ['Materials']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['light, remain, label, shortcut, pre, nice, eject, brower, clutch, low']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['start, white, rip, crack, terribl, month, plastic, stand, durabl, brake']
# Actual aspect: ['Quality']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['size, multimedia, arrow, tricki, requir, volum, million, difficult, bar, suppos']
# Actual aspect: ['Layout']
# Predicted aspect: ['Comfort']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['especi, light, need, littl, vaccuum, heavier, minor, probabl, ok, consid']
# Actual aspect: ['Weight']
# Predicted aspect: ['Size Fit']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['pc, appear, look, origin, cheap, good, laptop, size, lttle, nice']
# Actual aspect: ['Looks']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['respons, spent, time, multipl, custom, phone, chose, busi, repres, wait']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['normal, follow, especi, wise, true, size, wear, option, bacaus, order']
# Actual aspect: ['Size']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['comput, sort, intern, probabl, use, happen, protect, way, love, second']
# Actual aspect: ['Protection']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['right, far, light, 50, paid, cheap, price, spin, money, best']
# Actual aspect: ['Price']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['step, porous, repel, warm, defect, penetr, alcatraz, suppos, soak, resist']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['enabl, file, netflix, flash, rf, 45, connect, work, comcast, output']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['hulu, hub, quit, right, movi, smart, user, applic, easili, flash']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['empti, easili, instead, eye, extra, complet, replac, need, hardwood, crevic']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['caus, pictur, eye, clear, look, ok, white, imag, bright, excel']
# Actual aspect: ['Image']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['shallow, respond, quick, key, comfort, impecc, velvet, stick, relax, like']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['size, earplug, recommend, upright, explod, motor, lightweight, hide, deafen, sound']
# Actual aspect: ['Noise']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['perfect, perfect, easili, smaller, slim, actual, feel, cubbyhol, weigh, light']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
#  27%|██▋       | 4/15 [00:43<01:57, 10.66s/it]
# Epoch 4:	Training Loss 1.38
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['nice, overal, red, great, look, qualiti, color, eye, angl, ear']
# Actual aspect: ['Image']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['go, unattract, calm, wonder, ador, look, super, environ, concept, boot']
# Actual aspect: ['Look']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['backlit, beauti, feel, great, nice, keyboard, slim, like, origin, longer']
# Actual aspect: ['Looks']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['alright, movi, app, watch, youtub, netflix, samsung, brows, stream, hulu']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['hide, quit, earplug, ring, bearabl, motor, sound, light, explod, doggi']
# Actual aspect: ['Noise']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['stream, netflix, vga, port, work, input, comcast, power, dhcp, rf']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['dri, soak, stori, warm, defect, soak, outsid, step, chicago, deep']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['cesces']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['laptop, whine, trebl, dinner, pitch, quieter, improv, bass, weird, hear']
# Actual aspect: ['Sound']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['perfom, unders, pro, object, machin, ok, leav, weak, power, reason']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['space, tini, littl, chang, layout, insert, wide, small, paus, strike']
# Actual aspect: ['Layout']
# Predicted aspect: ['Layout']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['perfect, enjoy, super, minut, environ, light, feel, ankl, attract, comfort']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['advertis, fashion, leather, friction, back, elast, aerosol, come, smooth, soft']
# Actual aspect: ['Materials']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['dead, phone, respond, work, merit, hour, light, batteri, come, half']
# Actual aspect: ['Battery']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['backlight, power, wake, pen, internet, music, pre, multimedia, mute, blue']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['recogn, impecc, ibm, velvet, feel, stick, tension, stylish, perfect, wrist']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['burnt, swivel, last, barley, shut, upper, built, stop, unannounc, overheat']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['easili, fit, suitabl, ultra, differ, size, matrix, awkward, huge, store']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['lubric, depart, servic, self, useless, respons, help, video, purchas, repres']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['materi, gorgeous, design, style, boot, perfect, love, favorit, unbeliev, wonder']
# Actual aspect: ['Color']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['white, construct, smell, rip, tear, pull, broke, month, edg, zipper']
# Actual aspect: ['Quality']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['flexibl, carpet, crevic, power, remov, nozzl, prefer, retractor, corner, pile']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['attach, fact, need, requir, green, roll, brush, crevic, expens, get']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['size, whatnot, air, snug, fit, accommod, slight, load, nois, jacket']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Size Look']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['servic, carri, speak, entir, replac, cancel, communic, deliv, arriv, deliveri']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['need, consid, quit, feel, guess, perform, canist, size, rug, heavier']
# Actual aspect: ['Weight']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['pad, laptop, stylish, comput, probabl, count, protect, larg, perfect, way']
# Actual aspect: ['Protection']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['break, shorter, felt, adjust, length, left, adjust, later, adapt, firm']
# Actual aspect: ['Handles']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['left, option, width, beauti, shame, true, littl, bigger, wise, calf']
# Actual aspect: ['Size']
# Predicted aspect: ['Size Look']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['abl, thinner, provid, daili, true, numer, worn, sure, pretti, tear']
# Actual aspect: ['Durability']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['cabl, thing, save, reduct, wire, nice, cellphon, small, wish, accessori']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['like, paid, good, spin, 50, ok, think, bagless, pricey, spun']
# Actual aspect: ['Price']
# Predicted aspect: ['Quality']
#  33%|███▎      | 5/15 [00:52<01:43, 10.33s/it]
# Epoch 5:	Training Loss 1.44
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['wet, chicago, rain, dri, penetr, defect, repel, outsid, item, suppos']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['burn, poor, upper, easili, flimsi, burnt, problem, broke, attach, fifth']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['expens, weight, need, duster, good, money, pricey, price, feaur, spun']
# Actual aspect: ['Price']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['duster, extens, clean, wide, reach, rotat, scrap, cup, requir, basic']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['perfect, mush, keystrok, action, quick, feel, type, recogn, navig, velvet']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['appear, feel, size, lttle, keyboard, backlit, origin, cheap, small, pc']
# Actual aspect: ['Looks']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['pitch, dinner, eye, track, watt, loudest, trebl, muffl, kinda, horribl']
# Actual aspect: ['Sound']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['downstair, arriv, cancel, reschedul, communic, pilot, ship, fee, fact, pay']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['unattract, ador, durabl, rest, vent, wonder, pictur, weight, shame, go']
# Actual aspect: ['Look']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['compon, dlna, standard, server, flash, min, vga, play, conflict, wi']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['instead, nois, wallet, nice, adapt, wire, flap, remot, need, daytim']
# Actual aspect: ['Compartments']
# Predicted aspect: ['']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['time, turn, thing, low, nokia, love, meter, volum, hour, green']
# Actual aspect: ['Battery']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['button, blue, sleep, volum, music, activ, shortcut, light, power, mute']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['friend, smart, alright, time, speed, easili, smart, applic, flash, user']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Customer']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['maneuv, short, compact, quiet, store, price, lightweight, hard, need, area']
# Actual aspect: ['Weight']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['close, delet, perfect, paus, arrow, strike, print, wider, squish, place']
# Actual aspect: ['Layout']
# Predicted aspect: ['Compartments']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['quiet, upright, hide, bearabl, pro, louder, loud, recommend, silent, earplug']
# Actual aspect: ['Noise']
# Predicted aspect: ['Sound']
# ...
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['holiday, later, sacrific, smell, crack, rip, cancer, wear, daili, zipper']
# Actual aspect: ['Quality']
# Predicted aspect: ['Quality']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['need, hepa, regular, okay, turbo, brush, wonder, roll, rotat, clean']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Durability']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['advertis, cheaper, elast, insid, rubber, leather, especi, barn, hang, soft']
# Actual aspect: ['Materials']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['materi, look, taup, love, design, boot, blue, wonder, color, unbeliev']
# Actual aspect: ['Color']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['carri, nice, size, store, reason, perform, weight, compact, vaccuum, hard']
# Actual aspect: ['Weight']
# Predicted aspect: ['Weight']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['feel, comfort, key, usual, consist, clicki, shop, butteri, feather, like']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['moccasin, fring, light, casual, super, pictur, hang, look, unattract, go']
# Actual aspect: ['Look']
# Predicted aspect: ['Look']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['maneuv, direct, awkward, imposs, nozzl, prefer, person, remov, retract, pile']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Noise']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['daili, sure, cheapli, break, protect, pretti, long, appear, gone, use']
# Actual aspect: ['Durability']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['power, filter, carpet, dosen, pick, ok, unders, pro, power, job']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['duster, spin, money, 200, best, worth, ok, mayb, twice, wast']
# Actual aspect: ['Price']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['pc, nice, beauti, like, great, laptop, attract, keyboard, size, cheap']
# Actual aspect: ['Looks']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['pouch, bare, 13, load, sure, accessori, size, cloth, bulk, tight']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Accessories']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['turn, batteri, charg, life, sudden, red, dead, tone, star, light']
# Actual aspect: ['Battery']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['run, jacket, flap, need, insid, daytim, construct, player, remot, medium']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['expeci, look, white, qualiti, caus, beauti, fuzzi, nice, ok, inch']
# Actual aspect: ['Image']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['contact, spent, gotten, time, hoover, hour, custom, servic, ignor, common']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['45, conflict, work, end, rf, stop, play, slot, dlna, hdmi']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['insid, protect, drop, feel, pad, pad, love, use, second, like']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['realli, internet, quit, easili, movi, capabl, speed, smart, friend, mean']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['easili, 32, pentil, light, lightweight, consid, huge, suitabl, big, weigh']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Size Fit']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['upper, connect, simpli, month, belt, brush, bump, sturdi, minut, work']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['foot, term, lot, dewi, claim, repel, dri, outsid, scout, interest']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Customer service']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['sound, eye, ear, strain, quieter, weird, junki, margin, great, improv']
# Actual aspect: ['Sound']
# Predicted aspect: ['Sound']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['layout, navig, space, impecc, million, wide, quick, tricki, proof, bigger']
# Actual aspect: ['Layout']
# Predicted aspect: ['Layout']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['powerstick, incred, explod, turn, silent, bearabl, loudest, weight, nozzl, recommend']
# Actual aspect: ['Noise']
# Predicted aspect: ['Noise']
#  93%|█████████▎| 14/15 [02:25<00:10, 10.21s/it]
# Epoch 14:	Training Loss 0.84
# ------------------------------------------------------------
# ID: 0
# ------------------------------------------------------------
# Seed words: ['fact, cloth, hollow, aw, back, friction, calm, let, sole, aerosol']
# Actual aspect: ['Materials']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 1
# ------------------------------------------------------------
# Seed words: ['shut, construct, turn, connect, pop, portion, design, simpli, run, month']
# Actual aspect: ['Build Quality']
# Predicted aspect: ['Build Quality']
# ------------------------------------------------------------
# ID: 2
# ------------------------------------------------------------
# Seed words: ['small, power, need, heavi, histori, thought, ok, probabl, hardwood, purchas']
# Actual aspect: ['Weight']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 3
# ------------------------------------------------------------
# Seed words: ['feel, tongu, walk, snug, slide, longer, perfect, moment, weight, break']
# Actual aspect: ['Comfort']
# Predicted aspect: ['Feel Comfort']
# ------------------------------------------------------------
# ID: 4
# ------------------------------------------------------------
# Seed words: ['deliv, fix, po, ship, support, deliveri, undamag, diagnost, week, reschedul']
# Actual aspect: ['Customer service']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 5
# ------------------------------------------------------------
# Seed words: ['wide, block, easili, crevic, way, fact, regular, bag, complet, scrap']
# Actual aspect: ['Accessories']
# Predicted aspect: ['Materials']
# ------------------------------------------------------------
# ID: 6
# ------------------------------------------------------------
# Seed words: ['hubbi, decent, beauti, dvd, caus, nice, font, pixel, dead, pictur']
# Actual aspect: ['Image']
# Predicted aspect: ['Image']
# ------------------------------------------------------------
# ID: 7
# ------------------------------------------------------------
# Seed words: ['normal, cushion, protect, feel, adequ, insid, macbook, weak, probabl, pad']
# Actual aspect: ['Protection']
# Predicted aspect: ['Protection']
# ------------------------------------------------------------
# ID: 8
# ------------------------------------------------------------
# Seed words: ['wide, bar, key, movement, squish, activ, place, strike, place, vertic']
# Actual aspect: ['Layout']
# Predicted aspect: ['Layout']
# ------------------------------------------------------------
# ID: 9
# ------------------------------------------------------------
# Seed words: ['mush, type, keystrok, navig, mushi, natur, perfect, impecc, stick, deceler']
# Actual aspect: ['Feel Comfort']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# ID: 10
# ------------------------------------------------------------
# Seed words: ['use, buckl, tear, true, heel, barn, numer, style, need, pretti']
# Actual aspect: ['Durability']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# ID: 11
# ------------------------------------------------------------
# Seed words: ['decent, keyboard, imac, beauti, attract, nice, origin, great, size, backlit']
# Actual aspect: ['Looks']
# Predicted aspect: ['Looks']
# ------------------------------------------------------------
# ID: 12
# ------------------------------------------------------------
# Seed words: ['claim, foot, cold, step, san, waterproof, deep, stay, warm, let']
# Actual aspect: ['Weather resistance']
# Predicted aspect: ['Weather resistance']
# ------------------------------------------------------------
# ID: 13
# ------------------------------------------------------------
# Seed words: ['access, hub, movi, samsung, let, terribl, plus, lack, netflix, work']
# Actual aspect: ['Apps Interface']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# ID: 14
# ------------------------------------------------------------
# Seed words: ['audio, rf, dhcp, power, input, standard, stop, conflict, dlna, internet']
# Actual aspect: ['Connectivity']
# Predicted aspect: ['Connectivity']
# ------------------------------------------------------------
# ID: 15
# ------------------------------------------------------------
# Seed words: ['nokia, volum, better, light, later, come, color, thing, charger, simpl']
# Actual aspect: ['Battery']
# Predicted aspect: ['Battery']
# ------------------------------------------------------------
# ID: 16
# ------------------------------------------------------------
# Seed words: ['munchi, accessori, instead, thing, cellphon, construct, space, reduct, huge, pen']
# Actual aspect: ['Compartments']
# Predicted aspect: ['Layout']
# ------------------------------------------------------------
# ID: 17
# ------------------------------------------------------------
# Seed words: ['pre, multimedia, brower, clutch, programm, backlight, special, spillproof, mute, featur']
# Actual aspect: ['Extra functionality']
# Predicted aspect: ['Extra functionality']
# ------------------------------------------------------------
# ID: 18
# ------------------------------------------------------------
# Seed words: ['hp, nois, jacket, laptop, te, pouch, 17inch, perfect, dv7, cell']
# Actual aspect: ['Size Fit']
# Predicted aspect: ['Apps Interface']
# ------------------------------------------------------------
# ID: 19
# ------------------------------------------------------------
# Seed words: ['oh, view, differ, feel, hardwar, consid, hindsight, home, anticip, store']
# Actual aspect: ['Size Look']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 20
# ------------------------------------------------------------
# Seed words: ['help, problem, gotten, issu, ignor, hour, contact, mail, common, warranti']
# Actual aspect: ['Customer Service']
# Predicted aspect: ['Customer Service']
# ------------------------------------------------------------
# ID: 21
# ------------------------------------------------------------
# Seed words: ['vibrat, kinda, good, worthi, trebl, watt, chang, cheapest, horribl, terribl']
# Actual aspect: ['Sound']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 22
# ------------------------------------------------------------
# Seed words: ['size, baggi, bigger, sould, awar, moccasin, width, shame, shorter, option']
# Actual aspect: ['Size']
# Predicted aspect: ['Size Fit']
# ------------------------------------------------------------
# ID: 23
# ------------------------------------------------------------
# Seed words: ['suction, dosen, realli, pro, ergorapido, carpet, spot, bear, angl, perform']
# Actual aspect: ['Suction Power']
# Predicted aspect: ['Suction Power']
# ------------------------------------------------------------
# ID: 24
# ------------------------------------------------------------
# Seed words: ['pricey, spin, vacuum, 50, need, duster, ok, good, dyson, power']
# Actual aspect: ['Price']
# Predicted aspect: ['Price']
# ------------------------------------------------------------
# ID: 25
# ------------------------------------------------------------
# Seed words: ['style, blue, color, unbeliev, design, wonder, look, love, perfect, red']
# Actual aspect: ['Color']
# Predicted aspect: ['Color']
# ------------------------------------------------------------
# ID: 26
# ------------------------------------------------------------
# Seed words: ['pull, attach, tear, birth, wear, item, sacrific, durabl, later, handl']
# Actual aspect: ['Quality']
# Predicted aspect: ['Handles']
# ------------------------------------------------------------
# ID: 27
# ------------------------------------------------------------
# Seed words: ['loop, safe, rip, bend, lift, final, break, note, shorter, hand']
# Actual aspect: ['Handles']
# Predicted aspect: ['Durability']
# ------------------------------------------------------------
# ID: 28
# ------------------------------------------------------------
# Seed words: ['noisi, hide, quiet, pro, awesom, bearabl, louder, power, incred, fair']
# Actual aspect: ['Noise']
# Predicted aspect: ['Noise']
# ------------------------------------------------------------
# ID: 29
# ------------------------------------------------------------
# Seed words: ['corner, baseboard, prefer, propel, easier, hose, person, flexibl, direct, suck']
# Actual aspect: ['Ease of use']
# Predicted aspect: ['Size Fit']
# ------------------------------------------------------------
# ID: 30
# ------------------------------------------------------------
# Seed words: ['stylish, environ, color, boot, airi, casual, good, ador, weight, concept']
# Actual aspect: ['Look']
# Predicted aspect: ['Looks']
# 100%|██████████| 15/15 [02:35<00:00, 10.40s/it]
# Epoch 15:	Training Loss 0.72

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(all_train_loss, ls='-.', marker = 'X', color='blue')

# %%
stop_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-c3998c8be795> in <module>
# ----> 1 stop_
#
# NameError: name 'stop_' is not defined

# %%
# chk_1 =tokenizer('MaterialsComp', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_1['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_2 =tokenizer('Ease of use', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=6)

# %%
# tokenizer.batch_decode(chk_2['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False)

# %%
# chk_ = tokenizer('Compartments', 
#           padding="max_length", 
#           truncation=True, 
#           max_length=4)

# %%
# tokenizer.batch_decode(chk_['input_ids'], 
#                        skip_special_tokens=True, 
#                        clean_up_tokenization_spaces=False)

# %%
electronic_topics = open('electronics_40_topics').read()
electronic_topics = electronic_topics.split('\n')

# %%
electronic_topics = [x for ind, x in enumerate(electronic_topics) if ind%2==0]

# %%
electronic_topics = [x.replace("'", "") for x in electronic_topics]
electronic_topics = [x.replace("[", "") for x in electronic_topics]
electronic_topics = [x.replace("]", "") for x in electronic_topics]
electronic_topics = [x.replace(",", "") for x in electronic_topics]
electronic_topics = [x.split(' ')[1:] for x in electronic_topics]

# %%
electronic_topics = [x[:20] for x in electronic_topics]

# %%
test_data = []
for each_e_top in electronic_topics:
    test_data.append({'seeds': each_e_top[:20], 'aspect':'TestSet'})

# %%
test_dataset = aspectDataset(list_data=test_data, 
                              tokenizer=tokenizer)

# %%
test_loader = DataLoader(test_dataset, 
                         batch_size=1, 
                         shuffle=True,
                         num_workers=1)

# %%
model.eval()
for ind, batch in enumerate(test_loader):
    batch = {k: v.to('cuda') for k, v in batch.items()}
    model_op = model(**batch)
    print('---'*20)
    print('ID:', ind)
    print('---'*20)
    print('Seed words:', tokenizer.batch_decode(batch['input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    print('Actual aspect:', tokenizer.batch_decode(batch['decoder_input_ids'], skip_special_tokens=True, clean_up_tokenization_spaces=False))
    output_ids = model.generate(batch["input_ids"], num_beams=3, max_length=6)
    print('Predicted aspect:', tokenizer.batch_decode(output_ids, skip_special_tokens=True, clean_up_tokenization_spaces=True))

# %% [raw]
# 1. Sample 5-10 for each aspect. Get top 50 and then sample 10 each. done
# 2. Start from the bart-large and not cnn. done
# 3. Use very small learning rate (2e-5)| 1e-6 or 5e-7. done
# 4. Put a comma with the words. done
# 5. Stem the training data words. done

# %%
model_op['logits'].squeeze(dim=0).shape

# %%
torch.argmax(model_op['logits'].squeeze(dim=0), dim=1)

# %% [markdown]
# ## Orphan Code
# -------------

# %%
print(another_way_to_train)
for epoch in range(num_epochs):
    training_loss = 0.0
    model.train()
    for batch in tqdm(train_loader):
        batch = {k: v.to('cuda') for k, v in batch.items()}
        
        # Get the "input's representation"
        encoder_output = the_encoder(input_ids = batch['input_ids'],
                                   attention_mask = batch['attention_mask'])
      
        # Pass the representation + the target summary to the decoder
        decoder_output = the_decoder(input_ids=batch['decoder_input_ids'],
                                   attention_mask=batch['decoder_attention_mask'],
                                   encoder_hidden_states=encoder_output[0],
                                   encoder_attention_mask=batch['attention_mask'])

        # Use the last linear layer to predict the next token
        decoder_output = decoder_output.last_hidden_state
        lm_head_output = last_linear_layer(decoder_output)
        
        # Compute the loss
        loss = loss_fct(lm_head_output.view(-1, model.config.vocab_size),
                      batch['labels'].view(-1))
        training_loss += loss.item()
        
        loss.backward() # Update the weights
        optimizer.step() # Notify optimizer that a batch is done.
        lr_scheduler.step() # Notify the scheduler that a ...
        optimizer.zero_grad() # Reset the optimer
    training_loss = training_loss / len( train_data )
    print("Epoch {}:\tTraining Loss {:.2f}".format(epoch+1, training_loss))

# %%
lm_head_output.view(-1, model.config.vocab_size)
